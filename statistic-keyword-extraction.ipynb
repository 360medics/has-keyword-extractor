# %% [markdown]
# # Automatic Keyword Extraction From Any Text Document Using N-gram Rigid Collocation
#
# here is the [references article](https://www.researchgate.net/publication/272674061_Automatic_Keyword_Extraction_From_Any_Text_Document_Using_N-gram_Rigid_Collocation)
#
# we use this [wikipedia article](https://en.wikipedia.org/wiki/Mobile_phone) to test the algorithm

# %%
import nltk
import spacy
import re
import statistics
from scipy import stats
from nltk import *
from collections import Counter
import itertools
import math
import json

# %% [markdown]
# ### prepare document

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(' '.join(open("mobile_phone_wiki_article.txt", 'r').readlines()).lower())

# %% [markdown]
# ### pre-process the document

# %%
def remove_digits(text: str) -> str:
    return re.sub(r"\d+|[^\w\s]", "", text)

nlp = spacy.load('en_core_web_sm')

text = ' '.join(open("mobile_phone_wiki_article.txt", 'r').readlines()).lower()
text = remove_digits(text)
doc = nlp(text)
# tokenize text
doc = nlp(text)
# remove stopwords
word_list =  [token.text for token in doc if not token.is_stop and not token.is_space]
print(f'the document has {len(word_list)} words')
print(word_list[:100])
# Out:
# the document has 3211 words
# ['mobile', 'phone', 'cellular', 'phone', 'cell', 'phone', 'cellphone', 'handphone', 'hand', 'phone', 'shortened', 'simply', 'mobile', 'cell', 'phone', 'portable', 'telephone', 'receive', 'calls', 'radio', 'frequency', 'link', 'user', 'moving', 'telephone', 'service', 'area', 'radio', 'frequency', 'link', 'establishes', 'connection', 'switching', 'systems', 'mobile', 'phone', 'operator', 'provides', 'access', 'public', 'switched', 'telephone', 'network', 'pstn', 'modern', 'mobile', 'telephone', 'services', 'use', 'cellular', 'network', 'architecture', 'mobile', 'telephones', 'called', 'cellular', 'telephones', 'cell', 'phones', 'north', 'america', 'addition', 'telephony', 'digital', 'mobile', 'phones', 'g', 'support', 'variety', 'services', 'text', 'messaging', 'mms', 'email', 'internet', 'access', 'shortrange', 'wireless', 'communications', 'infrared', 'bluetooth', 'business', 'applications', 'video', 'games', 'digital', 'photography', 'mobile', 'phones', 'offering', 'capabilities', 'known', 'feature', 'phones', 'mobile', 'phones', 'offer', 'greatly', 'advanced', 'computing']

# %% [markdown]
# ## Definition
# * a collocation is just a set of words occuring more than by chance.
# * A collocation is an syntactic and semantic independent unit.
# * two type of collocation : rigid and flexible (the words order is not fixed)
#
# ## Motivation of the paper
# find top ranked N-gram rigid collocation could be used as keywords

# %% [markdown]
# # Popular Method to extract collocation

# %% [markdown]
# ### Point-Wise Mutual Information
#
# Goal : Find closeness between word pairs
#
# # $log_{2}[\frac{P(w_{1},w_{2})}{P(w_{1}), P(w_{2})}]$

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(word_list)
print(f'here is the top 10 bigram with PMI measure : {finder.nbest(bigram_measures.pmi, 10)}')
# Out:
# here is the top 10 bigram with PMI measure : [('according', 'federal'), ('activate', 'microphones'), ('activism', 'citizen'), ('address', 'gave'), ('administration', 'nhtsa'), ('adoption', 'mosfetbased'), ('adults', 'prefer'), ('advent', 'widespread'), ('affairs', 'clandestine'), ('affects', 'overall')]

# %% [markdown]
# ### T-score
# The T-Score is use to test the plausability of a hypthosis.
# We want to test the following hypothesis (the null hypothesis $H_{0}$) : $P(w_{1}, w_{2}) = P(w_{1}) \cdot P(w_{2})$.
# In other words we would like to see if two words come indepedently or not.
# ## $t = \bar{x} - \frac{\mu}{\sqrt{\frac{s^{2}}{N}}}$
#
# where :
#
# N is a total of words / bigram in the corpus
#
# $H_{0} = P(w_{1}) \cdot P(w_{2})$
#
# $P(w_{1}) = f(w_{1})/N$
#
# $P(w_{2}) = f(w_{2})/N$
#
# $P(w_{1}, w_{2}) = f(w_{1}w_{2})/N$
#
# $\mu = P_{w_{i}}$
#
# $s^{2} = P(w_{1}, w_{2})(1 - P(w_{1}, w_{2}))$
#
# $\bar{x} = P(w_{1}, w_{2})$
#
# then we compare the null hypothesis and the T-score. If T-score is greater than the null hypothesis then the bi-grams is considered as a collocation.

# %%
bigrams = list(nltk.bigrams(word_list))
bigram_frequency = Counter([i for i in bigrams])
monogram_frequency = Counter(word_list)
def compute_t_score(bigram, total_frequency):
    x_mean = bigram[1]/total_frequency
    s_2 = x_mean * (1 - x_mean)
    mu = monogram_frequency[bigram[0][0]]/total_frequency
    null_hypothesis = mu * (monogram_frequency[bigram[0][1]]/total_frequency)
    t_score = x_mean - (mu/math.sqrt(s_2/total_frequency))
    return [bigram[0], True if t_score >= null_hypothesis else False]


t_score = [compute_t_score(bigram, sum(bigram_frequency.values())) for bigram in bigram_frequency.items()]
[t for t in t_score if t[1]]
# Out:
# []

# %% [markdown]
# ## Proposed Methodology

# %% [markdown]
# there are three main steps :
# 1. extracts the list of bi-grams and arranges them in descending order based on their FBI
# 2. extracting the n-grams and arranges them in descending order of respective FNI
# 3. checks whether it is necessary to include monogram keywords

# %% [markdown]
# Before this three main steps we need to generate bi-gram and the frequency of monogram and bi-gram

# %%
bigrams = list(nltk.bigrams(word_list))
monogram_frequency = Counter(word_list)
bigram_frequency = Counter([i for i in bigrams])
list(bigram_frequency.items())
# Out:
# [(('mobile', 'phone'), 59),
#  (('phone', 'cellular'), 1),
#  (('cellular', 'phone'), 1),
#  (('phone', 'cell'), 2),
#  (('cell', 'phone'), 10),
#  (('phone', 'cellphone'), 1),
#  (('cellphone', 'handphone'), 1),
#  (('handphone', 'hand'), 1),
#  (('hand', 'phone'), 1),
#  (('phone', 'shortened'), 1),
#  (('shortened', 'simply'), 1),
#  (('simply', 'mobile'), 1),
#  (('mobile', 'cell'), 1),
#  (('phone', 'portable'), 1),
#  (('portable', 'telephone'), 2),
#  (('telephone', 'receive'), 1),
#  (('receive', 'calls'), 1),
#  (('calls', 'radio'), 1),
#  (('radio', 'frequency'), 2),
#  (('frequency', 'link'), 2),
#  (('link', 'user'), 1),
#  (('user', 'moving'), 1),
#  (('moving', 'telephone'), 1),
#  (('telephone', 'service'), 5),
#  (('service', 'area'), 2),
#  (('area', 'radio'), 1),
#  (('link', 'establishes'), 1),
#  (('establishes', 'connection'), 1),
#  (('connection', 'switching'), 1),
#  (('switching', 'systems'), 1),
#  (('systems', 'mobile'), 3),
#  (('phone', 'operator'), 3),
#  (('operator', 'provides'), 1),
#  (('provides', 'access'), 1),
#  (('access', 'public'), 1),
#  (('public', 'switched'), 1),
#  (('switched', 'telephone'), 1),
#  (('telephone', 'network'), 1),
#  (('network', 'pstn'), 1),
#  (('pstn', 'modern'), 1),
#  (('modern', 'mobile'), 2),
#  (('mobile', 'telephone'), 5),
#  (('telephone', 'services'), 1),
#  (('services', 'use'), 2),
#  (('use', 'cellular'), 1),
#  (('cellular', 'network'), 4),
#  (('network', 'architecture'), 1),
#  (('architecture', 'mobile'), 1),
#  (('mobile', 'telephones'), 1),
#  (('telephones', 'called'), 1),
#  (('called', 'cellular'), 1),
#  (('cellular', 'telephones'), 1),
#  (('telephones', 'cell'), 1),
#  (('cell', 'phones'), 5),
#  (('phones', 'north'), 1),
#  (('north', 'america'), 2),
#  (('america', 'addition'), 1),
#  (('addition', 'telephony'), 1),
#  (('telephony', 'digital'), 1),
#  (('digital', 'mobile'), 2),
#  (('mobile', 'phones'), 44),
#  (('phones', 'g'), 1),
#  (('g', 'support'), 1),
#  (('support', 'variety'), 1),
#  (('variety', 'services'), 1),
#  (('services', 'text'), 1),
#  (('text', 'messaging'), 5),
#  (('messaging', 'mms'), 1),
#  (('mms', 'email'), 1),
#  (('email', 'internet'), 1),
#  (('internet', 'access'), 1),
#  (('access', 'shortrange'), 1),
#  (('shortrange', 'wireless'), 1),
#  (('wireless', 'communications'), 2),
#  (('communications', 'infrared'), 1),
#  (('infrared', 'bluetooth'), 1),
#  (('bluetooth', 'business'), 1),
#  (('business', 'applications'), 1),
#  (('applications', 'video'), 1),
#  (('video', 'games'), 3),
#  (('games', 'digital'), 1),
#  (('digital', 'photography'), 1),
#  (('photography', 'mobile'), 1),
#  (('phones', 'offering'), 1),
#  (('offering', 'capabilities'), 1),
#  (('capabilities', 'known'), 1),
#  (('known', 'feature'), 1),
#  (('feature', 'phones'), 9),
#  (('phones', 'mobile'), 4),
#  (('phones', 'offer'), 2),
#  (('offer', 'greatly'), 1),
#  (('greatly', 'advanced'), 1),
#  (('advanced', 'computing'), 2),
#  (('computing', 'capabilities'), 1),
#  (('capabilities', 'referred'), 1),
#  (('referred', 'smartphones'), 1),
#  (('smartphones', 'development'), 1),
#  (('development', 'metaloxidesemiconductor'), 2),
#  (('metaloxidesemiconductor', 'mos'), 3),
#  (('mos', 'largescale'), 2),
#  (('largescale', 'integration'), 2),
#  (('integration', 'lsi'), 2),
#  (('lsi', 'technology'), 2),
#  (('technology', 'information'), 2),
#  (('information', 'theory'), 2),
#  (('theory', 'cellular'), 2),
#  (('cellular', 'networking'), 2),
#  (('networking', 'led'), 2),
#  (('led', 'development'), 2),
#  (('development', 'affordable'), 2),
#  (('affordable', 'mobile'), 2),
#  (('mobile', 'communications'), 2),
#  (('communications', 'handheld'), 1),
#  (('handheld', 'mobile'), 7),
#  (('phone', 'demonstrated'), 2),
#  (('demonstrated', 'john'), 2),
#  (('john', 'f'), 2),
#  (('f', 'mitchell'), 2),
#  (('mitchell', 'martin'), 2),
#  (('martin', 'cooper'), 3),
#  (('cooper', 'motorola'), 3),
#  (('motorola', 'handset'), 2),
#  (('handset', 'weighing'), 2),
#  (('weighing', 'c'), 1),
#  (('c', 'kilograms'), 1),
#  (('kilograms', 'lbs'), 1),
#  (('lbs', 'nippon'), 1),
#  (('nippon', 'telegraph'), 2),
#  (('telegraph', 'telephone'), 2),
#  (('telephone', 'ntt'), 1),
#  (('ntt', 'launched'), 1),
#  (('launched', 'worlds'), 1),
#  (('worlds', 'cellular'), 1),
#  (('network', 'japancitation'), 1),
#  (('japancitation', 'needed'), 1),
#  (('needed', 'dynatac'), 1),
#  (('dynatac', 'x'), 3),
#  (('x', 'commercially'), 3),
#  (('commercially', 'available'), 4),
#  (('available', 'handheld'), 3),
#  (('phone', 'worldwide'), 1),
#  (('worldwide', 'mobile'), 2),
#  (('phone', 'subscriptions'), 1),
#  (('subscriptions', 'grew'), 1),
#  (('grew', 'seven'), 1),
#  (('seven', 'billion'), 2),
#  (('billion', 'provide'), 1),
#  (('provide', 'person'), 1),
#  (('person', 'earth'), 1),
#  (('earth', 'quarter'), 1),
#  (('quarter', 'smartphone'), 1),
#  (('smartphone', 'developers'), 1),
#  (('developers', 'worldwide'), 1),
#  (('worldwide', 'samsung'), 2),
#  (('samsung', 'apple'), 3),
#  (('apple', 'huawei'), 3),
#  (('huawei', 'smartphone'), 1),
#  (('smartphone', 'sales'), 1),
#  (('sales', 'represented'), 1),
#  (('represented', 'percent'), 1),
#  (('percent', 'total'), 1),
#  (('total', 'mobile'), 1),
#  (('phone', 'sales'), 1),
#  (('sales', 'feature'), 1),
#  (('phones', 'slang'), 1),
#  (('slang', 'dumbphones'), 1),
#  (('dumbphones', 'largest'), 1),
#  (('largest', 'samsung'), 1),
#  (('samsung', 'nokia'), 1),
#  (('nokia', 'alcatel'), 1),
#  (('alcatel', 'history'), 1),
#  (('history', 'martin'), 1),
#  (('motorola', 'shown'), 1),
#  (('shown', 'reenactment'), 1),
#  (('reenactment', 'publicized'), 1),
#  (('publicized', 'handheld'), 1),
#  (('phone', 'prototype'), 1),
#  (('prototype', 'dynatac'), 1),
#  (('dynatac', 'model'), 1),
#  (('model', 'april'), 1),
#  (('april', 'handheld'), 1),
#  (('mobile', 'radio'), 1),
#  (('radio', 'telephone'), 1),
#  (('service', 'envisioned'), 1),
#  (('envisioned', 'early'), 1),
#  (('early', 'stages'), 1),
#  (('stages', 'radio'), 1),
#  (('radio', 'engineering'), 1),
#  (('engineering', 'finnish'), 1),
#  (('finnish', 'inventor'), 1),
#  (('inventor', 'eric'), 1),
#  (('eric', 'tigerstedt'), 1),
#  (('tigerstedt', 'filed'), 1),
#  (('filed', 'patent'), 1),
#  (('patent', 'pocketsize'), 1),
#  (('pocketsize', 'folding'), 1),
#  (('folding', 'telephone'), 1),
#  (('telephone', 'thin'), 1),
#  (('thin', 'carbon'), 1),
#  (('carbon', 'microphone'), 1),
#  (('microphone', 'early'), 1),
#  (('early', 'predecessors'), 1),
#  (('predecessors', 'cellular'), 1),
#  (('cellular', 'phones'), 2),
#  (('phones', 'included'), 1),
#  (('included', 'analog'), 1),
#  (('analog', 'radio'), 1),
#  (('radio', 'communications'), 1),
#  (('communications', 'ships'), 1),
#  (('ships', 'trains'), 1),
#  (('trains', 'race'), 1),
#  (('race', 'create'), 1),
#  (('create', 'truly'), 1),
#  (('truly', 'portable'), 1),
#  (('telephone', 'devices'), 1),
#  (('devices', 'began'), 1),
#  (('began', 'world'), 1),
#  (('world', 'war'), 2),
#  (('war', 'ii'), 1),
#  (('ii', 'developments'), 1),
#  (('developments', 'taking'), 1),
#  (('taking', 'place'), 1),
#  (('place', 'countries'), 1),
#  (('countries', 'advances'), 1),
#  (('advances', 'mobile'), 1),
#  (('mobile', 'telephony'), 3),
#  (('telephony', 'traced'), 1),
#  (('traced', 'successive'), 1),
#  (('successive', 'generations'), 1),
#  (('generations', 'starting'), 1),
#  (('starting', 'early'), 1),
#  (('early', 'zerothgeneration'), 1),
#  (('zerothgeneration', 'g'), 1),
#  (('g', 'services'), 1),
#  (('services', 'bell'), 1),
#  (('bell', 'systems'), 1),
#  (('service', 'successor'), 1),
#  (('successor', 'improved'), 1),
#  (('improved', 'mobile'), 1),
#  (('service', 'g'), 1),
#  (('g', 'systems'), 2),
#  (('systems', 'cellular'), 1),
#  (('cellular', 'supported'), 1),
#  (('supported', 'simultaneous'), 1),
#  (('simultaneous', 'calls'), 3),
#  (('calls', 'expensive'), 1),
#  (('expensive', 'motorola'), 1),
#  (('motorola', 'dynatac'), 1),
#  (('handheld', 'cellular'), 2),
#  (('cellular', 'mobile'), 2),
#  (('phone', 'development'), 1),
#  (('communications', 'devices'), 1),
#  (('devices', 'car'), 1),
#  (('car', 'phone'), 1),
#  (('phone', 'handheld'), 1),
#  (('weighing', 'kilograms'), 1),
#  (('kilograms', 'lb'), 1),
#  (('lb', 'commercial'), 1),
#  (('commercial', 'automated'), 1),
#  (('automated', 'cellular'), 1),
#  (('network', 'g'), 1),
#  (('g', 'analog'), 1),
#  (('analog', 'launched'), 1),
#  (('launched', 'japan'), 2),
#  (('japan', 'nippon'), 1),
#  (('telephone', 'followed'), 1),
#  (('followed', 'simultaneous'), 1),
#  (('simultaneous', 'launch'), 1),
#  (('launch', 'nordic'), 1),
#  (('nordic', 'mobile'), 1),
#  (('telephone', 'nmt'), 1),
#  (('nmt', 'system'), 1),
#  (('system', 'denmark'), 1),
#  (('denmark', 'finland'), 1),
#  (('finland', 'norway'), 1),
#  (('norway', 'sweden'), 1),
#  (('sweden', 'countries'), 1),
#  (('countries', 'followed'), 1),
#  (('followed', 'early'), 1),
#  (('early', 'mids'), 1),
#  (('mids', 'firstgeneration'), 1),
#  (('firstgeneration', 'g'), 1),
#  (('systems', 'support'), 1),
#  (('support', 'far'), 1),
#  (('far', 'simultaneous'), 1),
#  (('calls', 'analog'), 1),
#  (('analog', 'cellular'), 1),
#  (('cellular', 'technology'), 2),
#  (('technology', 'dynatac'), 1),
#  (('phone', 'digital'), 1),
#  (('digital', 'cellular'), 2),
#  (('cellular', 'networks'), 1),
#  (('networks', 'appeared'), 1),
#  (('appeared', 's'), 1),
#  (('s', 'enabled'), 1),
#  (('enabled', 'wide'), 1),
#  (('wide', 'adoption'), 1),
#  (('adoption', 'mosfetbased'), 1),
#  (('mosfetbased', 'rf'), 1),
#  (('rf', 'power'), 1),
#  (('power', 'amplifiers'), 1),
#  (('amplifiers', 'power'), 1),
#  (('power', 'mosfet'), 1),
#  (('mosfet', 'ldmos'), 1),
#  (('ldmos', 'rf'), 1),
#  (('rf', 'circuits'), 1),
#  (('circuits', 'rf'), 1),
#  (('rf', 'cmos'), 1),
#  (('cmos', 'leading'), 1),
#  (('leading', 'introduction'), 1),
#  (('introduction', 'digital'), 1),
#  (('digital', 'signal'), 1),
#  (('signal', 'processing'), 1),
#  (('processing', 'wireless'), 1),
#  (('communications', 'secondgeneration'), 1),
#  (('secondgeneration', 'g'), 1),
#  (('g', 'digital'), 1),
#  (('technology', 'launched'), 1),
#  (('launched', 'finland'), 2),
#  (('finland', 'radiolinja'), 1),
#  (('radiolinja', 'gsm'), 1),
#  (('gsm', 'standard'), 2),
#  (('standard', 'sparked'), 1),
#  (('sparked', 'competition'), 1),
#  (('competition', 'sector'), 1),
#  (('sector', 'new'), 1),
#  (('new', 'operators'), 1),
#  (('operators', 'challenged'), 1),
#  (('challenged', 'incumbent'), 1),
#  (('incumbent', 'g'), 1),
#  (('g', 'network'), 1),
#  (('network', 'operators'), 2),
#  (('operators', 'gsm'), 1),
#  (('standard', 'european'), 1),
#  (('european', 'initiative'), 1),
#  (('initiative', 'expressed'), 1),
#  (('expressed', 'cept'), 1),
#  (('cept', 'conférence'), 1),
#  (('conférence', 'européenne'), 1),
#  (('européenne', 'des'), 1),
#  (('des', 'postes'), 1),
#  (('postes', 'et'), 1),
#  (('et', 'telecommunications'), 1),
#  (('telecommunications', 'european'), 1),
#  (('european', 'postal'), 1),
#  (('postal', 'telecommunications'), 1),
#  (('telecommunications', 'conference'), 1),
#  (('conference', 'francogerman'), 1),
#  (('francogerman', 'rd'), 1),
#  (('rd', 'cooperation'), 1),
#  (('cooperation', 'demonstrated'), 1),
#  (('demonstrated', 'technical'), 1),
#  (('technical', 'feasibility'), 1),
#  (('feasibility', 'memorandum'), 1),
#  (('memorandum', 'understanding'), 1),
#  (('understanding', 'signed'), 1),
#  (('signed', 'european'), 1),
#  (('european', 'countries'), 1),
#  (('countries', 'agreed'), 1),
#  (('agreed', 'launch'), 1),
#  (('launch', 'commercial'), 1),
#  (('commercial', 'service'), 1),
#  (('service', 'version'), 1),
#  (('version', 'gsm'), 1),
#  (('gsm', 'g'), 2),
#  (('g', 'standard'), 1),
#  (('standard', 'pages'), 1),
#  (('pages', 'ieeerse'), 1),
#  (('ieeerse', 'awarded'), 1),
#  (('awarded', 'thomas'), 1),
#  (('thomas', 'haug'), 1),
#  (('haug', 'philippe'), 1),
#  (('philippe', 'dupuis'), 1),
#  (('dupuis', 'james'), 1),
#  (('james', 'clerk'), 1),
#  (('clerk', 'maxwell'), 1),
#  (('maxwell', 'medal'), 1),
#  (('medal', 'contributions'), 1),
#  (('contributions', 'digital'), 1),
#  (('telephone', 'standard'), 1),
#  (('standard', 'gsm'), 1),
#  (('gsm', 'billion'), 1),
#  (('billion', 'people'), 1),
#  (('people', 'countries'), 1),
#  (('countries', 'gsm'), 1),
#  (('g', 'evolved'), 1),
#  (('evolved', 'g'), 1),
#  (('g', 'g'), 3),
#  (('g', 'lithiumion'), 1),
#  (('lithiumion', 'battery'), 2),
#  (('battery', 'indispensable'), 1),
#  (('indispensable', 'energy'), 1),
#  (('energy', 'source'), 1),
#  (('source', 'modern'), 1),
#  (('phones', 'commercialized'), 1),
#  (('commercialized', 'sony'), 1),
#  (('sony', 'asahi'), 1),
#  (('asahi', 'kasei'), 1),
#  (('kasei', 'generation'), 1),
#  (('generation', 'g'), 1),
#  (('g', 'launched'), 1),
#  (('japan', 'ntt'), 1),
#  (('ntt', 'docomo'), 1),
#  (('docomo', 'wcdma'), 1),
#  (('wcdma', 'standard'), 1),
#  (('standard', 'followed'), 1),
#  (('followed', 'g'), 1),
#  (('g', 'turbo'), 1),
#  (('turbo', 'g'), 1),
#  (('g', 'enhancements'), 1),
#  (('enhancements', 'based'), 1),
#  (('based', 'highspeed'), 1),
#  (('highspeed', 'packet'), 1),
#  (('packet', 'access'), 1),
#  (('access', 'hspa'), 1),
#  (('hspa', 'family'), 1),
#  (('family', 'allowing'), 1),
#  (('allowing', 'umts'), 1),
#  (('umts', 'networks'), 1),
#  (('networks', 'higher'), 1),
#  (('higher', 'data'), 1),
#  (('data', 'transfer'), 1),
#  (('transfer', 'speeds'), 1),
#  (('speeds', 'capacity'), 1),
#  (('capacity', 'clear'), 1),
#  (('clear', 'point'), 1),
#  (('point', 'g'), 1),
#  (('g', 'networks'), 1),
#  (('networks', 'overwhelmed'), 1),
#  (('overwhelmed', 'growth'), 1),
#  (('growth', 'bandwidthintensive'), 1),
#  (('bandwidthintensive', 'applications'), 1),
#  (('applications', 'streaming'), 1),
#  (('streaming', 'media'), 1),
#  (('media', 'consequently'), 1),
#  (('consequently', 'industry'), 1),
#  (('industry', 'began'), 1),
#  (('began', 'looking'), 1),
#  (('looking', 'dataoptimized'), 1),
#  (('dataoptimized', 'fourthgeneration'), 1),
#  (('fourthgeneration', 'technologies'), 1),
#  (('technologies', 'promise'), 1),
#  (('promise', 'speed'), 1),
#  (('speed', 'improvements'), 1),
#  (('improvements', 'tenfold'), 1),
#  (('tenfold', 'existing'), 1),
#  (('existing', 'g'), 1),
#  (('g', 'technologies'), 1),
#  (('technologies', 'commercially'), 1),
#  (('available', 'technologies'), 1),
#  (('technologies', 'billed'), 1),
#  (('billed', 'g'), 1),
#  (('g', 'wimax'), 1),
#  (('wimax', 'standard'), 1),
#  (('standard', 'offered'), 2),
#  (('offered', 'north'), 1),
#  (('america', 'sprint'), 1),
#  (('sprint', 'lte'), 1),
#  (('lte', 'standard'), 1),
#  (('offered', 'scandinavia'), 1),
#  (('scandinavia', 'teliasonera'), 1),
#  (('teliasonera', 'g'), 1),
#  (('g', 'technology'), 1),
#  (('technology', 'term'), 1),
#  (('term', 'research'), 1),
#  (('research', 'papers'), 1),
#  (('papers', 'projects'), 1),
#  (('projects', 'denote'), 1),
#  (('denote', 'major'), 1),
#  (('major', 'phase'), 1),
#  (('phase', 'mobile'), 1),
#  (('mobile', 'telecommunication'), 1),
#  (('telecommunication', 'standards'), 1),
#  (('standards', 'gimtadvanced'), 1),
#  (('gimtadvanced', 'standards'), 1),
#  (('standards', 'term'), 1),
#  (('term', 'g'), 1),
#  (('g', 'officially'), 1),
#  (('officially', 'specification'), 1),
#  (('specification', 'official'), 1),
#  (('official', 'document'), 1),
#  (('document', 'public'), 1),
#  (('public', 'telecommunication'), 1),
#  (('telecommunication', 'companies'), 1),
#  (('companies', 'standardization'), 1),
#  (('standardization', 'bodies'), 2),
#  (('bodies', 'gpp'), 1),
#  (('gpp', 'wimax'), 1),
#  (('wimax', 'forum'), 1),
#  (('forum', 'itur'), 1),
#  (('itur', 'new'), 1),
#  (('new', 'standards'), 1),
#  (('standards', 'g'), 1),
#  (('g', 'currently'), 1),
#  (('currently', 'developed'), 1),
#  (('developed', 'standardization'), 1),
#  (('bodies', 'time'), 1),
#  (('time', 'seen'), 1),
#  (('seen', 'g'), 1),
#  (('g', 'umbrella'), 1),
#  (('umbrella', 'new'), 1),
#  (('new', 'mobile'), 1),
#  (('mobile', 'generation'), 1),
#  (('generation', 'types'), 1),
#  (('types', 'mobile'), 1),
#  (('mobile', 'subscriptions'), 1),
#  (('subscriptions', 'people'), 1),
#  (('people', 'active'), 1),
#  (('active', 'mobile'), 1),
#  (('mobile', 'broadband'), 1),
#  (('broadband', 'subscriptions'), 1),
#  (('subscriptions', 'inhabitants'), 1),
#  (('inhabitants', 'smartphone'), 1),
#  (('smartphone', 'smartphones'), 1),
#  (('smartphones', 'number'), 1),
#  (('number', 'distinguishing'), 1),
#  (('distinguishing', 'features'), 1),
#  (('features', 'international'), 1),
#  (('international', 'telecommunication'), 1),
#  (('telecommunication', 'union'), 1),
#  (('union', 'measures'), 1),
#  (('measures', 'internet'), 1),
#  (('internet', 'connection'), 1),
#  (('connection', 'calls'), 1),
#  (('calls', 'active'), 1),
#  (('active', 'mobilebroadband'), 1),
#  (('mobilebroadband', 'subscriptions'), 1),
#  (('subscriptions', 'includes'), 1),
#  (('includes', 'tablets'), 1),
#  (('tablets', 'etc'), 1),
#  (('etc', 'developed'), 1),
#  (('developed', 'world'), 1),
#  (('world', 'smartphones'), 1),
#  (('smartphones', 'overtaken'), 1),
#  (('overtaken', 'usage'), 1),
#  (('usage', 'earlier'), 1),
#  (('earlier', 'mobile'), 1),
#  (('mobile', 'systems'), 1),
#  (('systems', 'developing'), 1),
#  (('developing', 'world'), 1),
#  (('world', 'account'), 1),
#  (('account', 'mobile'), 1),
#  (('telephony', 'feature'), 1),
#  (('feature', 'phone'), 3),
#  (('phone', 'feature'), 1),
#  (('phone', 'term'), 1),
#  (('term', 'typically'), 1),
#  (('typically', 'retronym'), 1),
#  (('retronym', 'describe'), 1),
#  (('describe', 'mobile'), 1),
#  (('phones', 'limited'), 1),
#  (('limited', 'capabilities'), 1),
#  (('capabilities', 'contrast'), 1),
#  (('contrast', 'modern'), 1),
#  (('modern', 'smartphone'), 1),
#  (('smartphone', 'feature'), 1),
#  (('phones', 'typically'), 2),
#  (('typically', 'provide'), 1),
#  (('provide', 'voice'), 1),
#  (('voice', 'calling'), 2),
#  (('calling', 'text'), 2),
#  (('messaging', 'functionality'), 1),
#  (('functionality', 'addition'), 1),
#  (('addition', 'basic'), 1),
#  (('basic', 'multimedia'), 1),
#  (('multimedia', 'internet'), 1),
#  (('internet', 'capabilities'), 1),
#  (('capabilities', 'services'), 1),
#  (('services', 'offered'), 1),
#  (('offered', 'users'), 1),
#  (('users', 'wireless'), 1),
#  (('wireless', 'service'), 1),
#  (('service', 'provider'), 2),
#  (('provider', 'feature'), 1),
#  (('phone', 'additional'), 1),
#  (('additional', 'functions'), 1),
#  (('functions', 'basic'), 1),
#  (('basic', 'mobile'), 2),
#  (('phone', 'capable'), 1),
#  (('capable', 'voice'), 1),
#  (('messaging', 'feature'), 1),
#  (('phones', 'basic'), 2),
#  (('phones', 'tend'), 1),
#  (('tend', 'use'), 1),
#  (('use', 'proprietary'), 1),
#  (('proprietary', 'customdesigned'), 1),
#  (('customdesigned', 'software'), 1),
#  (('software', 'user'), 1),
#  (('user', 'interface'), 1),
#  (('interface', 'contrast'), 1),
#  (('contrast', 'smartphones'), 1),
#  (('smartphones', 'generally'), 1),
#  (('generally', 'use'), 1),
#  (('use', 'mobile'), 10),
#  (('mobile', 'operating'), 1),
#  (('operating', 'system'), 2),
#  (('system', 'shares'), 1),
#  (('shares', 'common'), 1),
#  (('common', 'traits'), 1),
#  (('traits', 'devices'), 1),
#  (('devices', 'infrastructure'), 1),
#  (('infrastructure', 'mobile'), 1),
#  (('phones', 'communicate'), 1),
#  (('communicate', 'cell'), 1),
#  (('cell', 'towers'), 3),
#  (('towers', 'placed'), 2),
#  (('placed', 'coverage'), 1),
#  (('coverage', 'telephone'), 1),
#  (('area', 'divided'), 1),
#  (('divided', 'cells'), 1),
#  (('cells', 'cell'), 1),
#  (('cell', 'uses'), 3),
#  (('uses', 'different'), 1),
#  (('different', 'set'), 1),
#  (('set', 'frequencies'), 1),
#  (('frequencies', 'neighboring'), 1),
#  (('neighboring', 'cells'), 1),
#  (('cells', 'typically'), 1),
#  (('typically', 'covered'), 1),
#  (('covered', 'towers'), 1),
#  (('placed', 'different'), 1),
#  (('different', 'locations'), 1),
#  (('locations', 'cell'), 1),
#  (('towers', 'usually'), 1),
#  (('usually', 'interconnected'), 1),
#  (('interconnected', 'phone'), 1),
#  (('phone', 'network'), 1),
#  (('network', 'internet'), 1),
#  (('internet', 'wired'), 1),
#  (('wired', 'connections'), 1),
#  (('connections', 'bandwidth'), 1),
#  (('bandwidth', 'limitations'), 1),
#  (('limitations', 'cell'), 1),
#  (('cell', 'maximum'), 1),
#  (('maximum', 'number'), 1),
#  (('number', 'cell'), 1),
#  (('phones', 'handle'), 1),
#  (('handle', 'cells'), 1),
#  (('cells', 'sized'), 1),
#  (('sized', 'depending'), 1),
#  (('depending', 'expected'), 1),
#  (('expected', 'usage'), 1),
#  (('usage', 'density'), 1),
#  (('density', 'smaller'), 1),
#  (('smaller', 'cities'), 1),
#  (('cities', 'case'), 1),
#  (('case', 'lower'), 1),
#  (('lower', 'transmitter'), 1),
#  (('transmitter', 'powers'), 1),
#  (('powers', 'avoid'), 1),
#  (('avoid', 'broadcasting'), 1),
#  (('broadcasting', 'cell'), 1),
#  (('cell', 'order'), 1),
#  (('order', 'handle'), 1),
#  (('handle', 'high'), 1),
#  (('high', 'traffic'), 2),
#  (('traffic', 'multiple'), 1),
#  (('multiple', 'towers'), 1),
#  (('towers', 'set'), 1),
#  (('set', 'area'), 1),
#  (('area', 'different'), 1),
#  (('different', 'frequencies'), 1),
#  (('frequencies', 'permanently'), 1),
#  (('permanently', 'temporarily'), 1),
#  (('temporarily', 'special'), 1),
#  (('special', 'events'), 1),
#  (('events', 'like'), 1),
#  (('like', 'super'), 1),
#  (('super', 'bowl'), 1),
#  (('bowl', 'taste'), 1),
#  (('taste', 'chicago'), 1),
#  (('chicago', 'state'), 1),
#  (('state', 'fair'), 1),
#  (('fair', 'nyc'), 1),
#  (('nyc', 'new'), 1),
#  (('new', 'years'), 1),
#  (('years', 'eve'), 1),
#  (('eve', 'hurricane'), 1),
#  (('hurricane', 'hit'), 1),
#  (('hit', 'cities'), 1),
#  (('cities', 'etc'), 1),
#  (('etc', 'cell'), 1),
#  (('phone', 'companies'), 2),
#  (('companies', 'bring'), 1),
#  (('bring', 'truck'), 1),
#  (('truck', 'equipment'), 1),
#  (('equipment', 'host'), 1),
#  (('host', 'abnormally'), 1),
#  (('abnormally', 'high'), 1),
#  (('traffic', 'portable'), 1),
#  (('portable', 'cell'), 1),
#  (('cell', 'cellular'), 1),
#  (('cellular', 'greatly'), 1),
#  (('greatly', 'increase'), 1),
#  (('increase', 'capacity'), 1),
#  (('capacity', 'simultaneous'), 1),
#  (('simultaneous', 'wireless'), 1),
#  (('wireless', 'phone'), 1),
#  (('phone', 'calls'), 1),
#  (('calls', 'phone'), 1),
#  (('phone', 'company'), 1),
#  (('company', 'example'), 1),
#  (('example', 'license'), 1),
#  (('license', 'frequencies'), 1),
#  (('frequencies', 'cell'), 1),
#  (('cell', 'use'), 1),
#  (('use', 'unique'), 1),
#  (('unique', 'frequencies'), 1),
#  (('frequencies', 'communicating'), 1),
#  (('communicating', 'cells'), 1),
#  (('cells', 'slightly'), 1),
#  (('slightly', 'overlap'), 1),
#  (('overlap', 'frequency'), 1),
#  (('frequency', 'reused'), 1),
#  (('reused', 'example'), 1),
#  (('example', 'cell'), 1),
#  (('uses', 'frequency'), 2),
#  (('frequency', 'door'), 2),
#  (('door', 'cell'), 1),
#  (('door', 'reuse'), 1),
#  (('reuse', 'frequency'), 1),
#  (('frequency', 'cells'), 1),
#  (('cells', 'touching'), 1),
#  (('touching', 'overlapcommunicate'), 1),
#  (('overlapcommunicate', 'reuse'), 1),
#  (('reuse', 'frequenciescitation'), 1),
#  (('frequenciescitation', 'needed'), 1),
#  (('needed', 'greatly'), 1),
#  (('greatly', 'increased'), 1),
#  (('increased', 'phone'), 1),
#  (('companies', 'implemented'), 1),
#  (('implemented', 'digital'), 1),
#  (('digital', 'networks'), 1),
#  (('networks', 'digital'), 1),
#  (('digital', 'frequency'), 1),
#  (('frequency', 'host'), 1),
#  (('host', 'multiple'), 1),
#  (('multiple', 'simultaneous'), 1),
#  (('calls', 'increasing'), 1),
#  (('increasing', 'capacity'), 1),
#  (('capacity', 'phone'), 1),
#  (('phone', 'moves'), 1),
#  (('moves', 'phone'), 1),
#  (('phone', 'hand'), 1),
#  (('hand', 'automatically'), 1),
#  (('automatically', 'disconnect'), 1),
#  (('disconnect', 'reconnect'), 1),
#  (('reconnect', 'tower'), 1),
#  (('tower', 'cell'), 1),
#  (('cell', 'gives'), 1),
#  (('gives', 'best'), 1),
#  (('best', 'reception'), 1),
#  (('reception', 'additionally'), 1),
#  (('additionally', 'shortrange'), 1),
#  (('shortrange', 'wifi'), 1),
#  (('wifi', 'infrastructure'), 1),
#  (('infrastructure', 'smartphones'), 1),
#  (('smartphones', 'possible'), 1),
#  (('possible', 'offloads'), 1),
#  (('offloads', 'traffic'), 1),
#  (('traffic', 'cell'), 1),
#  (('cell', 'networks'), 1),
#  (('networks', 'local'), 1),
#  (('local', 'area'), 1),
#  (('area', 'networks'), 1),
#  (('networks', 'hardware'), 1),
#  (('hardware', 'common'), 1),
#  (('common', 'components'), 1),
#  (('components', 'found'), 1),
#  (('found', 'mobile'), 2),
#  (('phones', 'central'), 2),
#  (('central', 'processing'), 3),
#  (('processing', 'unit'), 2),
#  (('unit', 'cpu'), 1),
#  (('cpu', 'processor'), 1),
#  (('processor', 'phones'), 1),
#  (('phones', 'cpu'), 1),
#  (('cpu', 'microprocessor'), 1),
#  (('microprocessor', 'fabricated'), 1),
#  (('fabricated', 'metaloxidesemiconductor'), 1),
#  (('mos', 'integrated'), 1),
#  (('integrated', 'circuit'), 1),
#  (('circuit', 'ic'), 1),
#  (('ic', 'chip'), 1),
#  (('chip', 'battery'), 1),
#  (('battery', 'providing'), 1),
#  (('providing', 'power'), 1),
#  (('power', 'source'), 1),
#  (('source', 'phone'), 1),
#  (('phone', 'functions'), 1),
#  (('functions', 'modern'), 1),
#  (('modern', 'handset'), 1),
#  (('handset', 'typically'), 1),
#  (('typically', 'uses'), 1),
#  (('uses', 'lithiumion'), 1),
#  (('battery', 'lib'), 1),
#  (('lib', 'older'), 1),
#  (('older', 'handsets'), 1),
#  (('handsets', 'nickelmetal'), 1),
#  (('nickelmetal', 'hydride'), 1),
#  (('hydride', 'nimh'), 1),
#  (('nimh', 'batteries'), 1),
#  (('batteries', 'input'), 1),
#  (('input', 'mechanism'), 1),
#  (('mechanism', 'allow'), 1),
#  (('allow', 'user'), 1),
#  (('user', 'interact'), 1),
#  (('interact', 'phone'), 1),
#  (('phone', 'keypad'), 1),
#  (('keypad', 'feature'), 1),
#  (('phones', 'touch'), 1),
#  (('touch', 'screens'), 1),
#  (('screens', 'smartphones'), 1),
#  (('smartphones', 'typically'), 1),
#  (('typically', 'capacitive'), 1),
#  (('capacitive', 'sensing'), 1),
#  (('sensing', 'display'), 1),
#  (('display', 'echoes'), 1),
#  (('echoes', 'users'), 1),
#  (('users', 'typing'), 1),
#  (('typing', 'displays'), 1),
#  (('displays', 'text'), 1),
#  (('text', 'messages'), 1),
#  (('messages', 'contacts'), 1),
#  (('contacts', 'display'), 1),
#  (('display', 'typically'), 1),
#  (('typically', 'liquidcrystal'), 1),
#  (('liquidcrystal', 'display'), 1),
#  (('display', 'lcd'), 1),
#  (('lcd', 'organic'), 1),
#  (('organic', 'lightemitting'), 1),
#  (('lightemitting', 'diode'), 1),
#  (('diode', 'oled'), 1),
#  (('oled', 'display'), 1),
#  (('display', 'speakers'), 1),
#  (('speakers', 'sound'), 1),
#  (('sound', 'subscriber'), 1),
#  (('subscriber', 'identity'), 2),
#  (('identity', 'module'), 3),
#  (('module', 'sim'), 2),
#  (('sim', 'cards'), 4),
#  (('cards', 'removable'), 1),
#  (('removable', 'user'), 1),
#  (('user', 'identity'), 1),
#  (('module', 'ruim'), 1),
#  (('ruim', 'cards'), 2),
#  (('cards', 'hardware'), 1),
#  (('hardware', 'notification'), 1),
#  (('notification', 'led'), 1),
#  (('led', 'phones'), 1),
#  (('phones', 'lowend'), 1),
#  (('lowend', 'mobile'), 1),
#  (('phones', 'referred'), 1),
#  (('referred', 'feature'), 1),
#  (('offer', 'basic'), 1),
#  (('basic', 'telephony'), 1),
#  (('telephony', 'handsets'), 1),
#  (('handsets', 'advanced'), 1),
#  (('computing', 'ability'), 1),
#  (('ability', 'use'), 1),
#  (('use', 'native'), 1),
#  (('native', 'software'), 1),
#  (('software', 'applications'), 1),
#  (('applications', 'known'), 1),
#  (('known', 'smartphones'), 1),
#  (('smartphones', 'central'), 1),
#  (('unit', 'mobile'), 1),
#  (('processing', 'units'), 1),
#  (('units', 'cpus'), 1),
#  (('cpus', 'similar'), 1),
#  (('similar', 'computers'), 1),
#  (('computers', 'optimised'), 1),
#  (('optimised', 'operate'), 1),
#  (('operate', 'low'), 1),
#  (('low', 'power'), 1),
#  (('power', 'environments'), 1),
#  (('environments', 'mobile'), 1),
#  (('mobile', 'cpu'), 1),
#  (('cpu', 'performance'), 1),
#  (('performance', 'depends'), 1),
#  (('depends', 'clock'), 1),
#  (('clock', 'rate'), 1),
#  (('rate', 'generally'), 1),
#  (('generally', 'given'), 1),
#  (('given', 'multiples'), 1),
#  (('multiples', 'hertz'), 1),
#  (('hertz', 'memory'), 1),
#  (('memory', 'hierarchy'), 1),
#  (('hierarchy', 'greatly'), 1),
#  (('greatly', 'affects'), 1),
#  (('affects', 'overall'), 1),
#  (('overall', 'performance'), 1),
#  (('performance', 'problems'), 1),
#  (('problems', 'performance'), 1),
#  (('performance', 'mobile'), 1),
#  (('phone', 'cpus'), 1),
#  (('cpus', 'appropriately'), 1),
#  (('appropriately', 'given'), 1),
#  (('given', 'scores'), 1),
#  (('scores', 'derived'), 1),
#  (('derived', 'standardized'), 1),
#  (('standardized', 'tests'), 1),
#  (('tests', 'measure'), 1),
#  (('measure', 'real'), 1),
#  (('real', 'effective'), 1),
#  (('effective', 'performance'), 1),
#  (('performance', 'commonly'), 1),
#  (('commonly', 'applications'), 1),
#  (('applications', 'display'), 1),
#  (('display', 'main'), 1),
#  (('main', 'characteristics'), 1),
#  (('characteristics', 'phones'), 1),
#  (('phones', 'screen'), 1),
#  (('screen', 'depending'), 1),
#  (('depending', 'devices'), 1),
#  (('devices', 'type'), 1),
#  (('type', 'design'), 1),
#  (('design', 'screen'), 1),
#  (('screen', 'fills'), 1),
#  (('fills', 'nearly'), 1),
#  (('nearly', 'space'), 1),
#  (('space', 'devices'), 1),
#  (('devices', 'surface'), 1),
#  (('surface', 'smartphone'), 1),
#  (('smartphone', 'displays'), 1),
#  (('displays', 'aspect'), 1),
#  (('aspect', 'ratio'), 1),
#  (('ratio', 'taller'), 1),
#  (('taller', 'aspect'), 2),
#  (('aspect', 'ratios'), 2),
#  (('ratios', 'common'), 1),
#  (('common', 'screen'), 1),
#  (('screen', 'sizes'), 4),
#  (('sizes', 'measured'), 1),
#  (('measured', 'diagonal'), 1),
#  (('diagonal', 'inches'), 1),
#  (('inches', 'millimeters'), 1),
#  (('millimeters', 'feature'), 1),
#  (('phones', 'generally'), 1),
#  (('generally', 'screen'), 1),
#  (('sizes', 'millimetres'), 1),
#  (('millimetres', 'phones'), 1),
#  (('phones', 'screens'), 1),
#  (('screens', 'larger'), 1),
#  (('larger', 'millimetres'), 1),
#  (('millimetres', 'called'), 1),
#  (('called', 'phablets'), 1),
#  (('phablets', 'smartphones'), 1),
#  (('smartphones', 'screens'), 1),
#  (('screens', 'millimetres'), 1),
#  (('millimetres', 'size'), 1),
#  (('size', 'commonly'), 1),
#  (('commonly', 'difficult'), 1),
#  (('difficult', 'use'), 1),
#  (('use', 'single'), 1),
#  (('single', 'hand'), 1),
#  (('hand', 'thumbs'), 1),
#  (('thumbs', 'reach'), 1),
#  (('reach', 'entire'), 1),
#  (('entire', 'screen'), 1),
#  (('screen', 'surface'), 1),
#  (('surface', 'need'), 1),
#  (('need', 'shifted'), 1),
#  (('shifted', 'hand'), 1),
#  (('hand', 'held'), 1),
#  (('held', 'hand'), 1),
#  (('hand', 'manipulated'), 1),
#  (('manipulated', 'place'), 1),
#  (('place', 'hands'), 1),
#  (('hands', 'design'), 1),
#  (('design', 'advances'), 1),
#  (('advances', 'modern'), 1),
#  (('modern', 'smartphones'), 1),
#  (('smartphones', 'large'), 1),
#  (('large', 'screen'), 1),
#  (('sizes', 'edgetoedge'), 1),
#  (('edgetoedge', 'designs'), 1),
#  (('designs', 'compact'), 1),
#  (('compact', 'builds'), 1),
#  (('builds', 'improve'), 1),
#  (('improve', 'ergonomics'), 1),
#  (('ergonomics', 'shift'), 1),
#  (('shift', 'taller'), 1),
#  (('ratios', 'resulted'), 1),
#  (('resulted', 'phones'), 1),
#  (('phones', 'larger'), 1),
#  (('larger', 'screen'), 1),
#  (('sizes', 'whilst'), 1),
#  (('whilst', 'maintaining'), 1),
#  (('maintaining', 'ergonomics'), 1),
#  (('ergonomics', 'associated'), 1),
#  (('associated', 'smaller'), 1),
#  (('smaller', 'displays'), 1),
#  (('displays', 'liquidcrystal'), 1),
#  (('liquidcrystal', 'displays'), 1),
#  (('displays', 'common'), 1),
#  (('common', 'ips'), 1),
#  (('ips', 'led'), 1),
#  (('led', 'oled'), 1),
#  (('oled', 'amoled'), 1),
#  ...]

# %% [markdown]
# Usually, $F_{iw}(i)$ is the number of word appeared $i$ times.
# But in our case, $F_{iw}(i)$ is different for bigram and monogram.
#
# For our monogram, $F_{iw}(i)$ is replace by the mean of other values apparence.
#
# For our bigram, $F_{iw}(1)$ is just replace by the mean of other values apparence.

# %%
def compute_cumul_freq_bigram(ngram_frequency):
    
    ngram_cumulative_freq = {}
    for i in ngram_frequency.values():
        if i not in ngram_cumulative_freq.keys():
            ngram_cumulative_freq[i] = 1
        ngram_cumulative_freq[i] += 1
    ngram_cumulative_freq[1] = statistics.mean([v for k,v in ngram_cumulative_freq.items() if k != 1]) 
    key_list = sorted(list(ngram_cumulative_freq.keys()), key=lambda x : x)
    cumul = 0
    for key in key_list :
        cumul += ngram_cumulative_freq[key]
        ngram_cumulative_freq[key] = cumul
    return ngram_cumulative_freq

def compute_cumul_freq_monogram(ngram_frequency):
    
    ngram_cumulative_freq = {}
    for i in ngram_frequency.values():
        if i not in ngram_cumulative_freq.keys():
            ngram_cumulative_freq[i] = 1
        ngram_cumulative_freq[i] += 1
    ngram_cumulative_freq = {k: statistics.mean([m_v for m_k, m_v in ngram_cumulative_freq.items() if m_k != k]) 
                             for k in ngram_cumulative_freq.keys()}
    key_list = sorted(list(ngram_cumulative_freq.keys()), key=lambda x : x)
    cumul = 0
    for key in key_list:
        cumul += ngram_cumulative_freq[key]
        ngram_cumulative_freq[key] = cumul

    
    return ngram_cumulative_freq


cumul_monogram = compute_cumul_freq_monogram(monogram_frequency)
cumul_bigram = compute_cumul_freq_bigram(bigram_frequency)
cumul_monogram
# Out:
# {150: 1519.9999999999995,
#  104: 1447.7142857142853,
#  20: 1086.2857142857142,
#  27: 1230.8571428571427,
#  2: 86.28571428571428,
#  1: 24.61904761904762,
#  5: 294.42857142857144,
#  4: 223.52380952380952,
#  3: 153.8095238095238,
#  15: 941.7619047619047,
#  13: 869.5714285714286,
#  7: 437.0,
#  8: 508.76190476190476,
#  10: 652.9047619047619,
#  38: 1303.1428571428569,
#  6: 365.61904761904765,
#  82: 1375.428571428571,
#  23: 1158.5714285714284,
#  9: 580.7619047619048,
#  11: 725.0952380952381,
#  12: 797.3809523809524,
#  16: 1014.0}

# %% [markdown]
# ## High Word Occurence (*HWO*)
#
# HWO is defined as $HWO(w) = C_{iw}(n) / C_{iw}(N_{max})$
#
# Cw is the cumulative frequency of an individual word.
#
# Here, $C_{iw}(n) = \sum_{i-1}^{n}F_{iw}(i)$

# %%
def HWO(word, monogram_frequency, cumul_monogram):
    key_max = max(list(cumul_monogram.keys()))
    return cumul_monogram[monogram_frequency[word]]/cumul_monogram[key_max]

# %%
hwo = {word: HWO(word, monogram_frequency, cumul_monogram) for word in word_list}
hwo
# Out:
# {'mobile': 1.0,
#  'phone': 0.9524436090225564,
#  'cellular': 0.7146616541353386,
#  'cell': 0.8097744360902257,
#  'cellphone': 0.0567669172932331,
#  'handphone': 0.016196741854636598,
#  'hand': 0.19370300751879707,
#  'shortened': 0.016196741854636598,
#  'simply': 0.14705513784461158,
#  'portable': 0.1011904761904762,
#  'telephone': 0.6195802005012533,
#  'receive': 0.016196741854636598,
#  'calls': 0.5720864661654137,
#  'radio': 0.19370300751879707,
#  'frequency': 0.2875000000000001,
#  'link': 0.0567669172932331,
#  'user': 0.3347117794486216,
#  'moving': 0.016196741854636598,
#  'service': 0.5720864661654137,
#  'area': 0.14705513784461158,
#  'establishes': 0.016196741854636598,
#  'connection': 0.0567669172932331,
#  'switching': 0.016196741854636598,
#  'systems': 0.2875000000000001,
#  'operator': 0.19370300751879707,
#  'provides': 0.0567669172932331,
#  'access': 0.2875000000000001,
#  'public': 0.14705513784461158,
#  'switched': 0.016196741854636598,
#  'network': 0.4295426065162909,
#  'pstn': 0.016196741854636598,
#  'modern': 0.19370300751879707,
#  'services': 0.2875000000000001,
#  'use': 0.8573308270676693,
#  'architecture': 0.016196741854636598,
#  'telephones': 0.0567669172932331,
#  'called': 0.24053884711779458,
#  'phones': 0.9048872180451129,
#  'north': 0.0567669172932331,
#  'america': 0.0567669172932331,
#  'addition': 0.14705513784461158,
#  'telephony': 0.24053884711779458,
#  'digital': 0.4295426065162909,
#  'g': 0.7622180451127821,
#  'support': 0.1011904761904762,
#  'variety': 0.14705513784461158,
#  'text': 0.3820802005012533,
#  'messaging': 0.2875000000000001,
#  'mms': 0.0567669172932331,
#  'email': 0.016196741854636598,
#  'internet': 0.3347117794486216,
#  'shortrange': 0.0567669172932331,
#  'wireless': 0.2875000000000001,
#  'communications': 0.24053884711779458,
#  'infrared': 0.016196741854636598,
#  'bluetooth': 0.016196741854636598,
#  'business': 0.24053884711779458,
#  'applications': 0.24053884711779458,
#  'video': 0.19370300751879707,
#  'games': 0.1011904761904762,
#  'photography': 0.016196741854636598,
#  'offering': 0.016196741854636598,
#  'capabilities': 0.19370300751879707,
#  'known': 0.1011904761904762,
#  'feature': 0.5720864661654137,
#  'offer': 0.0567669172932331,
#  'greatly': 0.14705513784461158,
#  'advanced': 0.14705513784461158,
#  'computing': 0.0567669172932331,
#  'referred': 0.0567669172932331,
#  'smartphones': 0.6195802005012533,
#  'development': 0.19370300751879707,
#  'metaloxidesemiconductor': 0.1011904761904762,
#  'mos': 0.1011904761904762,
#  'largescale': 0.0567669172932331,
#  'integration': 0.0567669172932331,
#  'lsi': 0.0567669172932331,
#  'technology': 0.3820802005012533,
#  'information': 0.19370300751879707,
#  'theory': 0.0567669172932331,
#  'networking': 0.0567669172932331,
#  'led': 0.14705513784461158,
#  'affordable': 0.0567669172932331,
#  'handheld': 0.6195802005012533,
#  'demonstrated': 0.1011904761904762,
#  'john': 0.0567669172932331,
#  'f': 0.0567669172932331,
#  'mitchell': 0.0567669172932331,
#  'martin': 0.1011904761904762,
#  'cooper': 0.1011904761904762,
#  'motorola': 0.24053884711779458,
#  'handset': 0.14705513784461158,
#  'weighing': 0.0567669172932331,
#  'c': 0.016196741854636598,
#  'kilograms': 0.0567669172932331,
#  'lbs': 0.016196741854636598,
#  'nippon': 0.0567669172932331,
#  'telegraph': 0.0567669172932331,
#  'ntt': 0.0567669172932331,
#  'launched': 0.3347117794486216,
#  'worlds': 0.1011904761904762,
#  'japancitation': 0.016196741854636598,
#  'needed': 0.3820802005012533,
#  'dynatac': 0.14705513784461158,
#  'x': 0.1011904761904762,
#  'commercially': 0.14705513784461158,
#  'available': 0.3820802005012533,
#  'worldwide': 0.2875000000000001,
#  'subscriptions': 0.14705513784461158,
#  'grew': 0.016196741854636598,
#  'seven': 0.0567669172932331,
#  'billion': 0.1011904761904762,
#  'provide': 0.14705513784461158,
#  'person': 0.14705513784461158,
#  'earth': 0.016196741854636598,
#  'quarter': 0.016196741854636598,
#  'smartphone': 0.4770363408521305,
#  'developers': 0.0567669172932331,
#  'samsung': 0.2875000000000001,
#  'apple': 0.24053884711779458,
#  'huawei': 0.14705513784461158,
#  'sales': 0.19370300751879707,
#  'represented': 0.016196741854636598,
#  'percent': 0.016196741854636598,
#  'total': 0.016196741854636598,
#  'slang': 0.016196741854636598,
#  'dumbphones': 0.016196741854636598,
#  'largest': 0.0567669172932331,
#  'nokia': 0.1011904761904762,
#  'alcatel': 0.016196741854636598,
#  'history': 0.016196741854636598,
#  'shown': 0.1011904761904762,
#  'reenactment': 0.016196741854636598,
#  'publicized': 0.016196741854636598,
#  'prototype': 0.016196741854636598,
#  'model': 0.016196741854636598,
#  'april': 0.016196741854636598,
#  'envisioned': 0.016196741854636598,
#  'early': 0.19370300751879707,
#  'stages': 0.016196741854636598,
#  'engineering': 0.016196741854636598,
#  'finnish': 0.0567669172932331,
#  'inventor': 0.016196741854636598,
#  'eric': 0.0567669172932331,
#  'tigerstedt': 0.016196741854636598,
#  'filed': 0.016196741854636598,
#  'patent': 0.016196741854636598,
#  'pocketsize': 0.016196741854636598,
#  'folding': 0.016196741854636598,
#  'thin': 0.016196741854636598,
#  'carbon': 0.016196741854636598,
#  'microphone': 0.016196741854636598,
#  'predecessors': 0.016196741854636598,
#  'included': 0.016196741854636598,
#  'analog': 0.1011904761904762,
#  'ships': 0.016196741854636598,
#  'trains': 0.016196741854636598,
#  'race': 0.016196741854636598,
#  'create': 0.016196741854636598,
#  'truly': 0.016196741854636598,
#  'devices': 0.4770363408521305,
#  'began': 0.0567669172932331,
#  'world': 0.3347117794486216,
#  'war': 0.14705513784461158,
#  'ii': 0.016196741854636598,
#  'developments': 0.016196741854636598,
#  'taking': 0.016196741854636598,
#  'place': 0.1011904761904762,
#  'countries': 0.5245927318295741,
#  'advances': 0.0567669172932331,
#  'traced': 0.016196741854636598,
#  'successive': 0.016196741854636598,
#  'generations': 0.016196741854636598,
#  'starting': 0.016196741854636598,
#  'zerothgeneration': 0.016196741854636598,
#  'bell': 0.016196741854636598,
#  'successor': 0.016196741854636598,
#  'improved': 0.0567669172932331,
#  'supported': 0.016196741854636598,
#  'simultaneous': 0.19370300751879707,
#  'expensive': 0.016196741854636598,
#  'car': 0.0567669172932331,
#  'lb': 0.016196741854636598,
#  'commercial': 0.1011904761904762,
#  'automated': 0.016196741854636598,
#  'japan': 0.14705513784461158,
#  'followed': 0.1011904761904762,
#  'launch': 0.0567669172932331,
#  'nordic': 0.016196741854636598,
#  'nmt': 0.016196741854636598,
#  'system': 0.14705513784461158,
#  'denmark': 0.016196741854636598,
#  'finland': 0.24053884711779458,
#  'norway': 0.016196741854636598,
#  'sweden': 0.016196741854636598,
#  'mids': 0.016196741854636598,
#  'firstgeneration': 0.016196741854636598,
#  'far': 0.016196741854636598,
#  'networks': 0.3347117794486216,
#  'appeared': 0.1011904761904762,
#  's': 0.016196741854636598,
#  'enabled': 0.0567669172932331,
#  'wide': 0.016196741854636598,
#  'adoption': 0.016196741854636598,
#  'mosfetbased': 0.016196741854636598,
#  'rf': 0.14705513784461158,
#  'power': 0.14705513784461158,
#  'amplifiers': 0.016196741854636598,
#  'mosfet': 0.016196741854636598,
#  'ldmos': 0.016196741854636598,
#  'circuits': 0.0567669172932331,
#  'cmos': 0.016196741854636598,
#  'leading': 0.016196741854636598,
#  'introduction': 0.0567669172932331,
#  'signal': 0.0567669172932331,
#  'processing': 0.14705513784461158,
#  'secondgeneration': 0.016196741854636598,
#  'radiolinja': 0.0567669172932331,
#  'gsm': 0.24053884711779458,
#  'standard': 0.2875000000000001,
#  'sparked': 0.016196741854636598,
#  'competition': 0.016196741854636598,
#  'sector': 0.016196741854636598,
#  'new': 0.24053884711779458,
#  'operators': 0.24053884711779458,
#  'challenged': 0.016196741854636598,
#  'incumbent': 0.016196741854636598,
#  'european': 0.1011904761904762,
#  'initiative': 0.016196741854636598,
#  'expressed': 0.016196741854636598,
#  'cept': 0.016196741854636598,
#  'conférence': 0.016196741854636598,
#  'européenne': 0.016196741854636598,
#  'des': 0.016196741854636598,
#  'postes': 0.016196741854636598,
#  'et': 0.016196741854636598,
#  'telecommunications': 0.0567669172932331,
#  'postal': 0.016196741854636598,
#  'conference': 0.016196741854636598,
#  'francogerman': 0.016196741854636598,
#  'rd': 0.016196741854636598,
#  'cooperation': 0.0567669172932331,
#  'technical': 0.016196741854636598,
#  'feasibility': 0.016196741854636598,
#  'memorandum': 0.016196741854636598,
#  'understanding': 0.016196741854636598,
#  'signed': 0.016196741854636598,
#  'agreed': 0.016196741854636598,
#  'version': 0.016196741854636598,
#  'pages': 0.016196741854636598,
#  'ieeerse': 0.016196741854636598,
#  'awarded': 0.016196741854636598,
#  'thomas': 0.016196741854636598,
#  'haug': 0.016196741854636598,
#  'philippe': 0.016196741854636598,
#  'dupuis': 0.016196741854636598,
#  'james': 0.016196741854636598,
#  'clerk': 0.016196741854636598,
#  'maxwell': 0.016196741854636598,
#  'medal': 0.016196741854636598,
#  'contributions': 0.016196741854636598,
#  'people': 0.24053884711779458,
#  'evolved': 0.016196741854636598,
#  'lithiumion': 0.1011904761904762,
#  'battery': 0.4295426065162909,
#  'indispensable': 0.016196741854636598,
#  'energy': 0.016196741854636598,
#  'source': 0.1011904761904762,
#  'commercialized': 0.016196741854636598,
#  'sony': 0.016196741854636598,
#  'asahi': 0.016196741854636598,
#  'kasei': 0.016196741854636598,
#  'generation': 0.0567669172932331,
#  'docomo': 0.016196741854636598,
#  'wcdma': 0.016196741854636598,
#  'turbo': 0.016196741854636598,
#  'enhancements': 0.016196741854636598,
#  'based': 0.016196741854636598,
#  'highspeed': 0.016196741854636598,
#  'packet': 0.016196741854636598,
#  'hspa': 0.016196741854636598,
#  'family': 0.1011904761904762,
#  'allowing': 0.016196741854636598,
#  'umts': 0.016196741854636598,
#  'higher': 0.016196741854636598,
#  'data': 0.19370300751879707,
#  'transfer': 0.0567669172932331,
#  'speeds': 0.016196741854636598,
#  'capacity': 0.1011904761904762,
#  'clear': 0.016196741854636598,
#  'point': 0.1011904761904762,
#  'overwhelmed': 0.016196741854636598,
#  'growth': 0.0567669172932331,
#  'bandwidthintensive': 0.016196741854636598,
#  'streaming': 0.016196741854636598,
#  'media': 0.14705513784461158,
#  'consequently': 0.016196741854636598,
#  'industry': 0.14705513784461158,
#  'looking': 0.0567669172932331,
#  'dataoptimized': 0.016196741854636598,
#  'fourthgeneration': 0.016196741854636598,
#  'technologies': 0.1011904761904762,
#  'promise': 0.016196741854636598,
#  'speed': 0.016196741854636598,
#  'improvements': 0.016196741854636598,
#  'tenfold': 0.016196741854636598,
#  'existing': 0.016196741854636598,
#  'billed': 0.016196741854636598,
#  'wimax': 0.0567669172932331,
#  'offered': 0.1011904761904762,
#  'sprint': 0.016196741854636598,
#  'lte': 0.0567669172932331,
#  'scandinavia': 0.016196741854636598,
#  'teliasonera': 0.016196741854636598,
#  'term': 0.19370300751879707,
#  'research': 0.14705513784461158,
#  'papers': 0.016196741854636598,
#  'projects': 0.016196741854636598,
#  'denote': 0.016196741854636598,
#  'major': 0.1011904761904762,
#  'phase': 0.016196741854636598,
#  'telecommunication': 0.14705513784461158,
#  'standards': 0.1011904761904762,
#  'gimtadvanced': 0.016196741854636598,
#  'officially': 0.016196741854636598,
#  'specification': 0.016196741854636598,
#  'official': 0.0567669172932331,
#  'document': 0.016196741854636598,
#  'companies': 0.14705513784461158,
#  'standardization': 0.0567669172932331,
#  'bodies': 0.0567669172932331,
#  'gpp': 0.016196741854636598,
#  'forum': 0.016196741854636598,
#  'itur': 0.016196741854636598,
#  'currently': 0.016196741854636598,
#  'developed': 0.14705513784461158,
#  'time': 0.14705513784461158,
#  'seen': 0.016196741854636598,
#  'umbrella': 0.016196741854636598,
#  'types': 0.016196741854636598,
#  'active': 0.0567669172932331,
#  'broadband': 0.0567669172932331,
#  'inhabitants': 0.0567669172932331,
#  'number': 0.3820802005012533,
#  'distinguishing': 0.016196741854636598,
#  'features': 0.14705513784461158,
#  'international': 0.1011904761904762,
#  'union': 0.016196741854636598,
#  'measures': 0.016196741854636598,
#  'mobilebroadband': 0.016196741854636598,
#  'includes': 0.016196741854636598,
#  'tablets': 0.016196741854636598,
#  'etc': 0.0567669172932331,
#  'overtaken': 0.016196741854636598,
#  'usage': 0.24053884711779458,
#  'earlier': 0.016196741854636598,
#  'developing': 0.1011904761904762,
#  'account': 0.016196741854636598,
#  'typically': 0.2875000000000001,
#  'retronym': 0.016196741854636598,
#  'describe': 0.016196741854636598,
#  'limited': 0.0567669172932331,
#  'contrast': 0.0567669172932331,
#  'voice': 0.14705513784461158,
#  'calling': 0.14705513784461158,
#  'functionality': 0.016196741854636598,
#  'basic': 0.19370300751879707,
#  'multimedia': 0.0567669172932331,
#  'users': 0.24053884711779458,
#  'provider': 0.0567669172932331,
#  'additional': 0.0567669172932331,
#  'functions': 0.0567669172932331,
#  'capable': 0.016196741854636598,
#  'tend': 0.016196741854636598,
#  'proprietary': 0.016196741854636598,
#  'customdesigned': 0.016196741854636598,
#  'software': 0.3347117794486216,
#  'interface': 0.016196741854636598,
#  'generally': 0.14705513784461158,
#  'operating': 0.14705513784461158,
#  'shares': 0.016196741854636598,
#  'common': 0.3347117794486216,
#  'traits': 0.016196741854636598,
#  'infrastructure': 0.0567669172932331,
#  'communicate': 0.016196741854636598,
#  'towers': 0.19370300751879707,
#  'placed': 0.1011904761904762,
#  'coverage': 0.0567669172932331,
#  'divided': 0.016196741854636598,
#  'cells': 0.19370300751879707,
#  'uses': 0.2875000000000001,
#  'different': 0.19370300751879707,
#  'set': 0.0567669172932331,
#  'frequencies': 0.14705513784461158,
#  'neighboring': 0.016196741854636598,
#  'covered': 0.016196741854636598,
#  'locations': 0.016196741854636598,
#  'usually': 0.1011904761904762,
#  'interconnected': 0.016196741854636598,
#  'wired': 0.016196741854636598,
#  'connections': 0.016196741854636598,
#  'bandwidth': 0.016196741854636598,
#  'limitations': 0.016196741854636598,
#  'maximum': 0.016196741854636598,
#  'handle': 0.0567669172932331,
#  'sized': 0.016196741854636598,
#  'depending': 0.14705513784461158,
#  'expected': 0.0567669172932331,
#  'density': 0.016196741854636598,
#  'smaller': 0.0567669172932331,
#  'cities': 0.0567669172932331,
#  'case': 0.016196741854636598,
#  'lower': 0.016196741854636598,
#  'transmitter': 0.016196741854636598,
#  'powers': 0.016196741854636598,
#  'avoid': 0.016196741854636598,
#  'broadcasting': 0.016196741854636598,
#  'order': 0.14705513784461158,
#  'high': 0.0567669172932331,
#  'traffic': 0.14705513784461158,
#  'multiple': 0.14705513784461158,
#  'permanently': 0.016196741854636598,
#  'temporarily': 0.016196741854636598,
#  'special': 0.016196741854636598,
#  'events': 0.1011904761904762,
#  'like': 0.1011904761904762,
#  'super': 0.016196741854636598,
#  'bowl': 0.016196741854636598,
#  'taste': 0.016196741854636598,
#  'chicago': 0.016196741854636598,
#  'state': 0.1011904761904762,
#  'fair': 0.016196741854636598,
#  'nyc': 0.016196741854636598,
#  'years': 0.19370300751879707,
#  'eve': 0.016196741854636598,
#  'hurricane': 0.016196741854636598,
#  'hit': 0.016196741854636598,
#  'bring': 0.016196741854636598,
#  'truck': 0.016196741854636598,
#  'equipment': 0.016196741854636598,
#  'host': 0.0567669172932331,
#  'abnormally': 0.016196741854636598,
#  'increase': 0.3820802005012533,
#  'company': 0.1011904761904762,
#  'example': 0.3347117794486216,
#  'license': 0.0567669172932331,
#  'unique': 0.1011904761904762,
#  'communicating': 0.016196741854636598,
#  'slightly': 0.016196741854636598,
#  'overlap': 0.016196741854636598,
#  'reused': 0.016196741854636598,
#  'door': 0.0567669172932331,
#  'reuse': 0.0567669172932331,
#  'touching': 0.016196741854636598,
#  'overlapcommunicate': 0.016196741854636598,
#  'frequenciescitation': 0.016196741854636598,
#  'increased': 0.0567669172932331,
#  'implemented': 0.016196741854636598,
#  'increasing': 0.0567669172932331,
#  'moves': 0.016196741854636598,
#  'automatically': 0.016196741854636598,
#  'disconnect': 0.016196741854636598,
#  'reconnect': 0.016196741854636598,
#  'tower': 0.016196741854636598,
#  'gives': 0.016196741854636598,
#  'best': 0.0567669172932331,
#  'reception': 0.016196741854636598,
#  'additionally': 0.016196741854636598,
#  'wifi': 0.0567669172932331,
#  'possible': 0.016196741854636598,
#  'offloads': 0.016196741854636598,
#  'local': 0.1011904761904762,
#  'hardware': 0.0567669172932331,
#  'components': 0.016196741854636598,
#  'found': 0.2875000000000001,
#  'central': 0.14705513784461158,
#  'unit': 0.1011904761904762,
#  'cpu': 0.1011904761904762,
#  'processor': 0.016196741854636598,
#  'microprocessor': 0.016196741854636598,
#  'fabricated': 0.016196741854636598,
#  'integrated': 0.1011904761904762,
#  'circuit': 0.0567669172932331,
#  'ic': 0.016196741854636598,
#  'chip': 0.016196741854636598,
#  'providing': 0.24053884711779458,
#  'lib': 0.016196741854636598,
#  'older': 0.016196741854636598,
#  'handsets': 0.1011904761904762,
#  'nickelmetal': 0.016196741854636598,
#  'hydride': 0.016196741854636598,
#  'nimh': 0.016196741854636598,
#  'batteries': 0.0567669172932331,
#  'input': 0.016196741854636598,
#  'mechanism': 0.016196741854636598,
#  'allow': 0.0567669172932331,
#  'interact': 0.016196741854636598,
#  'keypad': 0.016196741854636598,
#  'touch': 0.14705513784461158,
#  'screens': 0.1011904761904762,
#  'capacitive': 0.016196741854636598,
#  'sensing': 0.016196741854636598,
#  'display': 0.19370300751879707,
#  'echoes': 0.016196741854636598,
#  'typing': 0.016196741854636598,
#  'displays': 0.24053884711779458,
#  'messages': 0.0567669172932331,
#  'contacts': 0.016196741854636598,
#  'liquidcrystal': 0.0567669172932331,
#  'lcd': 0.016196741854636598,
#  'organic': 0.016196741854636598,
#  'lightemitting': 0.016196741854636598,
#  'diode': 0.016196741854636598,
#  'oled': 0.0567669172932331,
#  'speakers': 0.1011904761904762,
#  'sound': 0.14705513784461158,
#  'subscriber': 0.0567669172932331,
#  'identity': 0.1011904761904762,
#  'module': 0.1011904761904762,
#  'sim': 0.667105263157895,
#  'cards': 0.24053884711779458,
#  'removable': 0.016196741854636598,
#  'ruim': 0.0567669172932331,
#  'notification': 0.016196741854636598,
#  'lowend': 0.016196741854636598,
#  'ability': 0.0567669172932331,
#  'native': 0.016196741854636598,
#  'units': 0.1011904761904762,
#  'cpus': 0.0567669172932331,
#  'similar': 0.19370300751879707,
#  'computers': 0.0567669172932331,
#  'optimised': 0.016196741854636598,
#  'operate': 0.016196741854636598,
#  'low': 0.016196741854636598,
#  'environments': 0.016196741854636598,
#  'performance': 0.24053884711779458,
#  'depends': 0.016196741854636598,
#  'clock': 0.016196741854636598,
#  'rate': 0.0567669172932331,
#  'given': 0.0567669172932331,
#  'multiples': 0.016196741854636598,
#  'hertz': 0.016196741854636598,
#  'memory': 0.016196741854636598,
#  'hierarchy': 0.016196741854636598,
#  'affects': 0.016196741854636598,
#  'overall': 0.016196741854636598,
#  'problems': 0.016196741854636598,
#  'appropriately': 0.016196741854636598,
#  'scores': 0.016196741854636598,
#  'derived': 0.016196741854636598,
#  'standardized': 0.016196741854636598,
#  'tests': 0.016196741854636598,
#  'measure': 0.016196741854636598,
#  'real': 0.016196741854636598,
#  'effective': 0.016196741854636598,
#  'commonly': 0.1011904761904762,
#  'main': 0.016196741854636598,
#  'characteristics': 0.016196741854636598,
#  'screen': 0.2875000000000001,
#  'type': 0.0567669172932331,
#  'design': 0.1011904761904762,
#  'fills': 0.016196741854636598,
#  'nearly': 0.1011904761904762,
#  'space': 0.016196741854636598,
#  'surface': 0.0567669172932331,
#  'aspect': 0.1011904761904762,
#  'ratio': 0.016196741854636598,
#  'taller': 0.0567669172932331,
#  'ratios': 0.0567669172932331,
#  'sizes': 0.14705513784461158,
#  'measured': 0.016196741854636598,
#  'diagonal': 0.016196741854636598,
#  'inches': 0.016196741854636598,
#  'millimeters': 0.016196741854636598,
#  'millimetres': 0.1011904761904762,
#  'larger': 0.0567669172932331,
#  'phablets': 0.016196741854636598,
#  'size': 0.0567669172932331,
#  'difficult': 0.016196741854636598,
#  'single': 0.0567669172932331,
#  'thumbs': 0.016196741854636598,
#  'reach': 0.016196741854636598,
#  'entire': 0.016196741854636598,
#  'need': 0.0567669172932331,
#  'shifted': 0.016196741854636598,
#  'held': 0.016196741854636598,
#  'manipulated': 0.016196741854636598,
#  'hands': 0.016196741854636598,
#  'large': 0.0567669172932331,
#  'edgetoedge': 0.016196741854636598,
#  'designs': 0.016196741854636598,
#  'compact': 0.016196741854636598,
#  'builds': 0.016196741854636598,
#  'improve': 0.0567669172932331,
#  'ergonomics': 0.0567669172932331,
#  'shift': 0.016196741854636598,
#  'resulted': 0.0567669172932331,
#  'whilst': 0.016196741854636598,
#  'maintaining': 0.016196741854636598,
#  'associated': 0.016196741854636598,
#  'ips': 0.016196741854636598,
#  'amoled': 0.016196741854636598,
#  'pressuresensitive': 0.016196741854636598,
#  'digitizers': 0.016196741854636598,
#  'wacom': 0.016196741854636598,
#  'apples': 0.0567669172932331,
#  'd': 0.016196741854636598,
#  'vary': 0.016196741854636598,
#  'little': 0.016196741854636598,
#  'audioquality': 0.016196741854636598,
#  'enhancing': 0.016196741854636598,
#  'hd': 0.016196741854636598,
#  'newer': 0.016196741854636598,
#  'quality': 0.1011904761904762,
#  'remain': 0.016196741854636598,
#  'problem': 0.016196741854636598,
#  'compression': 0.016196741854636598,
#  'algorithms': 0.016196741854636598,
#  'longdistance': 0.0567669172932331,
#  'audio': 0.1011904761904762,
#  'voip': 0.016196741854636598,
#  'application': 0.2875000000000001,
#  'cellphones': 0.1011904761904762,
#  'small': 0.19370300751879707,
#  'speakerphone': 0.0567669172932331,
#  'talk': 0.016196741854636598,
#  'holding': 0.0567669172932331,
#  'ear': 0.0567669172932331,
#  'listen': 0.0567669172932331,
#  'files': 0.016196741854636598,
#  'music': 0.0567669172932331,
#  'speech': 0.016196741854636598,
#  'watch': 0.016196741854636598,
#  'videos': 0.016196741854636598,
#  'component': 0.016196741854636598,
#  'close': 0.016196741854636598,
#  'average': 0.1011904761904762,
#  'lasts': 0.016196741854636598,
#  'liion': 0.016196741854636598,
#  'charges': 0.016196741854636598,
#  'times': 0.0567669172932331,
#  'care': 0.016196741854636598,
#  'charging': 0.016196741854636598,
#  'techniques': 0.016196741854636598,
#  'natural': 0.0567669172932331,
#  'rechargeable': 0.016196741854636598,
#  'chemically': 0.016196741854636598,
#  'age': 0.0567669172932331,
#  'year': 0.1011904761904762,
#  'begin': 0.016196741854636598,
#  'deteriorate': 0.016196741854636598,
#  'life': 0.016196741854636598,
#  'extended': 0.016196741854636598,
#  'draining': 0.016196741854636598,
#  'regularly': 0.016196741854636598,
#  'overcharging': 0.016196741854636598,
#  'keeping': 0.0567669172932331,
#  'away': 0.016196741854636598,
#  'heat': 0.016196741854636598,
#  'card': 0.4295426065162909,
#  'require': 0.016196741854636598,
#  'microchip': 0.016196741854636598,
#  'function': 0.0567669172932331,
#  'approximately': 0.0567669172932331,
#  'postage': 0.016196741854636598,
#  'stamp': 0.016196741854636598,
#  'underneath': 0.016196741854636598,
#  'rear': 0.016196741854636598,
#  'securely': 0.016196741854636598,
#  'stores': 0.14705513784461158,
#  'servicesubscriber': 0.016196741854636598,
#  'key': 0.016196741854636598,
#  'imsi': 0.016196741854636598,
#  'ki': 0.016196741854636598,
#  'identify': 0.016196741854636598,
#  'authenticate': 0.016196741854636598,
#  'allows': 0.1011904761904762,
#  'change': 0.016196741854636598,
#  'removing': 0.016196741854636598,
#  'inserting': 0.016196741854636598,
#  'device': 0.19370300751879707,
#  'provided': 0.0567669172932331,
#  'prevented': 0.016196741854636598,
#  'lock': 0.016196741854636598,
#  'munich': 0.016196741854636598,
#  'smart': 0.0567669172932331,
#  'maker': 0.016196741854636598,
#  'giesecke': 0.016196741854636598,
#  'devrient': 0.016196741854636598,
#  'radiolinjacitation': 0.016196741854636598,
#  'hybrid': 0.016196741854636598,
#  'hold': 0.1011904761904762,
#  'having': 0.016196741854636598,
#  'imei': 0.19370300751879707,
#  'mixed': 0.016196741854636598,
#  'cdma': 0.016196741854636598,
#  'accessed': 0.0567669172932331,
#  'onwards': 0.016196741854636598,
#  'popular': 0.016196741854636598,
#  'emerging': 0.0567669172932331,
#  'markets': 0.016196741854636598,
#  'attributed': 0.016196741854636598,
#  'desire': 0.016196741854636598,
#  'obtain': 0.016196741854636598,
#  'lowest': 0.016196741854636598,
#  'onnet': 0.016196741854636598,
#  'platforms': 0.14705513784461158,
#  'section': 0.1011904761904762,
#  'needs': 0.1011904761904762,
#  'expansion': 0.016196741854636598,
#  'help': 0.016196741854636598,
#  'adding': 0.016196741854636598,
#  'october': 0.0567669172932331,
#  'android': 0.0567669172932331,
#  'os': 0.0567669172932331,
#  'bestselling': 0.016196741854636598,
#  'app': 0.3347117794486216,
#  'computer': 0.1011904761904762,
#  'program': 0.016196741854636598,
#  'designed': 0.0567669172932331,
#  'run': 0.016196741854636598,
#  'shortening': 0.016196741854636598,
#  'short': 0.016196741854636598,
#  'message': 0.14705513784461158,
#  'sms': 0.2875000000000001,
#  'sent': 0.0567669172932331,
#  'uk': 0.1011904761904762,
#  'persontoperson': 0.016196741854636598,
#  'news': 0.19370300751879707,
#  'delivered': 0.016196741854636598,
#  'citation': 0.0567669172932331,
#  'subsequently': 0.016196741854636598,
#  'organizations': 0.0567669172932331,
#  'ondemand': 0.016196741854636598,
#  'instant': 0.016196741854636598,
#  'introduced': 0.14705513784461158,
#  'store': 0.1011904761904762,
#  'iphone': 0.0567669172932331,
#  'ipod': 0.016196741854636598,
#  'july': 0.1011904761904762,
#  'popularized': 0.016196741854636598,
#  'manufacturerhosted': 0.016196741854636598,
#  'online': 0.0567669172932331,
#  'distribution': 0.1011904761904762,
#  'thirdparty': 0.0567669172932331,
#  'programs': 0.016196741854636598,
#  'focused': 0.016196741854636598,
#  'platform': 0.0567669172932331,
#  'huge': 0.016196741854636598,
#  'apps': 0.0567669172932331,
#  'including': 0.24053884711779458,
#  'products': 0.016196741854636598,
#  'tools': 0.016196741854636598,
#  'depended': 0.016196741854636598,
#  'sources': 0.016196741854636598,
#  'getjar': 0.016196741854636598,
#  'handango': 0.016196741854636598,
#  'handmark': 0.016196741854636598,
#  'pocketgear': 0.016196741854636598,
#  'following': 0.016196741854636598,
#  'success': 0.016196741854636598,
#  'manufacturers': 0.24053884711779458,
#  'googles': 0.016196741854636598,
#  'market': 0.19370300751879707,
#  'later': 0.016196741854636598,
#  'renamed': 0.016196741854636598,
#  'google': 0.016196741854636598,
#  'play': 0.0567669172932331,
#  'rims': 0.016196741854636598,
#  'blackberry': 0.016196741854636598,
#  'androidrelated': 0.016196741854636598,
#  'fdroid': 0.016196741854636598,
#  'february': 0.0567669172932331,
#  'targeting': 0.016196741854636598,
#  'updated': 0.016196741854636598,
#  'update': 0.0567669172932331,
#  'article': 0.016196741854636598,
#  'reflect': 0.016196741854636598,
#  'recent': 0.0567669172932331,
#  'newly': 0.016196741854636598,
#  'statistics': 0.016196741854636598,
#  'mid': 0.016196741854636598,
#  'parts': 0.0567669172932331,
#  'august': 0.016196741854636598,
#  'manufacturer': 0.1011904761904762,
#  'share': 0.0567669172932331,
#  'topfive': 0.016196741854636598,
#  'vendors': 0.1011904761904762,
#  'q': 0.1011904761904762,
#  'rank': 0.016196741854636598,
#  'strategy': 0.016196741854636598,
#  'analytics': 0.016196741854636598,
#  'report': 0.14705513784461158,
#  'oppo': 0.0567669172932331,
#  'xiaomi': 0.016196741854636598,
#  'note': 0.016196741854636598,
#  'vendor': 0.016196741854636598,
#  'shipments': 0.0567669172932331,
#  'branded': 0.016196741854636598,
#  'exclude': 0.016196741854636598,
#  'oem': 0.016196741854636598,
#  'leader': 0.0567669172932331,
#  'surpassed': 0.016196741854636598,
#  'selling': 0.1011904761904762,
#  'million': 0.24053884711779458,
#  'nokias': 0.016196741854636598,
#  'retained': 0.016196741854636598,
#  'position': 0.0567669172932331,
#  'vivo': 0.016196741854636598,
#  'overtook': 0.016196741854636598,
#  'secondlargest': 0.016196741854636598,
#  'subscribers': 0.3347117794486216,
#  'country': 0.1011904761904762,
#  'individual': 0.0567669172932331,
#  'china': 0.0567669172932331,
#  'june': 0.1011904761904762,
#  'end': 0.016196741854636598,
#  'growing': 0.016196741854636598,
#  'figure': 0.016196741854636598,
#  'estimated': 0.1011904761904762,
#  'purposes': 0.0567669172932331,
#  'members': 0.14705513784461158,
#  'conducting': 0.016196741854636598,
#  'event': 0.016196741854636598,
#  'emergency': 0.016196741854636598,
#  'carry': 0.016196741854636598,
#  'personal': 0.016196741854636598,
#  'advantage': 0.016196741854636598,
#  'benefits': 0.1011904761904762,
#  'plans': 0.016196741854636598,
#  'particular': 0.0567669172932331,
#  'plan': 0.016196741854636598,
#  'cheaper': 0.016196741854636598,
#  'roaming': 0.016196741854636598,
#  'diverse': 0.016196741854636598,
#  'contexts': 0.016196741854636598,
#  'society': 0.016196741854636598,
#  'study': 0.4770363408521305,
#  'second': 0.1011904761904762,
#  'kept': 0.016196741854636598,
#  'secret': 0.016196741854636598,
#  'engage': 0.016196741854636598,
#  'activities': 0.0567669172932331,
#  'extramarital': 0.016196741854636598,
#  'affairs': 0.016196741854636598,
#  'clandestine': 0.016196741854636598,
#  'dealings': 0.016196741854636598,
#  'assist': 0.016196741854636598,
#  'victims': 0.016196741854636598,
#  'domestic': 0.016196741854636598,
#  'violence': 0.016196741854636598,
#  'emergencies': 0.016196741854636598,
#  'refurbished': 0.016196741854636598,
#  'advent': 0.016196741854636598,
#  'widespread': 0.016196741854636598,
#  'textmessaging': 0.0567669172932331,
#  'novel': 0.016196741854636598,
#  'literary': 0.016196741854636598,
#  'genre': 0.016196741854636598,
#  'emerge': 0.016196741854636598,
#  'website': 0.016196741854636598,
#  'collects': 0.016196741854636598,
#  'novels': 0.016196741854636598,
#  'facilitates': 0.016196741854636598,
#  'activism': 0.016196741854636598,
#  'citizen': 0.016196741854636598,
#  'journalism': 0.016196741854636598,
#  'united': 0.19370300751879707,
#  'nations': 0.016196741854636598,
#  'reported': 0.3347117794486216,
#  'spread': 0.0567669172932331,
#  'faster': 0.016196741854636598,
#  'form': 0.016196741854636598,
#  'livelihood': 0.016196741854636598,
#  'poorest': 0.016196741854636598,
#  'places': 0.016196741854636598,
#  'landlines': 0.016196741854636598,
#  'especially': 0.016196741854636598,
#  'spawns': 0.016196741854636598,
#  'wealth': 0.016196741854636598,
#  'microenterprises': 0.016196741854636598,
#  'work': 0.0567669172932331,
#  'airtime': 0.016196741854636598,
#  'streets': 0.016196741854636598,
#  'repairing': 0.016196741854636598,
#  'refurbishing': 0.016196741854636598,
#  'mali': 0.016196741854636598,
#  'african': 0.016196741854636598,
#  'travel': 0.0567669172932331,
#  'village': 0.14705513784461158,
#  'let': 0.016196741854636598,
#  'friends': 0.0567669172932331,
#  'relatives': 0.016196741854636598,
#  'know': 0.016196741854636598,
#  'weddings': 0.016196741854636598,
#  'births': 0.016196741854636598,
#  'avoided': 0.016196741854636598,
#  'areas': 0.0567669172932331,
#  'extensive': 0.016196741854636598,
#  'landline': 0.016196741854636598,
#  'penetration': 0.016196741854636598,
#  'tv': 0.2875000000000001,
#  'recently': 0.1011904761904762,
#  'started': 0.016196741854636598,
#  'drive': 0.016196741854636598,
#  'live': 0.016196741854636598,
#  'viewing': 0.016196741854636598,
#  'advertising': 0.0567669172932331,
#  'social': 0.016196741854636598,
#  'americans': 0.016196741854636598,
#  'watching': 0.016196741854636598,
#  'sharing': 0.0567669172932331,
#  'prevalent': 0.016196741854636598,
#  'urban': 0.016196741854636598,
#  'india': 0.016196741854636598,
#  'families': 0.016196741854636598,
#  'groups': 0.016196741854636598,
#  'obvious': 0.016196741854636598,
#  'economic': 0.016196741854636598,
#  'familial': 0.016196741854636598,
#  'customs': 0.016196741854636598,
#  'traditional': 0.016196741854636598,
#  'gender': 0.016196741854636598,
#  'roles': 0.016196741854636598,
#  'owned': 0.016196741854636598,
#  'teacher': 0.016196741854636598,
#  'missionary': 0.016196741854636598,
#  'necessary': 0.016196741854636598,
#  'content': 0.2875000000000001,
#  'examples': 0.016196741854636598,
#  'distributing': 0.016196741854636598,
#  'sale': 0.0567669172932331,
#  'ringtones': 0.0567669172932331,
#  'soon': 0.016196741854636598,
#  'jokes': 0.016196741854636598,
#  'horoscopes': 0.016196741854636598,
#  'tended': 0.016196741854636598,
#  'copies': 0.016196741854636598,
#  'legacy': 0.016196741854636598,
#  'banner': 0.016196741854636598,
#  'advertisements': 0.016196741854636598,
#  'highlight': 0.016196741854636598,
#  'clips': 0.016196741854636598,
#  'ringback': 0.016196741854636598,
#  'tones': 0.016196741854636598,
#  'mobisodes': 0.016196741854636598,
#  'produced': 0.016196741854636598,
#  'exclusively': 0.016196741854636598,
#  'banking': 0.24053884711779458,
#  'payment': 0.016196741854636598,
#  'include': 0.016196741854636598,
#  'cash': 0.1011904761904762,
#  'payments': 0.2875000000000001,
#  'secure': 0.0567669172932331,
#  'kenyas': 0.016196741854636598,
#  'mpesa': 0.0567669172932331,
#  'customers': 0.016196741854636598,
#  'safaricom': 0.0567669172932331,
#  'balances': 0.016196741854636598,
#  'recorded': 0.016196741854636598,
#  'deposited': 0.016196741854636598,
#  'withdrawn': 0.016196741854636598,
#  'accounts': 0.016196741854636598,
#  'retail': 0.0567669172932331,
#  'outlets': 0.016196741854636598,
#  'located': 0.016196741854636598,
#  'transferred': 0.016196741854636598,
#  'electronically': 0.016196741854636598,
#  'pay': 0.016196741854636598,
#  'bills': 0.016196741854636598,
#  'branchless': 0.016196741854636598,
#  'successful': 0.016196741854636598,
#  'south': 0.016196741854636598,
#  'africa': 0.0567669172932331,
#  'philippines': 0.0567669172932331,
#  'pilot': 0.016196741854636598,
#  'project': 0.016196741854636598,
#  'bali': 0.016196741854636598,
#  'finance': 0.0567669172932331,
#  'corporation': 0.016196741854636598,
#  'indonesian': 0.016196741854636598,
#  'bank': 0.0567669172932331,
#  'mandiri': 0.016196741854636598,
#  'zidisha': 0.0567669172932331,
#  'usbased': 0.016196741854636598,
#  'nonprofit': 0.016196741854636598,
#  'microlending': 0.016196741854636598,
#  'residents': 0.0567669172932331,
#  'raise': 0.016196741854636598,
#  'loans': 0.016196741854636598,
#  'web': 0.016196741854636598,
#  'loan': 0.016196741854636598,
#  'disbursements': 0.016196741854636598,
#  'repayments': 0.016196741854636598,
#  'transferring': 0.016196741854636598,
#  'funds': 0.016196741854636598,
#  'lenders': 0.016196741854636598,
#  'states': 0.2875000000000001,
#  'borrowers': 0.016196741854636598,
#  'rural': 0.016196741854636598,
#  ...}

# %% [markdown]
# ## High Word Pair Occurence (HWPO)
#
# HWPO is a the computation than HWO except that we compute cumulative bi-grams frequencies

# %%
def HWPO(bigram, bigram_frequency, cumul_bigram):
    key_max = max(list(cumul_bigram.keys()))
    return cumul_bigram[bigram_frequency[bigram]]/cumul_bigram[key_max]

# %%
hwpo = {bigram: HWPO(bigram, bigram_frequency, cumul_bigram) for bigram in list(bigrams)}
hwpo
# Out:
# {('mobile', 'phone'): 1.0,
#  ('phone', 'cellular'): 0.09090909090909091,
#  ('cellular', 'phone'): 0.09090909090909091,
#  ('phone', 'cell'): 0.7002997002997002,
#  ('cell', 'phone'): 0.97002997002997,
#  ('phone', 'cellphone'): 0.09090909090909091,
#  ('cellphone', 'handphone'): 0.09090909090909091,
#  ('handphone', 'hand'): 0.09090909090909091,
#  ('hand', 'phone'): 0.09090909090909091,
#  ('phone', 'shortened'): 0.09090909090909091,
#  ('shortened', 'simply'): 0.09090909090909091,
#  ('simply', 'mobile'): 0.09090909090909091,
#  ('mobile', 'cell'): 0.09090909090909091,
#  ('phone', 'portable'): 0.09090909090909091,
#  ('portable', 'telephone'): 0.7002997002997002,
#  ('telephone', 'receive'): 0.09090909090909091,
#  ('receive', 'calls'): 0.09090909090909091,
#  ('calls', 'radio'): 0.09090909090909091,
#  ('radio', 'frequency'): 0.7002997002997002,
#  ('frequency', 'link'): 0.7002997002997002,
#  ('link', 'user'): 0.09090909090909091,
#  ('user', 'moving'): 0.09090909090909091,
#  ('moving', 'telephone'): 0.09090909090909091,
#  ('telephone', 'service'): 0.9300699300699301,
#  ('service', 'area'): 0.7002997002997002,
#  ('area', 'radio'): 0.09090909090909091,
#  ('link', 'establishes'): 0.09090909090909091,
#  ('establishes', 'connection'): 0.09090909090909091,
#  ('connection', 'switching'): 0.09090909090909091,
#  ('switching', 'systems'): 0.09090909090909091,
#  ('systems', 'mobile'): 0.8651348651348651,
#  ('phone', 'operator'): 0.8651348651348651,
#  ('operator', 'provides'): 0.09090909090909091,
#  ('provides', 'access'): 0.09090909090909091,
#  ('access', 'public'): 0.09090909090909091,
#  ('public', 'switched'): 0.09090909090909091,
#  ('switched', 'telephone'): 0.09090909090909091,
#  ('telephone', 'network'): 0.09090909090909091,
#  ('network', 'pstn'): 0.09090909090909091,
#  ('pstn', 'modern'): 0.09090909090909091,
#  ('modern', 'mobile'): 0.7002997002997002,
#  ('mobile', 'telephone'): 0.9300699300699301,
#  ('telephone', 'services'): 0.09090909090909091,
#  ('services', 'use'): 0.7002997002997002,
#  ('use', 'cellular'): 0.09090909090909091,
#  ('cellular', 'network'): 0.8951048951048951,
#  ('network', 'architecture'): 0.09090909090909091,
#  ('architecture', 'mobile'): 0.09090909090909091,
#  ('mobile', 'telephones'): 0.09090909090909091,
#  ('telephones', 'called'): 0.09090909090909091,
#  ('called', 'cellular'): 0.09090909090909091,
#  ('cellular', 'telephones'): 0.09090909090909091,
#  ('telephones', 'cell'): 0.09090909090909091,
#  ('cell', 'phones'): 0.9300699300699301,
#  ('phones', 'north'): 0.09090909090909091,
#  ('north', 'america'): 0.7002997002997002,
#  ('america', 'addition'): 0.09090909090909091,
#  ('addition', 'telephony'): 0.09090909090909091,
#  ('telephony', 'digital'): 0.09090909090909091,
#  ('digital', 'mobile'): 0.7002997002997002,
#  ('mobile', 'phones'): 0.99000999000999,
#  ('phones', 'g'): 0.09090909090909091,
#  ('g', 'support'): 0.09090909090909091,
#  ('support', 'variety'): 0.09090909090909091,
#  ('variety', 'services'): 0.09090909090909091,
#  ('services', 'text'): 0.09090909090909091,
#  ('text', 'messaging'): 0.9300699300699301,
#  ('messaging', 'mms'): 0.09090909090909091,
#  ('mms', 'email'): 0.09090909090909091,
#  ('email', 'internet'): 0.09090909090909091,
#  ('internet', 'access'): 0.09090909090909091,
#  ('access', 'shortrange'): 0.09090909090909091,
#  ('shortrange', 'wireless'): 0.09090909090909091,
#  ('wireless', 'communications'): 0.7002997002997002,
#  ('communications', 'infrared'): 0.09090909090909091,
#  ('infrared', 'bluetooth'): 0.09090909090909091,
#  ('bluetooth', 'business'): 0.09090909090909091,
#  ('business', 'applications'): 0.09090909090909091,
#  ('applications', 'video'): 0.09090909090909091,
#  ('video', 'games'): 0.8651348651348651,
#  ('games', 'digital'): 0.09090909090909091,
#  ('digital', 'photography'): 0.09090909090909091,
#  ('photography', 'mobile'): 0.09090909090909091,
#  ('phones', 'offering'): 0.09090909090909091,
#  ('offering', 'capabilities'): 0.09090909090909091,
#  ('capabilities', 'known'): 0.09090909090909091,
#  ('known', 'feature'): 0.09090909090909091,
#  ('feature', 'phones'): 0.955044955044955,
#  ('phones', 'mobile'): 0.8951048951048951,
#  ('phones', 'offer'): 0.7002997002997002,
#  ('offer', 'greatly'): 0.09090909090909091,
#  ('greatly', 'advanced'): 0.09090909090909091,
#  ('advanced', 'computing'): 0.7002997002997002,
#  ('computing', 'capabilities'): 0.09090909090909091,
#  ('capabilities', 'referred'): 0.09090909090909091,
#  ('referred', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'development'): 0.09090909090909091,
#  ('development', 'metaloxidesemiconductor'): 0.7002997002997002,
#  ('metaloxidesemiconductor', 'mos'): 0.8651348651348651,
#  ('mos', 'largescale'): 0.7002997002997002,
#  ('largescale', 'integration'): 0.7002997002997002,
#  ('integration', 'lsi'): 0.7002997002997002,
#  ('lsi', 'technology'): 0.7002997002997002,
#  ('technology', 'information'): 0.7002997002997002,
#  ('information', 'theory'): 0.7002997002997002,
#  ('theory', 'cellular'): 0.7002997002997002,
#  ('cellular', 'networking'): 0.7002997002997002,
#  ('networking', 'led'): 0.7002997002997002,
#  ('led', 'development'): 0.7002997002997002,
#  ('development', 'affordable'): 0.7002997002997002,
#  ('affordable', 'mobile'): 0.7002997002997002,
#  ('mobile', 'communications'): 0.7002997002997002,
#  ('communications', 'handheld'): 0.09090909090909091,
#  ('handheld', 'mobile'): 0.9400599400599401,
#  ('phone', 'demonstrated'): 0.7002997002997002,
#  ('demonstrated', 'john'): 0.7002997002997002,
#  ('john', 'f'): 0.7002997002997002,
#  ('f', 'mitchell'): 0.7002997002997002,
#  ('mitchell', 'martin'): 0.7002997002997002,
#  ('martin', 'cooper'): 0.8651348651348651,
#  ('cooper', 'motorola'): 0.8651348651348651,
#  ('motorola', 'handset'): 0.7002997002997002,
#  ('handset', 'weighing'): 0.7002997002997002,
#  ('weighing', 'c'): 0.09090909090909091,
#  ('c', 'kilograms'): 0.09090909090909091,
#  ('kilograms', 'lbs'): 0.09090909090909091,
#  ('lbs', 'nippon'): 0.09090909090909091,
#  ('nippon', 'telegraph'): 0.7002997002997002,
#  ('telegraph', 'telephone'): 0.7002997002997002,
#  ('telephone', 'ntt'): 0.09090909090909091,
#  ('ntt', 'launched'): 0.09090909090909091,
#  ('launched', 'worlds'): 0.09090909090909091,
#  ('worlds', 'cellular'): 0.09090909090909091,
#  ('network', 'japancitation'): 0.09090909090909091,
#  ('japancitation', 'needed'): 0.09090909090909091,
#  ('needed', 'dynatac'): 0.09090909090909091,
#  ('dynatac', 'x'): 0.8651348651348651,
#  ('x', 'commercially'): 0.8651348651348651,
#  ('commercially', 'available'): 0.8951048951048951,
#  ('available', 'handheld'): 0.8651348651348651,
#  ('phone', 'worldwide'): 0.09090909090909091,
#  ('worldwide', 'mobile'): 0.7002997002997002,
#  ('phone', 'subscriptions'): 0.09090909090909091,
#  ('subscriptions', 'grew'): 0.09090909090909091,
#  ('grew', 'seven'): 0.09090909090909091,
#  ('seven', 'billion'): 0.7002997002997002,
#  ('billion', 'provide'): 0.09090909090909091,
#  ('provide', 'person'): 0.09090909090909091,
#  ('person', 'earth'): 0.09090909090909091,
#  ('earth', 'quarter'): 0.09090909090909091,
#  ('quarter', 'smartphone'): 0.09090909090909091,
#  ('smartphone', 'developers'): 0.09090909090909091,
#  ('developers', 'worldwide'): 0.09090909090909091,
#  ('worldwide', 'samsung'): 0.7002997002997002,
#  ('samsung', 'apple'): 0.8651348651348651,
#  ('apple', 'huawei'): 0.8651348651348651,
#  ('huawei', 'smartphone'): 0.09090909090909091,
#  ('smartphone', 'sales'): 0.09090909090909091,
#  ('sales', 'represented'): 0.09090909090909091,
#  ('represented', 'percent'): 0.09090909090909091,
#  ('percent', 'total'): 0.09090909090909091,
#  ('total', 'mobile'): 0.09090909090909091,
#  ('phone', 'sales'): 0.09090909090909091,
#  ('sales', 'feature'): 0.09090909090909091,
#  ('phones', 'slang'): 0.09090909090909091,
#  ('slang', 'dumbphones'): 0.09090909090909091,
#  ('dumbphones', 'largest'): 0.09090909090909091,
#  ('largest', 'samsung'): 0.09090909090909091,
#  ('samsung', 'nokia'): 0.09090909090909091,
#  ('nokia', 'alcatel'): 0.09090909090909091,
#  ('alcatel', 'history'): 0.09090909090909091,
#  ('history', 'martin'): 0.09090909090909091,
#  ('motorola', 'shown'): 0.09090909090909091,
#  ('shown', 'reenactment'): 0.09090909090909091,
#  ('reenactment', 'publicized'): 0.09090909090909091,
#  ('publicized', 'handheld'): 0.09090909090909091,
#  ('phone', 'prototype'): 0.09090909090909091,
#  ('prototype', 'dynatac'): 0.09090909090909091,
#  ('dynatac', 'model'): 0.09090909090909091,
#  ('model', 'april'): 0.09090909090909091,
#  ('april', 'handheld'): 0.09090909090909091,
#  ('mobile', 'radio'): 0.09090909090909091,
#  ('radio', 'telephone'): 0.09090909090909091,
#  ('service', 'envisioned'): 0.09090909090909091,
#  ('envisioned', 'early'): 0.09090909090909091,
#  ('early', 'stages'): 0.09090909090909091,
#  ('stages', 'radio'): 0.09090909090909091,
#  ('radio', 'engineering'): 0.09090909090909091,
#  ('engineering', 'finnish'): 0.09090909090909091,
#  ('finnish', 'inventor'): 0.09090909090909091,
#  ('inventor', 'eric'): 0.09090909090909091,
#  ('eric', 'tigerstedt'): 0.09090909090909091,
#  ('tigerstedt', 'filed'): 0.09090909090909091,
#  ('filed', 'patent'): 0.09090909090909091,
#  ('patent', 'pocketsize'): 0.09090909090909091,
#  ('pocketsize', 'folding'): 0.09090909090909091,
#  ('folding', 'telephone'): 0.09090909090909091,
#  ('telephone', 'thin'): 0.09090909090909091,
#  ('thin', 'carbon'): 0.09090909090909091,
#  ('carbon', 'microphone'): 0.09090909090909091,
#  ('microphone', 'early'): 0.09090909090909091,
#  ('early', 'predecessors'): 0.09090909090909091,
#  ('predecessors', 'cellular'): 0.09090909090909091,
#  ('cellular', 'phones'): 0.7002997002997002,
#  ('phones', 'included'): 0.09090909090909091,
#  ('included', 'analog'): 0.09090909090909091,
#  ('analog', 'radio'): 0.09090909090909091,
#  ('radio', 'communications'): 0.09090909090909091,
#  ('communications', 'ships'): 0.09090909090909091,
#  ('ships', 'trains'): 0.09090909090909091,
#  ('trains', 'race'): 0.09090909090909091,
#  ('race', 'create'): 0.09090909090909091,
#  ('create', 'truly'): 0.09090909090909091,
#  ('truly', 'portable'): 0.09090909090909091,
#  ('telephone', 'devices'): 0.09090909090909091,
#  ('devices', 'began'): 0.09090909090909091,
#  ('began', 'world'): 0.09090909090909091,
#  ('world', 'war'): 0.7002997002997002,
#  ('war', 'ii'): 0.09090909090909091,
#  ('ii', 'developments'): 0.09090909090909091,
#  ('developments', 'taking'): 0.09090909090909091,
#  ('taking', 'place'): 0.09090909090909091,
#  ('place', 'countries'): 0.09090909090909091,
#  ('countries', 'advances'): 0.09090909090909091,
#  ('advances', 'mobile'): 0.09090909090909091,
#  ('mobile', 'telephony'): 0.8651348651348651,
#  ('telephony', 'traced'): 0.09090909090909091,
#  ('traced', 'successive'): 0.09090909090909091,
#  ('successive', 'generations'): 0.09090909090909091,
#  ('generations', 'starting'): 0.09090909090909091,
#  ('starting', 'early'): 0.09090909090909091,
#  ('early', 'zerothgeneration'): 0.09090909090909091,
#  ('zerothgeneration', 'g'): 0.09090909090909091,
#  ('g', 'services'): 0.09090909090909091,
#  ('services', 'bell'): 0.09090909090909091,
#  ('bell', 'systems'): 0.09090909090909091,
#  ('service', 'successor'): 0.09090909090909091,
#  ('successor', 'improved'): 0.09090909090909091,
#  ('improved', 'mobile'): 0.09090909090909091,
#  ('service', 'g'): 0.09090909090909091,
#  ('g', 'systems'): 0.7002997002997002,
#  ('systems', 'cellular'): 0.09090909090909091,
#  ('cellular', 'supported'): 0.09090909090909091,
#  ('supported', 'simultaneous'): 0.09090909090909091,
#  ('simultaneous', 'calls'): 0.8651348651348651,
#  ('calls', 'expensive'): 0.09090909090909091,
#  ('expensive', 'motorola'): 0.09090909090909091,
#  ('motorola', 'dynatac'): 0.09090909090909091,
#  ('handheld', 'cellular'): 0.7002997002997002,
#  ('cellular', 'mobile'): 0.7002997002997002,
#  ('phone', 'development'): 0.09090909090909091,
#  ('communications', 'devices'): 0.09090909090909091,
#  ('devices', 'car'): 0.09090909090909091,
#  ('car', 'phone'): 0.09090909090909091,
#  ('phone', 'handheld'): 0.09090909090909091,
#  ('weighing', 'kilograms'): 0.09090909090909091,
#  ('kilograms', 'lb'): 0.09090909090909091,
#  ('lb', 'commercial'): 0.09090909090909091,
#  ('commercial', 'automated'): 0.09090909090909091,
#  ('automated', 'cellular'): 0.09090909090909091,
#  ('network', 'g'): 0.09090909090909091,
#  ('g', 'analog'): 0.09090909090909091,
#  ('analog', 'launched'): 0.09090909090909091,
#  ('launched', 'japan'): 0.7002997002997002,
#  ('japan', 'nippon'): 0.09090909090909091,
#  ('telephone', 'followed'): 0.09090909090909091,
#  ('followed', 'simultaneous'): 0.09090909090909091,
#  ('simultaneous', 'launch'): 0.09090909090909091,
#  ('launch', 'nordic'): 0.09090909090909091,
#  ('nordic', 'mobile'): 0.09090909090909091,
#  ('telephone', 'nmt'): 0.09090909090909091,
#  ('nmt', 'system'): 0.09090909090909091,
#  ('system', 'denmark'): 0.09090909090909091,
#  ('denmark', 'finland'): 0.09090909090909091,
#  ('finland', 'norway'): 0.09090909090909091,
#  ('norway', 'sweden'): 0.09090909090909091,
#  ('sweden', 'countries'): 0.09090909090909091,
#  ('countries', 'followed'): 0.09090909090909091,
#  ('followed', 'early'): 0.09090909090909091,
#  ('early', 'mids'): 0.09090909090909091,
#  ('mids', 'firstgeneration'): 0.09090909090909091,
#  ('firstgeneration', 'g'): 0.09090909090909091,
#  ('systems', 'support'): 0.09090909090909091,
#  ('support', 'far'): 0.09090909090909091,
#  ('far', 'simultaneous'): 0.09090909090909091,
#  ('calls', 'analog'): 0.09090909090909091,
#  ('analog', 'cellular'): 0.09090909090909091,
#  ('cellular', 'technology'): 0.7002997002997002,
#  ('technology', 'dynatac'): 0.09090909090909091,
#  ('phone', 'digital'): 0.09090909090909091,
#  ('digital', 'cellular'): 0.7002997002997002,
#  ('cellular', 'networks'): 0.09090909090909091,
#  ('networks', 'appeared'): 0.09090909090909091,
#  ('appeared', 's'): 0.09090909090909091,
#  ('s', 'enabled'): 0.09090909090909091,
#  ('enabled', 'wide'): 0.09090909090909091,
#  ('wide', 'adoption'): 0.09090909090909091,
#  ('adoption', 'mosfetbased'): 0.09090909090909091,
#  ('mosfetbased', 'rf'): 0.09090909090909091,
#  ('rf', 'power'): 0.09090909090909091,
#  ('power', 'amplifiers'): 0.09090909090909091,
#  ('amplifiers', 'power'): 0.09090909090909091,
#  ('power', 'mosfet'): 0.09090909090909091,
#  ('mosfet', 'ldmos'): 0.09090909090909091,
#  ('ldmos', 'rf'): 0.09090909090909091,
#  ('rf', 'circuits'): 0.09090909090909091,
#  ('circuits', 'rf'): 0.09090909090909091,
#  ('rf', 'cmos'): 0.09090909090909091,
#  ('cmos', 'leading'): 0.09090909090909091,
#  ('leading', 'introduction'): 0.09090909090909091,
#  ('introduction', 'digital'): 0.09090909090909091,
#  ('digital', 'signal'): 0.09090909090909091,
#  ('signal', 'processing'): 0.09090909090909091,
#  ('processing', 'wireless'): 0.09090909090909091,
#  ('communications', 'secondgeneration'): 0.09090909090909091,
#  ('secondgeneration', 'g'): 0.09090909090909091,
#  ('g', 'digital'): 0.09090909090909091,
#  ('technology', 'launched'): 0.09090909090909091,
#  ('launched', 'finland'): 0.7002997002997002,
#  ('finland', 'radiolinja'): 0.09090909090909091,
#  ('radiolinja', 'gsm'): 0.09090909090909091,
#  ('gsm', 'standard'): 0.7002997002997002,
#  ('standard', 'sparked'): 0.09090909090909091,
#  ('sparked', 'competition'): 0.09090909090909091,
#  ('competition', 'sector'): 0.09090909090909091,
#  ('sector', 'new'): 0.09090909090909091,
#  ('new', 'operators'): 0.09090909090909091,
#  ('operators', 'challenged'): 0.09090909090909091,
#  ('challenged', 'incumbent'): 0.09090909090909091,
#  ('incumbent', 'g'): 0.09090909090909091,
#  ('g', 'network'): 0.09090909090909091,
#  ('network', 'operators'): 0.7002997002997002,
#  ('operators', 'gsm'): 0.09090909090909091,
#  ('standard', 'european'): 0.09090909090909091,
#  ('european', 'initiative'): 0.09090909090909091,
#  ('initiative', 'expressed'): 0.09090909090909091,
#  ('expressed', 'cept'): 0.09090909090909091,
#  ('cept', 'conférence'): 0.09090909090909091,
#  ('conférence', 'européenne'): 0.09090909090909091,
#  ('européenne', 'des'): 0.09090909090909091,
#  ('des', 'postes'): 0.09090909090909091,
#  ('postes', 'et'): 0.09090909090909091,
#  ('et', 'telecommunications'): 0.09090909090909091,
#  ('telecommunications', 'european'): 0.09090909090909091,
#  ('european', 'postal'): 0.09090909090909091,
#  ('postal', 'telecommunications'): 0.09090909090909091,
#  ('telecommunications', 'conference'): 0.09090909090909091,
#  ('conference', 'francogerman'): 0.09090909090909091,
#  ('francogerman', 'rd'): 0.09090909090909091,
#  ('rd', 'cooperation'): 0.09090909090909091,
#  ('cooperation', 'demonstrated'): 0.09090909090909091,
#  ('demonstrated', 'technical'): 0.09090909090909091,
#  ('technical', 'feasibility'): 0.09090909090909091,
#  ('feasibility', 'memorandum'): 0.09090909090909091,
#  ('memorandum', 'understanding'): 0.09090909090909091,
#  ('understanding', 'signed'): 0.09090909090909091,
#  ('signed', 'european'): 0.09090909090909091,
#  ('european', 'countries'): 0.09090909090909091,
#  ('countries', 'agreed'): 0.09090909090909091,
#  ('agreed', 'launch'): 0.09090909090909091,
#  ('launch', 'commercial'): 0.09090909090909091,
#  ('commercial', 'service'): 0.09090909090909091,
#  ('service', 'version'): 0.09090909090909091,
#  ('version', 'gsm'): 0.09090909090909091,
#  ('gsm', 'g'): 0.7002997002997002,
#  ('g', 'standard'): 0.09090909090909091,
#  ('standard', 'pages'): 0.09090909090909091,
#  ('pages', 'ieeerse'): 0.09090909090909091,
#  ('ieeerse', 'awarded'): 0.09090909090909091,
#  ('awarded', 'thomas'): 0.09090909090909091,
#  ('thomas', 'haug'): 0.09090909090909091,
#  ('haug', 'philippe'): 0.09090909090909091,
#  ('philippe', 'dupuis'): 0.09090909090909091,
#  ('dupuis', 'james'): 0.09090909090909091,
#  ('james', 'clerk'): 0.09090909090909091,
#  ('clerk', 'maxwell'): 0.09090909090909091,
#  ('maxwell', 'medal'): 0.09090909090909091,
#  ('medal', 'contributions'): 0.09090909090909091,
#  ('contributions', 'digital'): 0.09090909090909091,
#  ('telephone', 'standard'): 0.09090909090909091,
#  ('standard', 'gsm'): 0.09090909090909091,
#  ('gsm', 'billion'): 0.09090909090909091,
#  ('billion', 'people'): 0.09090909090909091,
#  ('people', 'countries'): 0.09090909090909091,
#  ('countries', 'gsm'): 0.09090909090909091,
#  ('g', 'evolved'): 0.09090909090909091,
#  ('evolved', 'g'): 0.09090909090909091,
#  ('g', 'g'): 0.8651348651348651,
#  ('g', 'lithiumion'): 0.09090909090909091,
#  ('lithiumion', 'battery'): 0.7002997002997002,
#  ('battery', 'indispensable'): 0.09090909090909091,
#  ('indispensable', 'energy'): 0.09090909090909091,
#  ('energy', 'source'): 0.09090909090909091,
#  ('source', 'modern'): 0.09090909090909091,
#  ('phones', 'commercialized'): 0.09090909090909091,
#  ('commercialized', 'sony'): 0.09090909090909091,
#  ('sony', 'asahi'): 0.09090909090909091,
#  ('asahi', 'kasei'): 0.09090909090909091,
#  ('kasei', 'generation'): 0.09090909090909091,
#  ('generation', 'g'): 0.09090909090909091,
#  ('g', 'launched'): 0.09090909090909091,
#  ('japan', 'ntt'): 0.09090909090909091,
#  ('ntt', 'docomo'): 0.09090909090909091,
#  ('docomo', 'wcdma'): 0.09090909090909091,
#  ('wcdma', 'standard'): 0.09090909090909091,
#  ('standard', 'followed'): 0.09090909090909091,
#  ('followed', 'g'): 0.09090909090909091,
#  ('g', 'turbo'): 0.09090909090909091,
#  ('turbo', 'g'): 0.09090909090909091,
#  ('g', 'enhancements'): 0.09090909090909091,
#  ('enhancements', 'based'): 0.09090909090909091,
#  ('based', 'highspeed'): 0.09090909090909091,
#  ('highspeed', 'packet'): 0.09090909090909091,
#  ('packet', 'access'): 0.09090909090909091,
#  ('access', 'hspa'): 0.09090909090909091,
#  ('hspa', 'family'): 0.09090909090909091,
#  ('family', 'allowing'): 0.09090909090909091,
#  ('allowing', 'umts'): 0.09090909090909091,
#  ('umts', 'networks'): 0.09090909090909091,
#  ('networks', 'higher'): 0.09090909090909091,
#  ('higher', 'data'): 0.09090909090909091,
#  ('data', 'transfer'): 0.09090909090909091,
#  ('transfer', 'speeds'): 0.09090909090909091,
#  ('speeds', 'capacity'): 0.09090909090909091,
#  ('capacity', 'clear'): 0.09090909090909091,
#  ('clear', 'point'): 0.09090909090909091,
#  ('point', 'g'): 0.09090909090909091,
#  ('g', 'networks'): 0.09090909090909091,
#  ('networks', 'overwhelmed'): 0.09090909090909091,
#  ('overwhelmed', 'growth'): 0.09090909090909091,
#  ('growth', 'bandwidthintensive'): 0.09090909090909091,
#  ('bandwidthintensive', 'applications'): 0.09090909090909091,
#  ('applications', 'streaming'): 0.09090909090909091,
#  ('streaming', 'media'): 0.09090909090909091,
#  ('media', 'consequently'): 0.09090909090909091,
#  ('consequently', 'industry'): 0.09090909090909091,
#  ('industry', 'began'): 0.09090909090909091,
#  ('began', 'looking'): 0.09090909090909091,
#  ('looking', 'dataoptimized'): 0.09090909090909091,
#  ('dataoptimized', 'fourthgeneration'): 0.09090909090909091,
#  ('fourthgeneration', 'technologies'): 0.09090909090909091,
#  ('technologies', 'promise'): 0.09090909090909091,
#  ('promise', 'speed'): 0.09090909090909091,
#  ('speed', 'improvements'): 0.09090909090909091,
#  ('improvements', 'tenfold'): 0.09090909090909091,
#  ('tenfold', 'existing'): 0.09090909090909091,
#  ('existing', 'g'): 0.09090909090909091,
#  ('g', 'technologies'): 0.09090909090909091,
#  ('technologies', 'commercially'): 0.09090909090909091,
#  ('available', 'technologies'): 0.09090909090909091,
#  ('technologies', 'billed'): 0.09090909090909091,
#  ('billed', 'g'): 0.09090909090909091,
#  ('g', 'wimax'): 0.09090909090909091,
#  ('wimax', 'standard'): 0.09090909090909091,
#  ('standard', 'offered'): 0.7002997002997002,
#  ('offered', 'north'): 0.09090909090909091,
#  ('america', 'sprint'): 0.09090909090909091,
#  ('sprint', 'lte'): 0.09090909090909091,
#  ('lte', 'standard'): 0.09090909090909091,
#  ('offered', 'scandinavia'): 0.09090909090909091,
#  ('scandinavia', 'teliasonera'): 0.09090909090909091,
#  ('teliasonera', 'g'): 0.09090909090909091,
#  ('g', 'technology'): 0.09090909090909091,
#  ('technology', 'term'): 0.09090909090909091,
#  ('term', 'research'): 0.09090909090909091,
#  ('research', 'papers'): 0.09090909090909091,
#  ('papers', 'projects'): 0.09090909090909091,
#  ('projects', 'denote'): 0.09090909090909091,
#  ('denote', 'major'): 0.09090909090909091,
#  ('major', 'phase'): 0.09090909090909091,
#  ('phase', 'mobile'): 0.09090909090909091,
#  ('mobile', 'telecommunication'): 0.09090909090909091,
#  ('telecommunication', 'standards'): 0.09090909090909091,
#  ('standards', 'gimtadvanced'): 0.09090909090909091,
#  ('gimtadvanced', 'standards'): 0.09090909090909091,
#  ('standards', 'term'): 0.09090909090909091,
#  ('term', 'g'): 0.09090909090909091,
#  ('g', 'officially'): 0.09090909090909091,
#  ('officially', 'specification'): 0.09090909090909091,
#  ('specification', 'official'): 0.09090909090909091,
#  ('official', 'document'): 0.09090909090909091,
#  ('document', 'public'): 0.09090909090909091,
#  ('public', 'telecommunication'): 0.09090909090909091,
#  ('telecommunication', 'companies'): 0.09090909090909091,
#  ('companies', 'standardization'): 0.09090909090909091,
#  ('standardization', 'bodies'): 0.7002997002997002,
#  ('bodies', 'gpp'): 0.09090909090909091,
#  ('gpp', 'wimax'): 0.09090909090909091,
#  ('wimax', 'forum'): 0.09090909090909091,
#  ('forum', 'itur'): 0.09090909090909091,
#  ('itur', 'new'): 0.09090909090909091,
#  ('new', 'standards'): 0.09090909090909091,
#  ('standards', 'g'): 0.09090909090909091,
#  ('g', 'currently'): 0.09090909090909091,
#  ('currently', 'developed'): 0.09090909090909091,
#  ('developed', 'standardization'): 0.09090909090909091,
#  ('bodies', 'time'): 0.09090909090909091,
#  ('time', 'seen'): 0.09090909090909091,
#  ('seen', 'g'): 0.09090909090909091,
#  ('g', 'umbrella'): 0.09090909090909091,
#  ('umbrella', 'new'): 0.09090909090909091,
#  ('new', 'mobile'): 0.09090909090909091,
#  ('mobile', 'generation'): 0.09090909090909091,
#  ('generation', 'types'): 0.09090909090909091,
#  ('types', 'mobile'): 0.09090909090909091,
#  ('mobile', 'subscriptions'): 0.09090909090909091,
#  ('subscriptions', 'people'): 0.09090909090909091,
#  ('people', 'active'): 0.09090909090909091,
#  ('active', 'mobile'): 0.09090909090909091,
#  ('mobile', 'broadband'): 0.09090909090909091,
#  ('broadband', 'subscriptions'): 0.09090909090909091,
#  ('subscriptions', 'inhabitants'): 0.09090909090909091,
#  ('inhabitants', 'smartphone'): 0.09090909090909091,
#  ('smartphone', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'number'): 0.09090909090909091,
#  ('number', 'distinguishing'): 0.09090909090909091,
#  ('distinguishing', 'features'): 0.09090909090909091,
#  ('features', 'international'): 0.09090909090909091,
#  ('international', 'telecommunication'): 0.09090909090909091,
#  ('telecommunication', 'union'): 0.09090909090909091,
#  ('union', 'measures'): 0.09090909090909091,
#  ('measures', 'internet'): 0.09090909090909091,
#  ('internet', 'connection'): 0.09090909090909091,
#  ('connection', 'calls'): 0.09090909090909091,
#  ('calls', 'active'): 0.09090909090909091,
#  ('active', 'mobilebroadband'): 0.09090909090909091,
#  ('mobilebroadband', 'subscriptions'): 0.09090909090909091,
#  ('subscriptions', 'includes'): 0.09090909090909091,
#  ('includes', 'tablets'): 0.09090909090909091,
#  ('tablets', 'etc'): 0.09090909090909091,
#  ('etc', 'developed'): 0.09090909090909091,
#  ('developed', 'world'): 0.09090909090909091,
#  ('world', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'overtaken'): 0.09090909090909091,
#  ('overtaken', 'usage'): 0.09090909090909091,
#  ('usage', 'earlier'): 0.09090909090909091,
#  ('earlier', 'mobile'): 0.09090909090909091,
#  ('mobile', 'systems'): 0.09090909090909091,
#  ('systems', 'developing'): 0.09090909090909091,
#  ('developing', 'world'): 0.09090909090909091,
#  ('world', 'account'): 0.09090909090909091,
#  ('account', 'mobile'): 0.09090909090909091,
#  ('telephony', 'feature'): 0.09090909090909091,
#  ('feature', 'phone'): 0.8651348651348651,
#  ('phone', 'feature'): 0.09090909090909091,
#  ('phone', 'term'): 0.09090909090909091,
#  ('term', 'typically'): 0.09090909090909091,
#  ('typically', 'retronym'): 0.09090909090909091,
#  ('retronym', 'describe'): 0.09090909090909091,
#  ('describe', 'mobile'): 0.09090909090909091,
#  ('phones', 'limited'): 0.09090909090909091,
#  ('limited', 'capabilities'): 0.09090909090909091,
#  ('capabilities', 'contrast'): 0.09090909090909091,
#  ('contrast', 'modern'): 0.09090909090909091,
#  ('modern', 'smartphone'): 0.09090909090909091,
#  ('smartphone', 'feature'): 0.09090909090909091,
#  ('phones', 'typically'): 0.7002997002997002,
#  ('typically', 'provide'): 0.09090909090909091,
#  ('provide', 'voice'): 0.09090909090909091,
#  ('voice', 'calling'): 0.7002997002997002,
#  ('calling', 'text'): 0.7002997002997002,
#  ('messaging', 'functionality'): 0.09090909090909091,
#  ('functionality', 'addition'): 0.09090909090909091,
#  ('addition', 'basic'): 0.09090909090909091,
#  ('basic', 'multimedia'): 0.09090909090909091,
#  ('multimedia', 'internet'): 0.09090909090909091,
#  ('internet', 'capabilities'): 0.09090909090909091,
#  ('capabilities', 'services'): 0.09090909090909091,
#  ('services', 'offered'): 0.09090909090909091,
#  ('offered', 'users'): 0.09090909090909091,
#  ('users', 'wireless'): 0.09090909090909091,
#  ('wireless', 'service'): 0.09090909090909091,
#  ('service', 'provider'): 0.7002997002997002,
#  ('provider', 'feature'): 0.09090909090909091,
#  ('phone', 'additional'): 0.09090909090909091,
#  ('additional', 'functions'): 0.09090909090909091,
#  ('functions', 'basic'): 0.09090909090909091,
#  ('basic', 'mobile'): 0.7002997002997002,
#  ('phone', 'capable'): 0.09090909090909091,
#  ('capable', 'voice'): 0.09090909090909091,
#  ('messaging', 'feature'): 0.09090909090909091,
#  ('phones', 'basic'): 0.7002997002997002,
#  ('phones', 'tend'): 0.09090909090909091,
#  ('tend', 'use'): 0.09090909090909091,
#  ('use', 'proprietary'): 0.09090909090909091,
#  ('proprietary', 'customdesigned'): 0.09090909090909091,
#  ('customdesigned', 'software'): 0.09090909090909091,
#  ('software', 'user'): 0.09090909090909091,
#  ('user', 'interface'): 0.09090909090909091,
#  ('interface', 'contrast'): 0.09090909090909091,
#  ('contrast', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'generally'): 0.09090909090909091,
#  ('generally', 'use'): 0.09090909090909091,
#  ('use', 'mobile'): 0.97002997002997,
#  ('mobile', 'operating'): 0.09090909090909091,
#  ('operating', 'system'): 0.7002997002997002,
#  ('system', 'shares'): 0.09090909090909091,
#  ('shares', 'common'): 0.09090909090909091,
#  ('common', 'traits'): 0.09090909090909091,
#  ('traits', 'devices'): 0.09090909090909091,
#  ('devices', 'infrastructure'): 0.09090909090909091,
#  ('infrastructure', 'mobile'): 0.09090909090909091,
#  ('phones', 'communicate'): 0.09090909090909091,
#  ('communicate', 'cell'): 0.09090909090909091,
#  ('cell', 'towers'): 0.8651348651348651,
#  ('towers', 'placed'): 0.7002997002997002,
#  ('placed', 'coverage'): 0.09090909090909091,
#  ('coverage', 'telephone'): 0.09090909090909091,
#  ('area', 'divided'): 0.09090909090909091,
#  ('divided', 'cells'): 0.09090909090909091,
#  ('cells', 'cell'): 0.09090909090909091,
#  ('cell', 'uses'): 0.8651348651348651,
#  ('uses', 'different'): 0.09090909090909091,
#  ('different', 'set'): 0.09090909090909091,
#  ('set', 'frequencies'): 0.09090909090909091,
#  ('frequencies', 'neighboring'): 0.09090909090909091,
#  ('neighboring', 'cells'): 0.09090909090909091,
#  ('cells', 'typically'): 0.09090909090909091,
#  ('typically', 'covered'): 0.09090909090909091,
#  ('covered', 'towers'): 0.09090909090909091,
#  ('placed', 'different'): 0.09090909090909091,
#  ('different', 'locations'): 0.09090909090909091,
#  ('locations', 'cell'): 0.09090909090909091,
#  ('towers', 'usually'): 0.09090909090909091,
#  ('usually', 'interconnected'): 0.09090909090909091,
#  ('interconnected', 'phone'): 0.09090909090909091,
#  ('phone', 'network'): 0.09090909090909091,
#  ('network', 'internet'): 0.09090909090909091,
#  ('internet', 'wired'): 0.09090909090909091,
#  ('wired', 'connections'): 0.09090909090909091,
#  ('connections', 'bandwidth'): 0.09090909090909091,
#  ('bandwidth', 'limitations'): 0.09090909090909091,
#  ('limitations', 'cell'): 0.09090909090909091,
#  ('cell', 'maximum'): 0.09090909090909091,
#  ('maximum', 'number'): 0.09090909090909091,
#  ('number', 'cell'): 0.09090909090909091,
#  ('phones', 'handle'): 0.09090909090909091,
#  ('handle', 'cells'): 0.09090909090909091,
#  ('cells', 'sized'): 0.09090909090909091,
#  ('sized', 'depending'): 0.09090909090909091,
#  ('depending', 'expected'): 0.09090909090909091,
#  ('expected', 'usage'): 0.09090909090909091,
#  ('usage', 'density'): 0.09090909090909091,
#  ('density', 'smaller'): 0.09090909090909091,
#  ('smaller', 'cities'): 0.09090909090909091,
#  ('cities', 'case'): 0.09090909090909091,
#  ('case', 'lower'): 0.09090909090909091,
#  ('lower', 'transmitter'): 0.09090909090909091,
#  ('transmitter', 'powers'): 0.09090909090909091,
#  ('powers', 'avoid'): 0.09090909090909091,
#  ('avoid', 'broadcasting'): 0.09090909090909091,
#  ('broadcasting', 'cell'): 0.09090909090909091,
#  ('cell', 'order'): 0.09090909090909091,
#  ('order', 'handle'): 0.09090909090909091,
#  ('handle', 'high'): 0.09090909090909091,
#  ('high', 'traffic'): 0.7002997002997002,
#  ('traffic', 'multiple'): 0.09090909090909091,
#  ('multiple', 'towers'): 0.09090909090909091,
#  ('towers', 'set'): 0.09090909090909091,
#  ('set', 'area'): 0.09090909090909091,
#  ('area', 'different'): 0.09090909090909091,
#  ('different', 'frequencies'): 0.09090909090909091,
#  ('frequencies', 'permanently'): 0.09090909090909091,
#  ('permanently', 'temporarily'): 0.09090909090909091,
#  ('temporarily', 'special'): 0.09090909090909091,
#  ('special', 'events'): 0.09090909090909091,
#  ('events', 'like'): 0.09090909090909091,
#  ('like', 'super'): 0.09090909090909091,
#  ('super', 'bowl'): 0.09090909090909091,
#  ('bowl', 'taste'): 0.09090909090909091,
#  ('taste', 'chicago'): 0.09090909090909091,
#  ('chicago', 'state'): 0.09090909090909091,
#  ('state', 'fair'): 0.09090909090909091,
#  ('fair', 'nyc'): 0.09090909090909091,
#  ('nyc', 'new'): 0.09090909090909091,
#  ('new', 'years'): 0.09090909090909091,
#  ('years', 'eve'): 0.09090909090909091,
#  ('eve', 'hurricane'): 0.09090909090909091,
#  ('hurricane', 'hit'): 0.09090909090909091,
#  ('hit', 'cities'): 0.09090909090909091,
#  ('cities', 'etc'): 0.09090909090909091,
#  ('etc', 'cell'): 0.09090909090909091,
#  ('phone', 'companies'): 0.7002997002997002,
#  ('companies', 'bring'): 0.09090909090909091,
#  ('bring', 'truck'): 0.09090909090909091,
#  ('truck', 'equipment'): 0.09090909090909091,
#  ('equipment', 'host'): 0.09090909090909091,
#  ('host', 'abnormally'): 0.09090909090909091,
#  ('abnormally', 'high'): 0.09090909090909091,
#  ('traffic', 'portable'): 0.09090909090909091,
#  ('portable', 'cell'): 0.09090909090909091,
#  ('cell', 'cellular'): 0.09090909090909091,
#  ('cellular', 'greatly'): 0.09090909090909091,
#  ('greatly', 'increase'): 0.09090909090909091,
#  ('increase', 'capacity'): 0.09090909090909091,
#  ('capacity', 'simultaneous'): 0.09090909090909091,
#  ('simultaneous', 'wireless'): 0.09090909090909091,
#  ('wireless', 'phone'): 0.09090909090909091,
#  ('phone', 'calls'): 0.09090909090909091,
#  ('calls', 'phone'): 0.09090909090909091,
#  ('phone', 'company'): 0.09090909090909091,
#  ('company', 'example'): 0.09090909090909091,
#  ('example', 'license'): 0.09090909090909091,
#  ('license', 'frequencies'): 0.09090909090909091,
#  ('frequencies', 'cell'): 0.09090909090909091,
#  ('cell', 'use'): 0.09090909090909091,
#  ('use', 'unique'): 0.09090909090909091,
#  ('unique', 'frequencies'): 0.09090909090909091,
#  ('frequencies', 'communicating'): 0.09090909090909091,
#  ('communicating', 'cells'): 0.09090909090909091,
#  ('cells', 'slightly'): 0.09090909090909091,
#  ('slightly', 'overlap'): 0.09090909090909091,
#  ('overlap', 'frequency'): 0.09090909090909091,
#  ('frequency', 'reused'): 0.09090909090909091,
#  ('reused', 'example'): 0.09090909090909091,
#  ('example', 'cell'): 0.09090909090909091,
#  ('uses', 'frequency'): 0.7002997002997002,
#  ('frequency', 'door'): 0.7002997002997002,
#  ('door', 'cell'): 0.09090909090909091,
#  ('door', 'reuse'): 0.09090909090909091,
#  ('reuse', 'frequency'): 0.09090909090909091,
#  ('frequency', 'cells'): 0.09090909090909091,
#  ('cells', 'touching'): 0.09090909090909091,
#  ('touching', 'overlapcommunicate'): 0.09090909090909091,
#  ('overlapcommunicate', 'reuse'): 0.09090909090909091,
#  ('reuse', 'frequenciescitation'): 0.09090909090909091,
#  ('frequenciescitation', 'needed'): 0.09090909090909091,
#  ('needed', 'greatly'): 0.09090909090909091,
#  ('greatly', 'increased'): 0.09090909090909091,
#  ('increased', 'phone'): 0.09090909090909091,
#  ('companies', 'implemented'): 0.09090909090909091,
#  ('implemented', 'digital'): 0.09090909090909091,
#  ('digital', 'networks'): 0.09090909090909091,
#  ('networks', 'digital'): 0.09090909090909091,
#  ('digital', 'frequency'): 0.09090909090909091,
#  ('frequency', 'host'): 0.09090909090909091,
#  ('host', 'multiple'): 0.09090909090909091,
#  ('multiple', 'simultaneous'): 0.09090909090909091,
#  ('calls', 'increasing'): 0.09090909090909091,
#  ('increasing', 'capacity'): 0.09090909090909091,
#  ('capacity', 'phone'): 0.09090909090909091,
#  ('phone', 'moves'): 0.09090909090909091,
#  ('moves', 'phone'): 0.09090909090909091,
#  ('phone', 'hand'): 0.09090909090909091,
#  ('hand', 'automatically'): 0.09090909090909091,
#  ('automatically', 'disconnect'): 0.09090909090909091,
#  ('disconnect', 'reconnect'): 0.09090909090909091,
#  ('reconnect', 'tower'): 0.09090909090909091,
#  ('tower', 'cell'): 0.09090909090909091,
#  ('cell', 'gives'): 0.09090909090909091,
#  ('gives', 'best'): 0.09090909090909091,
#  ('best', 'reception'): 0.09090909090909091,
#  ('reception', 'additionally'): 0.09090909090909091,
#  ('additionally', 'shortrange'): 0.09090909090909091,
#  ('shortrange', 'wifi'): 0.09090909090909091,
#  ('wifi', 'infrastructure'): 0.09090909090909091,
#  ('infrastructure', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'possible'): 0.09090909090909091,
#  ('possible', 'offloads'): 0.09090909090909091,
#  ('offloads', 'traffic'): 0.09090909090909091,
#  ('traffic', 'cell'): 0.09090909090909091,
#  ('cell', 'networks'): 0.09090909090909091,
#  ('networks', 'local'): 0.09090909090909091,
#  ('local', 'area'): 0.09090909090909091,
#  ('area', 'networks'): 0.09090909090909091,
#  ('networks', 'hardware'): 0.09090909090909091,
#  ('hardware', 'common'): 0.09090909090909091,
#  ('common', 'components'): 0.09090909090909091,
#  ('components', 'found'): 0.09090909090909091,
#  ('found', 'mobile'): 0.7002997002997002,
#  ('phones', 'central'): 0.7002997002997002,
#  ('central', 'processing'): 0.8651348651348651,
#  ('processing', 'unit'): 0.7002997002997002,
#  ('unit', 'cpu'): 0.09090909090909091,
#  ('cpu', 'processor'): 0.09090909090909091,
#  ('processor', 'phones'): 0.09090909090909091,
#  ('phones', 'cpu'): 0.09090909090909091,
#  ('cpu', 'microprocessor'): 0.09090909090909091,
#  ('microprocessor', 'fabricated'): 0.09090909090909091,
#  ('fabricated', 'metaloxidesemiconductor'): 0.09090909090909091,
#  ('mos', 'integrated'): 0.09090909090909091,
#  ('integrated', 'circuit'): 0.09090909090909091,
#  ('circuit', 'ic'): 0.09090909090909091,
#  ('ic', 'chip'): 0.09090909090909091,
#  ('chip', 'battery'): 0.09090909090909091,
#  ('battery', 'providing'): 0.09090909090909091,
#  ('providing', 'power'): 0.09090909090909091,
#  ('power', 'source'): 0.09090909090909091,
#  ('source', 'phone'): 0.09090909090909091,
#  ('phone', 'functions'): 0.09090909090909091,
#  ('functions', 'modern'): 0.09090909090909091,
#  ('modern', 'handset'): 0.09090909090909091,
#  ('handset', 'typically'): 0.09090909090909091,
#  ('typically', 'uses'): 0.09090909090909091,
#  ('uses', 'lithiumion'): 0.09090909090909091,
#  ('battery', 'lib'): 0.09090909090909091,
#  ('lib', 'older'): 0.09090909090909091,
#  ('older', 'handsets'): 0.09090909090909091,
#  ('handsets', 'nickelmetal'): 0.09090909090909091,
#  ('nickelmetal', 'hydride'): 0.09090909090909091,
#  ('hydride', 'nimh'): 0.09090909090909091,
#  ('nimh', 'batteries'): 0.09090909090909091,
#  ('batteries', 'input'): 0.09090909090909091,
#  ('input', 'mechanism'): 0.09090909090909091,
#  ('mechanism', 'allow'): 0.09090909090909091,
#  ('allow', 'user'): 0.09090909090909091,
#  ('user', 'interact'): 0.09090909090909091,
#  ('interact', 'phone'): 0.09090909090909091,
#  ('phone', 'keypad'): 0.09090909090909091,
#  ('keypad', 'feature'): 0.09090909090909091,
#  ('phones', 'touch'): 0.09090909090909091,
#  ('touch', 'screens'): 0.09090909090909091,
#  ('screens', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'typically'): 0.09090909090909091,
#  ('typically', 'capacitive'): 0.09090909090909091,
#  ('capacitive', 'sensing'): 0.09090909090909091,
#  ('sensing', 'display'): 0.09090909090909091,
#  ('display', 'echoes'): 0.09090909090909091,
#  ('echoes', 'users'): 0.09090909090909091,
#  ('users', 'typing'): 0.09090909090909091,
#  ('typing', 'displays'): 0.09090909090909091,
#  ('displays', 'text'): 0.09090909090909091,
#  ('text', 'messages'): 0.09090909090909091,
#  ('messages', 'contacts'): 0.09090909090909091,
#  ('contacts', 'display'): 0.09090909090909091,
#  ('display', 'typically'): 0.09090909090909091,
#  ('typically', 'liquidcrystal'): 0.09090909090909091,
#  ('liquidcrystal', 'display'): 0.09090909090909091,
#  ('display', 'lcd'): 0.09090909090909091,
#  ('lcd', 'organic'): 0.09090909090909091,
#  ('organic', 'lightemitting'): 0.09090909090909091,
#  ('lightemitting', 'diode'): 0.09090909090909091,
#  ('diode', 'oled'): 0.09090909090909091,
#  ('oled', 'display'): 0.09090909090909091,
#  ('display', 'speakers'): 0.09090909090909091,
#  ('speakers', 'sound'): 0.09090909090909091,
#  ('sound', 'subscriber'): 0.09090909090909091,
#  ('subscriber', 'identity'): 0.7002997002997002,
#  ('identity', 'module'): 0.8651348651348651,
#  ('module', 'sim'): 0.7002997002997002,
#  ('sim', 'cards'): 0.8951048951048951,
#  ('cards', 'removable'): 0.09090909090909091,
#  ('removable', 'user'): 0.09090909090909091,
#  ('user', 'identity'): 0.09090909090909091,
#  ('module', 'ruim'): 0.09090909090909091,
#  ('ruim', 'cards'): 0.7002997002997002,
#  ('cards', 'hardware'): 0.09090909090909091,
#  ('hardware', 'notification'): 0.09090909090909091,
#  ('notification', 'led'): 0.09090909090909091,
#  ('led', 'phones'): 0.09090909090909091,
#  ('phones', 'lowend'): 0.09090909090909091,
#  ('lowend', 'mobile'): 0.09090909090909091,
#  ('phones', 'referred'): 0.09090909090909091,
#  ('referred', 'feature'): 0.09090909090909091,
#  ('offer', 'basic'): 0.09090909090909091,
#  ('basic', 'telephony'): 0.09090909090909091,
#  ('telephony', 'handsets'): 0.09090909090909091,
#  ('handsets', 'advanced'): 0.09090909090909091,
#  ('computing', 'ability'): 0.09090909090909091,
#  ('ability', 'use'): 0.09090909090909091,
#  ('use', 'native'): 0.09090909090909091,
#  ('native', 'software'): 0.09090909090909091,
#  ('software', 'applications'): 0.09090909090909091,
#  ('applications', 'known'): 0.09090909090909091,
#  ('known', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'central'): 0.09090909090909091,
#  ('unit', 'mobile'): 0.09090909090909091,
#  ('processing', 'units'): 0.09090909090909091,
#  ('units', 'cpus'): 0.09090909090909091,
#  ('cpus', 'similar'): 0.09090909090909091,
#  ('similar', 'computers'): 0.09090909090909091,
#  ('computers', 'optimised'): 0.09090909090909091,
#  ('optimised', 'operate'): 0.09090909090909091,
#  ('operate', 'low'): 0.09090909090909091,
#  ('low', 'power'): 0.09090909090909091,
#  ('power', 'environments'): 0.09090909090909091,
#  ('environments', 'mobile'): 0.09090909090909091,
#  ('mobile', 'cpu'): 0.09090909090909091,
#  ('cpu', 'performance'): 0.09090909090909091,
#  ('performance', 'depends'): 0.09090909090909091,
#  ('depends', 'clock'): 0.09090909090909091,
#  ('clock', 'rate'): 0.09090909090909091,
#  ('rate', 'generally'): 0.09090909090909091,
#  ('generally', 'given'): 0.09090909090909091,
#  ('given', 'multiples'): 0.09090909090909091,
#  ('multiples', 'hertz'): 0.09090909090909091,
#  ('hertz', 'memory'): 0.09090909090909091,
#  ('memory', 'hierarchy'): 0.09090909090909091,
#  ('hierarchy', 'greatly'): 0.09090909090909091,
#  ('greatly', 'affects'): 0.09090909090909091,
#  ('affects', 'overall'): 0.09090909090909091,
#  ('overall', 'performance'): 0.09090909090909091,
#  ('performance', 'problems'): 0.09090909090909091,
#  ('problems', 'performance'): 0.09090909090909091,
#  ('performance', 'mobile'): 0.09090909090909091,
#  ('phone', 'cpus'): 0.09090909090909091,
#  ('cpus', 'appropriately'): 0.09090909090909091,
#  ('appropriately', 'given'): 0.09090909090909091,
#  ('given', 'scores'): 0.09090909090909091,
#  ('scores', 'derived'): 0.09090909090909091,
#  ('derived', 'standardized'): 0.09090909090909091,
#  ('standardized', 'tests'): 0.09090909090909091,
#  ('tests', 'measure'): 0.09090909090909091,
#  ('measure', 'real'): 0.09090909090909091,
#  ('real', 'effective'): 0.09090909090909091,
#  ('effective', 'performance'): 0.09090909090909091,
#  ('performance', 'commonly'): 0.09090909090909091,
#  ('commonly', 'applications'): 0.09090909090909091,
#  ('applications', 'display'): 0.09090909090909091,
#  ('display', 'main'): 0.09090909090909091,
#  ('main', 'characteristics'): 0.09090909090909091,
#  ('characteristics', 'phones'): 0.09090909090909091,
#  ('phones', 'screen'): 0.09090909090909091,
#  ('screen', 'depending'): 0.09090909090909091,
#  ('depending', 'devices'): 0.09090909090909091,
#  ('devices', 'type'): 0.09090909090909091,
#  ('type', 'design'): 0.09090909090909091,
#  ('design', 'screen'): 0.09090909090909091,
#  ('screen', 'fills'): 0.09090909090909091,
#  ('fills', 'nearly'): 0.09090909090909091,
#  ('nearly', 'space'): 0.09090909090909091,
#  ('space', 'devices'): 0.09090909090909091,
#  ('devices', 'surface'): 0.09090909090909091,
#  ('surface', 'smartphone'): 0.09090909090909091,
#  ('smartphone', 'displays'): 0.09090909090909091,
#  ('displays', 'aspect'): 0.09090909090909091,
#  ('aspect', 'ratio'): 0.09090909090909091,
#  ('ratio', 'taller'): 0.09090909090909091,
#  ('taller', 'aspect'): 0.7002997002997002,
#  ('aspect', 'ratios'): 0.7002997002997002,
#  ('ratios', 'common'): 0.09090909090909091,
#  ('common', 'screen'): 0.09090909090909091,
#  ('screen', 'sizes'): 0.8951048951048951,
#  ('sizes', 'measured'): 0.09090909090909091,
#  ('measured', 'diagonal'): 0.09090909090909091,
#  ('diagonal', 'inches'): 0.09090909090909091,
#  ('inches', 'millimeters'): 0.09090909090909091,
#  ('millimeters', 'feature'): 0.09090909090909091,
#  ('phones', 'generally'): 0.09090909090909091,
#  ('generally', 'screen'): 0.09090909090909091,
#  ('sizes', 'millimetres'): 0.09090909090909091,
#  ('millimetres', 'phones'): 0.09090909090909091,
#  ('phones', 'screens'): 0.09090909090909091,
#  ('screens', 'larger'): 0.09090909090909091,
#  ('larger', 'millimetres'): 0.09090909090909091,
#  ('millimetres', 'called'): 0.09090909090909091,
#  ('called', 'phablets'): 0.09090909090909091,
#  ('phablets', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'screens'): 0.09090909090909091,
#  ('screens', 'millimetres'): 0.09090909090909091,
#  ('millimetres', 'size'): 0.09090909090909091,
#  ('size', 'commonly'): 0.09090909090909091,
#  ('commonly', 'difficult'): 0.09090909090909091,
#  ('difficult', 'use'): 0.09090909090909091,
#  ('use', 'single'): 0.09090909090909091,
#  ('single', 'hand'): 0.09090909090909091,
#  ('hand', 'thumbs'): 0.09090909090909091,
#  ('thumbs', 'reach'): 0.09090909090909091,
#  ('reach', 'entire'): 0.09090909090909091,
#  ('entire', 'screen'): 0.09090909090909091,
#  ('screen', 'surface'): 0.09090909090909091,
#  ('surface', 'need'): 0.09090909090909091,
#  ('need', 'shifted'): 0.09090909090909091,
#  ('shifted', 'hand'): 0.09090909090909091,
#  ('hand', 'held'): 0.09090909090909091,
#  ('held', 'hand'): 0.09090909090909091,
#  ('hand', 'manipulated'): 0.09090909090909091,
#  ('manipulated', 'place'): 0.09090909090909091,
#  ('place', 'hands'): 0.09090909090909091,
#  ('hands', 'design'): 0.09090909090909091,
#  ('design', 'advances'): 0.09090909090909091,
#  ('advances', 'modern'): 0.09090909090909091,
#  ('modern', 'smartphones'): 0.09090909090909091,
#  ('smartphones', 'large'): 0.09090909090909091,
#  ('large', 'screen'): 0.09090909090909091,
#  ('sizes', 'edgetoedge'): 0.09090909090909091,
#  ('edgetoedge', 'designs'): 0.09090909090909091,
#  ('designs', 'compact'): 0.09090909090909091,
#  ('compact', 'builds'): 0.09090909090909091,
#  ('builds', 'improve'): 0.09090909090909091,
#  ('improve', 'ergonomics'): 0.09090909090909091,
#  ('ergonomics', 'shift'): 0.09090909090909091,
#  ('shift', 'taller'): 0.09090909090909091,
#  ('ratios', 'resulted'): 0.09090909090909091,
#  ('resulted', 'phones'): 0.09090909090909091,
#  ('phones', 'larger'): 0.09090909090909091,
#  ('larger', 'screen'): 0.09090909090909091,
#  ('sizes', 'whilst'): 0.09090909090909091,
#  ('whilst', 'maintaining'): 0.09090909090909091,
#  ('maintaining', 'ergonomics'): 0.09090909090909091,
#  ('ergonomics', 'associated'): 0.09090909090909091,
#  ('associated', 'smaller'): 0.09090909090909091,
#  ('smaller', 'displays'): 0.09090909090909091,
#  ('displays', 'liquidcrystal'): 0.09090909090909091,
#  ('liquidcrystal', 'displays'): 0.09090909090909091,
#  ('displays', 'common'): 0.09090909090909091,
#  ('common', 'ips'): 0.09090909090909091,
#  ('ips', 'led'): 0.09090909090909091,
#  ('led', 'oled'): 0.09090909090909091,
#  ('oled', 'amoled'): 0.09090909090909091,
#  ...}

# %% [markdown]
# # FBI Score
# We calculate the FBI score for each bi-gram on the corpus defined as :

# %%
# the alpha is defined between 0 and 0.5
def FBI(bigram, alpha, hwpo, hwo):
    return hwpo[bigram]*(1 - (alpha * (hwo[bigram[0]] + hwo[bigram[1]])))

# %%
fbi_bigrams = {bigram:FBI(bigram, 0.05, hwpo, hwo) for bigram in bigrams if FBI(bigram, 0.05, hwpo, hwo) > 0.5}
fbi_bigrams
# Out:
# {('mobile', 'phone'): 0.9023778195488722,
#  ('phone', 'cell'): 0.63859566185694,
#  ('cell', 'phone'): 0.8845597541556188,
#  ('portable', 'telephone'): 0.6750619258560987,
#  ('radio', 'frequency'): 0.6834503842022638,
#  ('frequency', 'link'): 0.6882451993495227,
#  ('telephone', 'service'): 0.8746532634032634,
#  ('service', 'area'): 0.6751189678116369,
#  ('systems', 'mobile'): 0.8094418081918082,
#  ('phone', 'operator'): 0.8155562952085509,
#  ('modern', 'mobile'): 0.6585022073790869,
#  ('mobile', 'telephone'): 0.8547537878787879,
#  ('services', 'use'): 0.6602134660452329,
#  ('cellular', 'network'): 0.8438957533694376,
#  ('cell', 'phones'): 0.8503321678321678,
#  ('north', 'america'): 0.6963243147829613,
#  ('digital', 'mobile'): 0.6502442873542497,
#  ('mobile', 'phones'): 0.8957171212246401,
#  ('text', 'messaging'): 0.8989321095571096,
#  ('wireless', 'communications'): 0.6818104279805407,
#  ('video', 'games'): 0.8523787334219666,
#  ('feature', 'phones'): 0.8845161417529838,
#  ('phones', 'mobile'): 0.8098512014301488,
#  ('phones', 'offer'): 0.6666273951612297,
#  ('advanced', 'computing'): 0.6931628740933251,
#  ('development', 'metaloxidesemiconductor'): 0.6899740093866034,
#  ('metaloxidesemiconductor', 'mos'): 0.8563805242376672,
#  ('mos', 'largescale'): 0.694768824533862,
#  ('largescale', 'integration'): 0.6963243147829613,
#  ('integration', 'lsi'): 0.6963243147829613,
#  ('lsi', 'technology'): 0.684933475046257,
#  ('technology', 'information'): 0.6801386598989981,
#  ('information', 'theory'): 0.6915294996357025,
#  ('theory', 'cellular'): 0.6732881404309975,
#  ('cellular', 'networking'): 0.6732881404309975,
#  ('networking', 'led'): 0.6931628740933251,
#  ('led', 'development'): 0.6883680589460663,
#  ('development', 'affordable'): 0.6915294996357025,
#  ('affordable', 'mobile'): 0.6632970225263458,
#  ('mobile', 'communications'): 0.656862251157364,
#  ('handheld', 'mobile'): 0.8639348167496663,
#  ('phone', 'demonstrated'): 0.6634067185946885,
#  ('demonstrated', 'john'): 0.694768824533862,
#  ('john', 'f'): 0.6963243147829613,
#  ('f', 'mitchell'): 0.6963243147829613,
#  ('mitchell', 'martin'): 0.694768824533862,
#  ('martin', 'cooper'): 0.8563805242376672,
#  ('cooper', 'motorola'): 0.8503527675332186,
#  ('motorola', 'handset'): 0.6867281027243433,
#  ('handset', 'weighing'): 0.6931628740933251,
#  ('nippon', 'telegraph'): 0.6963243147829613,
#  ('telegraph', 'telephone'): 0.676617416105198,
#  ('dynatac', 'x'): 0.8543965683439367,
#  ('x', 'commercially'): 0.8543965683439367,
#  ('commercially', 'available'): 0.8714233135285767,
#  ('available', 'handheld'): 0.8218062983382532,
#  ('worldwide', 'mobile'): 0.6552179070929071,
#  ('seven', 'billion'): 0.694768824533862,
#  ('worldwide', 'samsung'): 0.6801660839160838,
#  ('samsung', 'apple'): 0.8422936242955039,
#  ('apple', 'huawei'): 0.8483688116394883,
#  ('cellular', 'phones'): 0.6435912208092658,
#  ('world', 'war'): 0.6834306389099621,
#  ('mobile', 'telephony'): 0.8114731947250745,
#  ('g', 'systems'): 0.6635438386801168,
#  ('simultaneous', 'calls'): 0.8320093064829907,
#  ('handheld', 'cellular'): 0.6535812417532342,
#  ('cellular', 'mobile'): 0.6402608481743819,
#  ('launched', 'japan'): 0.6834306389099621,
#  ('cellular', 'technology'): 0.6618973006942931,
#  ('digital', 'cellular'): 0.6602354052589015,
#  ('launched', 'finland'): 0.6801573082306164,
#  ('gsm', 'standard'): 0.6818104279805407,
#  ('network', 'operators'): 0.6768368082418833,
#  ('gsm', 'g'): 0.6651881827445737,
#  ('g', 'g'): 0.7991927245686644,
#  ('lithiumion', 'battery'): 0.681716089361766,
#  ('standard', 'offered'): 0.6866897091004233,
#  ('standardization', 'bodies'): 0.6963243147829613,
#  ('feature', 'phone'): 0.7991886590852756,
#  ('phones', 'typically'): 0.658548279727791,
#  ('voice', 'calling'): 0.690001433403689,
#  ('calling', 'text'): 0.6817720343566207,
#  ('service', 'provider'): 0.678280408501273,
#  ('basic', 'mobile'): 0.6585022073790869,
#  ('phones', 'basic'): 0.6618325800139709,
#  ('use', 'mobile'): 0.8799466417041605,
#  ('operating', 'system'): 0.690001433403689,
#  ('cell', 'towers'): 0.8217276989927366,
#  ('towers', 'placed'): 0.6899740093866034,
#  ('cell', 'uses'): 0.8176703465707226,
#  ('high', 'traffic'): 0.6931628740933251,
#  ('phone', 'companies'): 0.6618007681541516,
#  ('uses', 'frequency'): 0.6801660839160838,
#  ('frequency', 'door'): 0.6882451993495227,
#  ('found', 'mobile'): 0.6552179070929071,
#  ('phones', 'central'): 0.6634659544715935,
#  ('central', 'processing'): 0.8524126124502064,
#  ('processing', 'unit'): 0.6916073838442259,
#  ('subscriber', 'identity'): 0.694768824533862,
#  ('identity', 'module'): 0.8563805242376672,
#  ('module', 'sim'): 0.6733978364993403,
#  ('sim', 'cards'): 0.8544830607988503,
#  ('ruim', 'cards'): 0.6898895434139795,
#  ('taller', 'aspect'): 0.694768824533862,
#  ('aspect', 'ratios'): 0.694768824533862,
#  ('screen', 'sizes'): 0.8756562735510104,
#  ('longdistance', 'calls'): 0.678280408501273,
#  ('small', 'speakers'): 0.6899740093866034,
#  ('sim', 'card'): 0.9026775542752986,
#  ('card', 'mobile'): 0.8032975076302143,
#  ('software', 'platforms'): 0.8442951972839191,
#  ('section', 'needs'): 0.6932133342847628,
#  ('smartphones', 'mobile'): 0.6435901238485824,
#  ('mobile', 'app'): 0.8073995803695052,
#  ('application', 'mobile'): 0.6552179070929071,
#  ('sms', 'text'): 0.6768543596128181,
#  ('citation', 'needed'): 0.684933475046257,
#  ('application', 'stores'): 0.6850837586598864,
#  ('app', 'store'): 0.685036589350499,
#  ('smartphone', 'manufacturers'): 0.8340948994614408,
#  ('huawei', 'oppo'): 0.6931628740933251,
#  ('market', 'leader'): 0.6915294996357025,
#  ('leader', 'mobile'): 0.6632970225263458,
#  ('million', 'units'): 0.6883340531648802,
#  ('phone', 'subscribers'): 0.870212703962704,
#  ('mobile', 'operators'): 0.8114731947250745,
#  ('operators', 'million'): 0.6834547720449975,
#  ('million', 'subscribers'): 0.6801573082306164,
#  ('family', 'members'): 0.6916073838442259,
#  ('phones', 'use'): 0.7889070515950215,
#  ('developing', 'countries'): 0.678387910648249,
#  ('world', 'mobile'): 0.6535647873429828,
#  ('phone', 'sharing'): 0.6649622088437878,
#  ('media', 'content'): 0.6850837586598864,
#  ('content', 'mobile'): 0.8094418081918082,
#  ('mobile', 'banking'): 0.8723805361305362,
#  ('text', 'message'): 0.6817720343566207,
#  ('united', 'states'): 0.8443195901842518,
#  ('mobile', 'payments'): 0.8094418081918082,
#  ('contactless', 'payments'): 0.6882451993495227,
#  ('law', 'enforcement'): 0.8483213809999525,
#  ('phone', 'use'): 0.8913392246850893,
#  ('use', 'certain'): 0.8236723552137085,
#  ('use', 'driving'): 0.6469215934441498,
#  ('driving', 'including'): 0.6685185553794576,
#  ('phone', 'texting'): 0.6552299736604248,
#  ('distracted', 'driving'): 0.6701585116011807,
#  ('phones', 'driving'): 0.7971355899739359,
#  ('handheld', 'handsfree'): 0.6718226009579392,
#  ('handsfree', 'use'): 0.6634977663314129,
#  ('countries', 'including'): 0.6735086295283663,
#  ('texting', 'driving'): 0.6652210915650765,
#  ('ban', 'handheld'): 0.6750619258560987,
#  ('states', 'banned'): 0.6834503842022638,
#  ('banned', 'texting'): 0.6817972644523396,
#  ('health', 'effects'): 0.6817720343566207,
#  ('phone', 'radiation'): 0.6618007681541516,
#  ('human', 'health'): 0.684933475046257,
#  ('increase', 'mobile'): 0.6519061827896414,
#  ('phone', 'usage'): 0.6585274374748059,
#  ('health', 'risk'): 0.678498703677275,
#  ('possibly', 'carcinogenic'): 0.694768824533862,
#  ('electronic', 'waste'): 0.694768824533862,
#  ('san', 'francisco'): 0.6963243147829613,
#  ('install', 'kill'): 0.6963243147829613,
#  ('imei', 'blacklisted'): 0.6899740093866034,
#  ('telecom', 'carriers'): 0.6932133342847628,
#  ('biological', 'group'): 0.694768824533862,
#  ('gps', 'tracker'): 0.694768824533862,
#  ('conflict', 'minerals'): 0.6916073838442259,
#  ('kosher', 'phones'): 0.82161522061898}

# %% [markdown]
# # FNI Score
#
# then we calculate the FNI for each n-gram present in the corpus

# %%
def FNI(ngrams):
    
    last_ngram = ngrams[-1]
    conserved_ngram = ngrams[-1]
    trigram = []
    it = iter(last_ngram)
    for (bigram, score) in it:
        next_bigram, next_score = next(it, (None, None))
        if next_bigram is None:
            break
        if bigram[1] == next_bigram[0]:
            trigram.append((tuple(list(bigram) + [next_bigram[-1]]), statistics.mean([score, next_score])))
            conserved_ngram.remove((bigram, score))
            conserved_ngram.remove((next_bigram, next_score))
        else:
            it = itertools.chain(it, [(next_bigram, next_score)])
        
    ngrams[-1] = conserved_ngram
    ngrams.append(trigram)
    if trigram != []:
        FNI(ngrams)
    return ngrams[:-1]
        
fni_ngrams = FNI([list(fbi_bigrams.items())])
fni_ngrams
# Out:
# [[(('cell', 'phone'), 0.8845597541556188),
#   (('portable', 'telephone'), 0.6750619258560987),
#   (('telephone', 'service'), 0.8746532634032634),
#   (('service', 'area'), 0.6751189678116369),
#   (('systems', 'mobile'), 0.8094418081918082),
#   (('phone', 'operator'), 0.8155562952085509),
#   (('services', 'use'), 0.6602134660452329),
#   (('cellular', 'network'), 0.8438957533694376),
#   (('cell', 'phones'), 0.8503321678321678),
#   (('north', 'america'), 0.6963243147829613),
#   (('text', 'messaging'), 0.8989321095571096),
#   (('wireless', 'communications'), 0.6818104279805407),
#   (('video', 'games'), 0.8523787334219666),
#   (('feature', 'phones'), 0.8845161417529838),
#   (('phones', 'mobile'), 0.8098512014301488),
#   (('phones', 'offer'), 0.6666273951612297),
#   (('advanced', 'computing'), 0.6931628740933251),
#   (('development', 'metaloxidesemiconductor'), 0.6899740093866034),
#   (('largescale', 'integration'), 0.6963243147829613),
#   (('integration', 'lsi'), 0.6963243147829613),
#   (('information', 'theory'), 0.6915294996357025),
#   (('theory', 'cellular'), 0.6732881404309975),
#   (('led', 'development'), 0.6883680589460663),
#   (('development', 'affordable'), 0.6915294996357025),
#   (('handheld', 'mobile'), 0.8639348167496663),
#   (('phone', 'demonstrated'), 0.6634067185946885),
#   (('f', 'mitchell'), 0.6963243147829613),
#   (('mitchell', 'martin'), 0.694768824533862),
#   (('motorola', 'handset'), 0.6867281027243433),
#   (('handset', 'weighing'), 0.6931628740933251),
#   (('dynatac', 'x'), 0.8543965683439367),
#   (('x', 'commercially'), 0.8543965683439367),
#   (('worldwide', 'mobile'), 0.6552179070929071),
#   (('seven', 'billion'), 0.694768824533862),
#   (('apple', 'huawei'), 0.8483688116394883),
#   (('cellular', 'phones'), 0.6435912208092658),
#   (('world', 'war'), 0.6834306389099621),
#   (('mobile', 'telephony'), 0.8114731947250745),
#   (('g', 'systems'), 0.6635438386801168),
#   (('simultaneous', 'calls'), 0.8320093064829907),
#   (('launched', 'japan'), 0.6834306389099621),
#   (('cellular', 'technology'), 0.6618973006942931),
#   (('digital', 'cellular'), 0.6602354052589015),
#   (('launched', 'finland'), 0.6801573082306164),
#   (('gsm', 'standard'), 0.6818104279805407),
#   (('network', 'operators'), 0.6768368082418833),
#   (('lithiumion', 'battery'), 0.681716089361766),
#   (('standard', 'offered'), 0.6866897091004233),
#   (('standardization', 'bodies'), 0.6963243147829613),
#   (('feature', 'phone'), 0.7991886590852756),
#   (('phones', 'typically'), 0.658548279727791),
#   (('voice', 'calling'), 0.690001433403689),
#   (('calling', 'text'), 0.6817720343566207),
#   (('service', 'provider'), 0.678280408501273),
#   (('basic', 'mobile'), 0.6585022073790869),
#   (('phones', 'basic'), 0.6618325800139709),
#   (('use', 'mobile'), 0.8799466417041605),
#   (('operating', 'system'), 0.690001433403689),
#   (('cell', 'uses'), 0.8176703465707226),
#   (('high', 'traffic'), 0.6931628740933251),
#   (('phone', 'companies'), 0.6618007681541516),
#   (('uses', 'frequency'), 0.6801660839160838),
#   (('frequency', 'door'), 0.6882451993495227),
#   (('found', 'mobile'), 0.6552179070929071),
#   (('processing', 'unit'), 0.6916073838442259),
#   (('subscriber', 'identity'), 0.694768824533862),
#   (('sim', 'cards'), 0.8544830607988503),
#   (('ruim', 'cards'), 0.6898895434139795),
#   (('screen', 'sizes'), 0.8756562735510104),
#   (('longdistance', 'calls'), 0.678280408501273),
#   (('small', 'speakers'), 0.6899740093866034),
#   (('sim', 'card'), 0.9026775542752986),
#   (('card', 'mobile'), 0.8032975076302143),
#   (('software', 'platforms'), 0.8442951972839191),
#   (('section', 'needs'), 0.6932133342847628),
#   (('smartphones', 'mobile'), 0.6435901238485824),
#   (('mobile', 'app'), 0.8073995803695052),
#   (('application', 'mobile'), 0.6552179070929071),
#   (('sms', 'text'), 0.6768543596128181),
#   (('citation', 'needed'), 0.684933475046257),
#   (('application', 'stores'), 0.6850837586598864),
#   (('app', 'store'), 0.685036589350499),
#   (('smartphone', 'manufacturers'), 0.8340948994614408),
#   (('huawei', 'oppo'), 0.6931628740933251),
#   (('million', 'units'), 0.6883340531648802),
#   (('phone', 'subscribers'), 0.870212703962704),
#   (('million', 'subscribers'), 0.6801573082306164),
#   (('family', 'members'), 0.6916073838442259),
#   (('phones', 'use'), 0.7889070515950215),
#   (('developing', 'countries'), 0.678387910648249),
#   (('world', 'mobile'), 0.6535647873429828),
#   (('phone', 'sharing'), 0.6649622088437878),
#   (('mobile', 'banking'), 0.8723805361305362),
#   (('text', 'message'), 0.6817720343566207),
#   (('united', 'states'), 0.8443195901842518),
#   (('mobile', 'payments'), 0.8094418081918082),
#   (('contactless', 'payments'), 0.6882451993495227),
#   (('law', 'enforcement'), 0.8483213809999525),
#   (('use', 'driving'), 0.6469215934441498),
#   (('driving', 'including'), 0.6685185553794576),
#   (('phone', 'texting'), 0.6552299736604248),
#   (('distracted', 'driving'), 0.6701585116011807),
#   (('phones', 'driving'), 0.7971355899739359),
#   (('handheld', 'handsfree'), 0.6718226009579392),
#   (('handsfree', 'use'), 0.6634977663314129),
#   (('countries', 'including'), 0.6735086295283663),
#   (('texting', 'driving'), 0.6652210915650765),
#   (('ban', 'handheld'), 0.6750619258560987),
#   (('health', 'effects'), 0.6817720343566207),
#   (('phone', 'radiation'), 0.6618007681541516),
#   (('human', 'health'), 0.684933475046257),
#   (('increase', 'mobile'), 0.6519061827896414),
#   (('phone', 'usage'), 0.6585274374748059),
#   (('health', 'risk'), 0.678498703677275),
#   (('possibly', 'carcinogenic'), 0.694768824533862),
#   (('electronic', 'waste'), 0.694768824533862),
#   (('san', 'francisco'), 0.6963243147829613),
#   (('install', 'kill'), 0.6963243147829613),
#   (('imei', 'blacklisted'), 0.6899740093866034),
#   (('telecom', 'carriers'), 0.6932133342847628),
#   (('biological', 'group'), 0.694768824533862),
#   (('gps', 'tracker'), 0.694768824533862),
#   (('conflict', 'minerals'), 0.6916073838442259),
#   (('kosher', 'phones'), 0.82161522061898)],
#  [(('mobile', 'phone', 'cell'), 0.7704867407029061),
#   (('radio', 'frequency', 'link'), 0.6858477917758932),
#   (('modern', 'mobile', 'telephone'), 0.7566279976289374),
#   (('digital', 'mobile', 'phones'), 0.7729807042894449),
#   (('metaloxidesemiconductor', 'mos', 'largescale'), 0.7755746743857646),
#   (('lsi', 'technology', 'information'), 0.6825360674726275),
#   (('cellular', 'networking', 'led'), 0.6832255072621614),
#   (('affordable', 'mobile', 'communications'), 0.6600796368418549),
#   (('demonstrated', 'john', 'f'), 0.6955465696584117),
#   (('martin', 'cooper', 'motorola'), 0.853366645885443),
#   (('nippon', 'telegraph', 'telephone'), 0.6864708654440796),
#   (('commercially', 'available', 'handheld'), 0.846614805933415),
#   (('worldwide', 'samsung', 'apple'), 0.7612298541057938),
#   (('handheld', 'cellular', 'mobile'), 0.6469210449638081),
#   (('gsm', 'g', 'g'), 0.7321904536566191),
#   (('cell', 'towers', 'placed'), 0.75585085418967),
#   (('phones', 'central', 'processing'), 0.7579392834609),
#   (('identity', 'module', 'sim'), 0.7648891803685037),
#   (('taller', 'aspect', 'ratios'), 0.694768824533862),
#   (('market', 'leader', 'mobile'), 0.6774132610810242),
#   (('mobile', 'operators', 'million'), 0.7474639833850361),
#   (('media', 'content', 'mobile'), 0.7472627834258473),
#   (('phone', 'use', 'certain'), 0.857505789949399),
#   (('states', 'banned', 'texting'), 0.6826238243273017)]]

# %% [markdown]
# # Extract High Relevant Monogram
# Finally, we extract the high relevant mono and n-gram

# %%
def extract_high_relevant_monogram(monograms, highest_freq_bigram):
    high_relevant_monograms = []
    for gram in monograms.items():
        if gram[1] > highest_freq_bigram * 8:
            high_relevant_monograms.append(gram)
    return high_relevant_monograms

highest_frequency = sorted(bigram_frequency.items(), key=lambda x : x[1], reverse=True)[0][1]
highest_monogram = extract_high_relevant_monogram(monogram_frequency, highest_frequency)

# %% [markdown]
# ## Extract High Relevant N-gram

# %%
top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)
highest_ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1] >= top_bigram_mean]

# %% [markdown]
# ## Visualize the Result

# %% [markdown]
# We extract the different top

# %%
top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)

ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1]]
top_ranked_ngram = sorted(ngrams, key=lambda x: x[1], reverse=True)[:11]

# %% [markdown]
# The final list is ordered as : top 5 monogram, top 10 bigram and top 10 ngram

# %%
print('-'* 30)
print('Top Monograms :')
print(highest_monogram)
print('-'* 30)
print('Top Highest Ngrams :')
print(highest_ngrams)
print('-'* 30)
print('Top Bigram :')
print('-'* 30)
print('\n'.join([' '.join(bigram[0]) for bigram in top_ranked_bigram]))
print('-' * 30)
print('Top Ngram :')
print('-'* 30)
print('\n'.join([' '.join(ngram[0]) for ngram in top_ranked_ngram]))
# Out:
# ------------------------------
# Top Monograms :
# []
# ------------------------------
# Top Highest Ngrams :
# []
# ------------------------------
# Top Bigram :
# ------------------------------
# sim card
# text messaging
# cell phone
# feature phones
# use mobile
# screen sizes
# telephone service
# mobile banking
# phone subscribers
# handheld mobile
# sim cards
# ------------------------------
# Top Ngram :
# ------------------------------
# phone use certain
# martin cooper motorola
# commercially available handheld
# metaloxidesemiconductor mos largescale
# digital mobile phones
# mobile phone cell
# identity module sim
# worldwide samsung apple
# phones central processing
# modern mobile telephone
# cell towers placed

# %% [markdown]
# # using the implementation on several texts

# %%
def automatic_keyword_extraction(word_list:list, alpha:float, threshold:float):
    bigrams = list(nltk.bigrams(word_list))
    monogram_frequency = Counter(word_list)
    bigram_frequency = Counter([i for i in bigrams])
    
    cumul_monogram = compute_cumul_freq_monogram(monogram_frequency)
    cumul_bigram = compute_cumul_freq_bigram(bigram_frequency)
    
    hwo = {word: HWO(word, monogram_frequency, cumul_monogram) for word in word_list}
    hwpo = {bigram: HWPO(bigram, bigram_frequency, cumul_bigram) for bigram in list(bigrams)}
    
    # Step 1
    fbi_bigrams = {bigram:FBI(bigram, alpha, hwpo, hwo) for bigram in bigrams if FBI(bigram, alpha, hwpo, hwo) > threshold}
    
    # Step 2
    fni_ngrams = FNI([list(fbi_bigrams.items())])
    
    # Step 3
    highest_frequency = sorted(bigram_frequency.items(), key=lambda x : x[1], reverse=True)[0][1]
    highest_monogram = extract_high_relevant_monogram(monogram_frequency, highest_frequency)
    
    top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
    top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)
    
    ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1]]
    highest_ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1] >= top_bigram_mean]
    top_ranked_ngram = sorted(ngrams, key=lambda x: x[1], reverse=True)[:11]
    
    return {'monograms': highest_monogram, 
            'highest n-grams': highest_ngrams, 
            'top ranked bigrams': top_ranked_bigram,
            'top ranked n-grams': top_ranked_ngram}

automatic_keyword_extraction(word_list, 0.02, 0.5)
# Out:
# {'monograms': [],
#  'highest n-grams': [],
#  'top ranked bigrams': [(('cell', 'phone'), 0.9358418836802295),
#   (('sim', 'card'), 0.9340979947370925),
#   (('use', 'mobile'), 0.9339966386996462),
#   (('feature', 'phones'), 0.9268334297281665),
#   (('text', 'messaging'), 0.9176148018648019),
#   (('handheld', 'mobile'), 0.9096098907358307),
#   (('telephone', 'service'), 0.9079032634032634),
#   (('mobile', 'banking'), 0.9069941724941726),
#   (('phone', 'subscribers'), 0.9061270396270397),
#   (('cell', 'phones'), 0.8981748251748252),
#   (('screen', 'sizes'), 0.8873254464833412)],
#  'top ranked n-grams': [(('phone', 'use', 'certain'), 0.8965487695262131),
#   (('commercially', 'available', 'handheld'), 0.8667178504452941),
#   (('martin', 'cooper', 'motorola'), 0.8604275774350962),
#   (('mobile', 'phone', 'cell'), 0.8182846063710725),
#   (('digital', 'mobile', 'phones'), 0.8162851888086851),
#   (('modern', 'mobile', 'telephone'), 0.7917620881624641),
#   (('metaloxidesemiconductor', 'mos', 'largescale'), 0.7798602393846754),
#   (('identity', 'module', 'sim'), 0.775586041777771),
#   (('worldwide', 'samsung', 'apple'), 0.7741223112726872),
#   (('phones', 'central', 'processing'), 0.7728060830147296),
#   (('cell', 'towers', 'placed'), 0.7719707113062375)]}

# %% [markdown]
# # Using the keyword extraction to the HAS corpus

# %% [markdown]
# ### load french spacy model

# %%
nlp = spacy.load('fr_core_news_sm')

# %%
has_json = json.load(open('processed-HAS.json', 'r'))

# %%
data = {}
url_c = 0
for url, article in has_json.items():
    text = remove_digits(article)
    # tokenize text
    doc = nlp(text)
    # remove stopwords
    word_list =  [token.text for token in doc if not token.is_stop and not token.is_space]
    if len(word_list) > 80:
        data[url] = [article, automatic_keyword_extraction(word_list, 0.02, 0.5)]
        url_c += 1
print(f'url : {len(has_json)}')
print(f'url processed : {url_c}')
json.dump(data, open('has_keywords_result.json', 'w'), indent=4, sort_keys=True)
# Out:
# url : 377
# url processed : 120
# {'https://www.has-sante.fr/jcms/c_1009982/fr/biologie-des-anomalies-de-l-hemostase': ['Ce travail a eu pour but d’évaluer dix actes de biologie mesurant les anomalies de l’hémostase, qui avaient été signalés par le demandeur de cette évaluation soit comme obsolètes mais figurant encore à la Nomenclature des actes de biologie médicale (NABM), soit comme pertinents mais ne figurant pourtant pas dans cette nomenclature. Cette évaluation pourra donc permettre l’actualisation du sous chapitre 5-02 « Hémostase et coagulation » de la NABM. Cette évaluation a donné lieu à la rédaction de sept documents : Tome I : Evaluation du Temps de saignement (Epreuve de DUKE et tests d’IVY) ;Tome II : Temps de Thrombine et correction du Temps de Thrombine ;Tome III : Test photométrique d’agrégation plaquettaire ;Tome IV : Recherche d’anticorps antifacteur 4 plaquettaire dans le cadre d’une thrombopénie induite par l’héparine ;Tome V : Recherche et titrage d’inhibiteur contre les facteurs antihémophiliques ;Tome VI : Détection d’un anticoagulant de type lupique ;Tome VII : Recherche de la mutation G1691A du gène du facteur V (FV de Leiden) et de la mutation G20210A du gène du facteur II. Le texte court de cette évaluation reprend la totalité des 7 tomes (10 actes évalués). Tome I : Evaluation du Temps de saignement (Epreuve de DUKE et tests d’IVY) ; Tome II : Temps de Thrombine et correction du Temps de Thrombine ; Tome III : Test photométrique d’agrégation plaquettaire ; Tome IV : Recherche d’anticorps antifacteur 4 plaquettaire dans le cadre d’une thrombopénie induite par l’héparine ; Tome V : Recherche et titrage d’inhibiteur contre les facteurs antihémophiliques ; Tome VI : Détection d’un anticoagulant de type lupique ; Tome VII : Recherche de la mutation G1691A du gène du facteur V (FV de Leiden) et de la mutation G20210A du gène du facteur II. Le texte court de cette évaluation reprend la totalité des 7 tomes (10 actes évalués).',
#   {'monograms': [],
#    'highest n-grams': [(('II', 'Temps', 'Thrombine'), 0.9516652825836216),
#     (('mutation', 'GA', 'gène'), 0.9833411764705883)],
#    'top ranked bigrams': [(('gène', 'facteur'), 0.9833411764705883),
#     (('saignement', 'Epreuve'), 0.9418509803921568),
#     (('Epreuve', 'DUKE'), 0.9418509803921568),
#     (('III', 'Test'), 0.9418509803921568),
#     (('Test', 'photométrique'), 0.9418509803921568),
#     (('danticorps', 'antifacteur'), 0.9418509803921568),
#     (('dune', 'thrombopénie'), 0.9418509803921568),
#     (('thrombopénie', 'induite'), 0.9418509803921568),
#     (('dinhibiteur', 'contre'), 0.9418509803921568),
#     (('contre', 'facteurs'), 0.9418509803921568),
#     (('VI', 'Détection'), 0.9418509803921568)],
#    'top ranked n-grams': [(('mutation', 'GA', 'gène'), 0.9833411764705883),
#     (('II', 'Temps', 'Thrombine'), 0.9516652825836216),
#     (('DUKE', 'tests', 'dIVY'), 0.9418509803921568),
#     (('Détection', 'dun', 'anticoagulant'), 0.9418509803921568),
#     (('reprend', 'totalité', 'tomes'), 0.9418509803921568),
#     (('photométrique', 'dagrégation', 'plaquettaire'), 0.9401727797001154),
#     (('plaquettaire', 'cadre', 'dune'), 0.9401727797001154),
#     (('V', 'FV', 'Leiden'), 0.9401727797001154),
#     (('II', 'texte', 'court'), 0.9401727797001154),
#     (('Recherche', 'titrage', 'dinhibiteur'), 0.9364807381776239),
#     (('induite', 'lhéparine', 'Tome'), 0.9346235294117646)]}],
#  'https://www.has-sante.fr/jcms/c_1164340/fr/evaluation-de-la-sialendoscopie-parotidienne-et-submandibulaire-a-visee-diagnostique-et-therapeutique': ["Objectifs Les questions médicales de cette évaluation portent sur la technique de sialendoscopie (endoscopie des voies salivaires principales: parotide et glande submandibulaire) et peuvent être regroupées en 3 grandes thématiques: la capacité de la technique à diagnostiquer une pathologie d’obstruction salivaire non tumorale;sa capacité à traiter avec une balance bénéfice-risque favorable les pathologies salivaires à type d’obstruction en améliorant la prise en charge des patients;les conditions de réalisation de cet acte. la capacité de la technique à diagnostiquer une pathologie d’obstruction salivaire non tumorale; sa capacité à traiter avec une balance bénéfice-risque favorable les pathologies salivaires à type d’obstruction en améliorant la prise en charge des patients; les conditions de réalisation de cet acte. Méthode La méthode d\\'évaluation utilisée dans ce rapport comporte: une analyse critique des études cliniques identifiées jusqu’en février 2015 par une revue systématique;le recueil de la position argumentée d’un groupe de travail multidisciplinaire. une analyse critique des études cliniques identifiées jusqu’en février 2015 par une revue systématique; le recueil de la position argumentée d’un groupe de travail multidisciplinaire. Les conclusions du rapport de l’évaluation sont fondées sur les données ainsi recueillies. Ces conclusions sont examinées par la Commission nationale d’évaluation des dispositifs médicaux et des technologies de santé (CNEDIMTS) puis validées par le Collège de la HAS. Résultats Actuellement, l’analyse de la littérature ne permet pas de conclure formellement ni sur les performances diagnostiques ni sur l’efficacité et la sécurité de l’acte quelle que soit l’indication obstructive concernée (lithiases, sténoses, sialadénites et sialodochites inflammatoires ou systémiques) en raison du niveau de preuve faible des études identifiées (n=38). Il s’agit d’études non comparatives, majoritairement des séries de cas rétrospectives avec un suivi de patients court présentant une hétérogénéité dans les formes pathologiques traitées et les modalités techniques utilisées (sialendoscopie interventionnelle avec accessoires de capture, fragmentation endocanalaire par fibres lasers, technique combinée d’abord chirurgical guidé par l’endoscope). Il est noté que la technique présente l’avantage très souvent de coupler dans le même temps opératoire la confirmation du diagnostic et le traitement. Les taux de complications rapportés sont relativement faibles. La position du groupe de travail consulté lors de cette évaluation est que la sialendoscopie a amélioré chez l’enfant et l’adulte le traitement des obstructions des voies salivaires et apporté des réponses pour le diagnostic des obstructions non lithiasiques. Elle a permis de diminuer les exérèses de glande salivaire, en premier lieu le nombre de parotidectomie, acte qui présente un risque nerveux élevé. L’absence de données fiables sur l’efficacité et la sécurité de cet acte est cependant reconnue et sa difficulté de réalisation est pointée. Ceci a conduit le groupe de travail à émettre des préconisations sur l’emploi de cette technique. Elles portent sur sa place dans le diagnostic, proposée après un bilan complet non concluant avec techniques d’imagerie, débuté par l’échographie, et sur la nécessaire formation spécifique des professionnels de santé impliqués. Les experts considèrent que son apport est majeur sur le plan thérapeutique, principalement dans les lithiases. Ils confirment que les données sont plus rares dans les sténoses, pour lesquelles l’étiologie est très variable (traumatique, inflammatoire, systémique) et l’efficacité de la technique n’est pas constante mais ils soulignent qu’aucune autre modalité thérapeutique conservatoire n’est actuellement validée. La sialendoscopie ne peut être réal ...
#   {'monograms': [],
#    'highest n-grams': [(('améliorant', 'prise', 'charge'),
#      0.9270958702064896)],
#    'top ranked bigrams': [(('groupe', 'travail'), 0.95025428932635),
#     (('conditions', 'réalisation'), 0.920466678706881),
#     (('dobstruction', 'salivaire'), 0.918178195171874),
#     (('bénéficerisque', 'favorable'), 0.8807239780868099),
#     (('favorable', 'pathologies'), 0.8807239780868099),
#     (('février', 'revue'), 0.8807239780868099),
#     (('dispositifs', 'médicaux'), 0.8807239780868099),
#     (('études', 'cliniques'), 0.8786403286978508),
#     (('cliniques', 'identifiées'), 0.8786403286978508),
#     (('bilan', 'complet'), 0.8786403286978508),
#     (('bloc', 'opératoire'), 0.8786403286978508)],
#    'top ranked n-grams': [(('améliorant', 'prise', 'charge'),
#      0.9270958702064896),
#     (('traiter', 'balance', 'bénéficerisque'), 0.8807239780868099),
#     (('analyse', 'critique', 'études'), 0.8796821533923304),
#     (('identifiées', 'jusquen', 'février'), 0.8796821533923304),
#     (('position', 'argumentée', 'dun'), 0.8786011378002527),
#     (('pathologies', 'salivaires', 'type'), 0.8743097345132743),
#     (('non', 'concluant', 'techniques'), 0.8742738095238095),
#     (('lefficacité', 'sécurité', 'acte'), 0.8722293510324484),
#     (('technique', 'diagnostiquer', 'pathologie'), 0.8720725874420564)]}],
#  'https://www.has-sante.fr/jcms/c_1225008/fr/evaluation-des-substituts-osseux': ["L’objectif de cette évaluation est de proposer une mise à jour des modalités de remboursement des substituts osseux inscrits sur la LPPR. Deux grandes catégories de substituts osseux sont distinguées par la Commission\\xa0: les substituts osseux synthétiques ne comportant aucun dérivé ou tissu d’origine biologique ou n’étant pas issu de tels dérivés\\xa0;les substituts osseux issus de dérivés, de tissus d\\'origine animale non viables ou en comportant. les substituts osseux synthétiques ne comportant aucun dérivé ou tissu d’origine biologique ou n’étant pas issu de tels dérivés\\xa0; les substituts osseux issus de dérivés, de tissus d\\'origine animale non viables ou en comportant. La CNEDiMTS recommande une indication commune à l’ensemble des descriptions génériques définies, à savoir\\xa0: «\\xa0apport osseux de substitution (comblement, reconstruction, fusion), lorsque les solutions autologues ne sont pas applicables ou suffisantes\\xa0». Les données disponibles ne permettent pas d’affirmer la supériorité d’un type de substituts osseux par rapport à un autre. La commission s’est prononcée pour une absence d’amélioration du service rendu (ASR V) entre les différentes descriptions génériques relatives aux substituts synthétiques et substituts osseux contenant des dérivés d’origine animale. La CNEDiMTS recommande une inscription sous nom de marque pour les substituts osseux ne répondant pas aux spécifications techniques retenues.",
#   {'monograms': [],
#    'highest n-grams': [(('substituts', 'osseux', 'synthétiques'),
#      0.8995780022446689)],
#    'top ranked bigrams': [(('dorigine', 'animale'), 0.9089943883277216),
#     (('biologique', 'nétant'), 0.8557890011223345),
#     (('nétant', 'issu'), 0.8557890011223345),
#     (('CNEDiMTS', 'recommande'), 0.8557890011223345),
#     (('descriptions', 'génériques'), 0.8557890011223345),
#     (('comportant', 'dérivé'), 0.8491358024691358),
#     (('viables', 'comportant'), 0.8491358024691358),
#     (('synthétiques', 'comportant'), 0.8458518518518519),
#     (('dorigine', 'biologique'), 0.8457665544332211),
#     (('tissus', 'dorigine'), 0.8457665544332211),
#     (('osseux', 'issus'), 0.8424399551066217)],
#    'top ranked n-grams': [(('substituts', 'osseux', 'synthétiques'),
#      0.8995780022446689),
#     (('animale', 'non', 'viables'), 0.8541470258136925),
#     (('issus', 'dérivés', 'tissus'), 0.8525050505050505),
#     (('dérivé', 'tissu', 'dorigine'), 0.8507777777777779)]}],
#  'https://www.has-sante.fr/jcms/c_1237001/fr/syndrome-de-bardet-biedl': ["Ce protocole national de diagnostic et de soins (PNDS) explicite aux professionnels concernés la prise en charge diagnostique et thérapeutique optimale et le parcours de soins des patients atteints du Syndrome de Bardet-Biedl. Il a été élaboré par le\\xa0Centre de Référence pour les Affections\\xa0Rares en Génétique Ophtalmologique (CARGO), le Centre de Référence anomalies du développement et syndromes malformatifs Sous l\\'égide et avec le partenariat de\\xa0La Filière de santé des maladies rares sensorielles SENSGENE et La Filière de Santé Anomalies du Développement avec ou sans Déficience Intellectuelle de causes Rares AnDDI-Rares à l’aide d’une méthodologie proposée par la HAS. Il n’a pas fait l’objet d’une validation par la HAS qui n’a pas participé à son élaboration. Ce protocole national de diagnostic et de soins (PNDS) explicite aux professionnels concernés la prise en charge diagnostique et thérapeutique optimale et le parcours de soins des patients atteints du Syndrome de Bardet-Biedl. Il a été élaboré par le\\xa0",
#   {'monograms': [],
#    'highest n-grams': [(('protocole', 'national', 'diagnostic'),
#      0.9793333333333333),
#     (('PNDS', 'explicite', 'professionnels'), 0.9793333333333333),
#     (('prise', 'charge', 'diagnostique'), 0.9793333333333333),
#     (('atteints', 'Syndrome', 'BardetBiedl'), 0.9793333333333333)],
#    'top ranked bigrams': [(('professionnels', 'concernés'),
#      0.9793333333333333),
#     (('concernés', 'prise'), 0.9793333333333333),
#     (('diagnostique', 'thérapeutique'), 0.9793333333333333),
#     (('thérapeutique', 'optimale'), 0.9793333333333333),
#     (('patients', 'atteints'), 0.9793333333333333),
#     (('BardetBiedl', 'élaboré'), 0.9793333333333333),
#     (('diagnostic', 'soins'), 0.9696666666666667),
#     (('soins', 'PNDS'), 0.9696666666666667),
#     (('soins', 'patients'), 0.9696666666666667)],
#    'top ranked n-grams': [(('protocole', 'national', 'diagnostic'),
#      0.9793333333333333),
#     (('PNDS', 'explicite', 'professionnels'), 0.9793333333333333),
#     (('prise', 'charge', 'diagnostique'), 0.9793333333333333),
#     (('atteints', 'Syndrome', 'BardetBiedl'), 0.9793333333333333),
#     (('optimale', 'parcours', 'soins'), 0.9744999999999999)]}],
#  'https://www.has-sante.fr/jcms/c_1261551/fr/delivrance-de-l-information-a-la-personne-sur-son-etat-de-sante': ['La loi du 4 mars 2002 reconnaît un droit général pour toute personne d’être informée sur son état de santé par les professionnels de santé1. Ce droit d’être informé est identique quels que soient le professionnel qui délivre l’information, son mode et son lieu d’exercice (privé et/ou public), quelles que soient les circonstances et qu’il s’agisse de prévention ou de soins. 1 L’information délivrée par le professionnel de santé à la personne est destinée à l’éclairer sur son état de santé et à lui permettre, si nécessaire, de prendre en connaissance de cause les décisions concernant sa santé en fonction de ce qu’elle estime être son intérêt. Cette information permet notamment à la personne d’accepter ou de refuser les actes à visée pré- ventive, diagnostique ou thérapeutique qui lui sont proposés. Pour ce faire, l’information porte sur l’objectif, la nature et le déroulement des actes et du suivi envisagés. L’information est un élément essentiel dans la relation de confiance réciproque entre le professionnel de santé et la per- sonne. À ce titre, elle s’inscrit dans un dialogue. Cette recommandation de bonne pratique actualise celle sur « Information des patients - Recommandations destinées aux médecins » de mars 2000. Les recommandations abordent de façon concrète la démarche d’information. Elles visent à aider les professionnels de santé à satisfaire à leur obligation d’information. \\xa0 Actualisation des recommandations Les modifications relatives à cette actualisation portent sur : \\r\\n\\r\\nle contenu et les qualités de l’information à délivrer, ainsi que sur les modalités de sa délivrance, sa cohérence et l’évaluation de l’information donnée ;\\r\\n\\r\\n\\r\\nl’ajout des paragraphes sur les situations complexes des mineurs et des majeurs protégés, ainsi que les situations de fait où l’information n’est pas délivrée à la personne, parce que les circonstances ne le permettent pas.\\r\\n\\r\\n \\r\\nle contenu et les qualités de l’information à délivrer, ainsi que sur les modalités de sa délivrance, sa cohérence et l’évaluation de l’information donnée ;\\r\\n le contenu et les qualités de l’information à délivrer, ainsi que sur les modalités de sa délivrance, sa cohérence et l’évaluation de l’information donnée ; \\r\\nl’ajout des paragraphes sur les situations complexes des mineurs et des majeurs protégés, ainsi que les situations de fait où l’information n’est pas délivrée à la personne, parce que les circonstances ne le permettent pas.\\r\\n l’ajout des paragraphes sur les situations complexes des mineurs et des majeurs protégés, ainsi que les situations de fait où l’information n’est pas délivrée à la personne, parce que les circonstances ne le permettent pas. Elles abordent également le cas où la personne exprime la volonté de ne pas recevoir l’information. Elles comportent des moyens d’apporter, si besoin, la preuve que l’information a été délivrée à la personne. Par ailleurs, elles ne concernent plus uniquement les médecins mais l’ensemble des professionnels de santé, c’est-à-dire, selon le Code de la santé publique, les professions médicales, les professions de la pharmacie, les auxiliaires médicaux, aides-soignants, auxiliaires de puériculture et ambulanciers. Consulter la liste des professions de santé telles que définies par le Code de la santé publique. Consulter la liste des professions de santé telles que définies par le Code de la santé publique Consulter la liste des professions de santé telles que définies par le Code de la santé publique \\xa0 Exclusions du champ des recommandations Ces recommandations n’abordent pas : \\r\\n\\r\\nl’information concernant les risques inconnus au moment de la réalisation des investigations, traitements ou actions de prévention, et dont la connaissance scientifique est acquise postérieurement ;\\r\\n\\r\\n\\r\\nl’information à donner à la personne sur les circo ...
#   {'monograms': [],
#    'highest n-grams': [(('issues', 'loi', 'n'), 0.9614766421868625)],
#    'top ranked bigrams': [(('Code', 'santé'), 0.9511204464649997),
#     (('santé', 'publique'), 0.9511204464649997),
#     (('délivrer', 'modalités'), 0.9146013871889025),
#     (('cohérence', 'lévaluation'), 0.9146013871889025),
#     (('mineurs', 'majeurs'), 0.9146013871889025),
#     (('majeurs', 'protégés'), 0.9146013871889025),
#     (('risques', 'inconnus'), 0.9146013871889025),
#     (('réalisation', 'investigations'), 0.9146013871889025),
#     (('investigations', 'traitements'), 0.9146013871889025),
#     (('décembre', 'protection'), 0.9146013871889025),
#     (('prêtent', 'recherches'), 0.9146013871889025)],
#    'top ranked n-grams': [(('issues', 'loi', 'n'), 0.9614766421868625),
#     (('causes', 'dun', 'dommage'), 0.9169671416914379),
#     (('modalités', 'délivrance', 'cohérence'), 0.9146013871889025),
#     (('inconnus', 'moment', 'réalisation'), 0.9146013871889025),
#     (('protection', 'personnes', 'prêtent'), 0.9146013871889025),
#     (('biomédicales', 'lois', 'dites'), 0.9146013871889025),
#     (('scientifique', 'acquise', 'postérieurement'), 0.9137135862913097),
#     (('fin', 'vie', 'régie'), 0.9137135862913097),
#     (('Consulter', 'liste', 'professions'), 0.9128119135046919),
#     (('traitements', 'actions', 'prévention'), 0.9128119135046919),
#     (('médicales', 'relevant', 'bioéthique'), 0.9119241126070992)]}],
#  'https://www.has-sante.fr/jcms/c_1343374/fr/prothese-epiretinienne-et-son-acte-d-implantation': ["L’objectif de ce travail est d’évaluer l’implant épirétinien ARGUS II et les actes professionnels y afférant afin de : proposer, le cas échéant, son remboursement ;définir ses indications et les situations cliniques d’utilisation ;évaluer son intérêt en prenant en compte le rapport effet thérapeutique/effets indésirables et la place dans la stratégie thérapeutique ;déterminer les conditions d’utilisation et l’environnement technique proposer, le cas échéant, son remboursement ; définir ses indications et les situations cliniques d’utilisation ; évaluer son intérêt en prenant en compte le rapport effet thérapeutique/effets indésirables et la place dans la stratégie thérapeutique ; déterminer les conditions d’utilisation et l’environnement technique ARGUS II est destiné à compenser le handicap lié à la perte de vision induite par la rétinopathie pigmentaire en restituant une fonction visuelle au patient. L’implant ARGUS II permet de se substituer aux cellules photoréceptrices dégénérées en stimulant par un faisceau d’électrodes les cellules ganglionnaires et bipolaires. Le signal généré est transmis au cortex visuel via le nerf optique avec comme résultante des perceptions lumineuses. Seule une étude de faisabilité prospective, non comparative, multicentrique portant sur 30 patients ayant un suivi minimal de 1 an a été retenue. Cette étude de faible niveau de preuve rapportait des résultats encourageants mais non encore probants, notamment en termes d’amélioration de la qualité de vie des patients. Les nombreuses limites méthodologiques de cette étude ne permettent pas de conclure sur l’efficacité spécifique du dispositif ARGUS II.  Ainsi, en l’état actuel des connaissances, envisager d’emblée une prise en charge généralisée du dispositif et de la procédure est précoce. Ainsi, le Service Attendu est insuffisant pour l\\'inscription du dispositif médical sur la liste des Produits et Prestations Remboursables et pour l’inscription de l’acte à la liste des actes prévues respectivement aux articles L.165-1 et L.162-1-7 du code de la sécurité sociale.  Cependant, le bénéfice potentiel de cette technique est notable. En conséquence, la HAS recommande un recueil de données cliniques complémentaires avec un encadrement spécifique en proposant la mise en œuvre d’une prise en charge temporaire et dérogatoire de la prothèse épirétinienne ARGUS II au titre de l’article L.165-1-1 du code de la sécurité sociale considérant le caractère innovant du dispositif, le caractère orphelin de la pathologie concernée, l’absence d’alternative thérapeutique, le fort potentiel d’amélioration de la qualité de vie des patients, le fort potentiel de compensation du handicap lié à la cécité et la probable balance bénéfice / risques favorable.   ",
#   {'monograms': [],
#    'highest n-grams': [],
#    'top ranked bigrams': [(('ARGUS', 'II'), 0.96),
#     (('proposer', 'cas'), 0.9514595384165937),
#     (('remboursement', 'définir'), 0.9514595384165937),
#     (('définir', 'indications'), 0.9514595384165937),
#     (('prenant', 'compte'), 0.9514595384165937),
#     (('compte', 'rapport'), 0.9514595384165937),
#     (('indésirables', 'place'), 0.9514595384165937),
#     (('place', 'stratégie'), 0.9514595384165937),
#     (('déterminer', 'conditions'), 0.9514595384165937),
#     (('handicap', 'lié'), 0.9514595384165937),
#     (('damélioration', 'qualité'), 0.9514595384165937)],
#    'top ranked n-grams': [(('cas', 'échéant', 'remboursement'),
#      0.9514595384165937),
#     (('évaluer', 'intérêt', 'prenant'), 0.9514595384165937),
#     (('rapport', 'thérapeutiqueeffets', 'indésirables'), 0.9514595384165937),
#     (('code', 'sécurité', 'sociale'), 0.9514595384165937),
#     (('indications', 'situations', 'cliniques'), 0.9491728016359919),
#     (('qualité', 'vie', 'patients'), 0.9491728016359919),
#     (('stratégie', 'thérapeutique', 'déterminer'), 0.9468860648553901),
#     (('dutilisation', 'lenvironnement', 'technique'), 0.9445255623721882)]}],
#  'https://www.has-sante.fr/jcms/c_1356838/fr/utilite-clinique-du-dosage-de-la-vitamine-d-rapport-d-evaluation': ['L’objectif de cette évaluation est de préciser les situations cliniques pour lesquelles la mesure de la concentration sérique en 25(OH)D est utile. Pour ce faire, il a été proposé lors du cadrage de cette évaluation de répondre successivement aux trois questions suivantes : Question 1 : Existe-t-il une association entre une hypovitaminose D et la survenue de pathologies identifiées dans la littérature et par les professionnels consultés ?\\xa0- Quelle est l’association entre les concentrations sériques en 25(OH)D et la survenue de pathologies ?\\xa0- Quels sont les effets de la supplémentation en vitamine D sur la survenue de pathologies ou sur l’amélioration des signes cliniques associés à ces pathologies ?   Question 2 : Lorsqu’une association entre la vitamine D et une pathologie est identifiée à la question 1, est-il possible de définir une valeur de référence associée à cette pathologie? Question 3 : Dans le cas où une valeur de référence existe (question 2), la supplémentation en vitamine D après une mesure de la concentration sérique en 25(OH)D améliore-t-elle la balance bénéfice/risque par rapport à une supplémentation en vitamine D réalisée sans mesure préalable de la concentration sérique en 25(OH)D ? Doit-on ensuite réaliser un dosage au cours du traitement pour vérifier l’atteinte de l’objectif thérapeutique ? \\xa0 La méthode d’évaluation est fondée sur l’analyse critique des données identifiées de la littérature scientifique et sur la position argumentée de professionnels de santé réunis dans un groupe de travail.',
#   {'monograms': [],
#    'highest n-grams': [(('mesure', 'concentration', 'sérique'),
#      0.7038490853658537),
#     (('supplémentation', 'vitamine', 'D'), 0.9087881097560975)],
#    'top ranked bigrams': [(('sérique', 'OHD'), 0.8526981707317073),
#     (('survenue', 'pathologies'), 0.8526981707317073),
#     (('identifiées', 'littérature'), 0.5559146341463415),
#     (('valeur', 'référence'), 0.5559146341463415),
#     (('D', 'survenue'), 0.5454192073170732)],
#    'top ranked n-grams': [(('supplémentation', 'vitamine', 'D'),
#      0.9087881097560975),
#     (('mesure', 'concentration', 'sérique'), 0.7038490853658537)]}],
#  'https://www.has-sante.fr/jcms/c_1364144/fr/radiotherapie-conformationnelle-avec-modulation-d-intensite-dans-le-cancer-du-canal-anal': ['Objectifs L’objectif de ce rapport était d’évaluer les données de sécurité et d’efficacité cliniques du traitement du cancer du canal anal par Radiothérapie conformationnelle avec modulation d’intensité (RCMI), en vue de sa prise en charge par l’Assurance Maladie, le comparateur étant la radiothérapie conformationnelle en trois dimensions (RTC-3D). Méthode La stratégie de recherche documentaire a privilégié les études comparatives randomisées et les revues systématiques; à défaut, les études comparatives non randomisées et les études prospectives, et enfin les études rétrospectives et les séries de cas. L’évaluation de la RCMI dans le cancer du canal anal a été fondée sur l’analyse critique des données cliniques issues de: 1 série de cas prospectives, 10 séries de cas rétrospectives dont quatre comparatives avec contrôle historique et 4 recommandations de bonne pratique. Les résultats de cette analyse ont été discutés par un groupe de travail pluridisciplinaire composé de 16 experts (6\\xa0radiothérapeutes, 2 radiophysiens, 2 oncologues médicaux, 3 gynécologues obstétriciens, 2\\xa0chirurgiens digestifs, 1 radiologue) et de 2 représentants des associations de patients. Le recueil de l’avis des professionnels a été complété par une consultation de 5 parties prenantes (l’ASN, l’IRSN, la SFPM, la SFRO et la SFRP). Résultats Les éléments clés qui sont ressortis de cette évaluation sont les suivants: une littérature insuffisamment probante;la conviction ferme des professionnels de l’intérêt de cette technique dans le cancer du canal anal;une pratique qui s’est imposée en France. Selon le rapport d’enquête de l’observatoire national de radiothérapie, il s’agit, avec le col de l’utérus, de la 3e indication la plus répandue après respectivement les cancers de la prostate et les cancers des voies aérodigestives supérieures. une littérature insuffisamment probante; la conviction ferme des professionnels de l’intérêt de cette technique dans le cancer du canal anal; une pratique qui s’est imposée en France. Selon le rapport d’enquête de l’observatoire national de radiothérapie, il s’agit, avec le col de l’utérus, de la 3e indication la plus répandue après respectivement les cancers de la prostate et les cancers des voies aérodigestives supérieures. e La HAS considère, au regard de ces éléments, que la mise en œuvre d’un traitement par RCMI du cancer du canal anal exige: une maturité des centres en termes: d’expérience, de ressources suffisantes, de compétences spécifiques pour les professionnels concernés (radiothérapeutes, radiophysiciens, dosimétristes, …) et d’organisation garantissant le respect des procédures d’assurance qualité;une information des patientes sur le niveau de connaissances disponible pour cette technologie et leur implication active dans le recueil de leurs données de suivi en termes de récidive et de toxicité à long terme;un recueil exhaustif des données de toxicité tardive et du taux de rechutes locales dans le cadre d’un registre national. Le recueil de ces données et leur exploitation pourraient être mis en œuvre dans le cadre du suivi du patient traité par irradiation, ce suivi est un des critères d’agrément définis par l’INCa et doit être satisfait au regard du 3° de l’article R. 6123-88 du Code de la Santé publique;une identification des cancers radio-induits qui pourrait s’inscrire dans le cadre de la mise en œuvre du système national de vigilance sanitaire. une maturité des centres en termes: d’expérience, de ressources suffisantes, de compétences spécifiques pour les professionnels concernés (radiothérapeutes, radiophysiciens, dosimétristes, …) et d’organisation garantissant le respect des procédures d’assurance qualité; une information des patientes sur le niveau de connaissances disponible pour cette technologie et leur implication active dans le recueil de leurs données ...
#   {'monograms': [],
#    'highest n-grams': [(('cancer', 'canal', 'anal'), 0.9722002761340148),
#     (('dose', 'totale', 'dose'), 0.9520439091208645),
#     (('durée', 'traitement', 'débit'), 0.9450461176483403),
#     (('modifiés', 'rapport', 'RTCD'), 0.9256401961077994)],
#    'top ranked bigrams': [(('fraction', 'durée'), 0.9589644157478084),
#     (('dose', 'fraction'), 0.9520439091208645),
#     (('débit', 'traitement'), 0.9450461176483403),
#     (('mise', 'œuvre'), 0.9143011276833881),
#     (('modulation', 'dintensité'), 0.9107448084172765),
#     (('littérature', 'insuffisamment'), 0.9107448084172765),
#     (('lintérêt', 'technique'), 0.9107448084172765),
#     (('voies', 'aérodigestives'), 0.9107448084172765),
#     (('aérodigestives', 'supérieures'), 0.9107448084172765),
#     (('dexpérience', 'ressources'), 0.9107448084172765),
#     (('ressources', 'suffisantes'), 0.9107448084172765)],
#    'top ranked n-grams': [(('cancer', 'canal', 'anal'), 0.9722002761340148),
#     (('dose', 'totale', 'dose'), 0.9520439091208645),
#     (('durée', 'traitement', 'débit'), 0.9450461176483403),
#     (('modifiés', 'rapport', 'RTCD'), 0.9256401961077994),
#     (('recueil', 'données', 'suivi'), 0.9196476159613085),
#     (('sest', 'imposée', 'France'), 0.9107448084172765),
#     (('sagit', 'col', 'lutérus'), 0.9107448084172765),
#     (('indication', 'répandue', 'respectivement'), 0.9107448084172765),
#     (('suffisantes', 'compétences', 'spécifiques'), 0.9107448084172765),
#     (('concernés', 'radiothérapeutes', 'radiophysiciens'), 0.9107448084172765),
#     (('dorganisation', 'garantissant', 'respect'), 0.9107448084172765)]}],
#  'https://www.has-sante.fr/jcms/c_1525658/fr/pose-et-entretien-des-catheters-veineux-peripheriques': ['Onze critères de qualité ont été élaborés et sélectionnés à partir de la recommandation de bonne pratique Prévention des infections liées aux cathéters veineux périphériques et constituent des éléments simples et opérationnels de bonne pratique. Prévention des infections liées aux cathéters veineux périphériques \\xa0 Les objectifs de qualité et de sécurité de ces 11 critères sont\\xa0 : Standardisation de la pratique de pose et d’entretien d’un cathéter veineux périphériquApplication des précautions standardRespect des bonnes pratiques d’antisepsie lors de la poseRespect des bonnes pratiques d’antisepsie pour les manipulations du cathéter, des tubulures et des robinetsEvaluation du maintien du cathétérisme Standardisation de la pratique de pose et d’entretien d’un cathéter veineux périphériqu Application des précautions standard Respect des bonnes pratiques d’antisepsie lors de la pose Respect des bonnes pratiques d’antisepsie pour les manipulations du cathéter, des tubulures et des robinets Evaluation du maintien du cathétérisme',
#   {'monograms': [],
#    'highest n-grams': [(('pratiques', 'dantisepsie', 'manipulations'),
#      0.9218676561533704)],
#    'top ranked bigrams': [(('bonnes', 'pratiques'), 0.96),
#     (('Prévention', 'infections'), 0.894743351886209),
#     (('infections', 'liées'), 0.894743351886209),
#     (('dentretien', 'dun'), 0.894743351886209),
#     (('maintien', 'cathétérisme'), 0.894743351886209),
#     (('veineux', 'périphériques'), 0.8837353123067409),
#     (('Standardisation', 'pratique'), 0.8837353123067409),
#     (('dun', 'cathéter'), 0.8837353123067409),
#     (('manipulations', 'cathéter'), 0.8837353123067409),
#     (('cathéter', 'tubulures'), 0.8837353123067409),
#     (('Respect', 'bonnes'), 0.8837353123067409)],
#    'top ranked n-grams': [(('pratiques', 'dantisepsie', 'manipulations'),
#      0.9218676561533704),
#     (('liées', 'cathéters', 'veineux'), 0.8892393320964749),
#     (('bonne', 'pratique', 'Prévention'), 0.8837353123067409),
#     (('pratique', 'pose', 'dentretien'), 0.883426097711812)]}],
#  'https://www.has-sante.fr/jcms/c_1528194/fr/jevtana-xtandi-et-zytiga-cabazitaxel-enzalutamide-et-abiraterone-des-progres-therapeutiques-pour-certains-cancers-metastatiques-de-la-prostate': ['Jevtana® (cabazitaxel) est un agent cytotoxique de la famille des taxanes, Xtandi® (enzalutamide) un inhibiteur des récepteurs aux androgènes et Zytiga® (abiratérone) un inhibiteur de la biosynthèse des androgènes.Dans le traitement du cancer métastatique de la prostate, chez les patients asymptomatiques ou peu symptomatiques, après échec d’un traitement par suppression androgénique (patients considérés comme résistant à la castration) ou lorsqu’une chimiothérapie n’est pas encore cliniquement indiquée, Zytiga® a l’AMM, en association à la prednisone ou à la prednisolone.Toujours chez les patients ayant un cancer métastatique de la prostate résistant à la castration, Jevtana®, Zytiga® et Xtandi® ont l’AMM* en seconde ligne chez les hommes dont la maladie a progressé pendant ou après une chimiothérapie à base de docétaxel.En seconde ligne après docétaxel, en termes d’efficacité sur la survie globale, Jevtana® a montré un allongement de 2,4 mois versus mitoxantrone, Zytiga® de 3,9 mois versus placebo et Xtandi® de 4,8 mois versus placebo. Le choix entre les trois produits se fera selon le terrain du malade :chez les patients risquant un cumul de toxicité des taxanes ou dont l’état général ne permet pas de supporter une reprise de la chimiothérapie, Zytiga® ou Xtandi® seront préférés ;chez les patients dont la maladie a progressé rapidement sous hormonothérapie, Jevtana® pourrait être proposé, selon les experts consultés, à condition que le traitement précédent par le docétaxel ait été bien toléré. Jevtana® (cabazitaxel) est un agent cytotoxique de la famille des taxanes, Xtandi® (enzalutamide) un inhibiteur des récepteurs aux androgènes et Zytiga® (abiratérone) un inhibiteur de la biosynthèse des androgènes. Jevtana® (cabazitaxel) est un agent cytotoxique de la famille des taxanes, Xtandi® (enzalutamide) un inhibiteur des récepteurs aux androgènes et Zytiga® (abiratérone) un inhibiteur de la biosynthèse des androgènes. Dans le traitement du cancer métastatique de la prostate, chez les patients asymptomatiques ou peu symptomatiques, après échec d’un traitement par suppression androgénique (patients considérés comme résistant à la castration) ou lorsqu’une chimiothérapie n’est pas encore cliniquement indiquée, Zytiga® a l’AMM, en association à la prednisone ou à la prednisolone. Dans le traitement du cancer métastatique de la prostate, chez les patients asymptomatiques ou peu symptomatiques, après échec d’un traitement par suppression androgénique (patients considérés comme résistant à la castration) ou lorsqu’une chimiothérapie n’est pas encore cliniquement indiquée, Zytiga® a l’AMM, en association à la prednisone ou à la prednisolone. Toujours chez les patients ayant un cancer métastatique de la prostate résistant à la castration, Jevtana®, Zytiga® et Xtandi® ont l’AMM* en seconde ligne chez les hommes dont la maladie a progressé pendant ou après une chimiothérapie à base de docétaxel. Toujours chez les patients ayant un cancer métastatique de la prostate résistant à la castration, Jevtana®, Zytiga® et Xtandi® ont l’AMM* en seconde ligne chez les hommes dont la maladie a progressé pendant ou après une chimiothérapie à base de docétaxel. En seconde ligne après docétaxel, en termes d’efficacité sur la survie globale, Jevtana® a montré un allongement de 2,4 mois versus mitoxantrone, Zytiga® de 3,9 mois versus placebo et Xtandi® de 4,8 mois versus placebo. Le choix entre les trois produits se fera selon le terrain du malade : En seconde ligne après docétaxel, en termes d’efficacité sur la survie globale, Jevtana® a montré un allongement de 2,4 mois versus mitoxantrone, Zytiga® de 3,9 mois versus placebo et Xtandi® de 4,8 mois versus placebo. Le choix entre les trois produits se fera selon le terrain du malade : chez les patients risquant un cum ...
#   {'monograms': [],
#    'highest n-grams': [(('métastatique', 'prostate', 'patients'),
#      0.930046672077922),
#     (('résistant', 'castration', 'lorsquune'), 0.936594696969697),
#     (('lAMM', 'seconde', 'ligne'), 0.9344951298701298),
#     (('maladie', 'progressé', 'chimiothérapie'), 0.9322774621212121),
#     (('mois', 'versus', 'mitoxantrone'), 0.9370369318181818),
#     (('versus', 'placebo', 'Xtandi'), 0.928798079004329)],
#    'top ranked bigrams': [(('cancer', 'métastatique'), 0.9643392857142856),
#     (('Zytiga', 'Xtandi'), 0.9477494047619047),
#     (('agent', 'cytotoxique'), 0.9130492424242426),
#     (('cytotoxique', 'famille'), 0.9130492424242426),
#     (('asymptomatiques', 'symptomatiques'), 0.9130492424242426),
#     (('defficacité', 'survie'), 0.9130492424242426),
#     (('survie', 'globale'), 0.9130492424242426),
#     (('montré', 'allongement'), 0.9130492424242426),
#     (('fera', 'terrain'), 0.9130492424242426),
#     (('terrain', 'malade'), 0.9130492424242426),
#     (('cumul', 'toxicité'), 0.9130492424242426)],
#    'top ranked n-grams': [(('mois', 'versus', 'mitoxantrone'),
#      0.9370369318181818),
#     (('résistant', 'castration', 'lorsquune'), 0.936594696969697),
#     (('lAMM', 'seconde', 'ligne'), 0.9344951298701298),
#     (('maladie', 'progressé', 'chimiothérapie'), 0.9322774621212121),
#     (('métastatique', 'prostate', 'patients'), 0.930046672077922),
#     (('versus', 'placebo', 'Xtandi'), 0.928798079004329),
#     (('symptomatiques', 'échec', 'dun'), 0.9130492424242426),
#     (('nest', 'cliniquement', 'indiquée'), 0.9130492424242426),
#     (('choix', 'produits', 'fera'), 0.9130492424242426),
#     (('experts', 'consultés', 'condition'), 0.9130492424242426),
#     (('lAMM', 'association', 'prednisone'), 0.9109496753246754)]}],
#  'https://www.has-sante.fr/jcms/c_1528391/fr/evaluation-des-implants-de-pontage': ['Les objectifs de la réévaluation des implants de pontage sont de : déterminer les indications des implants de pontage ;évaluer leur service rendu par indication\\xa0;définir leur place dans la stratégie thérapeutique\\xa0;caractériser les spécifications techniques conditionnant le service rendu, afin d’éviter les erreurs de codification et clarifier les dispositifs entrant sous les descriptions génériques ;proposer une nomenclature actualisée\\xa0;estimer la population cible\\xa0;définir les attentes de la CNEDIMTS pour les études présentées lors des demandes d’inscription sous nom de marque\\xa0;définir les modalités d’utilisation et de prescription à envisager pour l’inscription des produits sur la LPPR. déterminer les indications des implants de pontage ; évaluer leur service rendu par indication\\xa0; définir leur place dans la stratégie thérapeutique\\xa0; caractériser les spécifications techniques conditionnant le service rendu, afin d’éviter les erreurs de codification et clarifier les dispositifs entrant sous les descriptions génériques ; proposer une nomenclature actualisée\\xa0; estimer la population cible\\xa0; définir les attentes de la CNEDIMTS pour les études présentées lors des demandes d’inscription sous nom de marque\\xa0; définir les modalités d’utilisation et de prescription à envisager pour l’inscription des produits sur la LPPR. Cette évaluation concerne les implants de pontage inscrits sur la liste des produits et prestations remboursables (LPPR). La CNEDiMTS recommande, selon les types d’implants, soit une individualisation des descriptions génériques avec une redéfinition de celles-ci, et une actualisation des spécifications techniques, soit une inscription sous nom de marque pour certains types d’implants du pontage. La Commission recommande d’individualiser, pour une inscription sous description générique, les implants de pontage synthétiques ne comportant aucun dérivé ou tissu d’origine biologique ou n’étant pas issu de tels dérivés\\xa0 et les implants de pontage synthétiques imprégnés de produits d’origine animale, à l’exclusion des bioprothèses et tissus biologiques renforcés. Parmi les implants ne comportant aucun dérivé ou tissu d’origine biologique ou n’étant pas issu de tels dérivés, la Commission recommande d’individualiser les implants composites et les implants composés d’un seul matériau (polyester ou ePTFE) non recouverts par un traitement de surface. Les implants composites sont constitués de plusieurs matériaux (polyester, ePTFE, polyuréthane) ou d’un matériau associé à un traitement de surface contenant une substance non active. Pour chaque catégorie ainsi définie, la Commission recommande la création de 2 descriptions génériques en fonction du caractère droit ou bi/multifurqué des implants de pontage, en raison des lésions anatomiques distinctes auxquelles ils répondent. La CNEDIMTS s’est prononcée pour une absence d’amélioration du service rendu (ASR V) entre les différents types d’implants de pontage. La CNEDIMTS recommande donc que l’ensemble de ces dispositifs soient inscrits au remboursement, à l’exception des implants enduits d’un traitement de surface contenant une substance active. Pour ces dispositifs, une inscription sous nom de marque est recommandée, impliquant un dépôt de dossier par l’industriel concerné en vue d’une évaluation spécifique, avant d’envisager une prise en charge\\xa0sur la LPPR.',
#   {'monograms': [],
#    'highest n-grams': [(('évaluer', 'service', 'rendu'), 0.8829792739167739),
#     (('entrant', 'descriptions', 'génériques'), 0.8729041988416988),
#     (('Commission', 'recommande', 'dindividualiser'), 0.8569290272415272),
#     (('traitement', 'surface', 'contenant'), 0.8625163556413556)],
#    'top ranked bigrams': [(('implants', 'pontage'), 0.9632882882882883),
#     (('spécifications', 'techniques'), 0.8979150579150579),
#     (('types', 'dimplants'), 0.8979150579150579),
#     (('déterminer', 'indications'), 0.8296793221793222),
#     (('place', 'stratégie'), 0.8296793221793222),
#     (('déviter', 'erreurs'), 0.8296793221793222),
#     (('proposer', 'nomenclature'), 0.8296793221793222),
#     (('études', 'présentées'), 0.8296793221793222),
#     (('présentées', 'demandes'), 0.8296793221793222),
#     (('modalités', 'dutilisation'), 0.8296793221793222),
#     (('dutilisation', 'prescription'), 0.8296793221793222)],
#    'top ranked n-grams': [(('évaluer', 'service', 'rendu'),
#      0.8829792739167739),
#     (('entrant', 'descriptions', 'génériques'), 0.8729041988416988),
#     (('traitement', 'surface', 'contenant'), 0.8625163556413556),
#     (('Commission', 'recommande', 'dindividualiser'), 0.8569290272415272),
#     (('erreurs', 'codification', 'clarifier'), 0.8296793221793222),
#     (('prescription', 'envisager', 'linscription'), 0.8296793221793222),
#     (('dérivé', 'tissu', 'dorigine'), 0.8283984877734878),
#     (('demandes', 'dinscription', 'nom'), 0.8270799817674818),
#     (('attentes', 'CNEDIMTS', 'études'), 0.8244806413556414),
#     (('techniques', 'conditionnant', 'service'), 0.8244429697554698)]}],
#  'https://www.has-sante.fr/jcms/c_1604609/fr/recommandations-organisationnelles-de-la-chirurgie-ambulatoire-outils-et-guide': ["L\\'objectif de ce travail est de proposer des processus organisationnels opérationnels et des outils associés permettant aux acteurs de terrain de développer la chirurgie ambulatoire. Ce travail s\\'est appuyé sur : une approche ascendante issue du terrain :une étude de benchmark visant à identifier les facteurs clés de réussite du développement de la chirurgie ambulatoire,une analyse des modes de défaillances et de leurs effets (AMDE) visant à identifier les défaillances potentielles et les barrières de sécurité à mettre en oeuvre, une approche ascendante issue du terrain : une étude de benchmark visant à identifier les facteurs clés de réussite du développement de la chirurgie ambulatoire,une analyse des modes de défaillances et de leurs effets (AMDE) visant à identifier les défaillances potentielles et les barrières de sécurité à mettre en oeuvre, une étude de benchmark visant à identifier les facteurs clés de réussite du développement de la chirurgie ambulatoire, benchmark une analyse des modes de défaillances et de leurs effets (AMDE) visant à identifier les défaillances potentielles et les barrières de sécurité à mettre en oeuvre, une mobilisation de théories et de techniques organisationnelles issues du monde industriel (approche Lean pour la gestion des flux et méthode d\\'analyse des modes de défaillance et de leurs effets pour la gestion des risques) ;un accompagnement d\\'experts professionnels de terrain tout au long de la démarche. une mobilisation de théories et de techniques organisationnelles issues du monde industriel (approche Lean pour la gestion des flux et méthode d\\'analyse des modes de défaillance et de leurs effets pour la gestion des risques) ; un accompagnement d\\'experts professionnels de terrain tout au long de la démarche. Ce travail donne lieu à la publication de recommandations organisationnelles, de documents explicatifs. publication de recommandations organisationnelles, de documents explicatifs Les outils associés pour évaluer et mettre en oeuvre sont accessibles via les liens ci-dessous.",
#   {'monograms': [],
#    'highest n-grams': [(('facteurs', 'clés', 'réussite'), 0.9280536608408124)],
#    'top ranked bigrams': [(('visant', 'identifier'), 0.96),
#     (('mettre', 'oeuvre'), 0.9482233349078885),
#     (('réussite', 'développement'), 0.9280536608408124),
#     (('barrières', 'sécurité'), 0.9280536608408124),
#     (('développement', 'chirurgie'), 0.9246885214926783),
#     (('sécurité', 'mettre'), 0.9246885214926783),
#     (('analyse', 'modes'), 0.9211162966461974),
#     (('identifier', 'facteurs'), 0.9175440717997166),
#     (('AMDE', 'visant'), 0.9175440717997166),
#     (('modes', 'défaillances'), 0.9106067076051015),
#     (('identifier', 'défaillances'), 0.9070344827586206)],
#    'top ranked n-grams': [(('facteurs', 'clés', 'réussite'),
#      0.9280536608408124),
#     (('défaillances', 'potentielles', 'barrières'), 0.9227988663202645),
#     (('étude', 'benchmark', 'visant'), 0.9194337269721304),
#     (('défaillances', 'effets', 'AMDE'), 0.9158615021256495),
#     (('risques', 'accompagnement', 'dexperts'), 0.6888419461502125),
#     (('approche', 'ascendante', 'issue'), 0.6864374114312706),
#     (('théories', 'techniques', 'organisationnelles'), 0.6864374114312706),
#     (('monde', 'industriel', 'approche'), 0.6864374114312706),
#     (('gestion', 'flux', 'méthode'), 0.6864374114312706),
#     (('organisationnelles', 'documents', 'explicatifs'), 0.6864374114312706),
#     (('chirurgie', 'ambulatoireune', 'analyse'), 0.6852733112895606)]}],
# ...
#     (('moyens', 'efficaces', 'indice'), 0.8858848484848484),
#     (('prévention', 'grossesses', 'non'), 0.8858848484848484),
#     (('désogestrel', 'gestodène', 'norgestimate'), 0.8858848484848484),
#     (('indésirables', 'lacné', 'prise'), 0.8858848484848484),
#     (('nausées', 'mastodynies', 'dysménorrhée'), 0.8858848484848484),
#     (('efficacité', 'comparable', 'HAS'), 0.8858848484848484),
#     (('indispensable', 'rechercher', 'facteurs'), 0.8833160353535352),
#     (('déthinylestradiol', 'EExadoivent', 'préférés'), 0.8833160353535352)]}],
#  'https://www.has-sante.fr/jcms/r_1439953/fr/quelle-place-pour-la-sitagliptine-januvia/xelevia-dans-le-diabete-de-type-2': ['La sitagliptine (Januvia® ou Xelevia®) est un hypoglycémiant oral qui appartient à une nouvelle classe, celle des inhibiteurs de la dipeptidylpeptidase 4 (DPP-4).Elle est indiquée chez les diabétiques de type 2 pour améliorer le contrôle de la glycémie, en association à la metformine, lorsque régime alimentaire, exercice physique et metformine ne permettent pas d’obtenir un contrôle adéquat de la glycémie. Elle a aussi l’AMM chez ces patients lorsque l’utilisation d’une glitazone est appropriée et que la glitazone choisie, utilisée en monothérapie avec régime alimentaire et exercice physique, ne permet pas d’obtenir un contrôle adéquat de la glycémie.C’est un moyen thérapeutique supplémentaire de prise en charge des diabétiques de type 2.   \\xa0 Place dans la stratégie thérapeutique\\xa0: Place dans la stratégie thérapeutique\\xa0: Utilisée en association à la metformine, la sitagliptine apporte une amélioration du service médical rendu mineure (ASMR IV) dans la prise en charge du diabète de type 2, lorsque le taux d’HbA1c reste > 6,5% malgré des mesures hygiénodiététiques et une monothérapie par metformine à dose optimale.Les glitazones ayant une place limitée en monothérapie et en l’absence d’étude contrôlée comparant l’association glitazone + sitagliptine à une autre bithérapie, la Commission ne peut situer cette bithérapie par rapport aux autres. Ainsi utilisée, la sitagliptine n’apporte pas d’ASMR (ASMR V).  \\xa0 Autres caractéristiques à retenir\\xa0: Autres caractéristiques à retenir\\xa0: La sitagliptine ne doit pas être utilisée chez les patients ayant une insuffisance rénale modérée à sévère.',
#   {'monograms': [],
#    'highest n-grams': [(('régime', 'alimentaire', 'exercice'),
#      0.9888636363636364),
#     (('Place', 'stratégie', 'thérapeutiquexa'), 0.9888636363636364)],
#    'top ranked bigrams': [(('exercice', 'physique'), 0.9888636363636364),
#     (('prise', 'charge'), 0.9888636363636364),
#     (('caractéristiques', 'retenirxa'), 0.9888636363636364),
#     (('diabétiques', 'type'), 0.9842045454545455),
#     (('dobtenir', 'contrôle'), 0.9842045454545455),
#     (('contrôle', 'adéquat'), 0.9842045454545455),
#     (('association', 'metformine'), 0.9793181818181819)],
#    'top ranked n-grams': [(('régime', 'alimentaire', 'exercice'),
#      0.9888636363636364),
#     (('Place', 'stratégie', 'thérapeutiquexa'), 0.9888636363636364)]}],
#  'https://www.has-sante.fr/jcms/r_1440019/fr/quelle-place-pour-le-candesartan-atacand-kenzen-dans-l-insuffisance-cardiaque': ["Un traitement de deuxième intention de l\\'insuffisance cardiaque. Le candésartan est le premier antagoniste des récepteurs AT1 de l’angiotensine II (ARA II ou sartans) indiqué dans la prise en charge de l’insuffisance cardiaque (IC) systolique. Son emploi dans cette indication est toutefois limité à deux situations : il peut remplacer les inhibiteurs de l’enzyme de conversion (IEC) lorsqu’ils sont mal tolérés, ou leur être associé chez une partie des patients qui restent symptomatiques en dépit d’un traitement médical optimal. \\xa0 \\xa0Place dans la stratégie thérapeutique\\xa0: Place dans la stratégie thérapeutique\\xa0: Le candésartan est indiqué dans le traitement de l\\'insuffisance cardiaque de classe II à III NYHA avec dysfonction systolique ventriculaire gauche (fraction d’éjection du VG ≤ 40 %), dans deux situations seulement :\\xa0 - en cas d\\'intolérance aux inhibiteurs de l\\'enzyme de conversion (IEC), l\\'amélioration du service médical rendu est importante (ASMR de niveau II).\\xa0 - en association à un IEC, chez les patients qui restent symptomatiques en dépit d\\'un traitement médical optimal (IEC et bêtabloquant aux doses maximales tolérées), l\\'amélioration du service médical rendu est modérée (ASMR de niveau III). \\xa0   \\xa0 Autres caractéristiques à retenir\\xa0: Autres caractéristiques à retenir\\xa0: Une triple association à éviter. La triple association candésartan - IEC - diurétique hyperkaliémiant (spironolactone ou éplérénone) est fortement déconseillée en raison du risque important d’hyperkaliémie.",
#   {'monograms': [],
#    'highest n-grams': [],
#    'top ranked bigrams': [(('linsuffisance', 'cardiaque'), 0.9793023255813953),
#     (('inhibiteurs', 'lenzyme'), 0.9192288861689106),
#     (('patients', 'symptomatiques'), 0.9192288861689106),
#     (('symptomatiques', 'dépit'), 0.9192288861689106),
#     (('stratégie', 'thérapeutiquexa'), 0.9192288861689106),
#     (('lamélioration', 'service'), 0.9192288861689106),
#     (('ASMR', 'niveau'), 0.9192288861689106),
#     (('caractéristiques', 'retenirxa'), 0.9192288861689106),
#     (('triple', 'association'), 0.9149041207670339),
#     (('médical', 'optimal'), 0.9104712362301102),
#     (('traitement', 'médical'), 0.9017135862913097)],
#    'top ranked n-grams': [(('dépit', 'dun', 'traitement'), 0.9148500611995104),
#     (('lenzyme', 'conversion', 'IEC'), 0.9125795593635251),
#     (('service', 'médical', 'rendu'), 0.9104712362301102)]}],
#  'https://www.has-sante.fr/jcms/r_1497412/fr/realisation-d-une-grille-d-analyse-de-la-pertinence-des-demandes-de-transfert-et-d-admission-en-ssr-note-de-cadrage': ['La note de cadrage précise les questions d’évaluation, définit la méthode et le plan de réalisation qui seront mis en œuvre pour réaliser un outil d’aide à la décision sous forme de grille de pertinence pour l’admission des patients en soins de suite et de réadaptation. Les services de soins de suite et de réadaptation (SSR) correspondent à une des activités d’un établissement de santé. L’activité des SSR a pour objet de prévenir ou de réduire les conséquences fonctionnelles, physiques, cognitives, psychologiques ou sociales des déficiences et des limitations de capacité des patients et de promouvoir leur réadaptation et leur réinsertion. Elle comprend, le cas échéant, des actes à visée diagnostique ou thérapeutique. L’orientation d’un patient dans une structure de SSR et son admission doivent répondre à un objectif thérapeutique déterminé et régulièrement réévalué. Le SSR ne doit plus être seulement reconnu comme l’aval du court séjour, mais comme une structure sanitaire apportant une plus-value réelle au patient car permettant une prise en charge globale destinée à lui permettre de retourner dans son lieu de vie d’origine. Ainsi toute admission en SSR doit être précédée d’une évaluation des besoins médicaux, psychologiques et sociaux permettant de valider ou non l’adéquation de son orientation. Il n’existe pas à ce jour d’outil standardisé et opérationnel au niveau national permettant de proposer des critères d’orientation génériques sur la base d’une méthodologie validée. L’objectif du travail proposé dans la présente note de cadrage est de contribuer à élaborer un outil d’aide à la décision sous forme de grille de pertinence de type AEP pour l’admission des patients en soins de suite et de réadaptation. Méthodologie utilisée pour élaborer le rapport : Une grille déjà élaborée par le réseau REQUA Franche Comté en 2008 servira de point de départ à la constitution de la grille de pertinence. Elle sera modifiée autant que nécessaire en utilisant la méthode du consensus formalisé d’experts de la HAS. La validation de la grille pilote élaborée par un groupe de travail comprendra une phase dite « d’essai » par des professionnels. La méthodologie est décrite dans le guide HAS « Elaboration de critères de qualité pour l’évaluation et l’amélioration des pratiques professionnelles ». Le produit final sera une grille pilote qui devra faire l’objet dans un deuxième temps d’une validation sur un grand nombre de séjours, en lien avec le demandeur (DGOS).',
#   {'monograms': [],
#    'highest n-grams': [],
#    'top ranked bigrams': [(('soins', 'suite'), 0.9837073170731707),
#     (('suite', 'réadaptation'), 0.9797560975609756),
#     (('grille', 'pertinence'), 0.9718536585365853),
#     (('note', 'cadrage'), 0.7880087554721701),
#     (('outil', 'daide'), 0.7880087554721701),
#     (('forme', 'grille'), 0.7755428392745465),
#     (('grille', 'pilote'), 0.7755428392745465)],
#    'top ranked n-grams': [(('daide', 'décision', 'forme'), 0.7880087554721701),
#     (('ladmission', 'patients', 'soins'), 0.7834430894308942)]}],
#  'https://www.has-sante.fr/jcms/r_1499210/fr/evaluation-medico-economique-des-endoprotheses-aortiques-abdominales': ['L’évaluation médico-économique des endoprothèses aortiques par rapport à la chirurgie a pour objectif de comparer les deux techniques en termes de résultat et de coût, afin d’apporter des arguments médico-économiques d’aide à la décision en matière de tarification de ces dispositifs médicaux. L’analyse des données d’efficacité publiées depuis 2009 n’apporte pas d’éléments nouveaux concernant l’efficacité et la sécurité comparées de la technique endovasculaire et de la technique chirurgicale conventionnelle. En revanche, la prise en compte du critère d’efficience modifie la conclusion sur l’intérêt relatif de la technique endovasculaire par rapport à la chirurgie conventionnelle. Toutes les études médico-économiques concluent que le traitement endovasculaire n’est pas efficient chez les patients éligibles aux deux techniques, tous niveaux de risque opératoire confondus.Pour améliorer l’efficience de la technique endovasculaire, il est nécessaire de faire évoluer plusieurs variables de manière conjointe, impliquant des acteurs différents du système de santé et pouvant se résumer à deux points principaux :\\xa0 \\xa0  une réduction du coût de l’intervention initiale, dont la principale variable d’ajustement est le prix des endoprothèses aortiques ;une utilisation plus rationnelle de cette procédure passant par une meilleure sélection des patients sur leur niveau de risque préopératoire et par une sélection des centres autorisés à faire cette procédure. une réduction du coût de l’intervention initiale, dont la principale variable d’ajustement est le prix des endoprothèses aortiques ; une utilisation plus rationnelle de cette procédure passant par une meilleure sélection des patients sur leur niveau de risque préopératoire et par une sélection des centres autorisés à faire cette procédure.',
#   {'monograms': [],
#    'highest n-grams': [],
#    'top ranked bigrams': [(('endoprothèses', 'aortiques'), 0.9726164874551971),
#     (('technique', 'endovasculaire'), 0.96),
#     (('rapport', 'chirurgie'), 0.9145929339477727),
#     (('initiale', 'principale'), 0.9145929339477727),
#     (('principale', 'variable'), 0.9145929339477727),
#     (('passant', 'meilleure'), 0.9145929339477727),
#     (('centres', 'autorisés'), 0.9145929339477727),
#     (('réduction', 'coût'), 0.9088684075780851),
#     (('prix', 'endoprothèses'), 0.9088684075780851),
#     (('aortiques', 'utilisation'), 0.9088684075780851),
#     (('patients', 'niveau'), 0.9088684075780851)],
#    'top ranked n-grams': [(('variable', 'dajustement', 'prix'),
#      0.9145929339477727),
#     (('coût', 'lintervention', 'initiale'), 0.9117306707629289),
#     (('utilisation', 'rationnelle', 'procédure'), 0.9088018433179723),
#     (('risque', 'préopératoire', 'sélection'), 0.9059395801331285),
#     (('autorisés', 'faire', 'procédure'), 0.9030773169482847),
#     (('meilleure', 'sélection', 'patients'), 0.9001484895033283)]}],
#  'https://www.has-sante.fr/jcms/r_1499450/fr/efficacite-et-efficience-des-hypolipemiants-une-analyse-centree-sur-les-statines': ["Ce travail d’évaluation vise : d’une part, à préciser la place des statines dans le traitement de l’hypercholestérolémie et la prévention cardiovasculaire ; et d’autre part, à comparer les statines disponibles sur le marché français en termes d’efficacité, de tolérance et d’efficience. Toutes statines confondues, le traitement par statines diminue le risque de mortalité toutes causes de 10% quel que soit le profil du patient, et le risque d’événements cardiovasculaires de 15% à 23%, selon l’événement étudié.Le rapport coût-efficacité d’un traitement par statine est jugé favorable en prévention secondaire, et en prévention primaire pour les patients à haut risque cardiovasculaire. Les différentes statines n’ont pas d’effet significativement différent en termes de mortalité toutes causes et les effets indésirables sont de nature et de fréquence identiques. L’effet des différentes statines sur la survenue d’événements cardiovasculaires (ECV) ne peut pas être analysé de manière rigoureuse sur l\\'ensemble des molécules et des dosages à partir des données disponibles. Dans la mesure où il existe une relation démontrée entre la baisse du LDL-c et la réduction des ECV, la réduction du LDL-c peut être acceptée comme un indicateur intermédiaire de la morbidité CV. Les statines ayant une efficacité biologique différente, la prise en compte de ce second critère dans la décision conduit à recommander, pour un patient en initiation de traitement, la statine la plus efficiente en fonction de la baisse de LDL-c recherchée lorsqu’un traitement est jugé nécessaire par le prescripteur, en tenant compte du niveau de risque cardio-vasculaire initial du patient. La prescription d’une simvastatine générique est à envisager en priorité pour les hypercholestérolémies faibles à modérées (moins de 40% de réduction visée du niveau de LDL-c), avec un dosage adapté à la valeur cible recherchée (10 mg, 20 mg, 40 mg).\\xa0Lorsque la baisse de LDL-c souhaitée est très faible et qu’un traitement médicamenteux est jugé nécessaire, la pravastatine 10mg sera préférée.L’atorvastatine 10 mg et la rosuvastatine 5 mg sont des alternatives de la simvastatine 40 mg lorsque la baisse de LDL-c souhaitée est modérée (entre 30% et 40%). Pour une baisse du LDL-c souhaitée de plus de 40%, seules la rosuvastatine et l’atorvastatine permettent d’atteindre la valeur cible : entre 40% et 50%, la rosuvastatine (10, 20 mg) est à envisager en priorité ; au-delà, l’atorvastatine 80mg est la seule molécule permettant une réduction moyenne du LDL-c de plus de 50%. Toutes statines confondues, le traitement par statines diminue le risque de mortalité toutes causes de 10% quel que soit le profil du patient, et le risque d’événements cardiovasculaires de 15% à 23%, selon l’événement étudié. Le rapport coût-efficacité d’un traitement par statine est jugé favorable en prévention secondaire, et en prévention primaire pour les patients à haut risque cardiovasculaire.    ",
#   {'monograms': [],
#    'highest n-grams': [],
#    'top ranked bigrams': [(('baisse', 'LDLc'), 0.9712137486573577),
#     (('mortalité', 'causes'), 0.9467221625492303),
#     (('dévénements', 'cardiovasculaires'), 0.9467221625492303),
#     (('risque', 'cardiovasculaire'), 0.9360785893304691),
#     (('traitement', 'statine'), 0.9360580021482278),
#     (('LDLc', 'souhaitée'), 0.9360580021482278),
#     (('rapport', 'coûtefficacité'), 0.8277121374865736),
#     (('patients', 'haut'), 0.8277121374865736),
#     (('envisager', 'priorité'), 0.8277121374865736),
#     (('valeur', 'cible'), 0.8277121374865736),
#     (('causes', 'profil'), 0.8254744002864304)],
#    'top ranked n-grams': [(('prévention', 'primaire', 'patients'),
#      0.8242839240959542),
#     (('jugé', 'favorable', 'prévention'), 0.8220193340494093),
#     (('coûtefficacité', 'dun', 'traitement'), 0.8219566774078053),
#     (('profil', 'patient', 'risque'), 0.8185821697099893),
#     (('diminue', 'risque', 'mortalité'), 0.8173916935195131),
#     (('statines', 'confondues', 'traitement'), 0.815028643036162)]}]}

# %%
list_items = [site for site in data if site[1][1]['highest n-grams'] != [] and site[1][1]['top ranked bigrams'] != [] and site[1][1]['top ranked n-grams'] != []]
url_list = [site[0] for site in list_items]
highest_ngram_list = [site[1][1]['highest n-grams'] for site in list_items]
highest_ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in highest_ngram_list]
bigram_list = [site[1][1]['top ranked bigrams'] for site in list_items]
bigram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in bigram_list]
ngram_list = [site[1][1]['top ranked n-grams'] for site in list_items]
ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in ngram_list]

import pandas as pd
df = pd.DataFrame([element for element in zip(url_list, highest_ngram_list, bigram_list, ngram_list)],columns=['url','mots-clés très pertinent', 'mots-clés avec 2 mots', 'mots-clés avec plusieurs mots'])
df.to_csv('has_mot_cle.csv')
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-e3b0dc20b5ed> in <module>
#       1 list_items = [site for site in data]
#       2 url_list = [site[0] for site in list_items]
# ----> 3 highest_ngram_list = [site[1][1]['highest n-grams'] for site in list_items]
#       4 highest_ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in highest_ngram_list]
#       5 bigram_list = [site[1][1]['top ranked bigrams'] for site in list_items]
#
# <ipython-input-128-e3b0dc20b5ed> in <listcomp>(.0)
#       1 list_items = [site for site in data]
#       2 url_list = [site[0] for site in list_items]
# ----> 3 highest_ngram_list = [site[1][1]['highest n-grams'] for site in list_items]
#       4 highest_ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in highest_ngram_list]
#       5 bigram_list = [site[1][1]['top ranked bigrams'] for site in list_items]
#
# IndexError: string index out of range
