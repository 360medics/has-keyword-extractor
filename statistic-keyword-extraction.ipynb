# %% [markdown]
# # Automatic Keyword Extraction From Any Text Document Using N-gram Rigid Collocation
#
# here is the [references article](https://www.researchgate.net/publication/272674061_Automatic_Keyword_Extraction_From_Any_Text_Document_Using_N-gram_Rigid_Collocation)
#
# we use this [wikipedia article](https://en.wikipedia.org/wiki/Mobile_phone) to test the algorithm

# %%
import nltk
import spacy
import re
import statistics
from scipy import stats
from nltk import *
from collections import Counter
import itertools
import math
import json
from spacy import Language

# %% [markdown]
# ### prepare document

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(' '.join(open("mobile_phone_wiki_article.txt", 'r').readlines()).lower())

# %% [markdown]
# ### pre-process the document

# %%
def remove_digits(text: str) -> str:
    return re.sub(r"\d+", "", text)


nlp = spacy.load('en_core_web_sm')
text = ' '.join(open("mobile_phone_wiki_article.txt", 'r').readlines()).lower()
text = remove_digits(text)
doc = nlp(text)
# tokenize text
doc = nlp(text)
# remove stopwords


word_list =  []

for token in doc:
    if token.is_punct:
        word_list.append('[PUNCT]')
    elif not token.is_stop and not token.is_space:
        word_list.append(token.lemma_)

print(f'the document has {len(word_list)} words')
print(word_list[:100])
# Out:
# the document has 4415 words
# ['mobile', 'phone', '[PUNCT]', 'cellular', 'phone', '[PUNCT]', 'cell', 'phone', '[PUNCT]', 'cellphone', '[PUNCT]', 'handphone', '[PUNCT]', 'hand', 'phone', '[PUNCT]', 'shorten', 'simply', 'mobile', '[PUNCT]', 'cell', 'phone', '[PUNCT]', 'portable', 'telephone', 'receive', 'call', 'radio', 'frequency', 'link', 'user', 'move', 'telephone', 'service', 'area', '[PUNCT]', 'radio', 'frequency', 'link', 'establish', 'connection', 'switching', 'system', 'mobile', 'phone', 'operator', '[PUNCT]', 'provide', 'access', 'public', 'switch', 'telephone', 'network', '[PUNCT]', 'pstn', '[PUNCT]', '[PUNCT]', 'modern', 'mobile', 'telephone', 'service', 'use', 'cellular', 'network', 'architecture', '[PUNCT]', '[PUNCT]', 'mobile', 'telephone', 'call', 'cellular', 'telephone', 'cell', 'phone', 'north', 'america', '[PUNCT]', 'addition', 'telephony', '[PUNCT]', 'digital', 'mobile', 'phone', '[PUNCT]', 'g', '[PUNCT]', 'support', 'variety', 'service', '[PUNCT]', 'text', 'messaging', '[PUNCT]', 'mms', '[PUNCT]', 'email', '[PUNCT]', 'internet', 'access', '[PUNCT]']

# %% [markdown]
# ## Definition
# * a collocation is just a set of words occuring more than by chance.
# * A collocation is an syntactic and semantic independent unit.
# * two type of collocation : rigid and flexible (the words order is not fixed)
#
# ## Motivation of the paper
# find top ranked N-gram rigid collocation could be used as keywords

# %% [markdown]
# # Popular Method to extract collocation

# %% [markdown]
# ### Point-Wise Mutual Information
#
# Goal : Find closeness between word pairs
#
# # $log_{2}[\frac{P(w_{1},w_{2})}{P(w_{1}), P(w_{2})}]$

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(word_list)
print(f'here is the top 10 bigram with PMI measure : {finder.nbest(bigram_measures.pmi, 10)}')
# Out:
# here is the top 10 bigram with PMI measure : [('accord', 'federal'), ('activism', 'citizen'), ('advent', 'widespread'), ('affair', 'clandestine'), ('affect', 'overall'), ('airtime', 'street'), ('alongside', 'coffee'), ('article', 'reflect'), ('asahi', 'kasei'), ('assist', 'victim')]

# %% [markdown]
# ### T-score
# The T-Score is use to test the plausability of a hypthosis.
# We want to test the following hypothesis (the null hypothesis $H_{0}$) : $P(w_{1}, w_{2}) = P(w_{1}) \cdot P(w_{2})$.
# In other words we would like to see if two words come indepedently or not.
# ## $t = \bar{x} - \frac{\mu}{\sqrt{\frac{s^{2}}{N}}}$
#
# where :
#
# N is a total of words / bigram in the corpus
#
# $H_{0} = P(w_{1}) \cdot P(w_{2})$
#
# $P(w_{1}) = f(w_{1})/N$
#
# $P(w_{2}) = f(w_{2})/N$
#
# $P(w_{1}, w_{2}) = f(w_{1}w_{2})/N$
#
# $\mu = P_{w_{i}}$
#
# $s^{2} = P(w_{1}, w_{2})(1 - P(w_{1}, w_{2}))$
#
# $\bar{x} = P(w_{1}, w_{2})$
#
# then we compare the null hypothesis and the T-score. If T-score is greater than the null hypothesis then the bi-grams is considered as a collocation.

# %%
bigrams = list(nltk.bigrams(word_list))
bigram_frequency = Counter([i for i in bigrams])
monogram_frequency = Counter(word_list)
def compute_t_score(bigram, total_frequency):
    x_mean = bigram[1]/total_frequency
    s_2 = x_mean * (1 - x_mean)
    mu = monogram_frequency[bigram[0][0]]/total_frequency
    null_hypothesis = mu * (monogram_frequency[bigram[0][1]]/total_frequency)
    t_score = x_mean - (mu/math.sqrt(s_2/total_frequency))
    return [bigram[0], True if t_score >= null_hypothesis else False]


t_score = [compute_t_score(bigram, sum(bigram_frequency.values())) for bigram in bigram_frequency.items()]
[t for t in t_score if t[1]]
# Out:
# []

# %% [markdown]
# ## Proposed Methodology

# %% [markdown]
# there are three main steps :
# 1. extracts the list of bi-grams and arranges them in descending order based on their FBI
# 2. extracting the n-grams and arranges them in descending order of respective FNI
# 3. checks whether it is necessary to include monogram keywords

# %% [markdown]
# Before this three main steps we need to generate bi-gram and the frequency of monogram and bi-gram

# %%
bigrams = list(nltk.bigrams(word_list))
monogram_frequency = Counter(word_list)
bigram_frequency = Counter([i for i in bigrams])
list(bigram_frequency.items())
# Out:
# [(('mobile', 'phone'), 103),
#  (('phone', '[PUNCT]'), 38),
#  (('[PUNCT]', 'cellular'), 2),
#  (('cellular', 'phone'), 3),
#  (('[PUNCT]', 'cell'), 12),
#  (('cell', 'phone'), 15),
#  (('[PUNCT]', 'cellphone'), 2),
#  (('cellphone', '[PUNCT]'), 2),
#  (('[PUNCT]', 'handphone'), 1),
#  (('handphone', '[PUNCT]'), 1),
#  (('[PUNCT]', 'hand'), 4),
#  (('hand', 'phone'), 1),
#  (('[PUNCT]', 'shorten'), 1),
#  (('shorten', 'simply'), 1),
#  (('simply', 'mobile'), 1),
#  (('mobile', '[PUNCT]'), 4),
#  (('[PUNCT]', 'portable'), 1),
#  (('portable', 'telephone'), 2),
#  (('telephone', 'receive'), 1),
#  (('receive', 'call'), 1),
#  (('call', 'radio'), 1),
#  (('radio', 'frequency'), 2),
#  (('frequency', 'link'), 2),
#  (('link', 'user'), 1),
#  (('user', 'move'), 1),
#  (('move', 'telephone'), 1),
#  (('telephone', 'service'), 6),
#  (('service', 'area'), 2),
#  (('area', '[PUNCT]'), 3),
#  (('[PUNCT]', 'radio'), 1),
#  (('link', 'establish'), 1),
#  (('establish', 'connection'), 1),
#  (('connection', 'switching'), 1),
#  (('switching', 'system'), 1),
#  (('system', 'mobile'), 3),
#  (('phone', 'operator'), 3),
#  (('operator', '[PUNCT]'), 3),
#  (('[PUNCT]', 'provide'), 7),
#  (('provide', 'access'), 2),
#  (('access', 'public'), 1),
#  (('public', 'switch'), 1),
#  (('switch', 'telephone'), 1),
#  (('telephone', 'network'), 1),
#  (('network', '[PUNCT]'), 6),
#  (('[PUNCT]', 'pstn'), 1),
#  (('pstn', '[PUNCT]'), 1),
#  (('[PUNCT]', '[PUNCT]'), 310),
#  (('[PUNCT]', 'modern'), 3),
#  (('modern', 'mobile'), 2),
#  (('mobile', 'telephone'), 6),
#  (('service', 'use'), 2),
#  (('use', 'cellular'), 1),
#  (('cellular', 'network'), 5),
#  (('network', 'architecture'), 1),
#  (('architecture', '[PUNCT]'), 1),
#  (('[PUNCT]', 'mobile'), 30),
#  (('telephone', 'call'), 1),
#  (('call', 'cellular'), 1),
#  (('cellular', 'telephone'), 1),
#  (('telephone', 'cell'), 1),
#  (('phone', 'north'), 1),
#  (('north', 'america'), 2),
#  (('america', '[PUNCT]'), 1),
#  (('[PUNCT]', 'addition'), 2),
#  (('addition', 'telephony'), 1),
#  (('telephony', '[PUNCT]'), 3),
#  (('[PUNCT]', 'digital'), 5),
#  (('digital', 'mobile'), 2),
#  (('[PUNCT]', 'g'), 11),
#  (('g', '[PUNCT]'), 10),
#  (('[PUNCT]', 'support'), 2),
#  (('support', 'variety'), 1),
#  (('variety', 'service'), 1),
#  (('service', '[PUNCT]'), 10),
#  (('[PUNCT]', 'text'), 3),
#  (('text', 'messaging'), 3),
#  (('messaging', '[PUNCT]'), 2),
#  (('[PUNCT]', 'mms'), 2),
#  (('mms', '[PUNCT]'), 2),
#  (('[PUNCT]', 'email'), 1),
#  (('email', '[PUNCT]'), 1),
#  (('[PUNCT]', 'internet'), 1),
#  (('internet', 'access'), 1),
#  (('access', '[PUNCT]'), 3),
#  (('[PUNCT]', 'short'), 2),
#  (('short', '[PUNCT]'), 2),
#  (('[PUNCT]', 'range'), 2),
#  (('range', 'wireless'), 1),
#  (('wireless', 'communication'), 2),
#  (('communication', '[PUNCT]'), 6),
#  (('[PUNCT]', 'infrare'), 1),
#  (('infrare', '[PUNCT]'), 1),
#  (('[PUNCT]', 'bluetooth'), 1),
#  (('bluetooth', '[PUNCT]'), 1),
#  (('[PUNCT]', 'business'), 2),
#  (('business', 'application'), 1),
#  (('application', '[PUNCT]'), 5),
#  (('[PUNCT]', 'video'), 3),
#  (('video', 'game'), 3),
#  (('game', 'digital'), 1),
#  (('digital', 'photography'), 1),
#  (('photography', '[PUNCT]'), 1),
#  (('phone', 'offer'), 3),
#  (('offer', 'capability'), 1),
#  (('capability', 'know'), 1),
#  (('know', 'feature'), 1),
#  (('feature', 'phone'), 12),
#  (('offer', 'greatly'), 1),
#  (('greatly', 'advanced'), 1),
#  (('advanced', 'computing'), 2),
#  (('computing', 'capability'), 1),
#  (('capability', 'refer'), 1),
#  (('refer', 'smartphone'), 1),
#  (('smartphone', '[PUNCT]'), 8),
#  (('[PUNCT]', 'development'), 3),
#  (('development', 'metal'), 2),
#  (('metal', '[PUNCT]'), 3),
#  (('[PUNCT]', 'oxide'), 3),
#  (('oxide', '[PUNCT]'), 3),
#  (('[PUNCT]', 'semiconductor'), 3),
#  (('semiconductor', '[PUNCT]'), 3),
#  (('[PUNCT]', 'mos'), 3),
#  (('mos', '[PUNCT]'), 3),
#  (('[PUNCT]', 'large'), 5),
#  (('large', '[PUNCT]'), 2),
#  (('[PUNCT]', 'scale'), 2),
#  (('scale', 'integration'), 2),
#  (('integration', '[PUNCT]'), 2),
#  (('[PUNCT]', 'lsi'), 2),
#  (('lsi', '[PUNCT]'), 2),
#  (('[PUNCT]', 'technology'), 2),
#  (('technology', '[PUNCT]'), 5),
#  (('[PUNCT]', 'information'), 2),
#  (('information', 'theory'), 2),
#  (('theory', 'cellular'), 2),
#  (('cellular', 'networking'), 2),
#  (('networking', 'lead'), 2),
#  (('lead', 'development'), 2),
#  (('development', 'affordable'), 2),
#  (('affordable', 'mobile'), 2),
#  (('mobile', 'communication'), 3),
#  (('[PUNCT]', 'handheld'), 5),
#  (('handheld', 'mobile'), 6),
#  (('phone', 'demonstrate'), 2),
#  (('demonstrate', 'john'), 2),
#  (('john', 'f.'), 2),
#  (('f.', 'mitchell'), 2),
#  (('mitchell', '[PUNCT]'), 2),
#  (('[PUNCT]', 'martin'), 2),
#  (('martin', 'cooper'), 3),
#  (('cooper', 'motorola'), 3),
#  (('motorola', '[PUNCT]'), 3),
#  (('[PUNCT]', 'handset'), 3),
#  (('handset', 'weigh'), 2),
#  (('weigh', 'c.'), 1),
#  (('c.', 'kilogram'), 1),
#  (('kilogram', '[PUNCT]'), 2),
#  (('[PUNCT]', 'lbs'), 1),
#  (('lbs', '[PUNCT]'), 1),
#  (('[PUNCT]', 'nippon'), 1),
#  (('nippon', 'telegraph'), 2),
#  (('telegraph', 'telephone'), 2),
#  (('telephone', '[PUNCT]'), 3),
#  (('[PUNCT]', 'ntt'), 1),
#  (('ntt', '[PUNCT]'), 1),
#  (('[PUNCT]', 'launch'), 3),
#  (('launch', 'world'), 1),
#  (('world', 'cellular'), 1),
#  (('network', 'japan.[citation'), 1),
#  (('japan.[citation', 'need'), 1),
#  (('need', '[PUNCT]'), 10),
#  (('[PUNCT]', 'dynatac'), 2),
#  (('dynatac', 'x'), 2),
#  (('x', 'commercially'), 2),
#  (('commercially', 'available'), 4),
#  (('available', 'handheld'), 3),
#  (('[PUNCT]', 'worldwide'), 2),
#  (('worldwide', 'mobile'), 2),
#  (('phone', 'subscription'), 1),
#  (('subscription', 'grow'), 1),
#  (('grow', 'seven'), 1),
#  (('seven', 'billion'), 2),
#  (('billion', '[PUNCT]'), 1),
#  (('provide', 'person'), 1),
#  (('person', 'earth'), 1),
#  (('earth', '[PUNCT]'), 1),
#  (('[PUNCT]', 'quarter'), 1),
#  (('quarter', '[PUNCT]'), 1),
#  (('[PUNCT]', 'smartphone'), 12),
#  (('smartphone', 'developer'), 1),
#  (('developer', 'worldwide'), 1),
#  (('worldwide', 'samsung'), 2),
#  (('samsung', '[PUNCT]'), 5),
#  (('[PUNCT]', 'apple'), 6),
#  (('apple', 'huawei'), 1),
#  (('huawei', '[PUNCT]'), 3),
#  (('smartphone', 'sale'), 1),
#  (('sale', 'represent'), 1),
#  (('represent', 'percent'), 1),
#  (('percent', 'total'), 1),
#  (('total', 'mobile'), 1),
#  (('phone', 'sale'), 2),
#  (('sale', '[PUNCT]'), 1),
#  (('[PUNCT]', 'feature'), 7),
#  (('[PUNCT]', 'slang'), 1),
#  (('slang', '[PUNCT]'), 1),
#  (('[PUNCT]', 'dumbphone'), 1),
#  (('dumbphone', '[PUNCT]'), 1),
#  (('large', 'samsung'), 1),
#  (('[PUNCT]', 'nokia'), 2),
#  (('nokia', 'alcatel'), 1),
#  (('alcatel', '[PUNCT]'), 1),
#  (('[PUNCT]', 'history'), 1),
#  (('history', 'martin'), 1),
#  (('[PUNCT]', 'show'), 1),
#  (('show', 'reenactment'), 1),
#  (('reenactment', '[PUNCT]'), 1),
#  (('[PUNCT]', 'publicize'), 1),
#  (('publicize', 'handheld'), 1),
#  (('phone', 'prototype'), 1),
#  (('prototype', 'dynatac'), 1),
#  (('dynatac', 'model'), 1),
#  (('model', 'april'), 1),
#  (('april', '[PUNCT]'), 1),
#  (('mobile', 'radio'), 1),
#  (('radio', 'telephone'), 1),
#  (('service', 'envision'), 1),
#  (('envision', 'early'), 1),
#  (('early', 'stage'), 1),
#  (('stage', 'radio'), 1),
#  (('radio', 'engineering'), 1),
#  (('engineering', '[PUNCT]'), 1),
#  (('[PUNCT]', 'finnish'), 1),
#  (('finnish', 'inventor'), 1),
#  (('inventor', 'eric'), 1),
#  (('eric', 'tigerstedt'), 1),
#  (('tigerstedt', 'file'), 1),
#  (('file', 'patent'), 1),
#  (('patent', '[PUNCT]'), 1),
#  (('[PUNCT]', 'pocket'), 1),
#  (('pocket', '[PUNCT]'), 1),
#  (('[PUNCT]', 'size'), 2),
#  (('size', 'fold'), 1),
#  (('fold', 'telephone'), 1),
#  (('telephone', 'thin'), 1),
#  (('thin', 'carbon'), 1),
#  (('carbon', 'microphone'), 1),
#  (('microphone', '[PUNCT]'), 1),
#  (('[PUNCT]', 'early'), 2),
#  (('early', 'predecessor'), 1),
#  (('predecessor', 'cellular'), 1),
#  (('phone', 'include'), 1),
#  (('include', 'analog'), 1),
#  (('analog', 'radio'), 1),
#  (('radio', 'communication'), 1),
#  (('communication', 'ship'), 1),
#  (('ship', 'train'), 1),
#  (('train', '[PUNCT]'), 1),
#  (('[PUNCT]', 'race'), 1),
#  (('race', 'create'), 1),
#  (('create', 'truly'), 1),
#  (('truly', 'portable'), 1),
#  (('telephone', 'device'), 1),
#  (('device', 'begin'), 1),
#  (('begin', 'world'), 1),
#  (('world', 'war'), 2),
#  (('war', 'ii'), 1),
#  (('ii', '[PUNCT]'), 1),
#  (('development', 'take'), 1),
#  (('take', 'place'), 1),
#  (('place', 'country'), 1),
#  (('country', '[PUNCT]'), 8),
#  (('[PUNCT]', 'advance'), 1),
#  (('advance', 'mobile'), 1),
#  (('mobile', 'telephony'), 3),
#  (('telephony', 'trace'), 1),
#  (('trace', 'successive'), 1),
#  (('successive', '[PUNCT]'), 1),
#  (('[PUNCT]', 'generation'), 6),
#  (('generation', '[PUNCT]'), 6),
#  (('[PUNCT]', 'start'), 1),
#  (('start', 'early'), 1),
#  (('early', 'zeroth'), 1),
#  (('zeroth', '[PUNCT]'), 1),
#  (('[PUNCT]', 'service'), 2),
#  (('[PUNCT]', 'bell'), 1),
#  (('bell', 'system'), 1),
#  (('service', 'successor'), 1),
#  (('successor', '[PUNCT]'), 1),
#  (('[PUNCT]', 'improved'), 1),
#  (('improved', 'mobile'), 1),
#  (('g', 'system'), 1),
#  (('system', 'cellular'), 1),
#  (('cellular', '[PUNCT]'), 1),
#  (('support', 'simultaneous'), 1),
#  (('simultaneous', 'call'), 3),
#  (('call', '[PUNCT]'), 10),
#  (('[PUNCT]', 'expensive'), 1),
#  (('expensive', '[PUNCT]'), 1),
#  (('[PUNCT]', 'motorola'), 2),
#  (('motorola', 'dynatac'), 1),
#  (('dynatac', 'x.'), 1),
#  (('x.', '[PUNCT]'), 1),
#  (('[PUNCT]', 'commercially'), 2),
#  (('handheld', 'cellular'), 2),
#  (('cellular', 'mobile'), 2),
#  (('[PUNCT]', 'device'), 2),
#  (('device', 'car'), 1),
#  (('car', 'phone'), 1),
#  (('weigh', 'kilogram'), 1),
#  (('[PUNCT]', 'lb'), 1),
#  (('lb', '[PUNCT]'), 1),
#  (('[PUNCT]', 'commercial'), 1),
#  (('commercial', 'automate'), 1),
#  (('automate', 'cellular'), 1),
#  (('[PUNCT]', 'analog'), 1),
#  (('analog', 'launch'), 1),
#  (('launch', 'japan'), 2),
#  (('japan', 'nippon'), 1),
#  (('[PUNCT]', 'follow'), 3),
#  (('follow', 'simultaneous'), 1),
#  (('simultaneous', 'launch'), 1),
#  (('launch', 'nordic'), 1),
#  (('nordic', 'mobile'), 1),
#  (('[PUNCT]', 'nmt'), 1),
#  (('nmt', '[PUNCT]'), 1),
#  (('[PUNCT]', 'system'), 3),
#  (('system', 'denmark'), 1),
#  (('denmark', '[PUNCT]'), 1),
#  (('[PUNCT]', 'finland'), 1),
#  (('finland', '[PUNCT]'), 4),
#  (('[PUNCT]', 'norway'), 1),
#  (('norway', '[PUNCT]'), 1),
#  (('[PUNCT]', 'sweden'), 1),
#  (('sweden', '[PUNCT]'), 1),
#  (('[PUNCT]', 'country'), 2),
#  (('country', 'follow'), 1),
#  (('follow', 'early'), 1),
#  (('early', 'mid'), 1),
#  (('mid', '[PUNCT]'), 1),
#  (('[PUNCT]', 's.'), 1),
#  (('s.', '[PUNCT]'), 1),
#  (('system', 'support'), 1),
#  (('support', 'far'), 1),
#  (('far', 'simultaneous'), 1),
#  (('call', 'analog'), 1),
#  (('analog', 'cellular'), 1),
#  (('cellular', 'technology'), 2),
#  (('digital', 'cellular'), 2),
#  (('network', 'appear'), 1),
#  (('appear', 's'), 1),
#  (('s', '[PUNCT]'), 1),
#  (('[PUNCT]', 'enable'), 2),
#  (('enable', 'wide'), 1),
#  (('wide', 'adoption'), 1),
#  (('adoption', 'mosfet'), 1),
#  (('mosfet', '[PUNCT]'), 1),
#  (('[PUNCT]', 'base'), 2),
#  (('base', 'rf'), 1),
#  (('rf', 'power'), 1),
#  (('power', 'amplifier'), 1),
#  (('amplifier', '[PUNCT]'), 1),
#  (('[PUNCT]', 'power'), 1),
#  (('power', 'mosfet'), 1),
#  (('mosfet', 'ldmos'), 1),
#  (('ldmos', '[PUNCT]'), 1),
#  (('[PUNCT]', 'rf'), 3),
#  (('rf', 'circuit'), 1),
#  (('circuit', '[PUNCT]'), 3),
#  (('rf', 'cmos'), 1),
#  (('cmos', '[PUNCT]'), 1),
#  (('[PUNCT]', 'lead'), 3),
#  (('lead', 'introduction'), 1),
#  (('introduction', 'digital'), 1),
#  (('digital', 'signal'), 1),
#  (('signal', 'processing'), 1),
#  (('processing', 'wireless'), 1),
#  (('[PUNCT]', 'second'), 1),
#  (('second', '[PUNCT]'), 3),
#  (('technology', 'launch'), 1),
#  (('launch', 'finland'), 2),
#  (('finland', 'radiolinja'), 1),
#  (('radiolinja', 'gsm'), 1),
#  (('gsm', 'standard'), 2),
#  (('standard', '[PUNCT]'), 7),
#  (('[PUNCT]', 'spark'), 1),
#  (('spark', 'competition'), 1),
#  (('competition', 'sector'), 1),
#  (('sector', 'new'), 1),
#  (('new', 'operator'), 1),
#  (('operator', 'challenge'), 1),
#  (('challenge', 'incumbent'), 1),
#  (('incumbent', 'g'), 1),
#  (('g', 'network'), 2),
#  (('network', 'operator'), 3),
#  (('[PUNCT]', 'gsm'), 3),
#  (('standard', 'european'), 1),
#  (('european', 'initiative'), 1),
#  (('initiative', 'express'), 1),
#  (('express', 'cept'), 1),
#  (('cept', '[PUNCT]'), 1),
#  (('[PUNCT]', 'conférence'), 1),
#  (('conférence', 'européenne'), 1),
#  (('européenne', 'des'), 1),
#  (('des', 'poste'), 1),
#  (('poste', 'et'), 1),
#  (('et', 'telecommunication'), 1),
#  (('telecommunication', '[PUNCT]'), 1),
#  (('[PUNCT]', 'european'), 1),
#  (('european', 'postal'), 1),
#  (('postal', 'telecommunication'), 1),
#  (('telecommunication', 'conference'), 1),
#  (('conference', '[PUNCT]'), 1),
#  (('[PUNCT]', 'franco'), 1),
#  (('franco', '[PUNCT]'), 1),
#  (('[PUNCT]', 'german'), 1),
#  (('german', 'r&d'), 1),
#  (('r&d', 'cooperation'), 1),
#  (('cooperation', 'demonstrate'), 1),
#  (('demonstrate', 'technical'), 1),
#  (('technical', 'feasibility'), 1),
#  (('feasibility', '[PUNCT]'), 1),
#  (('[PUNCT]', 'memorandum'), 1),
#  (('memorandum', 'understanding'), 1),
#  (('understanding', 'sign'), 1),
#  (('sign', 'european'), 1),
#  (('european', 'country'), 1),
#  (('country', 'agree'), 1),
#  (('agree', 'launch'), 1),
#  (('launch', 'commercial'), 1),
#  (('commercial', 'service'), 1),
#  (('[PUNCT]', 'version'), 1),
#  (('version', 'gsm'), 1),
#  (('gsm', '(='), 1),
#  (('(=', 'g'), 1),
#  (('[PUNCT]', 'standard'), 1),
#  (('[PUNCT]', 'page'), 1),
#  (('page', '[PUNCT]'), 1),
#  (('[PUNCT]', 'ieee'), 1),
#  (('ieee', '[PUNCT]'), 1),
#  (('[PUNCT]', 'rse'), 1),
#  (('rse', 'award'), 1),
#  (('award', 'thoma'), 1),
#  (('thoma', 'haug'), 1),
#  (('haug', 'philippe'), 1),
#  (('philippe', 'dupuis'), 1),
#  (('dupuis', 'jame'), 1),
#  (('jame', 'clerk'), 1),
#  (('clerk', 'maxwell'), 1),
#  (('maxwell', 'medal'), 1),
#  (('medal', 'contribution'), 1),
#  (('contribution', 'digital'), 1),
#  (('telephone', 'standard'), 1),
#  (('gsm', 'billion'), 1),
#  (('billion', 'people'), 1),
#  (('people', 'country'), 1),
#  (('gsm', '[PUNCT]'), 1),
#  (('[PUNCT]', 'evolve'), 1),
#  (('evolve', 'g'), 1),
#  (('g', 'g.'), 1),
#  (('g.', 'lithium'), 1),
#  (('lithium', '[PUNCT]'), 3),
#  (('[PUNCT]', 'ion'), 4),
#  (('ion', 'battery'), 2),
#  (('battery', '[PUNCT]'), 5),
#  (('[PUNCT]', 'indispensable'), 1),
#  (('indispensable', 'energy'), 1),
#  (('energy', 'source'), 1),
#  (('source', 'modern'), 1),
#  (('[PUNCT]', 'commercialize'), 1),
#  (('commercialize', 'sony'), 1),
#  (('sony', 'asahi'), 1),
#  (('asahi', 'kasei'), 1),
#  (('kasei', '[PUNCT]'), 1),
#  (('japan', 'ntt'), 1),
#  (('ntt', 'docomo'), 1),
#  (('docomo', 'wcdma'), 1),
#  (('wcdma', 'standard'), 1),
#  (('follow', '.g'), 1),
#  (('.g', '[PUNCT]'), 1),
#  (('[PUNCT]', 'g+'), 1),
#  (('g+', 'turbo'), 1),
#  (('turbo', 'g'), 1),
#  (('g', 'enhancement'), 1),
#  (('enhancement', 'base'), 1),
#  (('base', 'high'), 1),
#  (('high', '[PUNCT]'), 1),
#  (('[PUNCT]', 'speed'), 1),
#  (('speed', 'packet'), 1),
#  (('packet', 'access'), 1),
#  (('[PUNCT]', 'hspa'), 1),
#  (('hspa', '[PUNCT]'), 1),
#  (('[PUNCT]', 'family'), 2),
#  (('family', '[PUNCT]'), 1),
#  (('[PUNCT]', 'allow'), 2),
#  (('allow', 'umts'), 1),
#  (('umts', 'network'), 1),
#  (('network', 'high'), 1),
#  (('high', 'data'), 1),
#  (('data', 'transfer'), 1),
#  (('transfer', 'speed'), 1),
#  (('speed', 'capacity'), 1),
#  (('capacity', '[PUNCT]'), 2),
#  (('[PUNCT]', 'clear'), 1),
#  (('clear', '[PUNCT]'), 1),
#  (('[PUNCT]', 'point'), 2),
#  (('point', '[PUNCT]'), 2),
#  (('network', 'overwhelm'), 1),
#  (('overwhelm', 'growth'), 1),
#  (('growth', 'bandwidth'), 1),
#  (('bandwidth', '[PUNCT]'), 1),
#  (('[PUNCT]', 'intensive'), 1),
#  (('intensive', 'application'), 1),
#  (('[PUNCT]', 'streaming'), 1),
#  (('streaming', 'medium'), 1),
#  (('medium', '[PUNCT]'), 2),
#  (('[PUNCT]', 'consequently'), 1),
#  (('consequently', '[PUNCT]'), 1),
#  (('[PUNCT]', 'industry'), 1),
#  (('industry', 'begin'), 1),
#  (('begin', 'look'), 1),
#  (('look', 'data'), 1),
#  (('data', '[PUNCT]'), 1),
#  (('[PUNCT]', 'optimize'), 1),
#  (('optimize', 'fourth'), 1),
#  (('fourth', '[PUNCT]'), 1),
#  (('generation', 'technology'), 1),
#  (('[PUNCT]', 'promise'), 1),
#  (('promise', 'speed'), 1),
#  (('speed', 'improvement'), 1),
#  (('improvement', '[PUNCT]'), 1),
#  (('[PUNCT]', 'fold'), 1),
#  (('fold', 'exist'), 1),
#  (('exist', 'g'), 1),
#  (('g', 'technology'), 2),
#  (('available', 'technology'), 1),
#  (('technology', 'bill'), 1),
#  (('bill', 'g'), 1),
#  (('g', 'wimax'), 1),
#  (('wimax', 'standard'), 1),
#  (('[PUNCT]', 'offer'), 2),
#  (('offer', 'north'), 1),
#  (('america', 'sprint'), 1),
#  (('sprint', '[PUNCT]'), 1),
#  (('[PUNCT]', 'lte'), 1),
#  (('lte', 'standard'), 1),
#  (('offer', 'scandinavia'), 1),
#  (('scandinavia', 'teliasonera'), 1),
#  (('teliasonera', '[PUNCT]'), 1),
#  (('technology', 'term'), 1),
#  (('term', 'research'), 1),
#  (('research', 'paper'), 1),
#  (('paper', 'project'), 1),
#  (('project', 'denote'), 1),
#  (('denote', 'major'), 1),
#  (('major', 'phase'), 1),
#  (('phase', 'mobile'), 1),
#  (('mobile', 'telecommunication'), 1),
#  (('telecommunication', 'standard'), 1),
#  (('standard', 'g'), 2),
#  (('[PUNCT]', 'imt'), 1),
#  (('imt', '[PUNCT]'), 1),
#  (('[PUNCT]', 'advanced'), 2),
#  (('advanced', 'standard'), 1),
#  (('[PUNCT]', 'term'), 4),
#  (('term', 'g'), 1),
#  (('g', 'officially'), 1),
#  (('officially', 'specification'), 1),
#  (('specification', 'official'), 1),
#  (('official', 'document'), 1),
#  (('document', 'public'), 1),
#  (('public', 'telecommunication'), 1),
#  (('telecommunication', 'company'), 1),
#  (('company', 'standardization'), 1),
#  (('standardization', 'body'), 2),
#  (('body', 'gpp'), 1),
#  (('gpp', '[PUNCT]'), 1),
#  (('[PUNCT]', 'wimax'), 1),
#  (('wimax', 'forum'), 1),
#  (('forum', 'itu'), 1),
#  (('itu', '[PUNCT]'), 1),
#  (('[PUNCT]', 'r.'), 1),
#  (('r.', 'new'), 1),
#  (('new', 'standard'), 1),
#  (('g', 'currently'), 1),
#  (('currently', 'develop'), 1),
#  (('develop', 'standardization'), 1),
#  (('body', '[PUNCT]'), 1),
#  (('[PUNCT]', 'time'), 2),
#  (('time', 'see'), 1),
#  (('see', 'g'), 1),
#  (('g', 'umbrella'), 1),
#  (('umbrella', '[PUNCT]'), 1),
#  (('[PUNCT]', 'new'), 2),
#  (('new', 'mobile'), 1),
#  (('mobile', 'generation'), 1),
#  (('[PUNCT]', 'type'), 3),
#  (('type', 'mobile'), 1),
#  (('mobile', 'subscription'), 1),
#  (('subscription', 'people'), 1),
#  (('people', '[PUNCT]'), 1),
#  (('[PUNCT]', 'active'), 1),
#  (('active', 'mobile'), 2),
#  (('mobile', 'broadband'), 1),
#  (('broadband', 'subscription'), 2),
#  (('subscription', 'inhabitant'), 1),
#  (('inhabitant', '[PUNCT]'), 2),
#  (('smartphone', 'smartphone'), 1),
#  (('smartphone', 'number'), 1),
#  (('number', 'distinguish'), 1),
#  (('distinguish', 'feature'), 1),
#  (('feature', '[PUNCT]'), 3),
#  (('[PUNCT]', 'international'), 2),
#  (('international', 'telecommunication'), 1),
#  (('telecommunication', 'union'), 1),
#  (('union', 'measure'), 1),
#  (('measure', 'internet'), 1),
#  (('internet', 'connection'), 1),
#  (('connection', '[PUNCT]'), 2),
#  (('[PUNCT]', 'call'), 3),
#  (('call', 'active'), 1),
#  (('[PUNCT]', 'broadband'), 1),
#  (('subscription', '[PUNCT]'), 1),
#  (('[PUNCT]', 'include'), 7),
#  (('include', 'tablet'), 1),
#  (('tablet', '[PUNCT]'), 1),
#  (('[PUNCT]', 'etc'), 2),
#  (('etc', '[PUNCT]'), 2),
#  (('[PUNCT]', 'developed'), 1),
#  (('developed', 'world'), 1),
#  (('world', '[PUNCT]'), 4),
#  (('smartphone', 'overtake'), 1),
#  (('overtake', 'usage'), 1),
#  (('usage', 'early'), 1),
#  (('early', 'mobile'), 1),
#  (('mobile', 'system'), 1),
#  (('system', '[PUNCT]'), 4),
#  (('[PUNCT]', 'develop'), 2),
#  (('develop', 'world'), 1),
#  (('[PUNCT]', 'account'), 1),
#  (('account', '[PUNCT]'), 1),
#  (('phone', 'feature'), 2),
#  (('phone', 'term'), 1),
#  (('term', 'typically'), 1),
#  (('typically', 'retronym'), 1),
#  (('retronym', 'describe'), 1),
#  (('describe', 'mobile'), 1),
#  (('phone', 'limit'), 1),
#  (('limit', 'capability'), 1),
#  (('capability', 'contrast'), 1),
#  (('contrast', 'modern'), 1),
#  (('modern', 'smartphone'), 2),
#  (('phone', 'typically'), 2),
#  (('typically', 'provide'), 1),
#  (('provide', 'voice'), 1),
#  (('voice', 'calling'), 2),
#  (('calling', 'text'), 2),
#  (('messaging', 'functionality'), 1),
#  (('functionality', '[PUNCT]'), 1),
#  (('addition', 'basic'), 1),
#  (('basic', 'multimedia'), 1),
#  (('multimedia', 'internet'), 1),
#  (('internet', 'capability'), 1),
#  (('capability', '[PUNCT]'), 2),
#  (('service', 'offer'), 1),
#  (('offer', 'user'), 1),
#  (('user', 'wireless'), 1),
#  (('wireless', 'service'), 1),
#  (('service', 'provider'), 2),
#  (('provider', '[PUNCT]'), 1),
#  (('phone', 'additional'), 1),
#  (('additional', 'function'), 1),
#  (('function', 'basic'), 1),
#  (('basic', 'mobile'), 2),
#  (('phone', 'capable'), 1),
#  (('capable', 'voice'), 1),
#  (('phone', 'basic'), 2),
#  (('phone', 'tend'), 2),
#  (('tend', 'use'), 1),
#  (('use', 'proprietary'), 1),
#  (('proprietary', '[PUNCT]'), 1),
#  (('[PUNCT]', 'custom'), 1),
#  (('custom', '[PUNCT]'), 1),
#  (('[PUNCT]', 'design'), 3),
#  (('design', 'software'), 1),
#  (('software', 'user'), 1),
#  (('user', 'interface'), 1),
#  (('interface', '[PUNCT]'), 1),
#  (('[PUNCT]', 'contrast'), 1),
#  (('contrast', '[PUNCT]'), 1),
#  (('smartphone', 'generally'), 1),
#  (('generally', 'use'), 1),
#  (('use', 'mobile'), 11),
#  (('mobile', 'operating'), 1),
#  (('operating', 'system'), 2),
#  (('system', 'share'), 1),
#  (('share', 'common'), 1),
#  (('common', 'trait'), 1),
#  (('trait', 'device'), 1),
#  (('device', '[PUNCT]'), 6),
#  (('[PUNCT]', 'infrastructure'), 1),
#  (('infrastructure', 'mobile'), 1),
#  (('phone', 'communicate'), 1),
#  (('communicate', 'cell'), 1),
#  (('cell', 'tower'), 3),
#  (('tower', 'place'), 2),
#  (('place', 'coverage'), 1),
#  (('coverage', 'telephone'), 1),
#  (('[PUNCT]', 'divide'), 1),
#  (('divide', '[PUNCT]'), 1),
#  (('cell', '[PUNCT]'), 5),
#  (('cell', 'use'), 4),
#  (('use', 'different'), 1),
#  (('different', 'set'), 1),
#  (('set', 'frequency'), 1),
#  (('frequency', 'neighboring'), 1),
#  (('neighboring', 'cell'), 1),
#  (('[PUNCT]', 'typically'), 2),
#  (('typically', 'cover'), 1),
#  (('cover', 'tower'), 1),
#  (('place', 'different'), 1),
#  (('different', 'location'), 1),
#  (('location', '[PUNCT]'), 2),
#  (('tower', 'usually'), 1),
#  (('usually', 'interconnect'), 1),
#  (('interconnect', 'phone'), 1),
#  (('phone', 'network'), 2),
#  (('network', 'internet'), 1),
#  (('internet', 'wire'), 1),
#  (('wire', 'connection'), 1),
#  (('[PUNCT]', 'bandwidth'), 1),
#  (('bandwidth', 'limitation'), 1),
#  (('limitation', 'cell'), 1),
#  (('cell', 'maximum'), 1),
#  (('maximum', 'number'), 1),
#  (('number', 'cell'), 1),
#  (('phone', 'handle'), 1),
#  (('handle', '[PUNCT]'), 1),
#  (('cell', 'sized'), 1),
#  (('sized', 'depend'), 1),
#  (('depend', 'expect'), 1),
#  (('expect', 'usage'), 1),
#  (('usage', 'density'), 1),
#  (('density', '[PUNCT]'), 1),
#  (('[PUNCT]', 'small'), 2),
#  (('small', 'city'), 1),
#  (('city', '[PUNCT]'), 2),
#  (('[PUNCT]', 'case'), 1),
#  (('case', 'low'), 1),
#  (('low', 'transmitter'), 1),
#  (('transmitter', 'power'), 1),
#  (('power', 'avoid'), 1),
#  (('avoid', 'broadcasting'), 1),
#  (('broadcasting', 'cell'), 1),
#  (('[PUNCT]', 'order'), 3),
#  (('order', 'handle'), 1),
#  (('handle', 'high'), 1),
#  (('high', 'traffic'), 2),
#  (('traffic', '[PUNCT]'), 1),
#  (('[PUNCT]', 'multiple'), 2),
#  (('multiple', 'tower'), 1),
#  (('tower', 'set'), 1),
#  (('set', 'area'), 1),
#  (('[PUNCT]', 'different'), 1),
#  (('different', 'frequency'), 1),
#  (('frequency', '[PUNCT]'), 6),
#  (('[PUNCT]', 'permanently'), 1),
#  (('permanently', 'temporarily'), 1),
#  (('temporarily', 'special'), 1),
#  (('special', 'event'), 1),
#  (('event', 'like'), 1),
#  (('like', 'super'), 1),
#  (('super', 'bowl'), 1),
#  (('bowl', '[PUNCT]'), 1),
#  (('[PUNCT]', 'taste'), 1),
#  (('taste', 'chicago'), 1),
#  (('chicago', '[PUNCT]'), 1),
#  (('[PUNCT]', 'state'), 5),
#  (('state', 'fair'), 1),
#  (('fair', '[PUNCT]'), 1),
#  (('[PUNCT]', 'nyc'), 1),
#  (('nyc', 'new'), 1),
#  (('new', 'year'), 1),
#  (('year', 'eve'), 1),
#  (('eve', '[PUNCT]'), 1),
#  (('[PUNCT]', 'hurricane'), 1),
#  (('hurricane', 'hit'), 1),
#  (('hit', 'city'), 1),
#  (('phone', 'company'), 3),
#  (('company', 'bring'), 1),
#  (('bring', 'truck'), 1),
#  (('truck', 'equipment'), 1),
#  (('equipment', 'host'), 1),
#  (('host', 'abnormally'), 1),
#  (('abnormally', 'high'), 1),
#  (('traffic', 'portable'), 1),
#  (('portable', 'cell'), 1),
#  (('cellular', 'greatly'), 1),
#  (('greatly', 'increase'), 2),
#  (('increase', 'capacity'), 2),
#  (('capacity', 'simultaneous'), 1),
#  (('simultaneous', 'wireless'), 1),
#  (('wireless', 'phone'), 1),
#  (('phone', 'call'), 1),
#  (('[PUNCT]', 'phone'), 13),
#  (('company', 'example'), 1),
#  (('example', '[PUNCT]'), 6),
#  (('[PUNCT]', 'license'), 1),
#  (('license', '[PUNCT]'), 1),
#  (('[PUNCT]', 'frequency'), 4),
#  (('use', 'unique'), 1),
#  (('unique', 'frequency'), 1),
#  (('frequency', 'communicate'), 1),
#  (('communicate', '[PUNCT]'), 1),
#  (('cell', 'slightly'), 1),
#  (('slightly', 'overlap'), 1),
#  (('overlap', '[PUNCT]'), 2),
#  (('frequency', 'reuse'), 1),
#  (('reuse', '[PUNCT]'), 1),
#  (('[PUNCT]', 'example'), 7),
#  (('example', 'cell'), 1),
#  (('use', 'frequency'), 2),
#  (('[PUNCT]', 'door'), 2),
#  (('door', 'cell'), 1),
#  (('door', 'reuse'), 1),
#  (('reuse', 'frequency'), 1),
#  (('[PUNCT]', 'touching'), 1),
#  (('touching', '[PUNCT]'), 1),
#  (('[PUNCT]', 'overlap'), 1),
#  (('[PUNCT]', 'communicate'), 1),
#  (('communicate', 'reuse'), 1),
#  (('reuse', 'frequencies.[citation'), 1),
#  (('frequencies.[citation', 'need'), 1),
#  (('[PUNCT]', 'greatly'), 1),
#  (('increase', 'phone'), 1),
#  (('company', 'implement'), 1),
#  (('implement', 'digital'), 1),
#  (('digital', 'network'), 1),
#  (('digital', '[PUNCT]'), 1),
#  (('frequency', 'host'), 1),
#  (('host', 'multiple'), 1),
#  (('multiple', 'simultaneous'), 1),
#  (('call', 'increase'), 1),
#  (('phone', 'move'), 1),
#  (('move', '[PUNCT]'), 1),
#  (('hand', '[PUNCT]'), 11),
#  (('[PUNCT]', 'automatically'), 1),
#  (('automatically', 'disconnect'), 1),
#  (('disconnect', 'reconnect'), 1),
#  (('reconnect', 'tower'), 1),
#  (('tower', 'cell'), 1),
#  (('cell', 'give'), 1),
#  (('give', 'good'), 1),
#  (('good', 'reception'), 1),
#  (('reception', '[PUNCT]'), 1),
#  (('[PUNCT]', 'additionally'), 1),
#  (('additionally', '[PUNCT]'), 1),
#  (('range', 'wi'), 1),
#  (('wi', '[PUNCT]'), 1),
#  (('[PUNCT]', 'fi'), 1),
#  (('fi', 'infrastructure'), 1),
#  (('infrastructure', 'smartphone'), 1),
#  (('smartphone', 'possible'), 1),
#  (('possible', 'offload'), 1),
#  (('offload', 'traffic'), 1),
#  (('traffic', 'cell'), 1),
#  (('cell', 'network'), 1),
#  (('network', 'local'), 1),
#  (('local', 'area'), 1),
#  (('area', 'network'), 1),
#  (('[PUNCT]', 'hardware'), 2),
#  (('hardware', 'common'), 1),
#  (('common', 'component'), 1),
#  (('component', 'find'), 1),
#  (('find', 'mobile'), 3),
#  (('[PUNCT]', 'central'), 2),
#  (('central', 'processing'), 2),
#  (('processing', 'unit'), 2),
#  (('unit', '[PUNCT]'), 4),
#  (('[PUNCT]', 'cpu'), 2),
#  (('cpu', '[PUNCT]'), 1),
#  (('[PUNCT]', 'processor'), 1),
#  (('processor', 'phone'), 1),
#  (('cpu', 'microprocessor'), 1),
#  (('microprocessor', 'fabricate'), 1),
#  (('fabricate', 'metal'), 1),
#  (('[PUNCT]', 'integrated'), 1),
#  (('integrated', 'circuit'), 1),
#  (('[PUNCT]', 'ic'), 1),
#  (('ic', '[PUNCT]'), 1),
#  (('[PUNCT]', 'chip'), 1),
#  (('chip', '[PUNCT]'), 1),
#  (('[PUNCT]', 'battery'), 5),
#  (('provide', 'power'), 1),
#  (('power', 'source'), 1),
#  (('source', 'phone'), 1),
#  (('phone', 'function'), 1),
#  (('function', '[PUNCT]'), 2),
#  (('modern', 'handset'), 1),
#  (('handset', 'typically'), 1),
#  (('typically', 'use'), 1),
#  (('use', 'lithium'), 2),
#  (('[PUNCT]', 'lib'), 1),
#  (('lib', '[PUNCT]'), 1),
#  (('[PUNCT]', 'old'), 1),
#  (('old', 'handset'), 1),
#  (('handset', 'nickel'), 1),
#  (('nickel', '[PUNCT]'), 1),
#  (('[PUNCT]', 'metal'), 1),
#  (('metal', 'hydride'), 1),
#  (('hydride', '[PUNCT]'), 1),
#  (('[PUNCT]', 'ni'), 1),
#  (('ni', '[PUNCT]'), 1),
#  (('[PUNCT]', 'mh'), 1),
#  (('mh', '[PUNCT]'), 1),
#  (('[PUNCT]', 'input'), 1),
#  (('input', 'mechanism'), 1),
#  (('mechanism', 'allow'), 1),
#  (('allow', 'user'), 2),
#  (('user', 'interact'), 1),
#  (('interact', 'phone'), 1),
#  (('[PUNCT]', 'keypad'), 1),
#  (('keypad', 'feature'), 1),
#  (('[PUNCT]', 'touch'), 1),
#  (('touch', 'screen'), 1),
#  (('screen', 'smartphone'), 1),
#  (('typically', 'capacitive'), 1),
#  (('capacitive', 'sensing'), 1),
#  (('sensing', '[PUNCT]'), 1),
#  (('[PUNCT]', 'display'), 7),
#  (('display', 'echo'), 1),
#  (('echo', 'user'), 1),
#  (('user', 'typing'), 1),
#  (('typing', '[PUNCT]'), 1),
#  (('display', 'text'), 1),
#  (('text', 'message'), 5),
#  (('message', '[PUNCT]'), 4),
#  (('[PUNCT]', 'contact'), 1),
#  (('contact', '[PUNCT]'), 1),
#  (('display', 'typically'), 1),
#  (('typically', 'liquid'), 1),
#  (('liquid', '[PUNCT]'), 2),
#  (('[PUNCT]', 'crystal'), 2),
#  (('crystal', 'display'), 2),
#  (('display', '[PUNCT]'), 4),
#  (('[PUNCT]', 'lcd'), 1),
#  (('lcd', '[PUNCT]'), 1),
#  (('[PUNCT]', 'organic'), 1),
#  (('organic', 'light'), 1),
#  (('light', '[PUNCT]'), 1),
#  (('[PUNCT]', 'emit'), 1),
#  (('emit', 'diode'), 1),
#  (('diode', '[PUNCT]'), 1),
#  (('[PUNCT]', 'ole'), 2),
#  (('ole', '[PUNCT]'), 2),
#  (('[PUNCT]', 'speaker'), 1),
#  (('speaker', 'sound'), 1),
#  (('sound', '[PUNCT]'), 2),
#  (('[PUNCT]', 'subscriber'), 2),
#  (('subscriber', 'identity'), 2),
#  (('identity', 'module'), 3),
#  (('module', '[PUNCT]'), 2),
#  (('[PUNCT]', 'sim'), 8),
#  (('sim', '[PUNCT]'), 1),
#  (('[PUNCT]', 'card'), 2),
#  (('card', 'removable'), 1),
#  (('removable', 'user'), 1),
#  (('user', 'identity'), 1),
#  (('[PUNCT]', 'r'), 1),
#  (('r', '[PUNCT]'), 2),
#  (('[PUNCT]', 'uim'), 2),
#  (('uim', '[PUNCT]'), 1),
#  (('card', '[PUNCT]'), 6),
#  (('hardware', 'notification'), 1),
#  (('notification', 'lead'), 1),
#  (('lead', 'phone'), 1),
#  (('phone', 'low'), 1),
#  (('low', '[PUNCT]'), 2),
#  (('[PUNCT]', 'end'), 1),
#  (('end', 'mobile'), 1),
#  (('phone', 'refer'), 1),
#  (('refer', 'feature'), 1),
#  (('offer', 'basic'), 1),
#  (('basic', 'telephony'), 1),
#  (('handset', 'advanced'), 1),
#  (('computing', 'ability'), 1),
#  (('ability', 'use'), 1),
#  (('use', 'native'), 1),
#  (('native', 'software'), 1),
#  (('software', 'application'), 2),
#  (('application', 'know'), 1),
#  (('know', 'smartphone'), 1),
#  (('central', 'process'), 1),
#  (('process', 'unit'), 1),
#  (('unit', 'mobile'), 1),
#  (('phone', 'central'), 1),
#  (('[PUNCT]', 'cpus'), 1),
#  (('cpus', '[PUNCT]'), 1),
#  (('[PUNCT]', 'similar'), 2),
#  (('similar', 'computer'), 1),
#  ...]

# %% [markdown]
# Usually, $F_{iw}(i)$ is the number of word appeared $i$ times.
# But in our case, $F_{iw}(i)$ is different for bigram and monogram.
#
# For our monogram, $F_{iw}(i)$ is replace by the mean of other values apparence.
#
# For our bigram, $F_{iw}(1)$ is just replace by the mean of other values apparence.

# %%
def compute_cumul_freq_bigram(ngram_frequency):
    
    ngram_cumulative_freq = {}
    for i in ngram_frequency.values():
        if i not in ngram_cumulative_freq.keys():
            ngram_cumulative_freq[i] = 1
        ngram_cumulative_freq[i] += 1
    ngram_cumulative_freq[1] = statistics.mean([v for k,v in ngram_cumulative_freq.items() if k != 1]) 
    key_list = sorted(list(ngram_cumulative_freq.keys()), key=lambda x : x)
    cumul = 0
    for key in key_list :
        cumul += ngram_cumulative_freq[key]
        ngram_cumulative_freq[key] = cumul
    return ngram_cumulative_freq

def compute_cumul_freq_monogram(ngram_frequency):
    
    ngram_cumulative_freq = {}
    for i in ngram_frequency.values():
        if i not in ngram_cumulative_freq.keys():
            ngram_cumulative_freq[i] = 1
        ngram_cumulative_freq[i] += 1
    ngram_cumulative_freq = {k: statistics.mean([m_v for m_k, m_v in ngram_cumulative_freq.items() if m_k != k]) 
                             for k in ngram_cumulative_freq.keys()}
    key_list = sorted(list(ngram_cumulative_freq.keys()), key=lambda x : x)
    cumul = 0
    for key in key_list:
        cumul += ngram_cumulative_freq[key]
        ngram_cumulative_freq[key] = cumul

    
    return ngram_cumulative_freq


cumul_monogram = compute_cumul_freq_monogram(monogram_frequency)
cumul_bigram = compute_cumul_freq_bigram(bigram_frequency)
cumul_monogram
# Out:
# {152: 1199.84,
#  187: 1251.9199999999998,
#  1119: 1303.9999999999998,
#  20: 939.4800000000001,
#  32: 1095.68,
#  5: 213.95999999999998,
#  1: 21.44,
#  14: 679.28,
#  4: 162.64,
#  3: 113.28,
#  17: 783.24,
#  19: 887.4000000000001,
#  6: 264.96,
#  12: 575.36,
#  2: 64.92,
#  21: 991.5200000000001,
#  11: 523.4,
#  9: 419.79999999999995,
#  18: 835.32,
#  45: 1147.76,
#  10: 471.59999999999997,
#  8: 368.03999999999996,
#  7: 316.15999999999997,
#  13: 627.36,
#  26: 1043.6000000000001,
#  16: 731.24}

# %% [markdown]
# ## High Word Occurence (*HWO*)
#
# HWO is defined as $HWO(w) = C_{iw}(n) / C_{iw}(N_{max})$
#
# Cw is the cumulative frequency of an individual word.
#
# Here, $C_{iw}(n) = \sum_{i-1}^{n}F_{iw}(i)$

# %%
def HWO(word, monogram_frequency, cumul_monogram):
    key_max = max(list(cumul_monogram.keys()))
    return cumul_monogram[monogram_frequency[word]]/cumul_monogram[key_max]

# %%
hwo = {word: HWO(word, monogram_frequency, cumul_monogram) for word in word_list}
hwo
# Out:
# {'mobile': 0.9201226993865032,
#  'phone': 0.9600613496932516,
#  '[PUNCT]': 1.0,
#  'cellular': 0.7204601226993868,
#  'cell': 0.8402453987730063,
#  'cellphone': 0.164079754601227,
#  'handphone': 0.016441717791411046,
#  'hand': 0.5209202453987731,
#  'shorten': 0.016441717791411046,
#  'simply': 0.12472392638036811,
#  'portable': 0.0868711656441718,
#  'telephone': 0.6006441717791412,
#  'receive': 0.016441717791411046,
#  'call': 0.6805214723926383,
#  'radio': 0.20319018404907976,
#  'frequency': 0.4412269938650308,
#  'link': 0.04978527607361964,
#  'user': 0.5209202453987731,
#  'move': 0.04978527607361964,
#  'service': 0.7603680981595095,
#  'area': 0.20319018404907976,
#  'establish': 0.016441717791411046,
#  'connection': 0.0868711656441718,
#  'switching': 0.016441717791411046,
#  'system': 0.4013803680981596,
#  'operator': 0.4013803680981596,
#  'provide': 0.5209202453987731,
#  'access': 0.32193251533742334,
#  'public': 0.12472392638036811,
#  'switch': 0.0868711656441718,
#  'network': 0.6405828220858897,
#  'pstn': 0.016441717791411046,
#  'modern': 0.164079754601227,
#  'use': 0.8801840490797548,
#  'architecture': 0.016441717791411046,
#  'north': 0.04978527607361964,
#  'america': 0.04978527607361964,
#  'addition': 0.12472392638036811,
#  'telephony': 0.20319018404907976,
#  'digital': 0.36165644171779143,
#  'g': 0.7603680981595095,
#  'support': 0.12472392638036811,
#  'variety': 0.12472392638036811,
#  'text': 0.4013803680981596,
#  'messaging': 0.12472392638036811,
#  'mms': 0.04978527607361964,
#  'email': 0.016441717791411046,
#  'internet': 0.28223926380368103,
#  'short': 0.0868711656441718,
#  'range': 0.0868711656441718,
#  'wireless': 0.24245398773006135,
#  'communication': 0.36165644171779143,
#  'infrare': 0.016441717791411046,
#  'bluetooth': 0.016441717791411046,
#  'business': 0.20319018404907976,
#  'application': 0.4811042944785277,
#  'video': 0.20319018404907976,
#  'game': 0.0868711656441718,
#  'photography': 0.016441717791411046,
#  'offer': 0.20319018404907976,
#  'capability': 0.20319018404907976,
#  'know': 0.164079754601227,
#  'feature': 0.6006441717791412,
#  'greatly': 0.12472392638036811,
#  'advanced': 0.164079754601227,
#  'computing': 0.04978527607361964,
#  'refer': 0.04978527607361964,
#  'smartphone': 0.8003067484662579,
#  'development': 0.20319018404907976,
#  'metal': 0.164079754601227,
#  'oxide': 0.0868711656441718,
#  'semiconductor': 0.0868711656441718,
#  'mos': 0.0868711656441718,
#  'large': 0.32193251533742334,
#  'scale': 0.04978527607361964,
#  'integration': 0.04978527607361964,
#  'lsi': 0.04978527607361964,
#  'technology': 0.4412269938650308,
#  'information': 0.164079754601227,
#  'theory': 0.04978527607361964,
#  'networking': 0.04978527607361964,
#  'lead': 0.24245398773006135,
#  'affordable': 0.04978527607361964,
#  'handheld': 0.4811042944785277,
#  'demonstrate': 0.0868711656441718,
#  'john': 0.04978527607361964,
#  'f.': 0.04978527607361964,
#  'mitchell': 0.04978527607361964,
#  'martin': 0.0868711656441718,
#  'cooper': 0.0868711656441718,
#  'motorola': 0.20319018404907976,
#  'handset': 0.24245398773006135,
#  'weigh': 0.04978527607361964,
#  'c.': 0.016441717791411046,
#  'kilogram': 0.04978527607361964,
#  'lbs': 0.016441717791411046,
#  'nippon': 0.04978527607361964,
#  'telegraph': 0.04978527607361964,
#  'ntt': 0.04978527607361964,
#  'launch': 0.36165644171779143,
#  'world': 0.4013803680981596,
#  'japan.[citation': 0.016441717791411046,
#  'need': 0.5209202453987731,
#  'dynatac': 0.12472392638036811,
#  'x': 0.04978527607361964,
#  'commercially': 0.12472392638036811,
#  'available': 0.32193251533742334,
#  'worldwide': 0.24245398773006135,
#  'subscription': 0.12472392638036811,
#  'grow': 0.04978527607361964,
#  'seven': 0.04978527607361964,
#  'billion': 0.0868711656441718,
#  'person': 0.20319018404907976,
#  'earth': 0.016441717791411046,
#  'quarter': 0.016441717791411046,
#  'developer': 0.04978527607361964,
#  'samsung': 0.24245398773006135,
#  'apple': 0.28223926380368103,
#  'huawei': 0.12472392638036811,
#  'sale': 0.24245398773006135,
#  'represent': 0.04978527607361964,
#  'percent': 0.016441717791411046,
#  'total': 0.016441717791411046,
#  'slang': 0.016441717791411046,
#  'dumbphone': 0.016441717791411046,
#  'nokia': 0.12472392638036811,
#  'alcatel': 0.016441717791411046,
#  'history': 0.016441717791411046,
#  'show': 0.24245398773006135,
#  'reenactment': 0.016441717791411046,
#  'publicize': 0.016441717791411046,
#  'prototype': 0.016441717791411046,
#  'model': 0.016441717791411046,
#  'april': 0.016441717791411046,
#  'envision': 0.016441717791411046,
#  'early': 0.20319018404907976,
#  'stage': 0.016441717791411046,
#  'engineering': 0.016441717791411046,
#  'finnish': 0.04978527607361964,
#  'inventor': 0.016441717791411046,
#  'eric': 0.04978527607361964,
#  'tigerstedt': 0.016441717791411046,
#  'file': 0.04978527607361964,
#  'patent': 0.016441717791411046,
#  'pocket': 0.016441717791411046,
#  'size': 0.24245398773006135,
#  'fold': 0.04978527607361964,
#  'thin': 0.016441717791411046,
#  'carbon': 0.016441717791411046,
#  'microphone': 0.04978527607361964,
#  'predecessor': 0.016441717791411046,
#  'include': 0.32193251533742334,
#  'analog': 0.0868711656441718,
#  'ship': 0.016441717791411046,
#  'train': 0.016441717791411046,
#  'race': 0.016441717791411046,
#  'create': 0.016441717791411046,
#  'truly': 0.016441717791411046,
#  'device': 0.5607668711656443,
#  'begin': 0.12472392638036811,
#  'war': 0.12472392638036811,
#  'ii': 0.016441717791411046,
#  'take': 0.016441717791411046,
#  'place': 0.24245398773006135,
#  'country': 0.5607668711656443,
#  'advance': 0.04978527607361964,
#  'trace': 0.016441717791411046,
#  'successive': 0.016441717791411046,
#  'generation': 0.24245398773006135,
#  'start': 0.04978527607361964,
#  'zeroth': 0.016441717791411046,
#  'bell': 0.016441717791411046,
#  'successor': 0.016441717791411046,
#  'improved': 0.016441717791411046,
#  'simultaneous': 0.164079754601227,
#  'expensive': 0.016441717791411046,
#  'x.': 0.016441717791411046,
#  'car': 0.04978527607361964,
#  'lb': 0.016441717791411046,
#  'commercial': 0.0868711656441718,
#  'automate': 0.016441717791411046,
#  'japan': 0.12472392638036811,
#  'follow': 0.12472392638036811,
#  'nordic': 0.016441717791411046,
#  'nmt': 0.016441717791411046,
#  'denmark': 0.016441717791411046,
#  'finland': 0.20319018404907976,
#  'norway': 0.016441717791411046,
#  'sweden': 0.016441717791411046,
#  'mid': 0.04978527607361964,
#  's.': 0.016441717791411046,
#  'far': 0.016441717791411046,
#  'appear': 0.0868711656441718,
#  's': 0.016441717791411046,
#  'enable': 0.12472392638036811,
#  'wide': 0.016441717791411046,
#  'adoption': 0.016441717791411046,
#  'mosfet': 0.04978527607361964,
#  'base': 0.12472392638036811,
#  'rf': 0.12472392638036811,
#  'power': 0.164079754601227,
#  'amplifier': 0.016441717791411046,
#  'ldmos': 0.016441717791411046,
#  'circuit': 0.12472392638036811,
#  'cmos': 0.016441717791411046,
#  'introduction': 0.04978527607361964,
#  'signal': 0.04978527607361964,
#  'processing': 0.0868711656441718,
#  'second': 0.20319018404907976,
#  'radiolinja': 0.04978527607361964,
#  'gsm': 0.20319018404907976,
#  'standard': 0.36165644171779143,
#  'spark': 0.016441717791411046,
#  'competition': 0.016441717791411046,
#  'sector': 0.016441717791411046,
#  'new': 0.24245398773006135,
#  'challenge': 0.016441717791411046,
#  'incumbent': 0.016441717791411046,
#  'european': 0.0868711656441718,
#  'initiative': 0.016441717791411046,
#  'express': 0.016441717791411046,
#  'cept': 0.016441717791411046,
#  'conférence': 0.016441717791411046,
#  'européenne': 0.016441717791411046,
#  'des': 0.016441717791411046,
#  'poste': 0.016441717791411046,
#  'et': 0.016441717791411046,
#  'telecommunication': 0.20319018404907976,
#  'postal': 0.016441717791411046,
#  'conference': 0.016441717791411046,
#  'franco': 0.016441717791411046,
#  'german': 0.016441717791411046,
#  'r&d': 0.016441717791411046,
#  'cooperation': 0.016441717791411046,
#  'technical': 0.016441717791411046,
#  'feasibility': 0.016441717791411046,
#  'memorandum': 0.016441717791411046,
#  'understanding': 0.016441717791411046,
#  'sign': 0.04978527607361964,
#  'agree': 0.016441717791411046,
#  'version': 0.016441717791411046,
#  '(=': 0.016441717791411046,
#  'page': 0.016441717791411046,
#  'ieee': 0.016441717791411046,
#  'rse': 0.016441717791411046,
#  'award': 0.016441717791411046,
#  'thoma': 0.016441717791411046,
#  'haug': 0.016441717791411046,
#  'philippe': 0.016441717791411046,
#  'dupuis': 0.016441717791411046,
#  'jame': 0.016441717791411046,
#  'clerk': 0.016441717791411046,
#  'maxwell': 0.016441717791411046,
#  'medal': 0.016441717791411046,
#  'contribution': 0.016441717791411046,
#  'people': 0.20319018404907976,
#  'evolve': 0.016441717791411046,
#  'g.': 0.016441717791411046,
#  'lithium': 0.0868711656441718,
#  'ion': 0.12472392638036811,
#  'battery': 0.4412269938650308,
#  'indispensable': 0.016441717791411046,
#  'energy': 0.016441717791411046,
#  'source': 0.12472392638036811,
#  'commercialize': 0.016441717791411046,
#  'sony': 0.016441717791411046,
#  'asahi': 0.016441717791411046,
#  'kasei': 0.016441717791411046,
#  'docomo': 0.016441717791411046,
#  'wcdma': 0.016441717791411046,
#  '.g': 0.016441717791411046,
#  'g+': 0.016441717791411046,
#  'turbo': 0.016441717791411046,
#  'enhancement': 0.016441717791411046,
#  'high': 0.164079754601227,
#  'speed': 0.0868711656441718,
#  'packet': 0.016441717791411046,
#  'hspa': 0.016441717791411046,
#  'family': 0.12472392638036811,
#  'allow': 0.20319018404907976,
#  'umts': 0.016441717791411046,
#  'data': 0.0868711656441718,
#  'transfer': 0.12472392638036811,
#  'capacity': 0.0868711656441718,
#  'clear': 0.016441717791411046,
#  'point': 0.12472392638036811,
#  'overwhelm': 0.016441717791411046,
#  'growth': 0.04978527607361964,
#  'bandwidth': 0.04978527607361964,
#  'intensive': 0.016441717791411046,
#  'streaming': 0.016441717791411046,
#  'medium': 0.12472392638036811,
#  'consequently': 0.016441717791411046,
#  'industry': 0.12472392638036811,
#  'look': 0.04978527607361964,
#  'optimize': 0.016441717791411046,
#  'fourth': 0.016441717791411046,
#  'promise': 0.016441717791411046,
#  'improvement': 0.016441717791411046,
#  'exist': 0.0868711656441718,
#  'bill': 0.12472392638036811,
#  'wimax': 0.04978527607361964,
#  'sprint': 0.016441717791411046,
#  'lte': 0.04978527607361964,
#  'scandinavia': 0.016441717791411046,
#  'teliasonera': 0.016441717791411046,
#  'term': 0.24245398773006135,
#  'research': 0.12472392638036811,
#  'paper': 0.016441717791411046,
#  'project': 0.04978527607361964,
#  'denote': 0.016441717791411046,
#  'major': 0.0868711656441718,
#  'phase': 0.016441717791411046,
#  'imt': 0.016441717791411046,
#  'officially': 0.016441717791411046,
#  'specification': 0.016441717791411046,
#  'official': 0.12472392638036811,
#  'document': 0.016441717791411046,
#  'company': 0.24245398773006135,
#  'standardization': 0.04978527607361964,
#  'body': 0.0868711656441718,
#  'gpp': 0.016441717791411046,
#  'forum': 0.016441717791411046,
#  'itu': 0.016441717791411046,
#  'r.': 0.016441717791411046,
#  'currently': 0.016441717791411046,
#  'develop': 0.24245398773006135,
#  'time': 0.20319018404907976,
#  'see': 0.016441717791411046,
#  'umbrella': 0.016441717791411046,
#  'type': 0.12472392638036811,
#  'active': 0.04978527607361964,
#  'broadband': 0.0868711656441718,
#  'inhabitant': 0.04978527607361964,
#  'number': 0.32193251533742334,
#  'distinguish': 0.04978527607361964,
#  'international': 0.0868711656441718,
#  'union': 0.016441717791411046,
#  'measure': 0.0868711656441718,
#  'tablet': 0.016441717791411046,
#  'etc': 0.04978527607361964,
#  'developed': 0.016441717791411046,
#  'overtake': 0.04978527607361964,
#  'usage': 0.20319018404907976,
#  'account': 0.04978527607361964,
#  'typically': 0.24245398773006135,
#  'retronym': 0.016441717791411046,
#  'describe': 0.016441717791411046,
#  'limit': 0.016441717791411046,
#  'contrast': 0.04978527607361964,
#  'voice': 0.12472392638036811,
#  'calling': 0.12472392638036811,
#  'functionality': 0.016441717791411046,
#  'basic': 0.164079754601227,
#  'multimedia': 0.04978527607361964,
#  'provider': 0.04978527607361964,
#  'additional': 0.04978527607361964,
#  'function': 0.12472392638036811,
#  'capable': 0.016441717791411046,
#  'tend': 0.04978527607361964,
#  'proprietary': 0.016441717791411046,
#  'custom': 0.04978527607361964,
#  'design': 0.24245398773006135,
#  'software': 0.28223926380368103,
#  'interface': 0.016441717791411046,
#  'generally': 0.12472392638036811,
#  'operating': 0.04978527607361964,
#  'share': 0.0868711656441718,
#  'common': 0.28223926380368103,
#  'trait': 0.016441717791411046,
#  'infrastructure': 0.04978527607361964,
#  'communicate': 0.0868711656441718,
#  'tower': 0.20319018404907976,
#  'coverage': 0.04978527607361964,
#  'divide': 0.016441717791411046,
#  'different': 0.164079754601227,
#  'set': 0.04978527607361964,
#  'neighboring': 0.016441717791411046,
#  'cover': 0.016441717791411046,
#  'location': 0.12472392638036811,
#  'usually': 0.0868711656441718,
#  'interconnect': 0.016441717791411046,
#  'wire': 0.016441717791411046,
#  'limitation': 0.016441717791411046,
#  'maximum': 0.016441717791411046,
#  'handle': 0.04978527607361964,
#  'sized': 0.016441717791411046,
#  'depend': 0.20319018404907976,
#  'expect': 0.04978527607361964,
#  'density': 0.016441717791411046,
#  'small': 0.24245398773006135,
#  'city': 0.0868711656441718,
#  'case': 0.016441717791411046,
#  'low': 0.12472392638036811,
#  'transmitter': 0.016441717791411046,
#  'avoid': 0.04978527607361964,
#  'broadcasting': 0.016441717791411046,
#  'order': 0.12472392638036811,
#  'traffic': 0.12472392638036811,
#  'multiple': 0.164079754601227,
#  'permanently': 0.016441717791411046,
#  'temporarily': 0.016441717791411046,
#  'special': 0.016441717791411046,
#  'event': 0.12472392638036811,
#  'like': 0.0868711656441718,
#  'super': 0.016441717791411046,
#  'bowl': 0.016441717791411046,
#  'taste': 0.016441717791411046,
#  'chicago': 0.016441717791411046,
#  'state': 0.4013803680981596,
#  'fair': 0.016441717791411046,
#  'nyc': 0.016441717791411046,
#  'year': 0.24245398773006135,
#  'eve': 0.016441717791411046,
#  'hurricane': 0.016441717791411046,
#  'hit': 0.016441717791411046,
#  'bring': 0.016441717791411046,
#  'truck': 0.016441717791411046,
#  'equipment': 0.016441717791411046,
#  'host': 0.0868711656441718,
#  'abnormally': 0.016441717791411046,
#  'increase': 0.4811042944785277,
#  'example': 0.32193251533742334,
#  'license': 0.04978527607361964,
#  'unique': 0.0868711656441718,
#  'slightly': 0.016441717791411046,
#  'overlap': 0.04978527607361964,
#  'reuse': 0.0868711656441718,
#  'door': 0.04978527607361964,
#  'touching': 0.016441717791411046,
#  'frequencies.[citation': 0.016441717791411046,
#  'implement': 0.0868711656441718,
#  'automatically': 0.016441717791411046,
#  'disconnect': 0.016441717791411046,
#  'reconnect': 0.016441717791411046,
#  'give': 0.12472392638036811,
#  'good': 0.0868711656441718,
#  'reception': 0.016441717791411046,
#  'additionally': 0.016441717791411046,
#  'wi': 0.016441717791411046,
#  'fi': 0.016441717791411046,
#  'possible': 0.016441717791411046,
#  'offload': 0.016441717791411046,
#  'local': 0.0868711656441718,
#  'hardware': 0.04978527607361964,
#  'component': 0.04978527607361964,
#  'find': 0.24245398773006135,
#  'central': 0.12472392638036811,
#  'unit': 0.20319018404907976,
#  'cpu': 0.0868711656441718,
#  'processor': 0.016441717791411046,
#  'microprocessor': 0.016441717791411046,
#  'fabricate': 0.016441717791411046,
#  'integrated': 0.016441717791411046,
#  'ic': 0.016441717791411046,
#  'chip': 0.016441717791411046,
#  'lib': 0.016441717791411046,
#  'old': 0.016441717791411046,
#  'nickel': 0.016441717791411046,
#  'hydride': 0.016441717791411046,
#  'ni': 0.016441717791411046,
#  'mh': 0.016441717791411046,
#  'input': 0.016441717791411046,
#  'mechanism': 0.016441717791411046,
#  'interact': 0.016441717791411046,
#  'keypad': 0.016441717791411046,
#  'touch': 0.12472392638036811,
#  'screen': 0.36165644171779143,
#  'capacitive': 0.016441717791411046,
#  'sensing': 0.016441717791411046,
#  'display': 0.4013803680981596,
#  'echo': 0.016441717791411046,
#  'typing': 0.016441717791411046,
#  'message': 0.4013803680981596,
#  'contact': 0.016441717791411046,
#  'liquid': 0.04978527607361964,
#  'crystal': 0.04978527607361964,
#  'lcd': 0.016441717791411046,
#  'organic': 0.016441717791411046,
#  'light': 0.016441717791411046,
#  'emit': 0.04978527607361964,
#  'diode': 0.016441717791411046,
#  'ole': 0.04978527607361964,
#  'speaker': 0.0868711656441718,
#  'sound': 0.12472392638036811,
#  'subscriber': 0.4013803680981596,
#  'identity': 0.0868711656441718,
#  'module': 0.0868711656441718,
#  'sim': 0.5607668711656443,
#  'card': 0.5607668711656443,
#  'removable': 0.016441717791411046,
#  'r': 0.04978527607361964,
#  'uim': 0.04978527607361964,
#  'notification': 0.016441717791411046,
#  'end': 0.04978527607361964,
#  'ability': 0.04978527607361964,
#  'native': 0.016441717791411046,
#  'process': 0.016441717791411046,
#  'cpus': 0.04978527607361964,
#  'similar': 0.164079754601227,
#  'computer': 0.164079754601227,
#  'optimise': 0.016441717791411046,
#  'operate': 0.0868711656441718,
#  'environment': 0.016441717791411046,
#  'performance': 0.20319018404907976,
#  'clock': 0.016441717791411046,
#  'rate': 0.04978527607361964,
#  'hertz': 0.016441717791411046,
#  'memory': 0.016441717791411046,
#  'hierarchy': 0.016441717791411046,
#  'affect': 0.016441717791411046,
#  'overall': 0.016441717791411046,
#  'problem': 0.04978527607361964,
#  'appropriately': 0.016441717791411046,
#  'score': 0.016441717791411046,
#  'derive': 0.016441717791411046,
#  'standardized': 0.016441717791411046,
#  'test': 0.016441717791411046,
#  'real': 0.016441717791411046,
#  'effective': 0.016441717791411046,
#  'commonly': 0.0868711656441718,
#  'main': 0.016441717791411046,
#  'characteristic': 0.016441717791411046,
#  'fill': 0.016441717791411046,
#  'nearly': 0.0868711656441718,
#  'space': 0.016441717791411046,
#  'surface': 0.04978527607361964,
#  'aspect': 0.0868711656441718,
#  'ratio': 0.0868711656441718,
#  'tall': 0.04978527607361964,
#  'diagonal': 0.016441717791411046,
#  'inch': 0.016441717791411046,
#  'millimeter': 0.016441717791411046,
#  'millimetre': 0.0868711656441718,
#  'phablet': 0.016441717791411046,
#  'difficult': 0.016441717791411046,
#  'single': 0.04978527607361964,
#  'thumb': 0.016441717791411046,
#  'reach': 0.016441717791411046,
#  'entire': 0.016441717791411046,
#  'shift': 0.04978527607361964,
#  'hold': 0.28223926380368103,
#  'manipulate': 0.016441717791411046,
#  'edge': 0.04978527607361964,
#  'compact': 0.016441717791411046,
#  'build': 0.016441717791411046,
#  'improve': 0.0868711656441718,
#  'ergonomic': 0.04978527607361964,
#  'result': 0.12472392638036811,
#  'whilst': 0.016441717791411046,
#  'maintain': 0.04978527607361964,
#  'associate': 0.016441717791411046,
#  'ips': 0.016441717791411046,
#  'amole': 0.016441717791411046,
#  'integrate': 0.04978527607361964,
#  'pressure': 0.016441717791411046,
#  'sensitive': 0.016441717791411046,
#  'digitizer': 0.016441717791411046,
#  'wacom': 0.016441717791411046,
#  'd': 0.016441717791411046,
#  'vary': 0.016441717791411046,
#  'little': 0.016441717791411046,
#  'audio': 0.12472392638036811,
#  'quality': 0.12472392638036811,
#  'enhancing': 0.016441717791411046,
#  'hd': 0.016441717791411046,
#  'remain': 0.016441717791411046,
#  'compression': 0.016441717791411046,
#  'algorithm': 0.016441717791411046,
#  'long': 0.12472392638036811,
#  'distance': 0.04978527607361964,
#  'voip': 0.016441717791411046,
#  'wifi': 0.016441717791411046,
#  'speakerphone': 0.04978527607361964,
#  'talk': 0.12472392638036811,
#  'ear': 0.04978527607361964,
#  'listen': 0.04978527607361964,
#  'music': 0.04978527607361964,
#  'speech': 0.016441717791411046,
#  'watch': 0.04978527607361964,
#  'close': 0.016441717791411046,
#  'average': 0.0868711656441718,
#  'last': 0.04978527607361964,
#  'li': 0.016441717791411046,
#  'charge': 0.04978527607361964,
#  'care': 0.016441717791411046,
#  'technique': 0.04978527607361964,
#  'natural': 0.04978527607361964,
#  'rechargeable': 0.016441717791411046,
#  'chemically': 0.016441717791411046,
#  'age': 0.04978527607361964,
#  'deteriorate': 0.016441717791411046,
#  'life': 0.0868711656441718,
#  'extend': 0.016441717791411046,
#  'drain': 0.016441717791411046,
#  'regularly': 0.016441717791411046,
#  'overcharge': 0.016441717791411046,
#  'keep': 0.0868711656441718,
#  'away': 0.016441717791411046,
#  'heat': 0.016441717791411046,
#  'require': 0.0868711656441718,
#  'microchip': 0.016441717791411046,
#  'approximately': 0.04978527607361964,
#  'postage': 0.016441717791411046,
#  'stamp': 0.016441717791411046,
#  'underneath': 0.016441717791411046,
#  'rear': 0.016441717791411046,
#  'securely': 0.016441717791411046,
#  'store': 0.24245398773006135,
#  'key': 0.016441717791411046,
#  'imsi': 0.016441717791411046,
#  'ki': 0.016441717791411046,
#  'identify': 0.016441717791411046,
#  'authenticate': 0.016441717791411046,
#  'change': 0.016441717791411046,
#  'remove': 0.016441717791411046,
#  'insert': 0.016441717791411046,
#  'prevent': 0.04978527607361964,
#  'lock': 0.016441717791411046,
#  'munich': 0.016441717791411046,
#  'smart': 0.04978527607361964,
#  'maker': 0.016441717791411046,
#  'giesecke': 0.016441717791411046,
#  'devrient': 0.016441717791411046,
#  'radiolinja.[citation': 0.016441717791411046,
#  'hybrid': 0.016441717791411046,
#  'have': 0.016441717791411046,
#  'imei': 0.164079754601227,
#  'mix': 0.016441717791411046,
#  'cdma': 0.016441717791411046,
#  'onwards': 0.016441717791411046,
#  'popular': 0.016441717791411046,
#  'emerge': 0.0868711656441718,
#  'market': 0.20319018404907976,
#  'attribute': 0.016441717791411046,
#  'desire': 0.04978527607361964,
#  'obtain': 0.016441717791411046,
#  'net': 0.016441717791411046,
#  'platform': 0.20319018404907976,
#  'section': 0.0868711656441718,
#  'expansion': 0.016441717791411046,
#  'help': 0.016441717791411046,
#  'add': 0.04978527607361964,
#  'october': 0.04978527607361964,
#  'android': 0.0868711656441718,
#  'os': 0.04978527607361964,
#  'well': 0.016441717791411046,
#  'sell': 0.12472392638036811,
#  'app': 0.36165644171779143,
#  'program': 0.04978527607361964,
#  'run': 0.04978527607361964,
#  'shortening': 0.016441717791411046,
#  'sms': 0.12472392638036811,
#  'send': 0.12472392638036811,
#  'uk': 0.0868711656441718,
#  'sm': 0.0868711656441718,
#  'news': 0.164079754601227,
#  'deliver': 0.016441717791411046,
#  'citation': 0.016441717791411046,
#  'subsequently': 0.016441717791411046,
#  'organization': 0.0868711656441718,
#  'demand': 0.04978527607361964,
#  'instant': 0.016441717791411046,
#  'introduce': 0.12472392638036811,
#  '.[citation': 0.016441717791411046,
#  'iphone': 0.0868711656441718,
#  'ipod': 0.016441717791411046,
#  'july': 0.0868711656441718,
#  'popularize': 0.016441717791411046,
#  'manufacturer': 0.36165644171779143,
#  'online': 0.04978527607361964,
#  'distribution': 0.0868711656441718,
#  'party': 0.04978527607361964,
#  'focus': 0.016441717791411046,
#  'huge': 0.016441717791411046,
#  'product': 0.016441717791411046,
#  'tool': 0.016441717791411046,
#  'getjar': 0.016441717791411046,
#  'handango': 0.016441717791411046,
#  'handmark': 0.016441717791411046,
#  'pocketgear': 0.016441717791411046,
#  'success': 0.016441717791411046,
#  'google': 0.04978527607361964,
#  'later': 0.016441717791411046,
#  'rename': 0.016441717791411046,
#  'play': 0.04978527607361964,
#  'rim': 0.016441717791411046,
#  'blackberry': 0.016441717791411046,
#  'relate': 0.04978527607361964,
#  'f': 0.016441717791411046,
#  'droid': 0.016441717791411046,
#  'february': 0.04978527607361964,
#  'target': 0.04978527607361964,
#  'update': 0.0868711656441718,
#  'article': 0.016441717791411046,
#  'reflect': 0.016441717791411046,
#  'recent': 0.04978527607361964,
#  'newly': 0.016441717791411046,
#  'statistic': 0.016441717791411046,
#  'part': 0.04978527607361964,
#  'august': 0.016441717791411046,
#  'vendor': 0.12472392638036811,
#  'q': 0.0868711656441718,
#  'rank': 0.04978527607361964,
#  'strategy': 0.016441717791411046,
#  'analytic': 0.016441717791411046,
#  'report': 0.4412269938650308,
#  'oppo': 0.04978527607361964,
#  'xiaomi': 0.016441717791411046,
#  'note': 0.016441717791411046,
#  'shipment': 0.04978527607361964,
#  'brand': 0.04978527607361964,
#  'exclude': 0.016441717791411046,
#  'oem': 0.016441717791411046,
#  'leader': 0.04978527607361964,
#  'surpass': 0.016441717791411046,
#  'selling': 0.016441717791411046,
#  'million': 0.20319018404907976,
#  'retain': 0.016441717791411046,
#  'position': 0.04978527607361964,
#  'vivo': 0.016441717791411046,
#  'individual': 0.04978527607361964,
#  'china': 0.04978527607361964,
#  'june': 0.0868711656441718,
#  'figure': 0.016441717791411046,
#  'estimate': 0.12472392638036811,
#  'purpose': 0.04978527607361964,
#  'member': 0.12472392638036811,
#  'conduct': 0.04978527607361964,
#  'emergency': 0.04978527607361964,
#  'carry': 0.016441717791411046,
#  'personal': 0.016441717791411046,
#  'advantage': 0.016441717791411046,
#  'benefit': 0.0868711656441718,
#  'plan': 0.04978527607361964,
#  'particular': 0.04978527607361964,
#  'cheap': 0.016441717791411046,
#  'roam': 0.016441717791411046,
#  'diverse': 0.016441717791411046,
#  'context': 0.016441717791411046,
#  'society': 0.016441717791411046,
#  'study': 0.6006441717791412,
#  'secret': 0.016441717791411046,
#  'engage': 0.016441717791411046,
#  'activity': 0.04978527607361964,
#  'extramarital': 0.016441717791411046,
#  'affair': 0.016441717791411046,
#  'clandestine': 0.016441717791411046,
#  'dealing': 0.016441717791411046,
#  'assist': 0.016441717791411046,
#  'victim': 0.016441717791411046,
#  'domestic': 0.016441717791411046,
#  'violence': 0.016441717791411046,
#  'refurbish': 0.04978527607361964,
#  'advent': 0.016441717791411046,
#  'widespread': 0.016441717791411046,
#  'novel': 0.04978527607361964,
#  'literary': 0.016441717791411046,
#  'genre': 0.016441717791411046,
#  'website': 0.016441717791411046,
#  'collect': 0.04978527607361964,
#  'facilitate': 0.016441717791411046,
#  'activism': 0.016441717791411046,
#  'citizen': 0.016441717791411046,
#  'journalism': 0.016441717791411046,
#  'united': 0.164079754601227,
#  'nation': 0.016441717791411046,
#  'spread': 0.04978527607361964,
#  'fast': 0.016441717791411046,
#  'form': 0.016441717791411046,
#  'livelihood': 0.016441717791411046,
#  'poor': 0.016441717791411046,
#  'landline': 0.016441717791411046,
#  'especially': 0.016441717791411046,
#  'spawn': 0.016441717791411046,
#  'wealth': 0.016441717791411046,
#  'micro': 0.04978527607361964,
#  'enterprise': 0.016441717791411046,
#  'work': 0.12472392638036811,
#  'airtime': 0.016441717791411046,
#  'street': 0.016441717791411046,
#  'repair': 0.016441717791411046,
#  'mali': 0.016441717791411046,
#  'african': 0.016441717791411046,
#  'travel': 0.04978527607361964,
#  'village': 0.12472392638036811,
#  'let': 0.016441717791411046,
#  'friend': 0.04978527607361964,
#  'relative': 0.016441717791411046,
#  'wedding': 0.016441717791411046,
#  'birth': 0.016441717791411046,
#  'extensive': 0.016441717791411046,
#  'land': 0.016441717791411046,
#  'line': 0.016441717791411046,
#  'penetration': 0.016441717791411046,
#  'tv': 0.24245398773006135,
#  'recently': 0.0868711656441718,
#  'drive': 0.5209202453987731,
#  'live': 0.016441717791411046,
#  'view': 0.04978527607361964,
#  'advertising': 0.04978527607361964,
#  'social': 0.016441717791411046,
#  'american': 0.04978527607361964,
#  'sharing': 0.04978527607361964,
#  'prevalent': 0.016441717791411046,
#  'urban': 0.016441717791411046,
#  'india': 0.016441717791411046,
#  'group': 0.0868711656441718,
#  'obvious': 0.016441717791411046,
#  'economic': 0.04978527607361964,
#  'familial': 0.016441717791411046,
#  'traditional': 0.016441717791411046,
#  'gender': 0.016441717791411046,
#  'role': 0.016441717791411046,
#  'own': 0.016441717791411046,
#  'teacher': 0.016441717791411046,
#  'missionary': 0.016441717791411046,
#  'necessary': 0.016441717791411046,
#  'content': 0.24245398773006135,
#  'distribute': 0.016441717791411046,
#  'ringtone': 0.04978527607361964,
#  'soon': 0.016441717791411046,
#  'joke': 0.016441717791411046,
#  'horoscope': 0.016441717791411046,
#  'copy': 0.016441717791411046,
#  'legacy': 0.016441717791411046,
#  'banner': 0.016441717791411046,
#  'advertisement': 0.016441717791411046,
#  'highlight': 0.016441717791411046,
#  'clip': 0.016441717791411046,
#  'ringback': 0.016441717791411046,
#  'tone': 0.016441717791411046,
#  'mobisode': 0.016441717791411046,
#  'produce': 0.04978527607361964,
#  'exclusively': 0.016441717791411046,
#  'banking': 0.20319018404907976,
#  'payment': 0.28223926380368103,
#  'cash': 0.0868711656441718,
#  'secure': 0.04978527607361964,
#  'kenya': 0.016441717791411046,
#  'm': 0.04978527607361964,
#  'pesa': 0.04978527607361964,
#  'customer': 0.016441717791411046,
#  'safaricom': 0.04978527607361964,
#  'balance': 0.04978527607361964,
#  'record': 0.04978527607361964,
#  'deposit': 0.016441717791411046,
#  'withdraw': 0.016441717791411046,
#  'retail': 0.04978527607361964,
#  'outlet': 0.016441717791411046,
#  'locate': 0.016441717791411046,
#  'electronically': 0.016441717791411046,
#  'pay': 0.016441717791411046,
#  'branchless': 0.016441717791411046,
#  'successful': 0.016441717791411046,
#  'south': 0.016441717791411046,
#  'africa': 0.04978527607361964,
#  'philippine': 0.04978527607361964,
#  'pilot': 0.016441717791411046,
#  'bali': 0.016441717791411046,
#  'finance': 0.04978527607361964,
#  'corporation': 0.016441717791411046,
#  'indonesian': 0.016441717791411046,
#  'bank': 0.04978527607361964,
#  'mandiri': 0.016441717791411046,
#  'zidisha': 0.04978527607361964,
#  'nonprofit': 0.016441717791411046,
#  'lending': 0.016441717791411046,
#  'resident': 0.04978527607361964,
#  'raise': 0.016441717791411046,
#  'loan': 0.04978527607361964,
#  'web': 0.016441717791411046,
#  'disbursement': 0.016441717791411046,
#  'repayment': 0.016441717791411046,
#  'fund': 0.016441717791411046,
#  'lender': 0.016441717791411046,
#  'borrower': 0.016441717791411046,
#  'rural': 0.016441717791411046,
#  'trialle': 0.016441717791411046,
#  'coca': 0.016441717791411046,
#  'cola': 0.016441717791411046,
#  'vending': 0.016441717791411046,
#  'machine': 0.016441717791411046,
#  'espoo': 0.016441717791411046,
#  'eventually': 0.016441717791411046,
#  'idea': 0.016441717791411046,
#  'globe': 0.016441717791411046,
#  'direct': 0.04978527607361964,
#  'billing': 0.016441717791411046,
#  'scheme': 0.04978527607361964,
#  'contactless': 0.04978527607361964,
#  'near': 0.0868711656441718,
#  'field': 0.016441717791411046,
#  'nfc': 0.04978527607361964,
#  'equip': 0.016441717791411046,
#  'co': 0.016441717791411046,
#  'operation': 0.04978527607361964,
#  'merchant': 0.016441717791411046,
#  'tracking': 0.016441717791411046,
#  'datum': 0.0868711656441718,
#  'turn': 0.016441717791411046,
#  'geographical': 0.016441717791411046,
#  'determine': 0.016441717791411046,
#  'easily': 0.04978527607361964,
#  'multilateration': 0.016441717791411046,
#  'calculate': 0.016441717791411046,
#  'difference': 0.016441717791411046,
#  'owner': 0.016441717791411046,
#  'movement': 0.016441717791411046,
#  'track': 0.12472392638036811,
#  'law': 0.36165644171779143,
#  'enforcement': 0.0868711656441718,
#  'agency': 0.016441717791411046,
#  'government': 0.04978527607361964,
#  'propose': 0.016441717791411046,
#  'commuting': 0.016441717791411046,
#  'pattern': 0.016441717791411046,
#  'beije': 0.016441717791411046,
#  'intelligence': 0.016441717791411046,
#  'perform': 0.016441717791411046,
#  'surveillance': 0.016441717791411046,
#  'possess': 0.016441717791411046,
#  'activate': 0.016441717791411046,
#  'remotely': 0.016441717791411046,
#  'conversation': 0.016441717791411046,
#  'hacker': 0.016441717791411046,
#  'able': 0.016441717791411046,
#  'read': 0.04978527607361964,
#  'driver': 0.32193251533742334,
#  'u.s': 0.12472392638036811,
#  'restrict': 0.0868711656441718,
#  'certain': 0.0868711656441718,
#  'day': 0.04978527607361964,
#  'am-:am': 0.016441717791411046,
#  'pm-:pm': 0.016441717791411046,
#  'texting': 0.164079754601227,
#  'controversial': 0.016441717791411046,
#  'widely': 0.016441717791411046,
#  'consider': 0.016441717791411046,
#  'dangerous': 0.016441717791411046,
#  'distracted': 0.04978527607361964,
#  'driving': 0.0868711656441718,
#  'distract': 0.0868711656441718,
#  'motor': 0.016441717791411046,
#  'vehicle': 0.016441717791411046,
#  'risk': 0.20319018404907976,
#  'accident': 0.0868711656441718,
#  'september': 0.016441717791411046,
#  'national': 0.04978527607361964,
#  'highway': 0.016441717791411046,
#  'safety': 0.0868711656441718,
#  'administration': 0.016441717791411046,
#  'nhtsa': 0.016441717791411046,
#  'kill': 0.0868711656441718,
#  'march': 0.04978527607361964,
#  'insurance': 0.04978527607361964,
#  'farm': 0.016441717791411046,
#  'announce': 0.04978527607361964,
#  'survey': 0.0868711656441718,
#  'jurisdiction': 0.04978527607361964,
#  'prohibit': 0.0868711656441718,
#  'egypt': 0.016441717791411046,
#  'israel': 0.04978527607361964,
#  'portugal': 0.016441717791411046,
#  'singapore': 0.016441717791411046,
#  'free': 0.164079754601227,
#  'ban': 0.32193251533742334,
#  'france': 0.04978527607361964,
#  'permit': 0.016441717791411046,
#  'college': 0.016441717791411046,
#  'student': 0.016441717791411046,
#  'initiate': 0.016441717791411046,
#  'reply': 0.016441717791411046,
#  'scientific': 0.016441717791411046,
#  'literature': 0.016441717791411046,
#  'danger': 0.016441717791411046,
#  'texte': 0.0868711656441718,
#  'limited': 0.016441717791411046,
#  'simulation': 0.016441717791411046,
#  'university': 0.04978527607361964,
#  'utah': 0.016441717791411046,
#  'sixfold': 0.016441717791411046,
#  'distraction': 0.016441717791411046,
#  'complexity': 0.016441717791411046,
#  'difficulty': 0.016441717791411046,
#  'attempt': 0.04978527607361964,
#  'apparent': 0.016441717791411046,
#  'tell': 0.016441717791411046,
#  'stop': 0.016441717791411046,
#  'illegally': 0.016441717791411046,
#  'fact': 0.016441717791411046,
#  'legally': 0.016441717791411046,
#  'incorporate': 0.016441717791411046,
#  'control': 0.016441717791411046,
#  'stereo': 0.016441717791411046,
#  'gps': 0.0868711656441718,
#  'satnav': 0.016441717791411046,
#  'review': 0.12472392638036811,
#  'incidence': 0.016441717791411046,
#  'cycle': 0.016441717791411046,
#  ...}

# %% [markdown]
# ## High Word Pair Occurence (HWPO)
#
# HWPO is a the computation than HWO except that we compute cumulative bi-grams frequencies

# %%
def HWPO(bigram, bigram_frequency, cumul_bigram):
    key_max = max(list(cumul_bigram.keys()))
    return cumul_bigram[bigram_frequency[bigram]]/cumul_bigram[key_max]

# %%
hwpo = {bigram: HWPO(bigram, bigram_frequency, cumul_bigram) for bigram in list(bigrams)}
hwpo
# Out:
# {('mobile', 'phone'): 0.9959981167608286,
#  ('phone', '[PUNCT]'): 0.9919962335216572,
#  ('[PUNCT]', 'cellular'): 0.6398305084745762,
#  ('cellular', 'phone'): 0.807909604519774,
#  ('[PUNCT]', 'cell'): 0.973987758945386,
#  ('cell', 'phone'): 0.9839924670433146,
#  ('[PUNCT]', 'cellphone'): 0.6398305084745762,
#  ('cellphone', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'handphone'): 0.05555555555555556,
#  ('handphone', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'hand'): 0.8579331450094162,
#  ('hand', 'phone'): 0.05555555555555556,
#  ('[PUNCT]', 'shorten'): 0.05555555555555556,
#  ('shorten', 'simply'): 0.05555555555555556,
#  ('simply', 'mobile'): 0.05555555555555556,
#  ('mobile', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'portable'): 0.05555555555555556,
#  ('portable', 'telephone'): 0.6398305084745762,
#  ('telephone', 'receive'): 0.05555555555555556,
#  ('receive', 'call'): 0.05555555555555556,
#  ('call', 'radio'): 0.05555555555555556,
#  ('radio', 'frequency'): 0.6398305084745762,
#  ('frequency', 'link'): 0.6398305084745762,
#  ('link', 'user'): 0.05555555555555556,
#  ('user', 'move'): 0.05555555555555556,
#  ('move', 'telephone'): 0.05555555555555556,
#  ('telephone', 'service'): 0.9179613935969868,
#  ('service', 'area'): 0.6398305084745762,
#  ('area', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'radio'): 0.05555555555555556,
#  ('link', 'establish'): 0.05555555555555556,
#  ('establish', 'connection'): 0.05555555555555556,
#  ('connection', 'switching'): 0.05555555555555556,
#  ('switching', 'system'): 0.05555555555555556,
#  ('system', 'mobile'): 0.807909604519774,
#  ('phone', 'operator'): 0.807909604519774,
#  ('operator', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'provide'): 0.9339689265536724,
#  ('provide', 'access'): 0.6398305084745762,
#  ('access', 'public'): 0.05555555555555556,
#  ('public', 'switch'): 0.05555555555555556,
#  ('switch', 'telephone'): 0.05555555555555556,
#  ('telephone', 'network'): 0.05555555555555556,
#  ('network', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'pstn'): 0.05555555555555556,
#  ('pstn', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', '[PUNCT]'): 1.0,
#  ('[PUNCT]', 'modern'): 0.807909604519774,
#  ('modern', 'mobile'): 0.6398305084745762,
#  ('mobile', 'telephone'): 0.9179613935969868,
#  ('service', 'use'): 0.6398305084745762,
#  ('use', 'cellular'): 0.05555555555555556,
#  ('cellular', 'network'): 0.8899482109227872,
#  ('network', 'architecture'): 0.05555555555555556,
#  ('architecture', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'mobile'): 0.9879943502824858,
#  ('telephone', 'call'): 0.05555555555555556,
#  ('call', 'cellular'): 0.05555555555555556,
#  ('cellular', 'telephone'): 0.05555555555555556,
#  ('telephone', 'cell'): 0.05555555555555556,
#  ('phone', 'north'): 0.05555555555555556,
#  ('north', 'america'): 0.6398305084745762,
#  ('america', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'addition'): 0.6398305084745762,
#  ('addition', 'telephony'): 0.05555555555555556,
#  ('telephony', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'digital'): 0.8899482109227872,
#  ('digital', 'mobile'): 0.6398305084745762,
#  ('[PUNCT]', 'g'): 0.9639830508474576,
#  ('g', '[PUNCT]'): 0.9559792843691148,
#  ('[PUNCT]', 'support'): 0.6398305084745762,
#  ('support', 'variety'): 0.05555555555555556,
#  ('variety', 'service'): 0.05555555555555556,
#  ('service', '[PUNCT]'): 0.9559792843691148,
#  ('[PUNCT]', 'text'): 0.807909604519774,
#  ('text', 'messaging'): 0.807909604519774,
#  ('messaging', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'mms'): 0.6398305084745762,
#  ('mms', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'email'): 0.05555555555555556,
#  ('email', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'internet'): 0.05555555555555556,
#  ('internet', 'access'): 0.05555555555555556,
#  ('access', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'short'): 0.6398305084745762,
#  ('short', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'range'): 0.6398305084745762,
#  ('range', 'wireless'): 0.05555555555555556,
#  ('wireless', 'communication'): 0.6398305084745762,
#  ('communication', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'infrare'): 0.05555555555555556,
#  ('infrare', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'bluetooth'): 0.05555555555555556,
#  ('bluetooth', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'business'): 0.6398305084745762,
#  ('business', 'application'): 0.05555555555555556,
#  ('application', '[PUNCT]'): 0.8899482109227872,
#  ('[PUNCT]', 'video'): 0.807909604519774,
#  ('video', 'game'): 0.807909604519774,
#  ('game', 'digital'): 0.05555555555555556,
#  ('digital', 'photography'): 0.05555555555555556,
#  ('photography', '[PUNCT]'): 0.05555555555555556,
#  ('phone', 'offer'): 0.807909604519774,
#  ('offer', 'capability'): 0.05555555555555556,
#  ('capability', 'know'): 0.05555555555555556,
#  ('know', 'feature'): 0.05555555555555556,
#  ('feature', 'phone'): 0.973987758945386,
#  ('offer', 'greatly'): 0.05555555555555556,
#  ('greatly', 'advanced'): 0.05555555555555556,
#  ('advanced', 'computing'): 0.6398305084745762,
#  ('computing', 'capability'): 0.05555555555555556,
#  ('capability', 'refer'): 0.05555555555555556,
#  ('refer', 'smartphone'): 0.05555555555555556,
#  ('smartphone', '[PUNCT]'): 0.941972693032015,
#  ('[PUNCT]', 'development'): 0.807909604519774,
#  ('development', 'metal'): 0.6398305084745762,
#  ('metal', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'oxide'): 0.807909604519774,
#  ('oxide', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'semiconductor'): 0.807909604519774,
#  ('semiconductor', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'mos'): 0.807909604519774,
#  ('mos', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'large'): 0.8899482109227872,
#  ('large', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'scale'): 0.6398305084745762,
#  ('scale', 'integration'): 0.6398305084745762,
#  ('integration', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'lsi'): 0.6398305084745762,
#  ('lsi', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'technology'): 0.6398305084745762,
#  ('technology', '[PUNCT]'): 0.8899482109227872,
#  ('[PUNCT]', 'information'): 0.6398305084745762,
#  ('information', 'theory'): 0.6398305084745762,
#  ('theory', 'cellular'): 0.6398305084745762,
#  ('cellular', 'networking'): 0.6398305084745762,
#  ('networking', 'lead'): 0.6398305084745762,
#  ('lead', 'development'): 0.6398305084745762,
#  ('development', 'affordable'): 0.6398305084745762,
#  ('affordable', 'mobile'): 0.6398305084745762,
#  ('mobile', 'communication'): 0.807909604519774,
#  ('[PUNCT]', 'handheld'): 0.8899482109227872,
#  ('handheld', 'mobile'): 0.9179613935969868,
#  ('phone', 'demonstrate'): 0.6398305084745762,
#  ('demonstrate', 'john'): 0.6398305084745762,
#  ('john', 'f.'): 0.6398305084745762,
#  ('f.', 'mitchell'): 0.6398305084745762,
#  ('mitchell', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'martin'): 0.6398305084745762,
#  ('martin', 'cooper'): 0.807909604519774,
#  ('cooper', 'motorola'): 0.807909604519774,
#  ('motorola', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'handset'): 0.807909604519774,
#  ('handset', 'weigh'): 0.6398305084745762,
#  ('weigh', 'c.'): 0.05555555555555556,
#  ('c.', 'kilogram'): 0.05555555555555556,
#  ('kilogram', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'lbs'): 0.05555555555555556,
#  ('lbs', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'nippon'): 0.05555555555555556,
#  ('nippon', 'telegraph'): 0.6398305084745762,
#  ('telegraph', 'telephone'): 0.6398305084745762,
#  ('telephone', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'ntt'): 0.05555555555555556,
#  ('ntt', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'launch'): 0.807909604519774,
#  ('launch', 'world'): 0.05555555555555556,
#  ('world', 'cellular'): 0.05555555555555556,
#  ('network', 'japan.[citation'): 0.05555555555555556,
#  ('japan.[citation', 'need'): 0.05555555555555556,
#  ('need', '[PUNCT]'): 0.9559792843691148,
#  ('[PUNCT]', 'dynatac'): 0.6398305084745762,
#  ('dynatac', 'x'): 0.6398305084745762,
#  ('x', 'commercially'): 0.6398305084745762,
#  ('commercially', 'available'): 0.8579331450094162,
#  ('available', 'handheld'): 0.807909604519774,
#  ('[PUNCT]', 'worldwide'): 0.6398305084745762,
#  ('worldwide', 'mobile'): 0.6398305084745762,
#  ('phone', 'subscription'): 0.05555555555555556,
#  ('subscription', 'grow'): 0.05555555555555556,
#  ('grow', 'seven'): 0.05555555555555556,
#  ('seven', 'billion'): 0.6398305084745762,
#  ('billion', '[PUNCT]'): 0.05555555555555556,
#  ('provide', 'person'): 0.05555555555555556,
#  ('person', 'earth'): 0.05555555555555556,
#  ('earth', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'quarter'): 0.05555555555555556,
#  ('quarter', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'smartphone'): 0.973987758945386,
#  ('smartphone', 'developer'): 0.05555555555555556,
#  ('developer', 'worldwide'): 0.05555555555555556,
#  ('worldwide', 'samsung'): 0.6398305084745762,
#  ('samsung', '[PUNCT]'): 0.8899482109227872,
#  ('[PUNCT]', 'apple'): 0.9179613935969868,
#  ('apple', 'huawei'): 0.05555555555555556,
#  ('huawei', '[PUNCT]'): 0.807909604519774,
#  ('smartphone', 'sale'): 0.05555555555555556,
#  ('sale', 'represent'): 0.05555555555555556,
#  ('represent', 'percent'): 0.05555555555555556,
#  ('percent', 'total'): 0.05555555555555556,
#  ('total', 'mobile'): 0.05555555555555556,
#  ('phone', 'sale'): 0.6398305084745762,
#  ('sale', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'feature'): 0.9339689265536724,
#  ('[PUNCT]', 'slang'): 0.05555555555555556,
#  ('slang', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'dumbphone'): 0.05555555555555556,
#  ('dumbphone', '[PUNCT]'): 0.05555555555555556,
#  ('large', 'samsung'): 0.05555555555555556,
#  ('[PUNCT]', 'nokia'): 0.6398305084745762,
#  ('nokia', 'alcatel'): 0.05555555555555556,
#  ('alcatel', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'history'): 0.05555555555555556,
#  ('history', 'martin'): 0.05555555555555556,
#  ('[PUNCT]', 'show'): 0.05555555555555556,
#  ('show', 'reenactment'): 0.05555555555555556,
#  ('reenactment', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'publicize'): 0.05555555555555556,
#  ('publicize', 'handheld'): 0.05555555555555556,
#  ('phone', 'prototype'): 0.05555555555555556,
#  ('prototype', 'dynatac'): 0.05555555555555556,
#  ('dynatac', 'model'): 0.05555555555555556,
#  ('model', 'april'): 0.05555555555555556,
#  ('april', '[PUNCT]'): 0.05555555555555556,
#  ('mobile', 'radio'): 0.05555555555555556,
#  ('radio', 'telephone'): 0.05555555555555556,
#  ('service', 'envision'): 0.05555555555555556,
#  ('envision', 'early'): 0.05555555555555556,
#  ('early', 'stage'): 0.05555555555555556,
#  ('stage', 'radio'): 0.05555555555555556,
#  ('radio', 'engineering'): 0.05555555555555556,
#  ('engineering', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'finnish'): 0.05555555555555556,
#  ('finnish', 'inventor'): 0.05555555555555556,
#  ('inventor', 'eric'): 0.05555555555555556,
#  ('eric', 'tigerstedt'): 0.05555555555555556,
#  ('tigerstedt', 'file'): 0.05555555555555556,
#  ('file', 'patent'): 0.05555555555555556,
#  ('patent', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'pocket'): 0.05555555555555556,
#  ('pocket', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'size'): 0.6398305084745762,
#  ('size', 'fold'): 0.05555555555555556,
#  ('fold', 'telephone'): 0.05555555555555556,
#  ('telephone', 'thin'): 0.05555555555555556,
#  ('thin', 'carbon'): 0.05555555555555556,
#  ('carbon', 'microphone'): 0.05555555555555556,
#  ('microphone', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'early'): 0.6398305084745762,
#  ('early', 'predecessor'): 0.05555555555555556,
#  ('predecessor', 'cellular'): 0.05555555555555556,
#  ('phone', 'include'): 0.05555555555555556,
#  ('include', 'analog'): 0.05555555555555556,
#  ('analog', 'radio'): 0.05555555555555556,
#  ('radio', 'communication'): 0.05555555555555556,
#  ('communication', 'ship'): 0.05555555555555556,
#  ('ship', 'train'): 0.05555555555555556,
#  ('train', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'race'): 0.05555555555555556,
#  ('race', 'create'): 0.05555555555555556,
#  ('create', 'truly'): 0.05555555555555556,
#  ('truly', 'portable'): 0.05555555555555556,
#  ('telephone', 'device'): 0.05555555555555556,
#  ('device', 'begin'): 0.05555555555555556,
#  ('begin', 'world'): 0.05555555555555556,
#  ('world', 'war'): 0.6398305084745762,
#  ('war', 'ii'): 0.05555555555555556,
#  ('ii', '[PUNCT]'): 0.05555555555555556,
#  ('development', 'take'): 0.05555555555555556,
#  ('take', 'place'): 0.05555555555555556,
#  ('place', 'country'): 0.05555555555555556,
#  ('country', '[PUNCT]'): 0.941972693032015,
#  ('[PUNCT]', 'advance'): 0.05555555555555556,
#  ('advance', 'mobile'): 0.05555555555555556,
#  ('mobile', 'telephony'): 0.807909604519774,
#  ('telephony', 'trace'): 0.05555555555555556,
#  ('trace', 'successive'): 0.05555555555555556,
#  ('successive', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'generation'): 0.9179613935969868,
#  ('generation', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'start'): 0.05555555555555556,
#  ('start', 'early'): 0.05555555555555556,
#  ('early', 'zeroth'): 0.05555555555555556,
#  ('zeroth', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'service'): 0.6398305084745762,
#  ('[PUNCT]', 'bell'): 0.05555555555555556,
#  ('bell', 'system'): 0.05555555555555556,
#  ('service', 'successor'): 0.05555555555555556,
#  ('successor', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'improved'): 0.05555555555555556,
#  ('improved', 'mobile'): 0.05555555555555556,
#  ('g', 'system'): 0.05555555555555556,
#  ('system', 'cellular'): 0.05555555555555556,
#  ('cellular', '[PUNCT]'): 0.05555555555555556,
#  ('support', 'simultaneous'): 0.05555555555555556,
#  ('simultaneous', 'call'): 0.807909604519774,
#  ('call', '[PUNCT]'): 0.9559792843691148,
#  ('[PUNCT]', 'expensive'): 0.05555555555555556,
#  ('expensive', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'motorola'): 0.6398305084745762,
#  ('motorola', 'dynatac'): 0.05555555555555556,
#  ('dynatac', 'x.'): 0.05555555555555556,
#  ('x.', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'commercially'): 0.6398305084745762,
#  ('handheld', 'cellular'): 0.6398305084745762,
#  ('cellular', 'mobile'): 0.6398305084745762,
#  ('[PUNCT]', 'device'): 0.6398305084745762,
#  ('device', 'car'): 0.05555555555555556,
#  ('car', 'phone'): 0.05555555555555556,
#  ('weigh', 'kilogram'): 0.05555555555555556,
#  ('[PUNCT]', 'lb'): 0.05555555555555556,
#  ('lb', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'commercial'): 0.05555555555555556,
#  ('commercial', 'automate'): 0.05555555555555556,
#  ('automate', 'cellular'): 0.05555555555555556,
#  ('[PUNCT]', 'analog'): 0.05555555555555556,
#  ('analog', 'launch'): 0.05555555555555556,
#  ('launch', 'japan'): 0.6398305084745762,
#  ('japan', 'nippon'): 0.05555555555555556,
#  ('[PUNCT]', 'follow'): 0.807909604519774,
#  ('follow', 'simultaneous'): 0.05555555555555556,
#  ('simultaneous', 'launch'): 0.05555555555555556,
#  ('launch', 'nordic'): 0.05555555555555556,
#  ('nordic', 'mobile'): 0.05555555555555556,
#  ('[PUNCT]', 'nmt'): 0.05555555555555556,
#  ('nmt', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'system'): 0.807909604519774,
#  ('system', 'denmark'): 0.05555555555555556,
#  ('denmark', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'finland'): 0.05555555555555556,
#  ('finland', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'norway'): 0.05555555555555556,
#  ('norway', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'sweden'): 0.05555555555555556,
#  ('sweden', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'country'): 0.6398305084745762,
#  ('country', 'follow'): 0.05555555555555556,
#  ('follow', 'early'): 0.05555555555555556,
#  ('early', 'mid'): 0.05555555555555556,
#  ('mid', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 's.'): 0.05555555555555556,
#  ('s.', '[PUNCT]'): 0.05555555555555556,
#  ('system', 'support'): 0.05555555555555556,
#  ('support', 'far'): 0.05555555555555556,
#  ('far', 'simultaneous'): 0.05555555555555556,
#  ('call', 'analog'): 0.05555555555555556,
#  ('analog', 'cellular'): 0.05555555555555556,
#  ('cellular', 'technology'): 0.6398305084745762,
#  ('digital', 'cellular'): 0.6398305084745762,
#  ('network', 'appear'): 0.05555555555555556,
#  ('appear', 's'): 0.05555555555555556,
#  ('s', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'enable'): 0.6398305084745762,
#  ('enable', 'wide'): 0.05555555555555556,
#  ('wide', 'adoption'): 0.05555555555555556,
#  ('adoption', 'mosfet'): 0.05555555555555556,
#  ('mosfet', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'base'): 0.6398305084745762,
#  ('base', 'rf'): 0.05555555555555556,
#  ('rf', 'power'): 0.05555555555555556,
#  ('power', 'amplifier'): 0.05555555555555556,
#  ('amplifier', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'power'): 0.05555555555555556,
#  ('power', 'mosfet'): 0.05555555555555556,
#  ('mosfet', 'ldmos'): 0.05555555555555556,
#  ('ldmos', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'rf'): 0.807909604519774,
#  ('rf', 'circuit'): 0.05555555555555556,
#  ('circuit', '[PUNCT]'): 0.807909604519774,
#  ('rf', 'cmos'): 0.05555555555555556,
#  ('cmos', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'lead'): 0.807909604519774,
#  ('lead', 'introduction'): 0.05555555555555556,
#  ('introduction', 'digital'): 0.05555555555555556,
#  ('digital', 'signal'): 0.05555555555555556,
#  ('signal', 'processing'): 0.05555555555555556,
#  ('processing', 'wireless'): 0.05555555555555556,
#  ('[PUNCT]', 'second'): 0.05555555555555556,
#  ('second', '[PUNCT]'): 0.807909604519774,
#  ('technology', 'launch'): 0.05555555555555556,
#  ('launch', 'finland'): 0.6398305084745762,
#  ('finland', 'radiolinja'): 0.05555555555555556,
#  ('radiolinja', 'gsm'): 0.05555555555555556,
#  ('gsm', 'standard'): 0.6398305084745762,
#  ('standard', '[PUNCT]'): 0.9339689265536724,
#  ('[PUNCT]', 'spark'): 0.05555555555555556,
#  ('spark', 'competition'): 0.05555555555555556,
#  ('competition', 'sector'): 0.05555555555555556,
#  ('sector', 'new'): 0.05555555555555556,
#  ('new', 'operator'): 0.05555555555555556,
#  ('operator', 'challenge'): 0.05555555555555556,
#  ('challenge', 'incumbent'): 0.05555555555555556,
#  ('incumbent', 'g'): 0.05555555555555556,
#  ('g', 'network'): 0.6398305084745762,
#  ('network', 'operator'): 0.807909604519774,
#  ('[PUNCT]', 'gsm'): 0.807909604519774,
#  ('standard', 'european'): 0.05555555555555556,
#  ('european', 'initiative'): 0.05555555555555556,
#  ('initiative', 'express'): 0.05555555555555556,
#  ('express', 'cept'): 0.05555555555555556,
#  ('cept', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'conférence'): 0.05555555555555556,
#  ('conférence', 'européenne'): 0.05555555555555556,
#  ('européenne', 'des'): 0.05555555555555556,
#  ('des', 'poste'): 0.05555555555555556,
#  ('poste', 'et'): 0.05555555555555556,
#  ('et', 'telecommunication'): 0.05555555555555556,
#  ('telecommunication', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'european'): 0.05555555555555556,
#  ('european', 'postal'): 0.05555555555555556,
#  ('postal', 'telecommunication'): 0.05555555555555556,
#  ('telecommunication', 'conference'): 0.05555555555555556,
#  ('conference', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'franco'): 0.05555555555555556,
#  ('franco', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'german'): 0.05555555555555556,
#  ('german', 'r&d'): 0.05555555555555556,
#  ('r&d', 'cooperation'): 0.05555555555555556,
#  ('cooperation', 'demonstrate'): 0.05555555555555556,
#  ('demonstrate', 'technical'): 0.05555555555555556,
#  ('technical', 'feasibility'): 0.05555555555555556,
#  ('feasibility', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'memorandum'): 0.05555555555555556,
#  ('memorandum', 'understanding'): 0.05555555555555556,
#  ('understanding', 'sign'): 0.05555555555555556,
#  ('sign', 'european'): 0.05555555555555556,
#  ('european', 'country'): 0.05555555555555556,
#  ('country', 'agree'): 0.05555555555555556,
#  ('agree', 'launch'): 0.05555555555555556,
#  ('launch', 'commercial'): 0.05555555555555556,
#  ('commercial', 'service'): 0.05555555555555556,
#  ('[PUNCT]', 'version'): 0.05555555555555556,
#  ('version', 'gsm'): 0.05555555555555556,
#  ('gsm', '(='): 0.05555555555555556,
#  ('(=', 'g'): 0.05555555555555556,
#  ('[PUNCT]', 'standard'): 0.05555555555555556,
#  ('[PUNCT]', 'page'): 0.05555555555555556,
#  ('page', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'ieee'): 0.05555555555555556,
#  ('ieee', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'rse'): 0.05555555555555556,
#  ('rse', 'award'): 0.05555555555555556,
#  ('award', 'thoma'): 0.05555555555555556,
#  ('thoma', 'haug'): 0.05555555555555556,
#  ('haug', 'philippe'): 0.05555555555555556,
#  ('philippe', 'dupuis'): 0.05555555555555556,
#  ('dupuis', 'jame'): 0.05555555555555556,
#  ('jame', 'clerk'): 0.05555555555555556,
#  ('clerk', 'maxwell'): 0.05555555555555556,
#  ('maxwell', 'medal'): 0.05555555555555556,
#  ('medal', 'contribution'): 0.05555555555555556,
#  ('contribution', 'digital'): 0.05555555555555556,
#  ('telephone', 'standard'): 0.05555555555555556,
#  ('gsm', 'billion'): 0.05555555555555556,
#  ('billion', 'people'): 0.05555555555555556,
#  ('people', 'country'): 0.05555555555555556,
#  ('gsm', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'evolve'): 0.05555555555555556,
#  ('evolve', 'g'): 0.05555555555555556,
#  ('g', 'g.'): 0.05555555555555556,
#  ('g.', 'lithium'): 0.05555555555555556,
#  ('lithium', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'ion'): 0.8579331450094162,
#  ('ion', 'battery'): 0.6398305084745762,
#  ('battery', '[PUNCT]'): 0.8899482109227872,
#  ('[PUNCT]', 'indispensable'): 0.05555555555555556,
#  ('indispensable', 'energy'): 0.05555555555555556,
#  ('energy', 'source'): 0.05555555555555556,
#  ('source', 'modern'): 0.05555555555555556,
#  ('[PUNCT]', 'commercialize'): 0.05555555555555556,
#  ('commercialize', 'sony'): 0.05555555555555556,
#  ('sony', 'asahi'): 0.05555555555555556,
#  ('asahi', 'kasei'): 0.05555555555555556,
#  ('kasei', '[PUNCT]'): 0.05555555555555556,
#  ('japan', 'ntt'): 0.05555555555555556,
#  ('ntt', 'docomo'): 0.05555555555555556,
#  ('docomo', 'wcdma'): 0.05555555555555556,
#  ('wcdma', 'standard'): 0.05555555555555556,
#  ('follow', '.g'): 0.05555555555555556,
#  ('.g', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'g+'): 0.05555555555555556,
#  ('g+', 'turbo'): 0.05555555555555556,
#  ('turbo', 'g'): 0.05555555555555556,
#  ('g', 'enhancement'): 0.05555555555555556,
#  ('enhancement', 'base'): 0.05555555555555556,
#  ('base', 'high'): 0.05555555555555556,
#  ('high', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'speed'): 0.05555555555555556,
#  ('speed', 'packet'): 0.05555555555555556,
#  ('packet', 'access'): 0.05555555555555556,
#  ('[PUNCT]', 'hspa'): 0.05555555555555556,
#  ('hspa', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'family'): 0.6398305084745762,
#  ('family', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'allow'): 0.6398305084745762,
#  ('allow', 'umts'): 0.05555555555555556,
#  ('umts', 'network'): 0.05555555555555556,
#  ('network', 'high'): 0.05555555555555556,
#  ('high', 'data'): 0.05555555555555556,
#  ('data', 'transfer'): 0.05555555555555556,
#  ('transfer', 'speed'): 0.05555555555555556,
#  ('speed', 'capacity'): 0.05555555555555556,
#  ('capacity', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'clear'): 0.05555555555555556,
#  ('clear', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'point'): 0.6398305084745762,
#  ('point', '[PUNCT]'): 0.6398305084745762,
#  ('network', 'overwhelm'): 0.05555555555555556,
#  ('overwhelm', 'growth'): 0.05555555555555556,
#  ('growth', 'bandwidth'): 0.05555555555555556,
#  ('bandwidth', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'intensive'): 0.05555555555555556,
#  ('intensive', 'application'): 0.05555555555555556,
#  ('[PUNCT]', 'streaming'): 0.05555555555555556,
#  ('streaming', 'medium'): 0.05555555555555556,
#  ('medium', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'consequently'): 0.05555555555555556,
#  ('consequently', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'industry'): 0.05555555555555556,
#  ('industry', 'begin'): 0.05555555555555556,
#  ('begin', 'look'): 0.05555555555555556,
#  ('look', 'data'): 0.05555555555555556,
#  ('data', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'optimize'): 0.05555555555555556,
#  ('optimize', 'fourth'): 0.05555555555555556,
#  ('fourth', '[PUNCT]'): 0.05555555555555556,
#  ('generation', 'technology'): 0.05555555555555556,
#  ('[PUNCT]', 'promise'): 0.05555555555555556,
#  ('promise', 'speed'): 0.05555555555555556,
#  ('speed', 'improvement'): 0.05555555555555556,
#  ('improvement', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'fold'): 0.05555555555555556,
#  ('fold', 'exist'): 0.05555555555555556,
#  ('exist', 'g'): 0.05555555555555556,
#  ('g', 'technology'): 0.6398305084745762,
#  ('available', 'technology'): 0.05555555555555556,
#  ('technology', 'bill'): 0.05555555555555556,
#  ('bill', 'g'): 0.05555555555555556,
#  ('g', 'wimax'): 0.05555555555555556,
#  ('wimax', 'standard'): 0.05555555555555556,
#  ('[PUNCT]', 'offer'): 0.6398305084745762,
#  ('offer', 'north'): 0.05555555555555556,
#  ('america', 'sprint'): 0.05555555555555556,
#  ('sprint', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'lte'): 0.05555555555555556,
#  ('lte', 'standard'): 0.05555555555555556,
#  ('offer', 'scandinavia'): 0.05555555555555556,
#  ('scandinavia', 'teliasonera'): 0.05555555555555556,
#  ('teliasonera', '[PUNCT]'): 0.05555555555555556,
#  ('technology', 'term'): 0.05555555555555556,
#  ('term', 'research'): 0.05555555555555556,
#  ('research', 'paper'): 0.05555555555555556,
#  ('paper', 'project'): 0.05555555555555556,
#  ('project', 'denote'): 0.05555555555555556,
#  ('denote', 'major'): 0.05555555555555556,
#  ('major', 'phase'): 0.05555555555555556,
#  ('phase', 'mobile'): 0.05555555555555556,
#  ('mobile', 'telecommunication'): 0.05555555555555556,
#  ('telecommunication', 'standard'): 0.05555555555555556,
#  ('standard', 'g'): 0.6398305084745762,
#  ('[PUNCT]', 'imt'): 0.05555555555555556,
#  ('imt', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'advanced'): 0.6398305084745762,
#  ('advanced', 'standard'): 0.05555555555555556,
#  ('[PUNCT]', 'term'): 0.8579331450094162,
#  ('term', 'g'): 0.05555555555555556,
#  ('g', 'officially'): 0.05555555555555556,
#  ('officially', 'specification'): 0.05555555555555556,
#  ('specification', 'official'): 0.05555555555555556,
#  ('official', 'document'): 0.05555555555555556,
#  ('document', 'public'): 0.05555555555555556,
#  ('public', 'telecommunication'): 0.05555555555555556,
#  ('telecommunication', 'company'): 0.05555555555555556,
#  ('company', 'standardization'): 0.05555555555555556,
#  ('standardization', 'body'): 0.6398305084745762,
#  ('body', 'gpp'): 0.05555555555555556,
#  ('gpp', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'wimax'): 0.05555555555555556,
#  ('wimax', 'forum'): 0.05555555555555556,
#  ('forum', 'itu'): 0.05555555555555556,
#  ('itu', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'r.'): 0.05555555555555556,
#  ('r.', 'new'): 0.05555555555555556,
#  ('new', 'standard'): 0.05555555555555556,
#  ('g', 'currently'): 0.05555555555555556,
#  ('currently', 'develop'): 0.05555555555555556,
#  ('develop', 'standardization'): 0.05555555555555556,
#  ('body', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'time'): 0.6398305084745762,
#  ('time', 'see'): 0.05555555555555556,
#  ('see', 'g'): 0.05555555555555556,
#  ('g', 'umbrella'): 0.05555555555555556,
#  ('umbrella', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'new'): 0.6398305084745762,
#  ('new', 'mobile'): 0.05555555555555556,
#  ('mobile', 'generation'): 0.05555555555555556,
#  ('[PUNCT]', 'type'): 0.807909604519774,
#  ('type', 'mobile'): 0.05555555555555556,
#  ('mobile', 'subscription'): 0.05555555555555556,
#  ('subscription', 'people'): 0.05555555555555556,
#  ('people', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'active'): 0.05555555555555556,
#  ('active', 'mobile'): 0.6398305084745762,
#  ('mobile', 'broadband'): 0.05555555555555556,
#  ('broadband', 'subscription'): 0.6398305084745762,
#  ('subscription', 'inhabitant'): 0.05555555555555556,
#  ('inhabitant', '[PUNCT]'): 0.6398305084745762,
#  ('smartphone', 'smartphone'): 0.05555555555555556,
#  ('smartphone', 'number'): 0.05555555555555556,
#  ('number', 'distinguish'): 0.05555555555555556,
#  ('distinguish', 'feature'): 0.05555555555555556,
#  ('feature', '[PUNCT]'): 0.807909604519774,
#  ('[PUNCT]', 'international'): 0.6398305084745762,
#  ('international', 'telecommunication'): 0.05555555555555556,
#  ('telecommunication', 'union'): 0.05555555555555556,
#  ('union', 'measure'): 0.05555555555555556,
#  ('measure', 'internet'): 0.05555555555555556,
#  ('internet', 'connection'): 0.05555555555555556,
#  ('connection', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'call'): 0.807909604519774,
#  ('call', 'active'): 0.05555555555555556,
#  ('[PUNCT]', 'broadband'): 0.05555555555555556,
#  ('subscription', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'include'): 0.9339689265536724,
#  ('include', 'tablet'): 0.05555555555555556,
#  ('tablet', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'etc'): 0.6398305084745762,
#  ('etc', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'developed'): 0.05555555555555556,
#  ('developed', 'world'): 0.05555555555555556,
#  ('world', '[PUNCT]'): 0.8579331450094162,
#  ('smartphone', 'overtake'): 0.05555555555555556,
#  ('overtake', 'usage'): 0.05555555555555556,
#  ('usage', 'early'): 0.05555555555555556,
#  ('early', 'mobile'): 0.05555555555555556,
#  ('mobile', 'system'): 0.05555555555555556,
#  ('system', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'develop'): 0.6398305084745762,
#  ('develop', 'world'): 0.05555555555555556,
#  ('[PUNCT]', 'account'): 0.05555555555555556,
#  ('account', '[PUNCT]'): 0.05555555555555556,
#  ('phone', 'feature'): 0.6398305084745762,
#  ('phone', 'term'): 0.05555555555555556,
#  ('term', 'typically'): 0.05555555555555556,
#  ('typically', 'retronym'): 0.05555555555555556,
#  ('retronym', 'describe'): 0.05555555555555556,
#  ('describe', 'mobile'): 0.05555555555555556,
#  ('phone', 'limit'): 0.05555555555555556,
#  ('limit', 'capability'): 0.05555555555555556,
#  ('capability', 'contrast'): 0.05555555555555556,
#  ('contrast', 'modern'): 0.05555555555555556,
#  ('modern', 'smartphone'): 0.6398305084745762,
#  ('phone', 'typically'): 0.6398305084745762,
#  ('typically', 'provide'): 0.05555555555555556,
#  ('provide', 'voice'): 0.05555555555555556,
#  ('voice', 'calling'): 0.6398305084745762,
#  ('calling', 'text'): 0.6398305084745762,
#  ('messaging', 'functionality'): 0.05555555555555556,
#  ('functionality', '[PUNCT]'): 0.05555555555555556,
#  ('addition', 'basic'): 0.05555555555555556,
#  ('basic', 'multimedia'): 0.05555555555555556,
#  ('multimedia', 'internet'): 0.05555555555555556,
#  ('internet', 'capability'): 0.05555555555555556,
#  ('capability', '[PUNCT]'): 0.6398305084745762,
#  ('service', 'offer'): 0.05555555555555556,
#  ('offer', 'user'): 0.05555555555555556,
#  ('user', 'wireless'): 0.05555555555555556,
#  ('wireless', 'service'): 0.05555555555555556,
#  ('service', 'provider'): 0.6398305084745762,
#  ('provider', '[PUNCT]'): 0.05555555555555556,
#  ('phone', 'additional'): 0.05555555555555556,
#  ('additional', 'function'): 0.05555555555555556,
#  ('function', 'basic'): 0.05555555555555556,
#  ('basic', 'mobile'): 0.6398305084745762,
#  ('phone', 'capable'): 0.05555555555555556,
#  ('capable', 'voice'): 0.05555555555555556,
#  ('phone', 'basic'): 0.6398305084745762,
#  ('phone', 'tend'): 0.6398305084745762,
#  ('tend', 'use'): 0.05555555555555556,
#  ('use', 'proprietary'): 0.05555555555555556,
#  ('proprietary', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'custom'): 0.05555555555555556,
#  ('custom', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'design'): 0.807909604519774,
#  ('design', 'software'): 0.05555555555555556,
#  ('software', 'user'): 0.05555555555555556,
#  ('user', 'interface'): 0.05555555555555556,
#  ('interface', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'contrast'): 0.05555555555555556,
#  ('contrast', '[PUNCT]'): 0.05555555555555556,
#  ('smartphone', 'generally'): 0.05555555555555556,
#  ('generally', 'use'): 0.05555555555555556,
#  ('use', 'mobile'): 0.9639830508474576,
#  ('mobile', 'operating'): 0.05555555555555556,
#  ('operating', 'system'): 0.6398305084745762,
#  ('system', 'share'): 0.05555555555555556,
#  ('share', 'common'): 0.05555555555555556,
#  ('common', 'trait'): 0.05555555555555556,
#  ('trait', 'device'): 0.05555555555555556,
#  ('device', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'infrastructure'): 0.05555555555555556,
#  ('infrastructure', 'mobile'): 0.05555555555555556,
#  ('phone', 'communicate'): 0.05555555555555556,
#  ('communicate', 'cell'): 0.05555555555555556,
#  ('cell', 'tower'): 0.807909604519774,
#  ('tower', 'place'): 0.6398305084745762,
#  ('place', 'coverage'): 0.05555555555555556,
#  ('coverage', 'telephone'): 0.05555555555555556,
#  ('[PUNCT]', 'divide'): 0.05555555555555556,
#  ('divide', '[PUNCT]'): 0.05555555555555556,
#  ('cell', '[PUNCT]'): 0.8899482109227872,
#  ('cell', 'use'): 0.8579331450094162,
#  ('use', 'different'): 0.05555555555555556,
#  ('different', 'set'): 0.05555555555555556,
#  ('set', 'frequency'): 0.05555555555555556,
#  ('frequency', 'neighboring'): 0.05555555555555556,
#  ('neighboring', 'cell'): 0.05555555555555556,
#  ('[PUNCT]', 'typically'): 0.6398305084745762,
#  ('typically', 'cover'): 0.05555555555555556,
#  ('cover', 'tower'): 0.05555555555555556,
#  ('place', 'different'): 0.05555555555555556,
#  ('different', 'location'): 0.05555555555555556,
#  ('location', '[PUNCT]'): 0.6398305084745762,
#  ('tower', 'usually'): 0.05555555555555556,
#  ('usually', 'interconnect'): 0.05555555555555556,
#  ('interconnect', 'phone'): 0.05555555555555556,
#  ('phone', 'network'): 0.6398305084745762,
#  ('network', 'internet'): 0.05555555555555556,
#  ('internet', 'wire'): 0.05555555555555556,
#  ('wire', 'connection'): 0.05555555555555556,
#  ('[PUNCT]', 'bandwidth'): 0.05555555555555556,
#  ('bandwidth', 'limitation'): 0.05555555555555556,
#  ('limitation', 'cell'): 0.05555555555555556,
#  ('cell', 'maximum'): 0.05555555555555556,
#  ('maximum', 'number'): 0.05555555555555556,
#  ('number', 'cell'): 0.05555555555555556,
#  ('phone', 'handle'): 0.05555555555555556,
#  ('handle', '[PUNCT]'): 0.05555555555555556,
#  ('cell', 'sized'): 0.05555555555555556,
#  ('sized', 'depend'): 0.05555555555555556,
#  ('depend', 'expect'): 0.05555555555555556,
#  ('expect', 'usage'): 0.05555555555555556,
#  ('usage', 'density'): 0.05555555555555556,
#  ('density', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'small'): 0.6398305084745762,
#  ('small', 'city'): 0.05555555555555556,
#  ('city', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'case'): 0.05555555555555556,
#  ('case', 'low'): 0.05555555555555556,
#  ('low', 'transmitter'): 0.05555555555555556,
#  ('transmitter', 'power'): 0.05555555555555556,
#  ('power', 'avoid'): 0.05555555555555556,
#  ('avoid', 'broadcasting'): 0.05555555555555556,
#  ('broadcasting', 'cell'): 0.05555555555555556,
#  ('[PUNCT]', 'order'): 0.807909604519774,
#  ('order', 'handle'): 0.05555555555555556,
#  ('handle', 'high'): 0.05555555555555556,
#  ('high', 'traffic'): 0.6398305084745762,
#  ('traffic', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'multiple'): 0.6398305084745762,
#  ('multiple', 'tower'): 0.05555555555555556,
#  ('tower', 'set'): 0.05555555555555556,
#  ('set', 'area'): 0.05555555555555556,
#  ('[PUNCT]', 'different'): 0.05555555555555556,
#  ('different', 'frequency'): 0.05555555555555556,
#  ('frequency', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'permanently'): 0.05555555555555556,
#  ('permanently', 'temporarily'): 0.05555555555555556,
#  ('temporarily', 'special'): 0.05555555555555556,
#  ('special', 'event'): 0.05555555555555556,
#  ('event', 'like'): 0.05555555555555556,
#  ('like', 'super'): 0.05555555555555556,
#  ('super', 'bowl'): 0.05555555555555556,
#  ('bowl', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'taste'): 0.05555555555555556,
#  ('taste', 'chicago'): 0.05555555555555556,
#  ('chicago', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'state'): 0.8899482109227872,
#  ('state', 'fair'): 0.05555555555555556,
#  ('fair', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'nyc'): 0.05555555555555556,
#  ('nyc', 'new'): 0.05555555555555556,
#  ('new', 'year'): 0.05555555555555556,
#  ('year', 'eve'): 0.05555555555555556,
#  ('eve', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'hurricane'): 0.05555555555555556,
#  ('hurricane', 'hit'): 0.05555555555555556,
#  ('hit', 'city'): 0.05555555555555556,
#  ('phone', 'company'): 0.807909604519774,
#  ('company', 'bring'): 0.05555555555555556,
#  ('bring', 'truck'): 0.05555555555555556,
#  ('truck', 'equipment'): 0.05555555555555556,
#  ('equipment', 'host'): 0.05555555555555556,
#  ('host', 'abnormally'): 0.05555555555555556,
#  ('abnormally', 'high'): 0.05555555555555556,
#  ('traffic', 'portable'): 0.05555555555555556,
#  ('portable', 'cell'): 0.05555555555555556,
#  ('cellular', 'greatly'): 0.05555555555555556,
#  ('greatly', 'increase'): 0.6398305084745762,
#  ('increase', 'capacity'): 0.6398305084745762,
#  ('capacity', 'simultaneous'): 0.05555555555555556,
#  ('simultaneous', 'wireless'): 0.05555555555555556,
#  ('wireless', 'phone'): 0.05555555555555556,
#  ('phone', 'call'): 0.05555555555555556,
#  ('[PUNCT]', 'phone'): 0.9779896421845574,
#  ('company', 'example'): 0.05555555555555556,
#  ('example', '[PUNCT]'): 0.9179613935969868,
#  ('[PUNCT]', 'license'): 0.05555555555555556,
#  ('license', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'frequency'): 0.8579331450094162,
#  ('use', 'unique'): 0.05555555555555556,
#  ('unique', 'frequency'): 0.05555555555555556,
#  ('frequency', 'communicate'): 0.05555555555555556,
#  ('communicate', '[PUNCT]'): 0.05555555555555556,
#  ('cell', 'slightly'): 0.05555555555555556,
#  ('slightly', 'overlap'): 0.05555555555555556,
#  ('overlap', '[PUNCT]'): 0.6398305084745762,
#  ('frequency', 'reuse'): 0.05555555555555556,
#  ('reuse', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'example'): 0.9339689265536724,
#  ('example', 'cell'): 0.05555555555555556,
#  ('use', 'frequency'): 0.6398305084745762,
#  ('[PUNCT]', 'door'): 0.6398305084745762,
#  ('door', 'cell'): 0.05555555555555556,
#  ('door', 'reuse'): 0.05555555555555556,
#  ('reuse', 'frequency'): 0.05555555555555556,
#  ('[PUNCT]', 'touching'): 0.05555555555555556,
#  ('touching', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'overlap'): 0.05555555555555556,
#  ('[PUNCT]', 'communicate'): 0.05555555555555556,
#  ('communicate', 'reuse'): 0.05555555555555556,
#  ('reuse', 'frequencies.[citation'): 0.05555555555555556,
#  ('frequencies.[citation', 'need'): 0.05555555555555556,
#  ('[PUNCT]', 'greatly'): 0.05555555555555556,
#  ('increase', 'phone'): 0.05555555555555556,
#  ('company', 'implement'): 0.05555555555555556,
#  ('implement', 'digital'): 0.05555555555555556,
#  ('digital', 'network'): 0.05555555555555556,
#  ('digital', '[PUNCT]'): 0.05555555555555556,
#  ('frequency', 'host'): 0.05555555555555556,
#  ('host', 'multiple'): 0.05555555555555556,
#  ('multiple', 'simultaneous'): 0.05555555555555556,
#  ('call', 'increase'): 0.05555555555555556,
#  ('phone', 'move'): 0.05555555555555556,
#  ('move', '[PUNCT]'): 0.05555555555555556,
#  ('hand', '[PUNCT]'): 0.9639830508474576,
#  ('[PUNCT]', 'automatically'): 0.05555555555555556,
#  ('automatically', 'disconnect'): 0.05555555555555556,
#  ('disconnect', 'reconnect'): 0.05555555555555556,
#  ('reconnect', 'tower'): 0.05555555555555556,
#  ('tower', 'cell'): 0.05555555555555556,
#  ('cell', 'give'): 0.05555555555555556,
#  ('give', 'good'): 0.05555555555555556,
#  ('good', 'reception'): 0.05555555555555556,
#  ('reception', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'additionally'): 0.05555555555555556,
#  ('additionally', '[PUNCT]'): 0.05555555555555556,
#  ('range', 'wi'): 0.05555555555555556,
#  ('wi', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'fi'): 0.05555555555555556,
#  ('fi', 'infrastructure'): 0.05555555555555556,
#  ('infrastructure', 'smartphone'): 0.05555555555555556,
#  ('smartphone', 'possible'): 0.05555555555555556,
#  ('possible', 'offload'): 0.05555555555555556,
#  ('offload', 'traffic'): 0.05555555555555556,
#  ('traffic', 'cell'): 0.05555555555555556,
#  ('cell', 'network'): 0.05555555555555556,
#  ('network', 'local'): 0.05555555555555556,
#  ('local', 'area'): 0.05555555555555556,
#  ('area', 'network'): 0.05555555555555556,
#  ('[PUNCT]', 'hardware'): 0.6398305084745762,
#  ('hardware', 'common'): 0.05555555555555556,
#  ('common', 'component'): 0.05555555555555556,
#  ('component', 'find'): 0.05555555555555556,
#  ('find', 'mobile'): 0.807909604519774,
#  ('[PUNCT]', 'central'): 0.6398305084745762,
#  ('central', 'processing'): 0.6398305084745762,
#  ('processing', 'unit'): 0.6398305084745762,
#  ('unit', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'cpu'): 0.6398305084745762,
#  ('cpu', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'processor'): 0.05555555555555556,
#  ('processor', 'phone'): 0.05555555555555556,
#  ('cpu', 'microprocessor'): 0.05555555555555556,
#  ('microprocessor', 'fabricate'): 0.05555555555555556,
#  ('fabricate', 'metal'): 0.05555555555555556,
#  ('[PUNCT]', 'integrated'): 0.05555555555555556,
#  ('integrated', 'circuit'): 0.05555555555555556,
#  ('[PUNCT]', 'ic'): 0.05555555555555556,
#  ('ic', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'chip'): 0.05555555555555556,
#  ('chip', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'battery'): 0.8899482109227872,
#  ('provide', 'power'): 0.05555555555555556,
#  ('power', 'source'): 0.05555555555555556,
#  ('source', 'phone'): 0.05555555555555556,
#  ('phone', 'function'): 0.05555555555555556,
#  ('function', '[PUNCT]'): 0.6398305084745762,
#  ('modern', 'handset'): 0.05555555555555556,
#  ('handset', 'typically'): 0.05555555555555556,
#  ('typically', 'use'): 0.05555555555555556,
#  ('use', 'lithium'): 0.6398305084745762,
#  ('[PUNCT]', 'lib'): 0.05555555555555556,
#  ('lib', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'old'): 0.05555555555555556,
#  ('old', 'handset'): 0.05555555555555556,
#  ('handset', 'nickel'): 0.05555555555555556,
#  ('nickel', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'metal'): 0.05555555555555556,
#  ('metal', 'hydride'): 0.05555555555555556,
#  ('hydride', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'ni'): 0.05555555555555556,
#  ('ni', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'mh'): 0.05555555555555556,
#  ('mh', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'input'): 0.05555555555555556,
#  ('input', 'mechanism'): 0.05555555555555556,
#  ('mechanism', 'allow'): 0.05555555555555556,
#  ('allow', 'user'): 0.6398305084745762,
#  ('user', 'interact'): 0.05555555555555556,
#  ('interact', 'phone'): 0.05555555555555556,
#  ('[PUNCT]', 'keypad'): 0.05555555555555556,
#  ('keypad', 'feature'): 0.05555555555555556,
#  ('[PUNCT]', 'touch'): 0.05555555555555556,
#  ('touch', 'screen'): 0.05555555555555556,
#  ('screen', 'smartphone'): 0.05555555555555556,
#  ('typically', 'capacitive'): 0.05555555555555556,
#  ('capacitive', 'sensing'): 0.05555555555555556,
#  ('sensing', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'display'): 0.9339689265536724,
#  ('display', 'echo'): 0.05555555555555556,
#  ('echo', 'user'): 0.05555555555555556,
#  ('user', 'typing'): 0.05555555555555556,
#  ('typing', '[PUNCT]'): 0.05555555555555556,
#  ('display', 'text'): 0.05555555555555556,
#  ('text', 'message'): 0.8899482109227872,
#  ('message', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'contact'): 0.05555555555555556,
#  ('contact', '[PUNCT]'): 0.05555555555555556,
#  ('display', 'typically'): 0.05555555555555556,
#  ('typically', 'liquid'): 0.05555555555555556,
#  ('liquid', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'crystal'): 0.6398305084745762,
#  ('crystal', 'display'): 0.6398305084745762,
#  ('display', '[PUNCT]'): 0.8579331450094162,
#  ('[PUNCT]', 'lcd'): 0.05555555555555556,
#  ('lcd', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'organic'): 0.05555555555555556,
#  ('organic', 'light'): 0.05555555555555556,
#  ('light', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'emit'): 0.05555555555555556,
#  ('emit', 'diode'): 0.05555555555555556,
#  ('diode', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'ole'): 0.6398305084745762,
#  ('ole', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'speaker'): 0.05555555555555556,
#  ('speaker', 'sound'): 0.05555555555555556,
#  ('sound', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'subscriber'): 0.6398305084745762,
#  ('subscriber', 'identity'): 0.6398305084745762,
#  ('identity', 'module'): 0.807909604519774,
#  ('module', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'sim'): 0.941972693032015,
#  ('sim', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'card'): 0.6398305084745762,
#  ('card', 'removable'): 0.05555555555555556,
#  ('removable', 'user'): 0.05555555555555556,
#  ('user', 'identity'): 0.05555555555555556,
#  ('[PUNCT]', 'r'): 0.05555555555555556,
#  ('r', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'uim'): 0.6398305084745762,
#  ('uim', '[PUNCT]'): 0.05555555555555556,
#  ('card', '[PUNCT]'): 0.9179613935969868,
#  ('hardware', 'notification'): 0.05555555555555556,
#  ('notification', 'lead'): 0.05555555555555556,
#  ('lead', 'phone'): 0.05555555555555556,
#  ('phone', 'low'): 0.05555555555555556,
#  ('low', '[PUNCT]'): 0.6398305084745762,
#  ('[PUNCT]', 'end'): 0.05555555555555556,
#  ('end', 'mobile'): 0.05555555555555556,
#  ('phone', 'refer'): 0.05555555555555556,
#  ('refer', 'feature'): 0.05555555555555556,
#  ('offer', 'basic'): 0.05555555555555556,
#  ('basic', 'telephony'): 0.05555555555555556,
#  ('handset', 'advanced'): 0.05555555555555556,
#  ('computing', 'ability'): 0.05555555555555556,
#  ('ability', 'use'): 0.05555555555555556,
#  ('use', 'native'): 0.05555555555555556,
#  ('native', 'software'): 0.05555555555555556,
#  ('software', 'application'): 0.6398305084745762,
#  ('application', 'know'): 0.05555555555555556,
#  ('know', 'smartphone'): 0.05555555555555556,
#  ('central', 'process'): 0.05555555555555556,
#  ('process', 'unit'): 0.05555555555555556,
#  ('unit', 'mobile'): 0.05555555555555556,
#  ('phone', 'central'): 0.05555555555555556,
#  ('[PUNCT]', 'cpus'): 0.05555555555555556,
#  ('cpus', '[PUNCT]'): 0.05555555555555556,
#  ('[PUNCT]', 'similar'): 0.6398305084745762,
#  ('similar', 'computer'): 0.05555555555555556,
#  ...}

# %% [markdown]
# # FBI Score
# We calculate the FBI score for each bi-gram on the corpus defined as :

# %%
# the alpha is defined between 0 and 0.5
def FBI(bigram, alpha, hwpo, hwo):
    return hwpo[bigram]*(1 - (alpha * (hwo[bigram[0]] + hwo[bigram[1]])))

# %%
fbi_bigrams = {bigram:FBI(bigram, 0.01, hwpo, hwo) for bigram in bigrams if FBI(bigram, 0.01, hwpo, hwo) > 0.5}
fbi_bigrams
# Out:
# {('mobile', 'phone'): 0.9772715190403567,
#  ('phone', '[PUNCT]'): 0.9725524987579864,
#  ('[PUNCT]', 'cellular'): 0.6288224797234064,
#  ('cellular', 'phone'): 0.7943325101382968,
#  ('[PUNCT]', 'cell'): 0.9560639940267812,
#  ('cell', 'phone'): 0.9662775842547341,
#  ('[PUNCT]', 'cellphone'): 0.6323823710616616,
#  ('cellphone', '[PUNCT]'): 0.6323823710616616,
#  ('[PUNCT]', 'hand'): 0.8448846661149816,
#  ('mobile', '[PUNCT]'): 0.8414597759465299,
#  ('portable', 'telephone'): 0.6354315755953,
#  ('radio', 'frequency'): 0.6357073307684309,
#  ('frequency', 'link'): 0.6366888621711552,
#  ('telephone', 'service'): 0.905467826396832,
#  ('service', 'area'): 0.6336653686180721,
#  ('area', '[PUNCT]'): 0.7981889154622024,
#  ('system', 'mobile'): 0.797233054313542,
#  ('phone', 'operator'): 0.7969103861217982,
#  ('operator', '[PUNCT]'): 0.7965877179300545,
#  ('[PUNCT]', 'provide'): 0.919764004063984,
#  ('provide', 'access'): 0.6344376793698658,
#  ('network', '[PUNCT]'): 0.9029014766602544,
#  ('[PUNCT]', '[PUNCT]'): 0.98,
#  ('[PUNCT]', 'modern'): 0.7985048923780805,
#  ('modern', 'mobile'): 0.6328934504003327,
#  ('mobile', 'telephone'): 0.9040013408330734,
#  ('service', 'use'): 0.6293337553291047,
#  ('cellular', 'network'): 0.8778356335857799,
#  ('[PUNCT]', 'mobile'): 0.9690236464940556,
#  ('north', 'america'): 0.6391934257044816,
#  ('[PUNCT]', 'addition'): 0.6326341816574815,
#  ('telephony', '[PUNCT]'): 0.7981889154622024,
#  ('[PUNCT]', 'digital'): 0.8778301737808047,
#  ('digital', 'mobile'): 0.6316292944785276,
#  ('[PUNCT]', 'g'): 0.9470134007486741,
#  ('g', '[PUNCT]'): 0.9391505300220673,
#  ('[PUNCT]', 'support'): 0.6326341816574815,
#  ('service', '[PUNCT]'): 0.9391505300220673,
#  ('[PUNCT]', 'text'): 0.7965877179300545,
#  ('text', 'messaging'): 0.803659157394891,
#  ('messaging', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'mms'): 0.6331136620047831,
#  ('mms', '[PUNCT]'): 0.6331136620047831,
#  ('access', '[PUNCT]'): 0.7972295847630931,
#  ('[PUNCT]', 'short'): 0.6328763751689715,
#  ('short', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'range'): 0.6328763751689715,
#  ('wireless', 'communication'): 0.635965225642092,
#  ('communication', '[PUNCT]'): 0.905461913148591,
#  ('[PUNCT]', 'business'): 0.6321321306020589,
#  ('application', '[PUNCT]'): 0.876767149752175,
#  ('[PUNCT]', 'video'): 0.7981889154622024,
#  ('video', 'game'): 0.8055661710166026,
#  ('phone', 'offer'): 0.7985115836539461,
#  ('feature', 'phone'): 0.9587866782130602,
#  ('advanced', 'computing'): 0.63846213476136,
#  ('smartphone', '[PUNCT]'): 0.9250142950706502,
#  ('[PUNCT]', 'development'): 0.7981889154622024,
#  ('development', 'metal'): 0.6374806033586358,
#  ('metal', '[PUNCT]'): 0.7985048923780805,
#  ('[PUNCT]', 'oxide'): 0.7991286679837787,
#  ('oxide', '[PUNCT]'): 0.7991286679837787,
#  ('[PUNCT]', 'semiconductor'): 0.7991286679837787,
#  ('semiconductor', '[PUNCT]'): 0.7991286679837787,
#  ('[PUNCT]', 'mos'): 0.7991286679837787,
#  ('mos', '[PUNCT]'): 0.7991286679837787,
#  ('[PUNCT]', 'large'): 0.8781836961529352,
#  ('large', '[PUNCT]'): 0.631372380940002,
#  ('[PUNCT]', 'scale'): 0.6331136620047831,
#  ('scale', 'integration'): 0.6391934257044816,
#  ('integration', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'lsi'): 0.6331136620047831,
#  ('lsi', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'technology'): 0.6306090984714567,
#  ('technology', '[PUNCT]'): 0.8771220370755491,
#  ('[PUNCT]', 'information'): 0.6323823710616616,
#  ('information', 'theory'): 0.63846213476136,
#  ('theory', 'cellular'): 0.6349022434231049,
#  ('cellular', 'networking'): 0.6349022434231049,
#  ('networking', 'lead'): 0.6379606725070187,
#  ('lead', 'development'): 0.6369791411042944,
#  ('development', 'affordable'): 0.6382118943017573,
#  ('affordable', 'mobile'): 0.6336247413434543,
#  ('mobile', 'communication'): 0.7975539877300613,
#  ('[PUNCT]', 'handheld'): 0.876767149752175,
#  ('handheld', 'mobile'): 0.9050986707566462,
#  ('phone', 'demonstrate'): 0.6331319148383071,
#  ('demonstrate', 'john'): 0.6389561388686701,
#  ('john', 'f.'): 0.6391934257044816,
#  ('f.', 'mitchell'): 0.6391934257044816,
#  ('mitchell', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'martin'): 0.6328763751689715,
#  ('martin', 'cooper'): 0.806505923538179,
#  ('cooper', 'motorola'): 0.8055661710166026,
#  ('motorola', '[PUNCT]'): 0.7981889154622024,
#  ('[PUNCT]', 'handset'): 0.7978716994211639,
#  ('handset', 'weigh'): 0.6379606725070187,
#  ('kilogram', '[PUNCT]'): 0.6331136620047831,
#  ('nippon', 'telegraph'): 0.6391934257044816,
#  ('telegraph', 'telephone'): 0.6356688624311115,
#  ('telephone', '[PUNCT]'): 0.7949778465217844,
#  ('[PUNCT]', 'launch'): 0.7969086513465737,
#  ('need', '[PUNCT]'): 0.9414396018913267,
#  ('[PUNCT]', 'dynatac'): 0.6326341816574815,
#  ('dynatac', 'x'): 0.63871394535718,
#  ('x', 'commercially'): 0.63871394535718,
#  ('commercially', 'available'): 0.8541011313515996,
#  ('available', 'handheld'): 0.8014217930054418,
#  ('[PUNCT]', 'worldwide'): 0.6318809088073203,
#  ('worldwide', 'mobile'): 0.6323919881459914,
#  ('seven', 'billion'): 0.6389561388686701,
#  ('[PUNCT]', 'smartphone'): 0.9564529915918569,
#  ('worldwide', 'samsung'): 0.636727919309556,
#  ('samsung', '[PUNCT]'): 0.8788910138874447,
#  ('[PUNCT]', 'apple'): 0.9061909321817267,
#  ('huawei', '[PUNCT]'): 0.7988228518942151,
#  ('phone', 'sale'): 0.6321364484766558,
#  ('[PUNCT]', 'feature'): 0.9190194073645628,
#  ('[PUNCT]', 'nokia'): 0.6326341816574815,
#  ('[PUNCT]', 'size'): 0.6318809088073203,
#  ('[PUNCT]', 'early'): 0.6321321306020589,
#  ('world', 'war'): 0.6364643326921077,
#  ('country', '[PUNCT]'): 0.9272706953037445,
#  ('mobile', 'telephony'): 0.7988342518456899,
#  ('[PUNCT]', 'generation'): 0.9065561456564186,
#  ('generation', '[PUNCT]'): 0.9065561456564186,
#  ('[PUNCT]', 'service'): 0.628567136321098,
#  ('simultaneous', 'call'): 0.8010859900869987,
#  ('call', '[PUNCT]'): 0.9399138472236663,
#  ('[PUNCT]', 'motorola'): 0.6321321306020589,
#  ('[PUNCT]', 'commercially'): 0.6326341816574815,
#  ('handheld', 'cellular'): 0.6321425327544972,
#  ('cellular', 'mobile'): 0.6293335590620776,
#  ('[PUNCT]', 'device'): 0.6298442458666944,
#  ('launch', 'japan'): 0.6367184984922533,
#  ('[PUNCT]', 'follow'): 0.7988228518942151,
#  ('[PUNCT]', 'system'): 0.7965877179300545,
#  ('finland', '[PUNCT]'): 0.8476105776229594,
#  ('[PUNCT]', 'country'): 0.6298442458666944,
#  ('cellular', 'technology'): 0.6323976798897785,
#  ('digital', 'cellular'): 0.6329067965581782,
#  ('[PUNCT]', 'enable'): 0.6326341816574815,
#  ('[PUNCT]', 'base'): 0.6326341816574815,
#  ('[PUNCT]', 'rf'): 0.7988228518942151,
#  ('circuit', '[PUNCT]'): 0.7988228518942151,
#  ('[PUNCT]', 'lead'): 0.7978716994211639,
#  ('second', '[PUNCT]'): 0.7981889154622024,
#  ('launch', 'finland'): 0.6362164474368306,
#  ('gsm', 'standard'): 0.6362164474368306,
#  ('standard', '[PUNCT]'): 0.9212514785016117,
#  ('g', 'network'): 0.6308667970780908,
#  ('network', 'operator'): 0.7994914838307164,
#  ('[PUNCT]', 'gsm'): 0.7981889154622024,
#  ('lithium', '[PUNCT]'): 0.7991286679837787,
#  ('[PUNCT]', 'ion'): 0.8482837656551477,
#  ('ion', 'battery'): 0.6362093818238536,
#  ('battery', '[PUNCT]'): 0.8771220370755491,
#  ('[PUNCT]', 'family'): 0.6326341816574815,
#  ('[PUNCT]', 'allow'): 0.6321321306020589,
#  ('capacity', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'point'): 0.6326341816574815,
#  ('point', '[PUNCT]'): 0.6326341816574815,
#  ('medium', '[PUNCT]'): 0.6326341816574815,
#  ('g', 'technology'): 0.6321423364874701,
#  ('[PUNCT]', 'offer'): 0.6321321306020589,
#  ('standard', 'g'): 0.6326514531558698,
#  ('[PUNCT]', 'advanced'): 0.6323823710616616,
#  ('[PUNCT]', 'term'): 0.8472737204371887,
#  ('standardization', 'body'): 0.6389561388686701,
#  ('[PUNCT]', 'time'): 0.6321321306020589,
#  ('[PUNCT]', 'new'): 0.6318809088073203,
#  ('[PUNCT]', 'type'): 0.7988228518942151,
#  ('active', 'mobile'): 0.6336247413434543,
#  ('broadband', 'subscription'): 0.6384766585213684,
#  ('inhabitant', '[PUNCT]'): 0.6331136620047831,
#  ('feature', '[PUNCT]'): 0.7949778465217844,
#  ('[PUNCT]', 'international'): 0.6328763751689715,
#  ('connection', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'call'): 0.7943325101382968,
#  ('[PUNCT]', 'include'): 0.9216224876304115,
#  ('[PUNCT]', 'etc'): 0.6331136620047831,
#  ('etc', '[PUNCT]'): 0.6331136620047831,
#  ('world', '[PUNCT]'): 0.8459102383438472,
#  ('system', '[PUNCT]'): 0.8459102383438472,
#  ('[PUNCT]', 'develop'): 0.6318809088073203,
#  ('phone', 'feature'): 0.6298446384007487,
#  ('modern', 'smartphone'): 0.6336600694083394,
#  ('phone', 'typically'): 0.6321364484766558,
#  ('voice', 'calling'): 0.6382344650098783,
#  ('calling', 'text'): 0.6364643326921077,
#  ('capability', '[PUNCT]'): 0.6321321306020589,
#  ('service', 'provider'): 0.6346469000207965,
#  ('basic', 'mobile'): 0.6328934504003327,
#  ('phone', 'basic'): 0.6326379107309972,
#  ('phone', 'tend'): 0.6333692016741187,
#  ('[PUNCT]', 'design'): 0.7978716994211639,
#  ('use', 'mobile'): 0.9466283989289799,
#  ('operating', 'system'): 0.6369438130394093,
#  ('device', '[PUNCT]'): 0.9036341562756346,
#  ('cell', 'tower'): 0.7994795882291775,
#  ('tower', 'place'): 0.6369791411042944,
#  ('cell', '[PUNCT]'): 0.8735709799198179,
#  ('cell', 'use'): 0.8431730105397849,
#  ('[PUNCT]', 'typically'): 0.6318809088073203,
#  ('location', '[PUNCT]'): 0.6326341816574815,
#  ('phone', 'network'): 0.6295890987314131,
#  ('[PUNCT]', 'small'): 0.6318809088073203,
#  ('city', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'order'): 0.7988228518942151,
#  ('high', 'traffic'): 0.6379826544140584,
#  ('[PUNCT]', 'multiple'): 0.6323823710616616,
#  ('frequency', '[PUNCT]'): 0.9047314861992074,
#  ('[PUNCT]', 'state'): 0.8774766514086745,
#  ('phone', 'company'): 0.7981943676129076,
#  ('greatly', 'increase'): 0.6359542346885723,
#  ('increase', 'capacity'): 0.6361964282000623,
#  ('[PUNCT]', 'phone'): 0.9588204452040946,
#  ('example', '[PUNCT]'): 0.9058265634567837,
#  ('[PUNCT]', 'frequency'): 0.8455683809342253,
#  ('overlap', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'example'): 0.9216224876304115,
#  ('use', 'frequency'): 0.6313757174794634,
#  ('[PUNCT]', 'door'): 0.6331136620047831,
#  ('hand', '[PUNCT]'): 0.9493216374649059,
#  ('[PUNCT]', 'hardware'): 0.6331136620047831,
#  ('find', 'mobile'): 0.7985170358046515,
#  ('[PUNCT]', 'central'): 0.6326341816574815,
#  ('central', 'processing'): 0.6384766585213684,
#  ('processing', 'unit'): 0.6379746074659457,
#  ('unit', '[PUNCT]'): 0.8476105776229594,
#  ('[PUNCT]', 'cpu'): 0.6328763751689715,
#  ('[PUNCT]', 'battery'): 0.8771220370755491,
#  ('function', '[PUNCT]'): 0.6326341816574815,
#  ('use', 'lithium'): 0.6336429941769782,
#  ('allow', 'user'): 0.6351974290319226,
#  ('[PUNCT]', 'display'): 0.9208804693728121,
#  ('text', 'message'): 0.8828040561130175,
#  ('message', '[PUNCT]'): 0.8459102383438472,
#  ('liquid', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'crystal'): 0.6331136620047831,
#  ('crystal', 'display'): 0.6369438130394093,
#  ('display', '[PUNCT]'): 0.8459102383438472,
#  ('[PUNCT]', 'ole'): 0.6331136620047831,
#  ('ole', '[PUNCT]'): 0.6331136620047831,
#  ('sound', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'subscriber'): 0.6308640493397109,
#  ('subscriber', 'identity'): 0.6367065262035977,
#  ('identity', 'module'): 0.806505923538179,
#  ('module', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'sim'): 0.9272706953037445,
#  ('[PUNCT]', 'card'): 0.6298442458666944,
#  ('r', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'uim'): 0.6331136620047831,
#  ('card', '[PUNCT]'): 0.9036341562756346,
#  ('low', '[PUNCT]'): 0.6326341816574815,
#  ('software', 'application'): 0.6349464035042113,
#  ('[PUNCT]', 'similar'): 0.6323823710616616,
#  ('rate', '[PUNCT]'): 0.6331136620047831,
#  ('performance', '[PUNCT]'): 0.6321321306020589,
#  ('[PUNCT]', 'performance'): 0.6321321306020589,
#  ('phone', 'screen'): 0.631373754809192,
#  ('[PUNCT]', 'depend'): 0.7981889154622024,
#  ('[PUNCT]', 'screen'): 0.6311182151398564,
#  ('surface', '[PUNCT]'): 0.6331136620047831,
#  ('aspect', 'ratio'): 0.806505923538179,
#  ('tall', 'aspect'): 0.6389561388686701,
#  ('common', '[PUNCT]'): 0.7975502703545804,
#  ('screen', 'size'): 0.8527502814027244,
#  ('millimetre', '[PUNCT]'): 0.7991286679837787,
#  ('[PUNCT]', 'hold'): 0.8469323893669196,
#  ('large', 'screen'): 0.6354566977747738,
#  ('[PUNCT]', 'edge'): 0.6331136620047831,
#  ('edge', '[PUNCT]'): 0.6331136620047831,
#  ('lead', '[PUNCT]'): 0.6318809088073203,
#  ('apple', '[PUNCT]'): 0.7975502703545804,
#  ('[PUNCT]', 'sound'): 0.6326341816574815,
#  ('[PUNCT]', 'audio'): 0.6326341816574815,
#  ('[PUNCT]', 'quality'): 0.6326341816574815,
#  ('long', '[PUNCT]'): 0.8482837656551477,
#  ('[PUNCT]', 'distance'): 0.6331136620047831,
#  ('distance', 'call'): 0.6351577830924404,
#  ('small', 'speaker'): 0.6377233856712071,
#  ('use', 'speakerphone'): 0.6338802810127898,
#  ('phone', 'hold'): 0.6318818901424561,
#  ('ear', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'year'): 0.6318809088073203,
#  ('ion', '[PUNCT]'): 0.6326341816574815,
#  ('time', '[PUNCT]'): 0.6321321306020589,
#  ('age', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'keep'): 0.6328763751689715,
#  ('sim', 'card'): 0.9630641575826372,
#  ('card', 'mobile'): 0.6303553252053654,
#  ('phone', 'require'): 0.6331319148383071,
#  ('phone', 'simply'): 0.6328897213268171,
#  ('market', '[PUNCT]'): 0.6321321306020589,
#  ('[PUNCT]', 'software'): 0.7975502703545804,
#  ('software', 'platform'): 0.8039877733874042,
#  ('section', 'need'): 0.6359416735988354,
#  ('october', '[PUNCT]'): 0.6331136620047831,
#  ('platform', '[PUNCT]'): 0.8476105776229594,
#  ('mobile', 'app'): 0.8469363369120654,
#  ('computer', 'program'): 0.63846213476136,
#  ('term', '[PUNCT]'): 0.6318809088073203,
#  ('app', '[PUNCT]'): 0.7969086513465737,
#  ('[PUNCT]', 'message'): 0.6308640493397109,
#  ('application', 'mobile'): 0.6308650306748466,
#  ('message', 'service'): 0.6323972873557242,
#  ('[PUNCT]', 'sms'): 0.6326341816574815,
#  ('news', 'service'): 0.633915609077675,
#  ('sm', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'news'): 0.7985048923780805,
#  ('[PUNCT]', 'introduce'): 0.6326341816574815,
#  ('[PUNCT]', 'application'): 0.6303539513361754,
#  ('application', 'store'): 0.6352009618384111,
#  ('app', 'store'): 0.8030289383383591,
#  ('manufacturer', '[PUNCT]'): 0.7969086513465737,
#  ('distribution', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'party'): 0.6331136620047831,
#  ('game', '[PUNCT]'): 0.6328763751689715,
#  ('store', '[PUNCT]'): 0.7978716994211639,
#  ('smartphone', 'manufacturer'): 0.7985219923052927,
#  ('[PUNCT]', 'relate'): 0.6331136620047831,
#  ('[PUNCT]', 'february'): 0.6331136620047831,
#  ('february', '[PUNCT]'): 0.6331136620047831,
#  ('update', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'update'): 0.6328763751689715,
#  ('[PUNCT]', 'manufacturer'): 0.6311182151398564,
#  ('vendor', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'q'): 0.7991286679837787,
#  ('report', '[PUNCT]'): 0.7962657932134068,
#  ('[PUNCT]', 'samsung'): 0.7978716994211639,
#  ('[PUNCT]', 'huawei'): 0.7988228518942151,
#  ('[PUNCT]', 'oppo'): 0.6331136620047831,
#  ('oppo', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'vendor'): 0.6326341816574815,
#  ('market', 'leader'): 0.6382118943017573,
#  ('leader', 'mobile'): 0.6336247413434543,
#  ('q', '[PUNCT]'): 0.6328763751689715,
#  ('nokia', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'million'): 0.8476105776229594,
#  ('million', 'unit'): 0.6372303628990329,
#  ('phone', 'manufacturer'): 0.631373754809192,
#  ('phone', 'subscriber'): 0.877832084712546,
#  ('mobile', 'operator'): 0.8465955321811491,
#  ('june', '[PUNCT]'): 0.7991286679837787,
#  ('operator', 'million'): 0.635962281636685,
#  ('million', 'subscriber'): 0.635962281636685,
#  ('worldwide', '[PUNCT]'): 0.6318809088073203,
#  ('[PUNCT]', 'number'): 0.631372380940002,
#  ('[PUNCT]', 'use'): 0.8418024228651808,
#  ('estimate', '[PUNCT]'): 0.6326341816574815,
#  ('phone', 'variety'): 0.6328897213268171,
#  ('purpose', '[PUNCT]'): 0.6331136620047831,
#  ('family', 'member'): 0.6382344650098783,
#  ('member', '[PUNCT]'): 0.7988228518942151,
#  ('emergency', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'people'): 0.6321321306020589,
#  ('use', '[PUNCT]'): 0.900702029897866,
#  ('[PUNCT]', 'study'): 0.9190194073645628,
#  ('provide', 'mobile'): 0.6306102760736196,
#  ('phone', 'use'): 0.9658845909442769,
#  ('text', '[PUNCT]'): 0.7965877179300545,
#  ('novel', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'united'): 0.6323823710616616,
#  ('develop', 'country'): 0.8014203060552494,
#  ('micro', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'tv'): 0.6318809088073203,
#  ('phone', 'drive'): 0.8452273130336326,
#  ('advertising', '[PUNCT]'): 0.6331136620047831,
#  ('tv', '[PUNCT]'): 0.7978716994211639,
#  ('[PUNCT]', 'estimate'): 0.6326341816574815,
#  ('phone', 'sharing'): 0.6333692016741187,
#  ('[PUNCT]', 'common'): 0.6316263504731204,
#  ('medium', 'content'): 0.6374811921597171,
#  ('content', 'mobile'): 0.7985170358046515,
#  ('mobile', 'banking'): 0.8799513080135871,
#  ('banking', 'service'): 0.6336653686180721,
#  ('m', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'pesa'): 0.6331136620047831,
#  ('company', '[PUNCT]'): 0.6318809088073203,
#  ('united', 'state'): 0.8033411978787564,
#  ('mobile', 'payment'): 0.798195606738068,
#  ('phone', 'mobile'): 0.6278005173130914,
#  ('scheme', '[PUNCT]'): 0.6331136620047831,
#  ('contactless', 'payment'): 0.637706114172819,
#  ('nfc', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'law'): 0.6311182151398564,
#  ('law', 'enforcement'): 0.804285906900974,
#  ('number', '[PUNCT]'): 0.631372380940002,
#  ('[PUNCT]', 'drive'): 0.6300991967349485,
#  ('u.s', '[PUNCT]'): 0.8482837656551477,
#  ('use', 'certain'): 0.6336429941769782,
#  ('use', 'drive'): 0.6308658157429552,
#  ('drive', '[PUNCT]'): 0.9315870574243527,
#  ('[PUNCT]', 'texting'): 0.6323823710616616,
#  ('increase', 'risk'): 0.6354521836331496,
#  ('[PUNCT]', 'national'): 0.6331136620047831,
#  ('[PUNCT]', 'report'): 0.8455683809342253,
#  ('driver', 'distract'): 0.6372148578038889,
#  ('march', '[PUNCT]'): 0.6331136620047831,
#  ('study', 'show'): 0.6344361092336487,
#  ('show', '[PUNCT]'): 0.7978716994211639,
#  ('access', 'internet'): 0.6359648331080378,
#  ('[PUNCT]', 'israel'): 0.6331136620047831,
#  ('israel', '[PUNCT]'): 0.6331136620047831,
#  ('[PUNCT]', 'japan'): 0.6326341816574815,
#  ('handheld', 'hand'): 0.6334192497660392,
#  ('[PUNCT]', 'free'): 0.8795885039729993,
#  ('free', 'use'): 0.6331489900696683,
#  ('[PUNCT]', 'ban'): 0.631372380940002,
#  ('state', '[PUNCT]'): 0.6308640493397109,
#  ('ban', 'hand'): 0.6344376793698658,
#  ('[PUNCT]', 'increase'): 0.7959436206717271,
#  ('ban', 'handheld'): 0.6346924339710929,
#  ('safety', '[PUNCT]'): 0.6328763751689715,
#  ('law', '[PUNCT]'): 0.6311182151398564,
#  ('state', 'ban'): 0.6352025319746283,
#  ('ban', 'texting'): 0.6367208536965789,
#  ('july', '[PUNCT]'): 0.6328763751689715,
#  ('[PUNCT]', 'public'): 0.6326341816574815,
#  ('[PUNCT]', 'health'): 0.7972295847630931,
#  ('health', 'effect'): 0.6367208536965789,
#  ('phone', 'radiation'): 0.6328897213268171,
#  ('human', 'health'): 0.6362193914422377,
#  ('recent[when', '[PUNCT]'): 0.6331136620047831,
#  ('increase', 'mobile'): 0.6308650306748466,
#  ('phone', 'usage'): 0.6323876702713944,
#  ('health', '[PUNCT]'): 0.631372380940002,
#  ('human', '[PUNCT]'): 0.7978716994211639,
#  ('health', 'risk'): 0.6364706132369762,
#  ('radiation', '[PUNCT]'): 0.6326341816574815,
#  ('possibly', 'carcinogenic'): 0.6389561388686701,
#  ('tumor', '[PUNCT]'): 0.6331136620047831,
#  ('year', '[PUNCT]'): 0.7978716994211639,
#  ('brain', 'cancer'): 0.6382344650098783,
#  ('cancer', '[PUNCT]'): 0.6326341816574815,
#  ('electronic', 'waste'): 0.6384766585213684,
#  ('theft', 'cellular'): 0.6344227630758033,
#  ('san', 'francisco'): 0.6391934257044816,
#  ('kill', 'switch'): 0.6387188520328585,
#  ('carrier', '[PUNCT]'): 0.7988228518942151,
#  ('telecom', 'carrier'): 0.8062001074486153,
#  ('imei', 'blacklist'): 0.6379826544140584,
#  ('blacklist', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'biological'): 0.6328763751689715,
#  ('biological', 'group'): 0.6387188520328585,
#  ('gps', 'tracker'): 0.6389561388686701,
#  ('conflict', 'mineral'): 0.6384766585213684,
#  ('war', '[PUNCT]'): 0.6326341816574815,
#  ('life', '[PUNCT]'): 0.6328763751689715,
#  ('industry', '[PUNCT]'): 0.6326341816574815,
#  ('[PUNCT]', 'kosher'): 0.6328763751689715,
#  ('kosher', 'phone'): 0.6331319148383071,
#  ('[PUNCT]', 'orthodox'): 0.6328763751689715,
#  ('worker', '[PUNCT]'): 0.6331136620047831}

# %% [markdown]
# # FNI Score
#
# then we calculate the FNI for each n-gram present in the corpus

# %%
def FNI(ngrams):
    
    last_ngram = ngrams[-1]
    conserved_ngram = ngrams[-1]
    trigram = []
    it = iter(last_ngram)
    for (bigram, score) in it:
        next_bigram, next_score = next(it, (None, None))
        if next_bigram is None:
            break
        if bigram[1] == next_bigram[0]:
            trigram.append((tuple(list(bigram) + [next_bigram[-1]]), statistics.mean([score, next_score])))
            conserved_ngram.remove((bigram, score))
            conserved_ngram.remove((next_bigram, next_score))
        else:
            it = itertools.chain(it, [(next_bigram, next_score)])
        
    ngrams[-1] = [ngram for ngram in conserved_ngram if '[PUNCT]' not in ngram[0]]
    ngrams.append(trigram)
    if trigram != []:
        FNI(ngrams)
    return ngrams[:-1]
        
fni_ngrams = FNI([list(fbi_bigrams.items())])
fni_ngrams
# Out:
# [[(('cellular', 'phone'), 0.7943325101382968),
#   (('portable', 'telephone'), 0.6354315755953),
#   (('radio', 'frequency'), 0.6357073307684309),
#   (('frequency', 'link'), 0.6366888621711552),
#   (('telephone', 'service'), 0.905467826396832),
#   (('system', 'mobile'), 0.797233054313542),
#   (('phone', 'operator'), 0.7969103861217982),
#   (('provide', 'access'), 0.6344376793698658),
#   (('modern', 'mobile'), 0.6328934504003327),
#   (('mobile', 'telephone'), 0.9040013408330734),
#   (('service', 'use'), 0.6293337553291047),
#   (('cellular', 'network'), 0.8778356335857799),
#   (('north', 'america'), 0.6391934257044816),
#   (('wireless', 'communication'), 0.635965225642092),
#   (('video', 'game'), 0.8055661710166026),
#   (('phone', 'offer'), 0.7985115836539461),
#   (('feature', 'phone'), 0.9587866782130602),
#   (('advanced', 'computing'), 0.63846213476136),
#   (('development', 'metal'), 0.6374806033586358),
#   (('cellular', 'networking'), 0.6349022434231049),
#   (('networking', 'lead'), 0.6379606725070187),
#   (('affordable', 'mobile'), 0.6336247413434543),
#   (('mobile', 'communication'), 0.7975539877300613),
#   (('phone', 'demonstrate'), 0.6331319148383071),
#   (('demonstrate', 'john'), 0.6389561388686701),
#   (('handset', 'weigh'), 0.6379606725070187),
#   (('dynatac', 'x'), 0.63871394535718),
#   (('x', 'commercially'), 0.63871394535718),
#   (('worldwide', 'mobile'), 0.6323919881459914),
#   (('seven', 'billion'), 0.6389561388686701),
#   (('phone', 'sale'), 0.6321364484766558),
#   (('world', 'war'), 0.6364643326921077),
#   (('mobile', 'telephony'), 0.7988342518456899),
#   (('simultaneous', 'call'), 0.8010859900869987),
#   (('handheld', 'cellular'), 0.6321425327544972),
#   (('cellular', 'mobile'), 0.6293335590620776),
#   (('launch', 'japan'), 0.6367184984922533),
#   (('cellular', 'technology'), 0.6323976798897785),
#   (('digital', 'cellular'), 0.6329067965581782),
#   (('launch', 'finland'), 0.6362164474368306),
#   (('g', 'network'), 0.6308667970780908),
#   (('network', 'operator'), 0.7994914838307164),
#   (('g', 'technology'), 0.6321423364874701),
#   (('standard', 'g'), 0.6326514531558698),
#   (('standardization', 'body'), 0.6389561388686701),
#   (('active', 'mobile'), 0.6336247413434543),
#   (('broadband', 'subscription'), 0.6384766585213684),
#   (('phone', 'feature'), 0.6298446384007487),
#   (('modern', 'smartphone'), 0.6336600694083394),
#   (('phone', 'typically'), 0.6321364484766558),
#   (('service', 'provider'), 0.6346469000207965),
#   (('basic', 'mobile'), 0.6328934504003327),
#   (('phone', 'basic'), 0.6326379107309972),
#   (('phone', 'tend'), 0.6333692016741187),
#   (('use', 'mobile'), 0.9466283989289799),
#   (('operating', 'system'), 0.6369438130394093),
#   (('cell', 'tower'), 0.7994795882291775),
#   (('tower', 'place'), 0.6369791411042944),
#   (('cell', 'use'), 0.8431730105397849),
#   (('phone', 'network'), 0.6295890987314131),
#   (('high', 'traffic'), 0.6379826544140584),
#   (('phone', 'company'), 0.7981943676129076),
#   (('use', 'frequency'), 0.6313757174794634),
#   (('find', 'mobile'), 0.7985170358046515),
#   (('processing', 'unit'), 0.6379746074659457),
#   (('use', 'lithium'), 0.6336429941769782),
#   (('allow', 'user'), 0.6351974290319226),
#   (('subscriber', 'identity'), 0.6367065262035977),
#   (('identity', 'module'), 0.806505923538179),
#   (('software', 'application'), 0.6349464035042113),
#   (('phone', 'screen'), 0.631373754809192),
#   (('aspect', 'ratio'), 0.806505923538179),
#   (('tall', 'aspect'), 0.6389561388686701),
#   (('screen', 'size'), 0.8527502814027244),
#   (('large', 'screen'), 0.6354566977747738),
#   (('distance', 'call'), 0.6351577830924404),
#   (('small', 'speaker'), 0.6377233856712071),
#   (('use', 'speakerphone'), 0.6338802810127898),
#   (('phone', 'hold'), 0.6318818901424561),
#   (('sim', 'card'), 0.9630641575826372),
#   (('card', 'mobile'), 0.6303553252053654),
#   (('phone', 'require'), 0.6331319148383071),
#   (('phone', 'simply'), 0.6328897213268171),
#   (('software', 'platform'), 0.8039877733874042),
#   (('section', 'need'), 0.6359416735988354),
#   (('mobile', 'app'), 0.8469363369120654),
#   (('computer', 'program'), 0.63846213476136),
#   (('application', 'mobile'), 0.6308650306748466),
#   (('message', 'service'), 0.6323972873557242),
#   (('news', 'service'), 0.633915609077675),
#   (('app', 'store'), 0.8030289383383591),
#   (('smartphone', 'manufacturer'), 0.7985219923052927),
#   (('market', 'leader'), 0.6382118943017573),
#   (('leader', 'mobile'), 0.6336247413434543),
#   (('million', 'unit'), 0.6372303628990329),
#   (('phone', 'manufacturer'), 0.631373754809192),
#   (('phone', 'subscriber'), 0.877832084712546),
#   (('mobile', 'operator'), 0.8465955321811491),
#   (('operator', 'million'), 0.635962281636685),
#   (('million', 'subscriber'), 0.635962281636685),
#   (('phone', 'variety'), 0.6328897213268171),
#   (('family', 'member'), 0.6382344650098783),
#   (('provide', 'mobile'), 0.6306102760736196),
#   (('phone', 'use'), 0.9658845909442769),
#   (('develop', 'country'), 0.8014203060552494),
#   (('phone', 'drive'), 0.8452273130336326),
#   (('phone', 'sharing'), 0.6333692016741187),
#   (('medium', 'content'), 0.6374811921597171),
#   (('banking', 'service'), 0.6336653686180721),
#   (('united', 'state'), 0.8033411978787564),
#   (('mobile', 'payment'), 0.798195606738068),
#   (('phone', 'mobile'), 0.6278005173130914),
#   (('contactless', 'payment'), 0.637706114172819),
#   (('use', 'certain'), 0.6336429941769782),
#   (('increase', 'risk'), 0.6354521836331496),
#   (('driver', 'distract'), 0.6372148578038889),
#   (('access', 'internet'), 0.6359648331080378),
#   (('handheld', 'hand'), 0.6334192497660392),
#   (('free', 'use'), 0.6331489900696683),
#   (('ban', 'hand'), 0.6344376793698658),
#   (('ban', 'handheld'), 0.6346924339710929),
#   (('phone', 'radiation'), 0.6328897213268171),
#   (('human', 'health'), 0.6362193914422377),
#   (('increase', 'mobile'), 0.6308650306748466),
#   (('phone', 'usage'), 0.6323876702713944),
#   (('health', 'risk'), 0.6364706132369762),
#   (('possibly', 'carcinogenic'), 0.6389561388686701),
#   (('electronic', 'waste'), 0.6384766585213684),
#   (('theft', 'cellular'), 0.6344227630758033),
#   (('san', 'francisco'), 0.6391934257044816),
#   (('kill', 'switch'), 0.6387188520328585),
#   (('telecom', 'carrier'), 0.8062001074486153),
#   (('biological', 'group'), 0.6387188520328585),
#   (('gps', 'tracker'), 0.6389561388686701),
#   (('conflict', 'mineral'), 0.6384766585213684),
#   (('kosher', 'phone'), 0.6331319148383071)],
#  [(('information', 'theory', 'cellular'), 0.6366821890922325),
#   (('lead', 'development', 'affordable'), 0.6375955177030259),
#   (('john', 'f.', 'mitchell'), 0.6391934257044816),
#   (('martin', 'cooper', 'motorola'), 0.8060360472773908),
#   (('nippon', 'telegraph', 'telephone'), 0.6374311440677966),
#   (('commercially', 'available', 'handheld'), 0.8277614621785208),
#   (('voice', 'calling', 'text'), 0.6373493988509931),
#   (('greatly', 'increase', 'capacity'), 0.6360753314443173),
#   (('content', 'mobile', 'banking'), 0.8392341719091193),
#   (('state', 'ban', 'texting'), 0.6359616928356036)],
#  []]

# %% [markdown]
# # Extract High Relevant Monogram
# Finally, we extract the high relevant mono and n-gram

# %%
def extract_high_relevant_monogram(monograms, highest_freq_bigram):
    high_relevant_monograms = []
    for gram in monograms.items():
        if gram[1] > highest_freq_bigram * 8 and gram[0] != '[PUNCT]':
            high_relevant_monograms.append(gram)
    return high_relevant_monograms

highest_frequency = sorted(bigram_frequency.items(), key=lambda x : x[1], reverse=True)[0][1]
highest_monogram = extract_high_relevant_monogram(monogram_frequency, highest_frequency)

# %% [markdown]
# ## Extract High Relevant N-gram

# %%
top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)
highest_ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1] >= top_bigram_mean]

# %% [markdown]
# ## Visualize the Result

# %% [markdown]
# We extract the different top

# %%
top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)

ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1]]
top_ranked_ngram = sorted(ngrams, key=lambda x: x[1], reverse=True)[:11]

# %% [markdown]
# The final list is ordered as : top 5 monogram, top 10 bigram and top 10 ngram

# %%
print('-'* 30)
print('Top Monograms :')
print(highest_monogram)
print('-'* 30)
print('Top Highest Ngrams :')
print(highest_ngrams)
print('-'* 30)
print('Top Bigram :')
print('-'* 30)
print('\n'.join([' '.join(bigram[0]) for bigram in top_ranked_bigram]))
print('-' * 30)
print('Top Ngram :')
print('-'* 30)
print('\n'.join([' '.join(ngram[0]) for ngram in top_ranked_ngram]))
# Out:
# ------------------------------
# Top Monograms :
# []
# ------------------------------
# Top Highest Ngrams :
# []
# ------------------------------
# Top Bigram :
# ------------------------------
# phone use
# sim card
# feature phone
# use mobile
# telephone service
# mobile telephone
# cellular network
# phone subscriber
# screen size
# mobile app
# mobile operator
# ------------------------------
# Top Ngram :
# ------------------------------
# content mobile banking
# commercially available handheld
# martin cooper motorola
# john f. mitchell
# lead development affordable
# nippon telegraph telephone
# voice calling text
# information theory cellular
# greatly increase capacity
# state ban texting

# %% [markdown]
# # using the implementation on several texts

# %%
def automatic_keyword_extraction(word_list:list, alpha:float, threshold:float):
    bigrams = list(nltk.bigrams(word_list))
    monogram_frequency = Counter(word_list)
    bigram_frequency = Counter([i for i in bigrams])
    
    cumul_monogram = compute_cumul_freq_monogram(monogram_frequency)
    cumul_bigram = compute_cumul_freq_bigram(bigram_frequency)
    
    hwo = {word: HWO(word, monogram_frequency, cumul_monogram) for word in word_list}
    hwpo = {bigram: HWPO(bigram, bigram_frequency, cumul_bigram) for bigram in list(bigrams)}
    
    # Step 1
    fbi_bigrams = {bigram:FBI(bigram, alpha, hwpo, hwo) for bigram in bigrams if FBI(bigram, alpha, hwpo, hwo) > threshold}
    
    # Step 2
    fni_ngrams = FNI([list(fbi_bigrams.items())])
    
    # Step 3
    highest_frequency = sorted(bigram_frequency.items(), key=lambda x : x[1], reverse=True)[0][1]
    highest_monogram = extract_high_relevant_monogram(monogram_frequency, highest_frequency)
    
    top_ranked_bigram = sorted(fni_ngrams[0], key=lambda x: x[1], reverse=True)[:11]
    top_bigram_mean = statistics.mean(bigram[1] for bigram in top_ranked_bigram)
    
    ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1]]
    highest_ngrams = [ngram for ngrams in fni_ngrams[1:] for ngram in ngrams if ngram[1] >= top_bigram_mean]
    top_ranked_ngram = sorted(ngrams, key=lambda x: x[1], reverse=True)[:11]
    
    return {'monograms': highest_monogram, 
            'highest n-grams': highest_ngrams, 
            'top ranked bigrams': top_ranked_bigram,
            'top ranked n-grams': top_ranked_ngram}

automatic_keyword_extraction(word_list, 0.02, 0.5)
# Out:
# {'monograms': [],
#  'highest n-grams': [],
#  'top ranked bigrams': [(('sim', 'card'), 0.9521405562198884),
#   (('phone', 'use'), 0.9477767148452394),
#   (('feature', 'phone'), 0.9435855974807342),
#   (('use', 'mobile'), 0.9292737470105022),
#   (('telephone', 'service'), 0.8929742591966772),
#   (('mobile', 'telephone'), 0.8900412880691599),
#   (('cellular', 'network'), 0.8657230562487723),
#   (('phone', 'subscriber'), 0.865715958502305),
#   (('screen', 'size'), 0.8475674177960325),
#   (('mobile', 'app'), 0.8359395288147147),
#   (('mobile', 'operator'), 0.8352579193528821)],
#  'top ranked n-grams': [(('content', 'mobile', 'banking'), 0.8295394360969579),
#   (('commercially', 'available', 'handheld'), 0.8226015495924462),
#   (('martin', 'cooper', 'motorola'), 0.8041624900350075),
#   (('john', 'f.', 'mitchell'), 0.638556342934387),
#   (('lead', 'development', 'affordable'), 0.6353605269314755),
#   (('nippon', 'telegraph', 'telephone'), 0.635031779661017),
#   (('voice', 'calling', 'text'), 0.6348682892274098),
#   (('information', 'theory', 'cellular'), 0.6335338697098887),
#   (('greatly', 'increase', 'capacity'), 0.6323201544140584),
#   (('state', 'ban', 'texting'), 0.632092877196631)]}

# %% [markdown]
# # Using the keyword extraction to the HAS corpus

# %% [markdown]
# ### load french spacy model

# %%
nlp = spacy.load('fr_core_news_sm')

# %%
has_json = json.load(open('processed-HAS.json', 'r'))

# %%
data = {}
url_c = 0
for url, article in has_json.items():
    text = remove_digits(article)
    # tokenize text
    doc = nlp(text)
    # remove stopwords
    word_list =  []

    for token in doc:
        if token.is_punct:
            word_list.append('[PUNCT]')
        elif not token.is_stop and not token.is_space:
            word_list.append(token.lemma_)

    if len(word_list) > 70:
        data[url] = [article, automatic_keyword_extraction(word_list, 0.02, 0.3)]
        url_c += 1
print(f'url : {len(has_json)}')
print(f'url processed : {url_c}')
json.dump(data, open('has_keywords_result.json', 'w'), indent=4, sort_keys=True)
# Out:
# url : 377
# url processed : 175

# %%
list_items = [site for site in data.items() if site[1][1]['highest n-grams'] != [] and site[1][1]['top ranked bigrams'] != [] and site[1][1]['top ranked n-grams'] != []]
url_list = [site[0] for site in list_items]
highest_ngram_list = [site[1][1]['highest n-grams'] for site in list_items]
highest_ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in highest_ngram_list]
bigram_list = [site[1][1]['top ranked bigrams'] for site in list_items]
bigram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in bigram_list]
ngram_list = [site[1][1]['top ranked n-grams'] for site in list_items]
ngram_list = [(lambda ngram: '; '.join([' '.join(n[0]) for n in ngram]))(ngram) for ngram in ngram_list]

import pandas as pd
df = pd.DataFrame([element for element in zip(url_list, highest_ngram_list, bigram_list, ngram_list)],columns=['url','mots-clés très pertinent', 'mots-clés avec 2 mots', 'mots-clés avec plusieurs mots'])
df.to_csv('has_mot_cle.csv')
df
# Out:
#                                                    url  \
# 0    https://www.has-sante.fr/jcms/c_1009982/fr/bio...
# 1    https://www.has-sante.fr/jcms/c_1164340/fr/eva...
# 2    https://www.has-sante.fr/jcms/c_1173766/fr/l-h...
# 3    https://www.has-sante.fr/jcms/c_1237001/fr/syn...
# 4    https://www.has-sante.fr/jcms/c_1261551/fr/del...
# ..                                                 ...
# 113  https://www.has-sante.fr/jcms/r_1439925/fr/les...
# 114  https://www.has-sante.fr/jcms/r_1440019/fr/que...
# 115  https://www.has-sante.fr/jcms/r_1495740/fr/pri...
# 116  https://www.has-sante.fr/jcms/r_1497412/fr/rea...
# 117  https://www.has-sante.fr/jcms/r_1499422/fr/eva...
#
#                               mots-clés très pertinent  \
# 0                                recherche mutation ga
# 1                           condition réalisation acte
# 2    interrogation commission transparence; amélior...
# 3    protocole national diagnostic; professionnel c...
# 4       évaluation information donner; issu loi numéro
# ..                                                 ...
# 113  traitement reflux gastro-oesophagien; traiteme...
# 114                        patient symptomatique dépit
# 115                   deprévention secondaire aspirine
# 116  note cadrage précise; réaliser outil aide; for...
# 117  évaluer classe antihypertenseur; charge HTA es...
#
#                                  mots-clés avec 2 mots  \
# 0    ga gène; gène facteur; epreuve duke; duke test...
# 1    prise charge; groupe travail; sécurité acte; o...
# 2    répondre interrogation; transparence porter; p...
# 3    explicite professionnel; prise charge; charge ...
# 4    information délivrer; régir règle; santé publi...
# ..                                                 ...
# 113  gastroduodénale devoir; devoir anti-inflammato...
# 114  stratégie thérapeutique\xa; l\'amélioration se...
# 115  immédiat accident; accident ischémique; patien...
# 116  suite réadaptation; aide décision; décision fo...
# 117  préciser problématique; œuvre calendrier; cale...
#
#                          mots-clés avec plusieurs mots
# 0    recherche mutation ga; titrage inhibiteur cont...
# 1    condition réalisation acte; traiter balance bé...
# 2    interrogation commission transparence; toléran...
# 3    protocole national diagnostic; professionnel c...
# 4    issu loi numéro; évaluation information donner...
# ..                                                 ...
# 113  anti-inflammatoire non stéroïdien; traitement ...
# 114                        patient symptomatique dépit
# 115  deprévention secondaire aspirine; diagnostique...
# 116  patient soin suite; forme grille pertinence; n...
# 117  évaluer classe antihypertenseur; charge HTA es...
#
# [118 rows x 4 columns]
